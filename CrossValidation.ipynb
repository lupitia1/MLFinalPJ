# %% [markdown]
# # Load packages

# %%
# skip reinstalling packages we already have
using Pkg

pkgs = [
    "MLJ", "MLJBase", "MLJModels", "MLJEnsembles", "MLJLinearModels",
    "DecisionTree", "MLJDecisionTreeInterface", "NaiveBayes", 
    "MLJNaiveBayesInterface", "EvoTrees", "CategoricalArrays", "Random",
    "LIBSVM", "MLJLIBSVMInterface", "Plots", "MLJModelInterface",
    "CSV", "DataFrames", "UrlDownload", "XGBoost", "NNlib"
]

# Filter out packages already installed
missing_pkgs = filter(pkg -> !(pkg in keys(Pkg.project().dependencies)), pkgs)

if !isempty(missing_pkgs)
    println("Installing missing packages: ", missing_pkgs)
    Pkg.add(missing_pkgs)
else
    println(" All required packages are already installed.")
end
# Out:
#  All required packages are already installed.

# %%
using MLJ
using LIBSVM
using NNlib
using Flux
using Flux.Losses
using Statistics

# %%
#Load your library of functions
include("utils.jl")
# Set a global random seed for reproducibility
using Random
Random.seed!(42)
# Out:
# TaskLocalRNG()

# %% [markdown]
# # Load Data

# %%
using CSV, DataFrames, Random
using CategoricalArrays

df = CSV.read("./data/updated_pollution_dataset.csv", DataFrame)

# Some log
println("First 5 rows of df:")
show(df[1:5, :], allcols=true)

# Convert last column to categorical (in-place!)
df[!, end] = categorical(df[!, end])

# Extract the integer codes of the categories
targets = Float32.(levelcode.(df[!, end]))

# Use all columns except the last one as inputs
inputs = Matrix{Float32}(df[:, 1:end-1])

println("First 5 inputs::")
for i in 1:5
    println(inputs[i, :])
end

println("\n\nFirst 5 targets:")
println(targets[1:5])

# Extract labels (categories) as strings
label_names = levels(df[!, 10])
println("Labels: ", label_names)
# Out:
# First 5 rows of df:
# 5×10 DataFrame
#  Row │ Temperature  Humidity  PM2.5    PM10     NO2      SO2      CO       Proximity_to_Industrial_Areas  Population_Density  Air Quality
#      │ Float64      Float64   Float64  Float64  Float64  Float64  Float64  Float64                        Int64               String15
# ─────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#    1 │        29.8      59.1      5.2     17.9     18.9      9.2     1.72                            6.3                 319  Moderate
#    2 │        28.3      75.6      2.3     12.2     30.8      9.7     1.64                            6.0                 611  Moderate
#    3 │        23.1      74.7     26.7     33.8     24.4     12.6     1.63                            5.2                 619  Moderate
#    4 │        27.1      39.1      6.1      6.3     13.5      5.3     1.15                           11.1                 551  Good
#    5 │        26.5      70.7      6.9     16.0     21.9      5.6     1.01                           12.7                 303  GoodFirst 5 inputs::
# Float32[29.8, 59.1, 5.2, 17.9, 18.9, 9.2, 1.72, 6.3, 319.0]
# Float32[28.3, 75.6, 2.3, 12.2, 30.8, 9.7, 1.64, 6.0, 611.0]
# Float32[23.1, 74.7, 26.7, 33.8, 24.4, 12.6, 1.63, 5.2, 619.0]
# Float32[27.1, 39.1, 6.1, 6.3, 13.5, 5.3, 1.15, 11.1, 551.0]
# Float32[26.5, 70.7, 6.9, 16.0, 21.9, 5.6, 1.01, 12.7, 303.0]
#
#
# First 5 targets:
# Float32[3.0, 3.0, 3.0, 1.0, 1.0]
# Labels: String15["Good", "Hazardous", "Moderate", "Poor"]

# %% [markdown]
# # Split train-test datasets

# %%
trainIdx, testIdx = holdOut(size(df,1), 0.2)

trainingInputs  = inputs[trainIdx, :]
testInputs      = inputs[testIdx, :]

trainingTargets = targets[trainIdx]
testTargets     = targets[testIdx]
# Out:
# 1000-element Vector{Float32}:
#  2.0
#  3.0
#  1.0
#  2.0
#  1.0
#  1.0
#  4.0
#  4.0
#  2.0
#  1.0
#  3.0
#  1.0
#  4.0
#  ⋮
#  3.0
#  1.0
#  1.0
#  1.0
#  1.0
#  4.0
#  4.0
#  3.0
#  3.0
#  2.0
#  1.0
#  3.0

# %%
results = Dict()
crossValidationIndices = crossvalidation(trainingTargets, 5)
# Out:
# 4000-element Vector{Int64}:
#  5
#  5
#  3
#  2
#  2
#  1
#  2
#  1
#  3
#  2
#  1
#  2
#  3
#  ⋮
#  1
#  3
#  2
#  3
#  4
#  4
#  4
#  4
#  4
#  3
#  5
#  5

# %%
function printExperimentResult(model, hyperparams, results, class_labels)
    (
        (accuracy_mean, accuracy_std),
        (error_rate_mean, error_rate_std),
        (sensitivity_mean, sensitivity_std),
        (specificity_mean, specificity_std),
        (ppv_mean, ppv_std),
        (npv_mean, npv_std),
        (f1_mean, f1_std),
        cm
    ) = results

    println("\n=====================================================")
    println(" Model: $model")
    println(" Hyperparameters: $hyperparams")
    println("=====================================================")

    println(" Accuracy (mean)               : ", round(accuracy_mean, digits=4))
    println(" Accuracy (std)                : ", round(accuracy_std, digits=4))

    println(" Error Rate (mean)             : ", round(error_rate_mean, digits=4))
    println(" Error Rate (std)              : ", round(error_rate_std, digits=4))

    println(" Sensitivity/Recall (mean)     : ", round(sensitivity_mean, digits=4))
    println(" Sensitivity/Recall (std)      : ", round(sensitivity_std,  digits=4))

    println(" Specificity (mean)            : ", round(specificity_mean, digits=4))
    println(" Specificity (std)             : ", round(specificity_std,  digits=4))

    println(" PPV (mean)                    : ", round(ppv_mean,         digits=4))
    println(" PPV (std)                     : ", round(ppv_std,          digits=4))

    println(" NPV (mean)                    : ", round(npv_mean,         digits=4))
    println(" NPV (std)                     : ", round(npv_std,          digits=4))

    println(" F1 Score (mean)               : ", round(f1_mean,          digits=4))
    println(" F1 Score (std)                : ", round(f1_std,           digits=4))

    println("\nConfusion Matrix:")
    println(cm)

    PrettyTables.pretty_table(DataFrame(cm, :auto); header=class_labels, row_labels=class_labels)

    println("=====================================================\n")
end
# Out:
# printExperimentResult (generic function with 1 method)

# %% [markdown]
# # Artificial Neural Networks

# %%
############# 1. ARTIFICIAL NEURAL NETWORKS (8+ topologies) #############
default_ann = Dict(      
    "numExecutions" => 5,
    #"transferFunctions" => [σ, σ, σ, σ],
    "maxEpochs" => 200,
    "minLoss" => 0.0,
    "learningRate" => 0.01,
    "validationRatio" => 0.1,
    "maxEpochsVal" => 20
)

ann_search_space = [
    Dict("topology"=>[4, 4]),
    Dict("topology"=>[8, 8]),
    Dict("topology"=>[16, 16]),
    Dict("topology"=>[10, 4]),
    Dict("topology"=>[10, 6, 4]),
    Dict("topology"=>[10, 8, 4]),
    Dict("topology"=>[10, 8, 6, 4]),
    Dict("topology"=>[10, 12, 6, 4])
]
# Out:
# 8-element Vector{Dict{String, Vector{Int64}}}:
#  Dict("topology" => [4, 4])
#  Dict("topology" => [8, 8])
#  Dict("topology" => [16, 16])
#  Dict("topology" => [10, 4])
#  Dict("topology" => [10, 6, 4])
#  Dict("topology" => [10, 8, 4])
#  Dict("topology" => [10, 8, 6, 4])
#  Dict("topology" => [10, 12, 6, 4])

# %%
########################
# 1. ANN GRID SEARCH
########################
ann_results = []

for hp in ann_search_space
    println("\n=== ANN experiment: topology = $(hp["topology"]) ===")
    full_hp = merge(default_ann, hp)
    res = modelCrossValidation(:ANN, full_hp, (trainingInputs, trainingTargets), crossValidationIndices)
    push!(ann_results, (model=:ANN, hyperparams=hp, results=res))
end

results[:ANN] = ann_results
# Out:
# === ANN experiment: topology = [4, 4] ===
# === ANN experiment: topology = [8, 8] ===
#
# === ANN experiment: topology = [16, 16] ===
#
# === ANN experiment: topology = [10, 4] ===
#
# === ANN experiment: topology = [10, 6, 4] ===
#
# === ANN experiment: topology = [10, 8, 4] ===
#
# === ANN experiment: topology = [10, 8, 6, 4] ===
#
# === ANN experiment: topology = [10, 12, 6, 4] ===
# 8-element Vector{Any}:
#  (model = :ANN, hyperparams = Dict("topology" => [4, 4]), results = ((0.94074315f0, 0.0042731683f0), (0.059256874f0, 0.0042731655f0), (0.94074315f0, 0.0042731683f0), (0.98274595f0, 0.0025842295f0), (0.9379606f0, 0.009482839f0), (0.98563397f0, 0.0011026161f0), (0.9388195f0, 0.007021723f0), Float32[267.36002 0.52 2.76 2.76; 3.64 173.36002 9.72 4.4800005; 2.3200002 4.0 211.23999 6.04; 2.76 4.5199995 3.8799999 100.64]))
#  (model = :ANN, hyperparams = Dict("topology" => [8, 8]), results = ((0.94404685f0, 0.0044486574f0), (0.055953186f0, 0.004448656f0), (0.94404685f0, 0.0044486574f0), (0.9838977f0, 0.0011569984f0), (0.944022f0, 0.0051273378f0), (0.9860857f0, 0.0008367489f0), (0.94367075f0, 0.004500241f0), Float32[267.6 0.6 2.52 2.6799998; 3.36 176.12 7.2400002 4.48; 2.28 4.0800004 211.8 5.44; 2.8799999 4.7200003 4.48 99.72]))
#  (model = :ANN, hyperparams = Dict("topology" => [16, 16]), results = ((0.9439484f0, 0.0041749845f0), (0.056051623f0, 0.0041750036f0), (0.9439484f0, 0.0041749845f0), (0.9839613f0, 0.0011785286f0), (0.9439925f0, 0.0050039836f0), (0.9862178f0, 0.0009622718f0), (0.9435457f0, 0.0042501106f0), Float32[267.76 0.6 2.56 2.48; 3.3200002 176.28 7.2 4.4; 2.52 4.12 211.51999 5.44; 2.8 5.12 4.2799997 99.59999]))
#  (model = :ANN, hyperparams = Dict("topology" => [10, 4]), results = ((0.9428962f0, 0.0045224763f0), (0.057103813f0, 0.004522469f0), (0.9428962f0, 0.0045224763f0), (0.9835998f0, 0.001286638f0), (0.942952f0, 0.0052181412f0), (0.98575306f0, 0.0008718254f0), (0.9425152f0, 0.0045381263f0), Float32[267.4 0.6 2.6399999 2.76; 3.4 175.68001 7.3599997 4.7599998; 2.3600001 3.9599998 211.31999 5.96; 2.8799999 4.6 4.4 99.92]))
#  (model = :ANN, hyperparams = Dict("topology" => [10, 6, 4]), results = ((0.9430481f0, 0.006054976f0), (0.056951873f0, 0.0060549728f0), (0.9430481f0, 0.006054976f0), (0.9835744f0, 0.0015346148f0), (0.9429468f0, 0.006656539f0), (0.98600566f0, 0.0014488717f0), (0.94261247f0, 0.0060954727f0), Float32[267.24 0.56 2.96 2.64; 3.16 176.31999 7.2400002 4.48; 2.3600001 4.32 211.36002 5.56; 3.04 5.12 4.12 99.52]))
#  (model = :ANN, hyperparams = Dict("topology" => [10, 8, 4]), results = ((0.9411971f0, 0.0023063233f0), (0.05880282f0, 0.0023063112f0), (0.9411971f0, 0.0023063233f0), (0.9830834f0, 0.002026026f0), (0.94131565f0, 0.0030357353f0), (0.9856529f0, 0.001049691f0), (0.94062984f0, 0.002208715f0), Float32[267.48 0.56 2.6799998 2.6799998; 3.2400002 175.31999 8.04 4.6; 2.6 4.2400002 210.72 6.04; 3.04 5.2400002 4.08 99.44]))
#  (model = :ANN, hyperparams = Dict("topology" => [10, 8, 6, 4]), results = ((0.946098f0, 0.007589831f0), (0.05390199f0, 0.007589796f0), (0.946098f0, 0.007589831f0), (0.98443604f0, 0.0017392786f0), (0.9460739f0, 0.00797976f0), (0.98677427f0, 0.001564567f0), (0.94568175f0, 0.007706345f0), Float32[267.36002 0.56000006 3.0800002 2.4; 2.84 177.75998 6.5200005 4.08; 2.28 4.2 212.24002 4.88; 2.9199998 5.32 4.04 99.52]))
#  (model = :ANN, hyperparams = Dict("topology" => [10, 12, 6, 4]), results = ((0.9418953f0, 0.010557563f0), (0.058104746f0, 0.0105575295f0), (0.9418953f0, 0.010557563f0), (0.98326653f0, 0.0029825787f0), (0.9392556f0, 0.0164805f0), (0.986215f0, 0.0017978781f0), (0.9399546f0, 0.013710096f0), Float32[267.47998 0.4 2.96 2.56; 3.28 177.12 6.4800005 4.32; 2.4 4.12 211.68001 5.4; 2.8 7.44 4.32 97.240005]))

# %%
for entry in results[:ANN]
    printExperimentResult(entry.model, entry.hyperparams, entry.results, label_names)
end
# Out:
# =====================================================
#  Model: ANN
#  Hyperparameters: Dict("topology" => [4, 4])
# =====================================================
#  Accuracy (mean)               : 0.9407
#  Accuracy (std)                : 0.0043
#  Error Rate (mean)             : 0.0593
#  Error Rate (std)              : 0.0043
#  Sensitivity/Recall (mean)     : 0.9407
#  Sensitivity/Recall (std)      : 0.0043
#  Specificity (mean)            : 0.9827
#  Specificity (std)             : 0.0026
#  PPV (mean)                    : 0.938
#  PPV (std)                     : 0.0095
#  NPV (mean)                    : 0.9856
#  NPV (std)                     : 0.0011
#  F1 Score (mean)               : 0.9388
#  F1 Score (std)                : 0.007
#
# Confusion Matrix:
# Float32[267.36002 0.52 2.76 2.76; 3.64 173.36002 9.72 4.4800005; 2.3200002 4.0 211.23999 6.04; 2.76 4.5199995 3.8799999 100.64]
# ┌───────────┬────────┬───────────┬──────────┬────────┐
# │           │   Good │ Hazardous │ Moderate │   Poor │
# ├───────────┼────────┼───────────┼──────────┼────────┤
# │      Good │ 267.36 │      0.52 │     2.76 │   2.76 │
# │ Hazardous │   3.64 │    173.36 │     9.72 │   4.48 │
# │  Moderate │   2.32 │       4.0 │   211.24 │   6.04 │
# │      Poor │   2.76 │      4.52 │     3.88 │ 100.64 │
# └───────────┴────────┴───────────┴──────────┴────────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN
#  Hyperparameters: Dict("topology" => [8, 8])
# =====================================================
#  Accuracy (mean)               : 0.944
#  Accuracy (std)                : 0.0044
#  Error Rate (mean)             : 0.056
#  Error Rate (std)              : 0.0044
#  Sensitivity/Recall (mean)     : 0.944
#  Sensitivity/Recall (std)      : 0.0044
#  Specificity (mean)            : 0.9839
#  Specificity (std)             : 0.0012
#  PPV (mean)                    : 0.944
#  PPV (std)                     : 0.0051
#  NPV (mean)                    : 0.9861
#  NPV (std)                     : 0.0008
#  F1 Score (mean)               : 0.9437
#  F1 Score (std)                : 0.0045
#
# Confusion Matrix:
# Float32[267.6 0.6 2.52 2.6799998; 3.36 176.12 7.2400002 4.48; 2.28 4.0800004 211.8 5.44; 2.8799999 4.7200003 4.48 99.72]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 267.6 │       0.6 │     2.52 │  2.68 │
# │ Hazardous │  3.36 │    176.12 │     7.24 │  4.48 │
# │  Moderate │  2.28 │      4.08 │    211.8 │  5.44 │
# │      Poor │  2.88 │      4.72 │     4.48 │ 99.72 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN
#  Hyperparameters: Dict("topology" => [16, 16])
# =====================================================
#  Accuracy (mean)               : 0.9439
#  Accuracy (std)                : 0.0042
#  Error Rate (mean)             : 0.0561
#  Error Rate (std)              : 0.0042
#  Sensitivity/Recall (mean)     : 0.9439
#  Sensitivity/Recall (std)      : 0.0042
#  Specificity (mean)            : 0.984
#  Specificity (std)             : 0.0012
#  PPV (mean)                    : 0.944
#  PPV (std)                     : 0.005
#  NPV (mean)                    : 0.9862
#  NPV (std)                     : 0.001
#  F1 Score (mean)               : 0.9435
#  F1 Score (std)                : 0.0043
#
# Confusion Matrix:
# Float32[267.76 0.6 2.56 2.48; 3.3200002 176.28 7.2 4.4; 2.52 4.12 211.51999 5.44; 2.8 5.12 4.2799997 99.59999]
# ┌───────────┬────────┬───────────┬──────────┬──────┐
# │           │   Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼────────┼───────────┼──────────┼──────┤
# │      Good │ 267.76 │       0.6 │     2.56 │ 2.48 │
# │ Hazardous │   3.32 │    176.28 │      7.2 │  4.4 │
# │  Moderate │   2.52 │      4.12 │   211.52 │ 5.44 │
# │      Poor │    2.8 │      5.12 │     4.28 │ 99.6 │
# └───────────┴────────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN
#  Hyperparameters: Dict("topology" => [10, 4])
# =====================================================
#  Accuracy (mean)               : 0.9429
#  Accuracy (std)                : 0.0045
#  Error Rate (mean)             : 0.0571
#  Error Rate (std)              : 0.0045
#  Sensitivity/Recall (mean)     : 0.9429
#  Sensitivity/Recall (std)      : 0.0045
#  Specificity (mean)            : 0.9836
#  Specificity (std)             : 0.0013
#  PPV (mean)                    : 0.943
#  PPV (std)                     : 0.0052
#  NPV (mean)                    : 0.9858
#  NPV (std)                     : 0.0009
#  F1 Score (mean)               : 0.9425
#  F1 Score (std)                : 0.0045
#
# Confusion Matrix:
# Float32[267.4 0.6 2.6399999 2.76; 3.4 175.68001 7.3599997 4.7599998; 2.3600001 3.9599998 211.31999 5.96; 2.8799999 4.6 4.4 99.92]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 267.4 │       0.6 │     2.64 │  2.76 │
# │ Hazardous │   3.4 │    175.68 │     7.36 │  4.76 │
# │  Moderate │  2.36 │      3.96 │   211.32 │  5.96 │
# │      Poor │  2.88 │       4.6 │      4.4 │ 99.92 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN
#  Hyperparameters: Dict("topology" => [10, 6, 4])
# =====================================================
#  Accuracy (mean)               : 0.943
#  Accuracy (std)                : 0.0061
#  Error Rate (mean)             : 0.057
#  Error Rate (std)              : 0.0061
#  Sensitivity/Recall (mean)     : 0.943
#  Sensitivity/Recall (std)      : 0.0061
#  Specificity (mean)            : 0.9836
#  Specificity (std)             : 0.0015
#  PPV (mean)                    : 0.9429
#  PPV (std)                     : 0.0067
#  NPV (mean)                    : 0.986
#  NPV (std)                     : 0.0014
#  F1 Score (mean)               : 0.9426
#  F1 Score (std)                : 0.0061
#
# Confusion Matrix:
# Float32[267.24 0.56 2.96 2.64; 3.16 176.31999 7.2400002 4.48; 2.3600001 4.32 211.36002 5.56; 3.04 5.12 4.12 99.52]
# ┌───────────┬────────┬───────────┬──────────┬───────┐
# │           │   Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼────────┼───────────┼──────────┼───────┤
# │      Good │ 267.24 │      0.56 │     2.96 │  2.64 │
# │ Hazardous │   3.16 │    176.32 │     7.24 │  4.48 │
# │  Moderate │   2.36 │      4.32 │   211.36 │  5.56 │
# │      Poor │   3.04 │      5.12 │     4.12 │ 99.52 │
# └───────────┴────────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN
#  Hyperparameters: Dict("topology" => [10, 8, 4])
# =====================================================
#  Accuracy (mean)               : 0.9412
#  Accuracy (std)                : 0.0023
#  Error Rate (mean)             : 0.0588
#  Error Rate (std)              : 0.0023
#  Sensitivity/Recall (mean)     : 0.9412
#  Sensitivity/Recall (std)      : 0.0023
#  Specificity (mean)            : 0.9831
#  Specificity (std)             : 0.002
#  PPV (mean)                    : 0.9413
#  PPV (std)                     : 0.003
#  NPV (mean)                    : 0.9857
#  NPV (std)                     : 0.001
#  F1 Score (mean)               : 0.9406
#  F1 Score (std)                : 0.0022
#
# Confusion Matrix:
# Float32[267.48 0.56 2.6799998 2.6799998; 3.2400002 175.31999 8.04 4.6; 2.6 4.2400002 210.72 6.04; 3.04 5.2400002 4.08 99.44]
# ┌───────────┬────────┬───────────┬──────────┬───────┐
# │           │   Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼────────┼───────────┼──────────┼───────┤
# │      Good │ 267.48 │      0.56 │     2.68 │  2.68 │
# │ Hazardous │   3.24 │    175.32 │     8.04 │   4.6 │
# │  Moderate │    2.6 │      4.24 │   210.72 │  6.04 │
# │      Poor │   3.04 │      5.24 │     4.08 │ 99.44 │
# └───────────┴────────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN
#  Hyperparameters: Dict("topology" => [10, 8, 6, 4])
# =====================================================
#  Accuracy (mean)               : 0.9461
#  Accuracy (std)                : 0.0076
#  Error Rate (mean)             : 0.0539
#  Error Rate (std)              : 0.0076
#  Sensitivity/Recall (mean)     : 0.9461
#  Sensitivity/Recall (std)      : 0.0076
#  Specificity (mean)            : 0.9844
#  Specificity (std)             : 0.0017
#  PPV (mean)                    : 0.9461
#  PPV (std)                     : 0.008
#  NPV (mean)                    : 0.9868
#  NPV (std)                     : 0.0016
#  F1 Score (mean)               : 0.9457
#  F1 Score (std)                : 0.0077
#
# Confusion Matrix:
# Float32[267.36002 0.56000006 3.0800002 2.4; 2.84 177.75998 6.5200005 4.08; 2.28 4.2 212.24002 4.88; 2.9199998 5.32 4.04 99.52]
# ┌───────────┬────────┬───────────┬──────────┬───────┐
# │           │   Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼────────┼───────────┼──────────┼───────┤
# │      Good │ 267.36 │      0.56 │     3.08 │   2.4 │
# │ Hazardous │   2.84 │    177.76 │     6.52 │  4.08 │
# │  Moderate │   2.28 │       4.2 │   212.24 │  4.88 │
# │      Poor │   2.92 │      5.32 │     4.04 │ 99.52 │
# └───────────┴────────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN
#  Hyperparameters: Dict("topology" => [10, 12, 6, 4])
# =====================================================
#  Accuracy (mean)               : 0.9419
#  Accuracy (std)                : 0.0106
#  Error Rate (mean)             : 0.0581
#  Error Rate (std)              : 0.0106
#  Sensitivity/Recall (mean)     : 0.9419
#  Sensitivity/Recall (std)      : 0.0106
#  Specificity (mean)            : 0.9833
#  Specificity (std)             : 0.003
#  PPV (mean)                    : 0.9393
#  PPV (std)                     : 0.0165
#  NPV (mean)                    : 0.9862
#  NPV (std)                     : 0.0018
#  F1 Score (mean)               : 0.94
#  F1 Score (std)                : 0.0137
#
# Confusion Matrix:
# Float32[267.47998 0.4 2.96 2.56; 3.28 177.12 6.4800005 4.32; 2.4 4.12 211.68001 5.4; 2.8 7.44 4.32 97.240005]
# ┌───────────┬────────┬───────────┬──────────┬───────┐
# │           │   Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼────────┼───────────┼──────────┼───────┤
# │      Good │ 267.48 │       0.4 │     2.96 │  2.56 │
# │ Hazardous │   3.28 │    177.12 │     6.48 │  4.32 │
# │  Moderate │    2.4 │      4.12 │   211.68 │   5.4 │
# │      Poor │    2.8 │      7.44 │     4.32 │ 97.24 │
# └───────────┴────────┴───────────┴──────────┴───────┘
# =====================================================

# %%
########################
# 1. ANN FINAL TESTING
########################

# BEST HYPERPARAMETERS
topology = [10, 8, 6, 4]

hp = Dict(      
    "numExecutions" => 5,
    "maxEpochs" => 200,
    "minLoss" => 0.0,
    "learningRate" => 0.01,
    "validationRatio" => 0.1,
    "maxEpochsVal" => 20
)

learningRate = hp["learningRate"]
epochs = hp["maxEpochs"]
validationRatio = hp["validationRatio"]

# ============================
# NORMALIZATION
# ============================
normParams = calculateMinMaxNormalizationParameters(trainingInputs)
norm_train_val_inputs = normalizeMinMax(trainingInputs, normParams)
norm_test_inputs  = normalizeMinMax(testInputs,  normParams)

# ============================
# CREATE VALIDATION SPLIT
# ============================
N = size(inputs, 1)
nTrainVal = size(norm_train_val_inputs, 1)

nVal = Int(floor(validationRatio * N))
realValidationRatio = nVal / nTrainVal

(train_idx, val_idx) = holdOut(nTrainVal, realValidationRatio)

norm_train_inputs = norm_train_val_inputs[train_idx, :]
norm_val_inputs   = norm_train_val_inputs[val_idx, :]

# ============================
# ONE–HOT ENCODING FOR TARGETS
# ============================
trainTargetsVec = trainingTargets[train_idx]
valTargetsVec   = trainingTargets[val_idx]
testTargetsVec  = testTargets

trainTargetsOH = Matrix(oneHotEncoding(vec(trainTargetsVec), sort(levels(categorical(trainingTargets)))))
valTargetsOH   = Matrix(oneHotEncoding(vec(valTargetsVec),   sort(levels(categorical(trainingTargets)))))
testTargetsOH  = Matrix(oneHotEncoding(vec(testTargetsVec),  sort(levels(categorical(trainingTargets)))))

# ============================
# TRAIN ANN
# ============================
finalAnn, trainLoss, valLoss, testLoss = trainClassANN(
    topology,
    (norm_train_inputs, trainTargetsOH),
    validationDataset = (norm_val_inputs, valTargetsOH),
    testDataset = (norm_test_inputs, testTargetsOH),
    maxEpochs = hp["maxEpochs"],
    minLoss = hp["minLoss"],
    learningRate = hp["learningRate"],
    maxEpochsVal = hp["maxEpochsVal"],
    showText = false
)

# ============================
# PREDICTION
# ============================
testOutputs = finalAnn(norm_test_inputs')
testPredictions = classifyOutputs(testOutputs')   # boolean matrix (N × classes)

# ============================
# METRICS
# ============================
metrics = confusionMatrix(testPredictions, testTargetsOH)

printANNResult(
    :ANN,
    Dict("topology" => topology),
    metrics,
    label_names
)
# Out:
# =====================================================
#  Model: ANN
#  Hyperparameters: Dict("topology" => [10, 8, 6, 4])
# =====================================================
#  Accuracy                : 0.852
#  Error Rate              : 0.148
#  Sensitivity/Recall      : 0.852
#  Specificity             : 0.9532
#  PPV                     : 0.781
#  NPV                     : 0.9741
#  F1 Score                : 0.8124
#
# Confusion Matrix:
# [383 0 0 0; 0 0 0 103; 2 0 285 9; 0 0 34 184]
# =====================================================
#
# ┌───────────┬──────┬───────────┬──────────┬──────┐
# │           │ Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼──────┼───────────┼──────────┼──────┤
# │      Good │  383 │         0 │        0 │    0 │
# │ Hazardous │    0 │         0 │        0 │  103 │
# │  Moderate │    2 │         0 │      285 │    9 │
# │      Poor │    0 │         0 │       34 │  184 │
# └───────────┴──────┴───────────┴──────────┴──────┘

# %% [markdown]
# # Support Vector Machines

# %%
SVMClassifier = MLJ.@load SVC pkg=LIBSVM verbosity=0
# Out:
# MLJLIBSVMInterface.SVC

# %%
############# 2. SVM (8+ configs: kernels × C) #############
default_svm = Dict(
    "gamma" => 1.0,
    "degree" => Int32(3),
    "coef0" => 0.0
)
svm_search_space = [
    Dict("kernel"=>"linear", "C"=>0.1),
    Dict("kernel"=>"linear", "C"=>1.0),
    Dict("kernel"=>"linear", "C"=>10.0),

    Dict("kernel"=>"rbf", "C"=>1.0, "gamma" => 2.0),
    Dict("kernel"=>"rbf", "C"=>10.0, "gamma" => 0.5),

    Dict("kernel"=>"sigmoid", "C"=>1.0, "gamma" => 1.0),

    Dict("kernel"=>"poly", "C"=>1.0, "degree" => 3, "gamma" => 1),
    Dict("kernel"=>"poly", "C"=>5.0, "degree" => 4, "gamma" => 0.5),
]
# Out:
# 8-element Vector{Dict{String, Any}}:
#  Dict("C" => 0.1, "kernel" => "linear")
#  Dict("C" => 1.0, "kernel" => "linear")
#  Dict("C" => 10.0, "kernel" => "linear")
#  Dict("C" => 1.0, "kernel" => "rbf", "gamma" => 2.0)
#  Dict("C" => 10.0, "kernel" => "rbf", "gamma" => 0.5)
#  Dict("C" => 1.0, "kernel" => "sigmoid", "gamma" => 1.0)
#  Dict("C" => 1.0, "kernel" => "poly", "gamma" => 1, "degree" => 3)
#  Dict("C" => 5.0, "kernel" => "poly", "gamma" => 0.5, "degree" => 4)

# %%
########################
# 2. SVM GRID SEARCH
########################
svm_results = []

for hp in svm_search_space
    println("\n=== SVM experiment: kernel=$(hp["kernel"]) C=$(get(hp,"C","-")) ===")
    full_hp = merge(default_svm, hp)
    res = modelCrossValidation(:SVC, full_hp, (trainingInputs, trainingTargets), crossValidationIndices)
    push!(svm_results, (model=:SVC, hyperparams=hp, results=res))
end

results[:SVC] = svm_results
# Out:
# === SVM experiment: kernel=linear C=0.1 ===
#
# === SVM experiment: kernel=linear C=1.0 ===
#
# === SVM experiment: kernel=linear C=10.0 ===
#
# === SVM experiment: kernel=rbf C=1.0 ===
#
# === SVM experiment: kernel=rbf C=10.0 ===
#
# === SVM experiment: kernel=sigmoid C=1.0 ===
#
# === SVM experiment: kernel=poly C=1.0 ===
#
# === SVM experiment: kernel=poly C=5.0 ===
# 8-element Vector{Any}:
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 0.1, "kernel" => "linear"), results = ((0.9304966f0, 0.005035769f0), (0.06950344f0, 0.005035765f0), (0.9304966f0, 0.005035769f0), (0.9750918f0, 0.00083392154f0), (0.9309021f0, 0.005551302f0), (0.9843459f0, 0.0011032501f0), (0.9289301f0, 0.0056161913f0), Float32[268.0 0.2 4.8 0.4; 5.4 175.8 8.6 1.4; 2.4 6.4 209.0 5.8; 5.0 8.8 6.4 91.6]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 1.0, "kernel" => "linear"), results = ((0.9417473f0, 0.0034394085f0), (0.05825276f0, 0.0034394148f0), (0.9417473f0, 0.0034394085f0), (0.98124313f0, 0.0008948613f0), (0.9411415f0, 0.0038164093f0), (0.98613167f0, 0.0007897962f0), (0.94100016f0, 0.003653778f0), Float32[268.0 0.4 3.4 1.6; 4.2 177.0 6.6 3.4; 2.4 5.4 210.6 5.2; 3.4 5.4 5.2 97.8]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 10.0, "kernel" => "linear"), results = ((0.9417513f0, 0.005474671f0), (0.0582487f0, 0.005474683f0), (0.9417513f0, 0.005474671f0), (0.9822444f0, 0.0009261883f0), (0.94139254f0, 0.006179872f0), (0.9854784f0, 0.0013172269f0), (0.9412023f0, 0.005560789f0), Float32[266.6 0.6 3.6 2.6; 4.0 176.0 6.8 4.4; 2.8 4.6 210.6 5.6; 2.8 4.2 4.6 100.2]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 1.0, "kernel" => "rbf", "gamma" => 2.0), results = ((0.9475004f0, 0.005286944f0), (0.052499603f0, 0.0052869353f0), (0.9475004f0, 0.005286944f0), (0.9840585f0, 0.0017111459f0), (0.9470391f0, 0.0056922906f0), (0.9874155f0, 0.0014215661f0), (0.9469487f0, 0.0053033484f0), Float32[267.2 0.4 3.6 2.2; 3.2 178.0 6.4 3.6; 2.0 4.6 211.8 5.2; 3.0 3.8 4.0 101.0]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 10.0, "kernel" => "rbf", "gamma" => 0.5), results = ((0.94575137f0, 0.0048700506f0), (0.054248672f0, 0.004870051f0), (0.94575137f0, 0.0048700506f0), (0.9835283f0, 0.0018687029f0), (0.94538057f0, 0.005340096f0), (0.9870086f0, 0.0015285251f0), (0.9451439f0, 0.0048873806f0), Float32[266.8 0.4 3.6 2.6; 3.2 177.4 6.4 4.2; 2.2 4.4 211.8 5.2; 2.8 4.8 3.6 100.6]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 1.0, "kernel" => "sigmoid", "gamma" => 1.0), results = ((0.6192027f0, 0.041615505f0), (0.38079733f0, 0.041615516f0), (0.6192027f0, 0.041615505f0), (0.85435474f0, 0.007623934f0), (0.5201373f0, 0.011745112f0), (0.8992013f0, 0.020823956f0), (0.5575983f0, 0.01891605f0), Float32[228.4 0.2 32.8 12.0; 36.0 85.0 43.8 26.4; 2.8 29.6 146.2 45.0; 19.8 26.2 30.0 35.8]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 1.0, "kernel" => "poly", "gamma" => 1, "degree" => 3), results = ((0.94124687f0, 0.003135885f0), (0.058753066f0, 0.0031358816f0), (0.94124687f0, 0.003135885f0), (0.9803815f0, 0.0011586255f0), (0.94061404f0, 0.0038093566f0), (0.98556757f0, 0.0008350336f0), (0.9405012f0, 0.003265678f0), Float32[267.4 0.4 3.8 1.8; 4.4 176.0 6.8 4.0; 2.8 5.2 210.0 5.6; 3.0 4.8 4.4 99.6]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 5.0, "kernel" => "poly", "gamma" => 0.5, "degree" => 4), results = ((0.92999345f0, 0.003580242f0), (0.07000655f0, 0.0035802566f0), (0.92999345f0, 0.003580242f0), (0.97344065f0, 0.0032831004f0), (0.92903596f0, 0.0035478072f0), (0.9815073f0, 0.0016295775f0), (0.92897224f0, 0.003633362f0), Float32[266.4 0.4 4.8 1.8; 5.8 174.8 6.8 3.8; 4.4 6.8 206.2 6.2; 5.2 5.4 4.6 96.6]))

# %%
for entry in results[:SVC]
    printExperimentResult(entry.model, entry.hyperparams, entry.results, label_names)
end
# Out:
# =====================================================
#  Model: SVC
#  Hyperparameters: Dict{String, Any}("C" => 0.1, "kernel" => "linear")
# =====================================================
#  Accuracy (mean)               : 0.9305
#  Accuracy (std)                : 0.005
#  Error Rate (mean)             : 0.0695
#  Error Rate (std)              : 0.005
#  Sensitivity/Recall (mean)     : 0.9305
#  Sensitivity/Recall (std)      : 0.005
#  Specificity (mean)            : 0.9751
#  Specificity (std)             : 0.0008
#  PPV (mean)                    : 0.9309
#  PPV (std)                     : 0.0056
#  NPV (mean)                    : 0.9843
#  NPV (std)                     : 0.0011
#  F1 Score (mean)               : 0.9289
#  F1 Score (std)                : 0.0056
#
# Confusion Matrix:
# Float32[268.0 0.2 4.8 0.4; 5.4 175.8 8.6 1.4; 2.4 6.4 209.0 5.8; 5.0 8.8 6.4 91.6]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 268.0 │       0.2 │      4.8 │  0.4 │
# │ Hazardous │   5.4 │     175.8 │      8.6 │  1.4 │
# │  Moderate │   2.4 │       6.4 │    209.0 │  5.8 │
# │      Poor │   5.0 │       8.8 │      6.4 │ 91.6 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC
#  Hyperparameters: Dict{String, Any}("C" => 1.0, "kernel" => "linear")
# =====================================================
#  Accuracy (mean)               : 0.9417
#  Accuracy (std)                : 0.0034
#  Error Rate (mean)             : 0.0583
#  Error Rate (std)              : 0.0034
#  Sensitivity/Recall (mean)     : 0.9417
#  Sensitivity/Recall (std)      : 0.0034
#  Specificity (mean)            : 0.9812
#  Specificity (std)             : 0.0009
#  PPV (mean)                    : 0.9411
#  PPV (std)                     : 0.0038
#  NPV (mean)                    : 0.9861
#  NPV (std)                     : 0.0008
#  F1 Score (mean)               : 0.941
#  F1 Score (std)                : 0.0037
#
# Confusion Matrix:
# Float32[268.0 0.4 3.4 1.6; 4.2 177.0 6.6 3.4; 2.4 5.4 210.6 5.2; 3.4 5.4 5.2 97.8]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 268.0 │       0.4 │      3.4 │  1.6 │
# │ Hazardous │   4.2 │     177.0 │      6.6 │  3.4 │
# │  Moderate │   2.4 │       5.4 │    210.6 │  5.2 │
# │      Poor │   3.4 │       5.4 │      5.2 │ 97.8 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC
#  Hyperparameters: Dict{String, Any}("C" => 10.0, "kernel" => "linear")
# =====================================================
#  Accuracy (mean)               : 0.9418
#  Accuracy (std)                : 0.0055
#  Error Rate (mean)             : 0.0582
#  Error Rate (std)              : 0.0055
#  Sensitivity/Recall (mean)     : 0.9418
#  Sensitivity/Recall (std)      : 0.0055
#  Specificity (mean)            : 0.9822
#  Specificity (std)             : 0.0009
#  PPV (mean)                    : 0.9414
#  PPV (std)                     : 0.0062
#  NPV (mean)                    : 0.9855
#  NPV (std)                     : 0.0013
#  F1 Score (mean)               : 0.9412
#  F1 Score (std)                : 0.0056
#
# Confusion Matrix:
# Float32[266.6 0.6 3.6 2.6; 4.0 176.0 6.8 4.4; 2.8 4.6 210.6 5.6; 2.8 4.2 4.6 100.2]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 266.6 │       0.6 │      3.6 │   2.6 │
# │ Hazardous │   4.0 │     176.0 │      6.8 │   4.4 │
# │  Moderate │   2.8 │       4.6 │    210.6 │   5.6 │
# │      Poor │   2.8 │       4.2 │      4.6 │ 100.2 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC
#  Hyperparameters: Dict{String, Any}("C" => 1.0, "kernel" => "rbf", "gamma" => 2.0)
# =====================================================
#  Accuracy (mean)               : 0.9475
#  Accuracy (std)                : 0.0053
#  Error Rate (mean)             : 0.0525
#  Error Rate (std)              : 0.0053
#  Sensitivity/Recall (mean)     : 0.9475
#  Sensitivity/Recall (std)      : 0.0053
#  Specificity (mean)            : 0.9841
#  Specificity (std)             : 0.0017
#  PPV (mean)                    : 0.947
#  PPV (std)                     : 0.0057
#  NPV (mean)                    : 0.9874
#  NPV (std)                     : 0.0014
#  F1 Score (mean)               : 0.9469
#  F1 Score (std)                : 0.0053
#
# Confusion Matrix:
# Float32[267.2 0.4 3.6 2.2; 3.2 178.0 6.4 3.6; 2.0 4.6 211.8 5.2; 3.0 3.8 4.0 101.0]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 267.2 │       0.4 │      3.6 │   2.2 │
# │ Hazardous │   3.2 │     178.0 │      6.4 │   3.6 │
# │  Moderate │   2.0 │       4.6 │    211.8 │   5.2 │
# │      Poor │   3.0 │       3.8 │      4.0 │ 101.0 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC
#  Hyperparameters: Dict{String, Any}("C" => 10.0, "kernel" => "rbf", "gamma" => 0.5)
# =====================================================
#  Accuracy (mean)               : 0.9458
#  Accuracy (std)                : 0.0049
#  Error Rate (mean)             : 0.0542
#  Error Rate (std)              : 0.0049
#  Sensitivity/Recall (mean)     : 0.9458
#  Sensitivity/Recall (std)      : 0.0049
#  Specificity (mean)            : 0.9835
#  Specificity (std)             : 0.0019
#  PPV (mean)                    : 0.9454
#  PPV (std)                     : 0.0053
#  NPV (mean)                    : 0.987
#  NPV (std)                     : 0.0015
#  F1 Score (mean)               : 0.9451
#  F1 Score (std)                : 0.0049
#
# Confusion Matrix:
# Float32[266.8 0.4 3.6 2.6; 3.2 177.4 6.4 4.2; 2.2 4.4 211.8 5.2; 2.8 4.8 3.6 100.6]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 266.8 │       0.4 │      3.6 │   2.6 │
# │ Hazardous │   3.2 │     177.4 │      6.4 │   4.2 │
# │  Moderate │   2.2 │       4.4 │    211.8 │   5.2 │
# │      Poor │   2.8 │       4.8 │      3.6 │ 100.6 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC
#  Hyperparameters: Dict{String, Any}("C" => 1.0, "kernel" => "sigmoid", "gamma" => 1.0)
# =====================================================
#  Accuracy (mean)               : 0.6192
#  Accuracy (std)                : 0.0416
#  Error Rate (mean)             : 0.3808
#  Error Rate (std)              : 0.0416
#  Sensitivity/Recall (mean)     : 0.6192
#  Sensitivity/Recall (std)      : 0.0416
#  Specificity (mean)            : 0.8544
#  Specificity (std)             : 0.0076
#  PPV (mean)                    : 0.5201
#  PPV (std)                     : 0.0117
#  NPV (mean)                    : 0.8992
#  NPV (std)                     : 0.0208
#  F1 Score (mean)               : 0.5576
#  F1 Score (std)                : 0.0189
#
# Confusion Matrix:
# Float32[228.4 0.2 32.8 12.0; 36.0 85.0 43.8 26.4; 2.8 29.6 146.2 45.0; 19.8 26.2 30.0 35.8]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 228.4 │       0.2 │     32.8 │ 12.0 │
# │ Hazardous │  36.0 │      85.0 │     43.8 │ 26.4 │
# │  Moderate │   2.8 │      29.6 │    146.2 │ 45.0 │
# │      Poor │  19.8 │      26.2 │     30.0 │ 35.8 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC
#  Hyperparameters: Dict{String, Any}("C" => 1.0, "kernel" => "poly", "gamma" => 1, "degree" => 3)
# =====================================================
#  Accuracy (mean)               : 0.9412
#  Accuracy (std)                : 0.0031
#  Error Rate (mean)             : 0.0588
#  Error Rate (std)              : 0.0031
#  Sensitivity/Recall (mean)     : 0.9412
#  Sensitivity/Recall (std)      : 0.0031
#  Specificity (mean)            : 0.9804
#  Specificity (std)             : 0.0012
#  PPV (mean)                    : 0.9406
#  PPV (std)                     : 0.0038
#  NPV (mean)                    : 0.9856
#  NPV (std)                     : 0.0008
#  F1 Score (mean)               : 0.9405
#  F1 Score (std)                : 0.0033
#
# Confusion Matrix:
# Float32[267.4 0.4 3.8 1.8; 4.4 176.0 6.8 4.0; 2.8 5.2 210.0 5.6; 3.0 4.8 4.4 99.6]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 267.4 │       0.4 │      3.8 │  1.8 │
# │ Hazardous │   4.4 │     176.0 │      6.8 │  4.0 │
# │  Moderate │   2.8 │       5.2 │    210.0 │  5.6 │
# │      Poor │   3.0 │       4.8 │      4.4 │ 99.6 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC
#  Hyperparameters: Dict{String, Any}("C" => 5.0, "kernel" => "poly", "gamma" => 0.5, "degree" => 4)
# =====================================================
#  Accuracy (mean)               : 0.93
#  Accuracy (std)                : 0.0036
#  Error Rate (mean)             : 0.07
#  Error Rate (std)              : 0.0036
#  Sensitivity/Recall (mean)     : 0.93
#  Sensitivity/Recall (std)      : 0.0036
#  Specificity (mean)            : 0.9734
#  Specificity (std)             : 0.0033
#  PPV (mean)                    : 0.929
#  PPV (std)                     : 0.0035
#  NPV (mean)                    : 0.9815
#  NPV (std)                     : 0.0016
#  F1 Score (mean)               : 0.929
#  F1 Score (std)                : 0.0036
#
# Confusion Matrix:
# Float32[266.4 0.4 4.8 1.8; 5.8 174.8 6.8 3.8; 4.4 6.8 206.2 6.2; 5.2 5.4 4.6 96.6]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 266.4 │       0.4 │      4.8 │  1.8 │
# │ Hazardous │   5.8 │     174.8 │      6.8 │  3.8 │
# │  Moderate │   4.4 │       6.8 │    206.2 │  6.2 │
# │      Poor │   5.2 │       5.4 │      4.6 │ 96.6 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================

# %%
########################
# 2. SVM FINAL TESTING 
########################

# BEST HYPERPARAMETERS
hp = Dict("kernel"=>"rbf", "C"=>1.0, "gamma"=>2.0)

# Compute normalization parameters from TRAINING set only
normParams = calculateMinMaxNormalizationParameters(trainingInputs)
train_df = normalizeMinMax(trainingInputs, normParams)
test_df = normalizeMinMax(testInputs, normParams)

# --- Convert targets ---
train_y_cat = categorical(vec(trainingTargets))
test_y_cat  = categorical(vec(testTargets))

# Load model (insert hyperparameters manually)
model = SVMClassifier(kernel=LIBSVM.Kernel.RadialBasis, cost=Float64(1), gamma=Float64(2))
    
# --- Train machine ---
mach = machine(model, MLJ.table(train_df), train_y_cat)
MLJ.fit!(mach)
    
# --- Predict ---
ŷ = MLJ.predict(mach, test_df)              # probabilistic predictions
y_pred = CategoricalArray(ŷ)         # convert to class labels
    
# --- Compute metrics ---
metrics = confusionMatrix(y_pred, test_y_cat)

printResult(:SVC, hp, metrics, label_names)
# Out:
# =====================================================
# [ Info: Training machine(SVC(kernel = RadialBasis, …), …).
#  Model: SVC
#  Hyperparameters: Dict{String, Any}("C" => 1.0, "kernel" => "rbf", "gamma" => 2.0)
# =====================================================
#  Accuracy                : 0.928
#  Error Rate              : 0.072
#  Sensitivity/Recall      : 0.928
#  Specificity             : 0.9784
#  PPV                     : 0.9273
#  NPV                     : 0.9824
#  F1 Score                : 0.9271
#
# Confusion Matrix:
# [77 0 0 26; 0 284 1 11; 0 0 383 0; 12 22 0 184]
# =====================================================
#
# ┌───────────┬──────┬───────────┬──────────┬──────┐
# │           │ Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼──────┼───────────┼──────────┼──────┤
# │      Good │   77 │         0 │        0 │   26 │
# │ Hazardous │    0 │       284 │        1 │   11 │
# │  Moderate │    0 │         0 │      383 │    0 │
# │      Poor │   12 │        22 │        0 │  184 │
# └───────────┴──────┴───────────┴──────────┴──────┘

# %% [markdown]
# # Decission Trees

# %%
DTClassifier = MLJ.@load DecisionTreeClassifier pkg=DecisionTree verbosity=0
# Out:
# MLJDecisionTreeInterface.DecisionTreeClassifier

# %%
############# 3. DECISION TREES (6 depths) #############
default_dt = Dict(
    "rng" => Random.MersenneTwister(1)
)

dt_search_space = [
    Dict("max_depth"=>2),
    Dict("max_depth"=>3),
    Dict("max_depth"=>4),
    Dict("max_depth"=>5),
    Dict("max_depth"=>6),
    Dict("max_depth"=>8)
]
# Out:
# 6-element Vector{Dict{String, Int64}}:
#  Dict("max_depth" => 2)
#  Dict("max_depth" => 3)
#  Dict("max_depth" => 4)
#  Dict("max_depth" => 5)
#  Dict("max_depth" => 6)
#  Dict("max_depth" => 8)

# %%
########################
# 3. DECISION TREE GRID SEARCH
########################
dt_results = []

for hp in dt_search_space
    println("\n=== Decision Tree experiment: max_depth=$(hp["max_depth"]) ===")
    full_hp = merge(default_dt, hp) 
    res = modelCrossValidation(:DecisionTreeClassifier, full_hp, (trainingInputs, trainingTargets), crossValidationIndices)
    push!(dt_results, (model=:DT, hyperparams=hp, results=res))
end

results[:DT] = dt_results
# Out:
# === Decision Tree experiment: max_depth=2 ===
#
# === Decision Tree experiment: max_depth=3 ===
#
# === Decision Tree experiment: max_depth=4 ===
#
# === Decision Tree experiment: max_depth=5 ===
#
# === Decision Tree experiment: max_depth=6 ===
#
# === Decision Tree experiment: max_depth=8 ===
# 6-element Vector{Any}:
#  (model = :DT, hyperparams = Dict("max_depth" => 2), results = ((0.8247405f0, 0.006871341f0), (0.1752595f0, 0.0068713464f0), (0.8247405f0, 0.006871341f0), (0.9448327f0, 0.0034481913f0), (0.7582999f0, 0.007281201f0), (0.96567047f0, 0.0036217559f0), (0.78805333f0, 0.0068843667f0), Float32[260.8 2.6 8.4 1.6; 8.6 154.4 28.0 0.2; 3.6 11.6 199.8 8.6; 16.6 31.8 18.6 44.8]))
#  (model = :DT, hyperparams = Dict("max_depth" => 3), results = ((0.8897629f0, 0.009560379f0), (0.11023704f0, 0.009560377f0), (0.8897629f0, 0.009560379f0), (0.9693753f0, 0.0016073347f0), (0.88850796f0, 0.009277768f0), (0.97364223f0, 0.004388472f0), (0.8877665f0, 0.008821769f0), Float32[260.4 2.6 5.2 5.2; 4.8 164.4 13.6 8.4; 4.0 9.8 204.2 5.6; 8.0 11.0 10.0 82.8]))
#  (model = :DT, hyperparams = Dict("max_depth" => 4), results = ((0.9032677f0, 0.011706319f0), (0.096732296f0, 0.011706326f0), (0.9032677f0, 0.011706319f0), (0.9724762f0, 0.0030279022f0), (0.9031806f0, 0.010536734f0), (0.9754895f0, 0.0042972825f0), (0.90204304f0, 0.011704887f0), Float32[259.6 3.0 5.2 5.6; 4.0 171.0 11.2 5.0; 4.0 9.8 203.8 6.0; 5.2 11.6 6.8 88.2]))
#  (model = :DT, hyperparams = Dict("max_depth" => 5), results = ((0.90726453f0, 0.008193353f0), (0.09273542f0, 0.00819335f0), (0.90726453f0, 0.008193353f0), (0.97469634f0, 0.0030124462f0), (0.91045123f0, 0.008354253f0), (0.9767071f0, 0.0028872027f0), (0.9062872f0, 0.007783912f0), Float32[259.8 3.0 3.8 6.8; 4.0 168.6 13.8 4.8; 5.0 5.0 206.2 7.4; 3.8 10.4 6.4 91.2]))
#  (model = :DT, hyperparams = Dict("max_depth" => 6), results = ((0.9165184f0, 0.010055398f0), (0.083481625f0, 0.010055374f0), (0.9165184f0, 0.010055398f0), (0.9765655f0, 0.0038756754f0), (0.9175604f0, 0.010988316f0), (0.97889197f0, 0.0034824198f0), (0.91600305f0, 0.010097393f0), Float32[262.6 3.0 4.0 3.8; 4.0 173.2 10.6 3.4; 4.0 6.8 206.8 6.0; 4.2 10.4 6.6 90.6]))
#  (model = :DT, hyperparams = Dict("max_depth" => 8), results = ((0.92525655f0, 0.011114043f0), (0.074743465f0, 0.011114039f0), (0.92525655f0, 0.011114043f0), (0.97832596f0, 0.003992249f0), (0.92454875f0, 0.011695416f0), (0.9819379f0, 0.003027513f0), (0.924205f0, 0.01160784f0), Float32[265.4 1.8 3.4 2.8; 5.8 171.6 9.6 4.2; 2.2 7.4 206.0 8.0; 2.8 8.2 3.6 97.2]))

# %%
for entry in results[:DT]
    printExperimentResult(entry.model, entry.hyperparams, entry.results, label_names)
end
# Out:
# =====================================================
#  Model: DT
#  Hyperparameters: Dict("max_depth" => 2)
# =====================================================
#  Accuracy (mean)               : 0.8247
#  Accuracy (std)                : 0.0069
#  Error Rate (mean)             : 0.1753
#  Error Rate (std)              : 0.0069
#  Sensitivity/Recall (mean)     : 0.8247
#  Sensitivity/Recall (std)      : 0.0069
#  Specificity (mean)            : 0.9448
#  Specificity (std)             : 0.0034
#  PPV (mean)                    : 0.7583
#  PPV (std)                     : 0.0073
#  NPV (mean)                    : 0.9657
#  NPV (std)                     : 0.0036
#  F1 Score (mean)               : 0.7881
#  F1 Score (std)                : 0.0069
#
# Confusion Matrix:
# Float32[260.8 2.6 8.4 1.6; 8.6 154.4 28.0 0.2; 3.6 11.6 199.8 8.6; 16.6 31.8 18.6 44.8]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 260.8 │       2.6 │      8.4 │  1.6 │
# │ Hazardous │   8.6 │     154.4 │     28.0 │  0.2 │
# │  Moderate │   3.6 │      11.6 │    199.8 │  8.6 │
# │      Poor │  16.6 │      31.8 │     18.6 │ 44.8 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: DT
#  Hyperparameters: Dict("max_depth" => 3)
# =====================================================
#  Accuracy (mean)               : 0.8898
#  Accuracy (std)                : 0.0096
#  Error Rate (mean)             : 0.1102
#  Error Rate (std)              : 0.0096
#  Sensitivity/Recall (mean)     : 0.8898
#  Sensitivity/Recall (std)      : 0.0096
#  Specificity (mean)            : 0.9694
#  Specificity (std)             : 0.0016
#  PPV (mean)                    : 0.8885
#  PPV (std)                     : 0.0093
#  NPV (mean)                    : 0.9736
#  NPV (std)                     : 0.0044
#  F1 Score (mean)               : 0.8878
#  F1 Score (std)                : 0.0088
#
# Confusion Matrix:
# Float32[260.4 2.6 5.2 5.2; 4.8 164.4 13.6 8.4; 4.0 9.8 204.2 5.6; 8.0 11.0 10.0 82.8]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 260.4 │       2.6 │      5.2 │  5.2 │
# │ Hazardous │   4.8 │     164.4 │     13.6 │  8.4 │
# │  Moderate │   4.0 │       9.8 │    204.2 │  5.6 │
# │      Poor │   8.0 │      11.0 │     10.0 │ 82.8 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: DT
#  Hyperparameters: Dict("max_depth" => 4)
# =====================================================
#  Accuracy (mean)               : 0.9033
#  Accuracy (std)                : 0.0117
#  Error Rate (mean)             : 0.0967
#  Error Rate (std)              : 0.0117
#  Sensitivity/Recall (mean)     : 0.9033
#  Sensitivity/Recall (std)      : 0.0117
#  Specificity (mean)            : 0.9725
#  Specificity (std)             : 0.003
#  PPV (mean)                    : 0.9032
#  PPV (std)                     : 0.0105
#  NPV (mean)                    : 0.9755
#  NPV (std)                     : 0.0043
#  F1 Score (mean)               : 0.902
#  F1 Score (std)                : 0.0117
#
# Confusion Matrix:
# Float32[259.6 3.0 5.2 5.6; 4.0 171.0 11.2 5.0; 4.0 9.8 203.8 6.0; 5.2 11.6 6.8 88.2]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 259.6 │       3.0 │      5.2 │  5.6 │
# │ Hazardous │   4.0 │     171.0 │     11.2 │  5.0 │
# │  Moderate │   4.0 │       9.8 │    203.8 │  6.0 │
# │      Poor │   5.2 │      11.6 │      6.8 │ 88.2 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: DT
#  Hyperparameters: Dict("max_depth" => 5)
# =====================================================
#  Accuracy (mean)               : 0.9073
#  Accuracy (std)                : 0.0082
#  Error Rate (mean)             : 0.0927
#  Error Rate (std)              : 0.0082
#  Sensitivity/Recall (mean)     : 0.9073
#  Sensitivity/Recall (std)      : 0.0082
#  Specificity (mean)            : 0.9747
#  Specificity (std)             : 0.003
#  PPV (mean)                    : 0.9105
#  PPV (std)                     : 0.0084
#  NPV (mean)                    : 0.9767
#  NPV (std)                     : 0.0029
#  F1 Score (mean)               : 0.9063
#  F1 Score (std)                : 0.0078
#
# Confusion Matrix:
# Float32[259.8 3.0 3.8 6.8; 4.0 168.6 13.8 4.8; 5.0 5.0 206.2 7.4; 3.8 10.4 6.4 91.2]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 259.8 │       3.0 │      3.8 │  6.8 │
# │ Hazardous │   4.0 │     168.6 │     13.8 │  4.8 │
# │  Moderate │   5.0 │       5.0 │    206.2 │  7.4 │
# │      Poor │   3.8 │      10.4 │      6.4 │ 91.2 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: DT
#  Hyperparameters: Dict("max_depth" => 6)
# =====================================================
#  Accuracy (mean)               : 0.9165
#  Accuracy (std)                : 0.0101
#  Error Rate (mean)             : 0.0835
#  Error Rate (std)              : 0.0101
#  Sensitivity/Recall (mean)     : 0.9165
#  Sensitivity/Recall (std)      : 0.0101
#  Specificity (mean)            : 0.9766
#  Specificity (std)             : 0.0039
#  PPV (mean)                    : 0.9176
#  PPV (std)                     : 0.011
#  NPV (mean)                    : 0.9789
#  NPV (std)                     : 0.0035
#  F1 Score (mean)               : 0.916
#  F1 Score (std)                : 0.0101
#
# Confusion Matrix:
# Float32[262.6 3.0 4.0 3.8; 4.0 173.2 10.6 3.4; 4.0 6.8 206.8 6.0; 4.2 10.4 6.6 90.6]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 262.6 │       3.0 │      4.0 │  3.8 │
# │ Hazardous │   4.0 │     173.2 │     10.6 │  3.4 │
# │  Moderate │   4.0 │       6.8 │    206.8 │  6.0 │
# │      Poor │   4.2 │      10.4 │      6.6 │ 90.6 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: DT
#  Hyperparameters: Dict("max_depth" => 8)
# =====================================================
#  Accuracy (mean)               : 0.9253
#  Accuracy (std)                : 0.0111
#  Error Rate (mean)             : 0.0747
#  Error Rate (std)              : 0.0111
#  Sensitivity/Recall (mean)     : 0.9253
#  Sensitivity/Recall (std)      : 0.0111
#  Specificity (mean)            : 0.9783
#  Specificity (std)             : 0.004
#  PPV (mean)                    : 0.9245
#  PPV (std)                     : 0.0117
#  NPV (mean)                    : 0.9819
#  NPV (std)                     : 0.003
#  F1 Score (mean)               : 0.9242
#  F1 Score (std)                : 0.0116
#
# Confusion Matrix:
# Float32[265.4 1.8 3.4 2.8; 5.8 171.6 9.6 4.2; 2.2 7.4 206.0 8.0; 2.8 8.2 3.6 97.2]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 265.4 │       1.8 │      3.4 │  2.8 │
# │ Hazardous │   5.8 │     171.6 │      9.6 │  4.2 │
# │  Moderate │   2.2 │       7.4 │    206.0 │  8.0 │
# │      Poor │   2.8 │       8.2 │      3.6 │ 97.2 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================

# %%
########################
# 3. DT FINAL TESTING 
########################

# BEST HYPERPARAMETERS
hp = Dict("max_depth"=>8)

# Compute normalization parameters from TRAINING set only
normParams = calculateMinMaxNormalizationParameters(trainingInputs)
train_df = normalizeMinMax(trainingInputs, normParams)
test_df = normalizeMinMax(testInputs, normParams)

# --- Convert targets ---
train_y_cat = categorical(vec(trainingTargets))
test_y_cat  = categorical(vec(testTargets))

# Load model (insert hyperparameters manually)
model = DTClassifier(max_depth=6, rng=Random.MersenneTwister(1))    

# --- Train machine ---
mach = machine(model, MLJ.table(train_df), train_y_cat)
MLJ.fit!(mach)
    
# --- Predict ---
ŷ = MLJ.predict(mach, MLJ.table(test_df))              # probabilistic predictions
y_pred = CategoricalArray(mode.(ŷ))         # convert to class labels
    
# --- Compute metrics ---
metrics = confusionMatrix(y_pred, test_y_cat)

printResult(:DT, hp, metrics, label_names)
# Out:
# [ Info: Training machine(DecisionTreeClassifier(max_depth = 6, …), …).
# =====================================================
#  Model: DT
#  Hyperparameters: Dict("max_depth" => 8)
# =====================================================
#  Accuracy                : 0.921
#  Error Rate              : 0.079
#  Sensitivity/Recall      : 0.921
#  Specificity             : 0.9775
#  PPV                     : 0.9247
#  NPV                     : 0.9779
#  F1 Score                : 0.9214
#
# Confusion Matrix:
# [76 0 0 27; 0 269 1 26; 0 2 381 0; 11 12 0 195]
# =====================================================
#
# ┌───────────┬──────┬───────────┬──────────┬──────┐
# │           │ Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼──────┼───────────┼──────────┼──────┤
# │      Good │   76 │         0 │        0 │   27 │
# │ Hazardous │    0 │       269 │        1 │   26 │
# │  Moderate │    0 │         2 │      381 │    0 │
# │      Poor │   11 │        12 │        0 │  195 │
# └───────────┴──────┴───────────┴──────────┴──────┘

# %% [markdown]
# # K-Nearest Neighbors

# %%
kNNClassifier = MLJ.@load KNNClassifier pkg=NearestNeighborModels verbosity=0
# Out:
# NearestNeighborModels.KNNClassifier

# %%
############# 4. kNN (6 values) #############
knn_search_space = [
    Dict("K"=>1),
    Dict("K"=>3),
    Dict("K"=>5),
    Dict("K"=>7),
    Dict("K"=>9),
    Dict("K"=>11)
]
# Out:
# 6-element Vector{Dict{String, Int64}}:
#  Dict("K" => 1)
#  Dict("K" => 3)
#  Dict("K" => 5)
#  Dict("K" => 7)
#  Dict("K" => 9)
#  Dict("K" => 11)

# %%
########################
# 4. KNN GRID SEARCH
########################
knn_results = []

for hp in knn_search_space
    println("\n=== kNN experiment: K=$(hp["K"]) ===")
    res = modelCrossValidation(:KNeighborsClassifier, hp, (trainingInputs, trainingTargets), crossValidationIndices)
    push!(knn_results, (model=:KNN, hyperparams=hp, results=res))
end

results[:KNN] = knn_results
# Out:
# === kNN experiment: K=1 ===
# === kNN experiment: K=3 ===
#
# === kNN experiment: K=5 ===
#
# === kNN experiment: K=7 ===
#
# === kNN experiment: K=9 ===
#
# === kNN experiment: K=11 ===
# 6-element Vector{Any}:
#  (model = :KNN, hyperparams = Dict("K" => 1), results = ((0.91574585f0, 0.011013997f0), (0.08425412f0, 0.011013993f0), (0.91574585f0, 0.011013997f0), (0.97418725f0, 0.003764723f0), (0.9146147f0, 0.010846263f0), (0.97899264f0, 0.003636073f0), (0.91474324f0, 0.010814225f0), Float32[264.4 0.8 5.6 2.6; 3.8 171.2 11.8 4.4; 4.4 7.6 203.4 8.2; 4.8 6.6 6.8 93.6]))
#  (model = :KNN, hyperparams = Dict("K" => 3), results = ((0.93125135f0, 0.0065393206f0), (0.06874873f0, 0.0065393127f0), (0.93125135f0, 0.0065393206f0), (0.9782092f0, 0.0030846733f0), (0.93018085f0, 0.0067967884f0), (0.98437274f0, 0.0026192376f0), (0.9300531f0, 0.006574418f0), Float32[267.6 0.0 4.4 1.4; 3.4 174.4 9.2 4.2; 2.4 6.2 208.8 6.2; 4.6 8.0 5.0 94.2]))
#  (model = :KNN, hyperparams = Dict("K" => 5), results = ((0.93400156f0, 0.002801467f0), (0.06599842f0, 0.0028014837f0), (0.93400156f0, 0.002801467f0), (0.97837484f0, 0.001903854f0), (0.9328934f0, 0.0028109066f0), (0.9855808f0, 0.0013901182f0), (0.9326143f0, 0.0027897814f0), Float32[267.8 0.0 4.6 1.0; 4.2 175.0 8.2 3.8; 2.0 5.4 209.4 6.8; 4.6 7.4 4.8 95.0]))
#  (model = :KNN, hyperparams = Dict("K" => 7), results = ((0.9330038f0, 0.0036184748f0), (0.06699624f0, 0.0036184648f0), (0.9330038f0, 0.0036184748f0), (0.97780067f0, 0.0019375748f0), (0.9318565f0, 0.0040266854f0), (0.9852966f0, 0.0017068529f0), (0.93151987f0, 0.0037684303f0), Float32[267.2 0.0 5.0 1.2; 4.6 175.4 7.6 3.6; 2.0 6.4 209.4 5.8; 4.4 7.8 5.2 94.4]))
#  (model = :KNN, hyperparams = Dict("K" => 9), results = ((0.9312504f0, 0.0019548854f0), (0.06874968f0, 0.0019548913f0), (0.9312504f0, 0.0019548854f0), (0.9770241f0, 0.0017308127f0), (0.930478f0, 0.0019511342f0), (0.98480636f0, 0.0014938554f0), (0.9297517f0, 0.001864768f0), Float32[267.4 0.0 4.8 1.2; 4.4 175.0 8.6 3.2; 2.6 6.4 208.6 6.0; 4.6 8.0 5.2 94.0]))
#  (model = :KNN, hyperparams = Dict("K" => 11), results = ((0.9287491f0, 0.003437169f0), (0.07125093f0, 0.0034371808f0), (0.9287491f0, 0.003437169f0), (0.9752367f0, 0.0025881217f0), (0.92840207f0, 0.0031634702f0), (0.9841734f0, 0.0017731715f0), (0.9270852f0, 0.0033516486f0), Float32[267.4 0.0 5.2 0.8; 5.0 173.8 9.8 2.6; 2.6 6.4 208.6 6.0; 5.4 8.2 5.0 93.2]))

# %%
for entry in results[:KNN]
    printExperimentResult(entry.model, entry.hyperparams, entry.results, label_names)
end
# Out:
# =====================================================
#  Model: KNN
#  Hyperparameters: Dict("K" => 1)
# =====================================================
#  Accuracy (mean)               : 0.9157
#  Accuracy (std)                : 0.011
#  Error Rate (mean)             : 0.0843
#  Error Rate (std)              : 0.011
#  Sensitivity/Recall (mean)     : 0.9157
#  Sensitivity/Recall (std)      : 0.011
#  Specificity (mean)            : 0.9742
#  Specificity (std)             : 0.0038
#  PPV (mean)                    : 0.9146
#  PPV (std)                     : 0.0108
#  NPV (mean)                    : 0.979
#  NPV (std)                     : 0.0036
#  F1 Score (mean)               : 0.9147
#  F1 Score (std)                : 0.0108
#
# Confusion Matrix:
# Float32[264.4 0.8 5.6 2.6; 3.8 171.2 11.8 4.4; 4.4 7.6 203.4 8.2; 4.8 6.6 6.8 93.6]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 264.4 │       0.8 │      5.6 │  2.6 │
# │ Hazardous │   3.8 │     171.2 │     11.8 │  4.4 │
# │  Moderate │   4.4 │       7.6 │    203.4 │  8.2 │
# │      Poor │   4.8 │       6.6 │      6.8 │ 93.6 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN
#  Hyperparameters: Dict("K" => 3)
# =====================================================
#  Accuracy (mean)               : 0.9313
#  Accuracy (std)                : 0.0065
#  Error Rate (mean)             : 0.0687
#  Error Rate (std)              : 0.0065
#  Sensitivity/Recall (mean)     : 0.9313
#  Sensitivity/Recall (std)      : 0.0065
#  Specificity (mean)            : 0.9782
#  Specificity (std)             : 0.0031
#  PPV (mean)                    : 0.9302
#  PPV (std)                     : 0.0068
#  NPV (mean)                    : 0.9844
#  NPV (std)                     : 0.0026
#  F1 Score (mean)               : 0.9301
#  F1 Score (std)                : 0.0066
#
# Confusion Matrix:
# Float32[267.6 0.0 4.4 1.4; 3.4 174.4 9.2 4.2; 2.4 6.2 208.8 6.2; 4.6 8.0 5.0 94.2]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 267.6 │       0.0 │      4.4 │  1.4 │
# │ Hazardous │   3.4 │     174.4 │      9.2 │  4.2 │
# │  Moderate │   2.4 │       6.2 │    208.8 │  6.2 │
# │      Poor │   4.6 │       8.0 │      5.0 │ 94.2 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN
#  Hyperparameters: Dict("K" => 5)
# =====================================================
#  Accuracy (mean)               : 0.934
#  Accuracy (std)                : 0.0028
#  Error Rate (mean)             : 0.066
#  Error Rate (std)              : 0.0028
#  Sensitivity/Recall (mean)     : 0.934
#  Sensitivity/Recall (std)      : 0.0028
#  Specificity (mean)            : 0.9784
#  Specificity (std)             : 0.0019
#  PPV (mean)                    : 0.9329
#  PPV (std)                     : 0.0028
#  NPV (mean)                    : 0.9856
#  NPV (std)                     : 0.0014
#  F1 Score (mean)               : 0.9326
#  F1 Score (std)                : 0.0028
#
# Confusion Matrix:
# Float32[267.8 0.0 4.6 1.0; 4.2 175.0 8.2 3.8; 2.0 5.4 209.4 6.8; 4.6 7.4 4.8 95.0]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 267.8 │       0.0 │      4.6 │  1.0 │
# │ Hazardous │   4.2 │     175.0 │      8.2 │  3.8 │
# │  Moderate │   2.0 │       5.4 │    209.4 │  6.8 │
# │      Poor │   4.6 │       7.4 │      4.8 │ 95.0 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN
#  Hyperparameters: Dict("K" => 7)
# =====================================================
#  Accuracy (mean)               : 0.933
#  Accuracy (std)                : 0.0036
#  Error Rate (mean)             : 0.067
#  Error Rate (std)              : 0.0036
#  Sensitivity/Recall (mean)     : 0.933
#  Sensitivity/Recall (std)      : 0.0036
#  Specificity (mean)            : 0.9778
#  Specificity (std)             : 0.0019
#  PPV (mean)                    : 0.9319
#  PPV (std)                     : 0.004
#  NPV (mean)                    : 0.9853
#  NPV (std)                     : 0.0017
#  F1 Score (mean)               : 0.9315
#  F1 Score (std)                : 0.0038
#
# Confusion Matrix:
# Float32[267.2 0.0 5.0 1.2; 4.6 175.4 7.6 3.6; 2.0 6.4 209.4 5.8; 4.4 7.8 5.2 94.4]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 267.2 │       0.0 │      5.0 │  1.2 │
# │ Hazardous │   4.6 │     175.4 │      7.6 │  3.6 │
# │  Moderate │   2.0 │       6.4 │    209.4 │  5.8 │
# │      Poor │   4.4 │       7.8 │      5.2 │ 94.4 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN
#  Hyperparameters: Dict("K" => 9)
# =====================================================
#  Accuracy (mean)               : 0.9313
#  Accuracy (std)                : 0.002
#  Error Rate (mean)             : 0.0687
#  Error Rate (std)              : 0.002
#  Sensitivity/Recall (mean)     : 0.9313
#  Sensitivity/Recall (std)      : 0.002
#  Specificity (mean)            : 0.977
#  Specificity (std)             : 0.0017
#  PPV (mean)                    : 0.9305
#  PPV (std)                     : 0.002
#  NPV (mean)                    : 0.9848
#  NPV (std)                     : 0.0015
#  F1 Score (mean)               : 0.9298
#  F1 Score (std)                : 0.0019
#
# Confusion Matrix:
# Float32[267.4 0.0 4.8 1.2; 4.4 175.0 8.6 3.2; 2.6 6.4 208.6 6.0; 4.6 8.0 5.2 94.0]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 267.4 │       0.0 │      4.8 │  1.2 │
# │ Hazardous │   4.4 │     175.0 │      8.6 │  3.2 │
# │  Moderate │   2.6 │       6.4 │    208.6 │  6.0 │
# │      Poor │   4.6 │       8.0 │      5.2 │ 94.0 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN
#  Hyperparameters: Dict("K" => 11)
# =====================================================
#  Accuracy (mean)               : 0.9287
#  Accuracy (std)                : 0.0034
#  Error Rate (mean)             : 0.0713
#  Error Rate (std)              : 0.0034
#  Sensitivity/Recall (mean)     : 0.9287
#  Sensitivity/Recall (std)      : 0.0034
#  Specificity (mean)            : 0.9752
#  Specificity (std)             : 0.0026
#  PPV (mean)                    : 0.9284
#  PPV (std)                     : 0.0032
#  NPV (mean)                    : 0.9842
#  NPV (std)                     : 0.0018
#  F1 Score (mean)               : 0.9271
#  F1 Score (std)                : 0.0034
#
# Confusion Matrix:
# Float32[267.4 0.0 5.2 0.8; 5.0 173.8 9.8 2.6; 2.6 6.4 208.6 6.0; 5.4 8.2 5.0 93.2]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 267.4 │       0.0 │      5.2 │  0.8 │
# │ Hazardous │   5.0 │     173.8 │      9.8 │  2.6 │
# │  Moderate │   2.6 │       6.4 │    208.6 │  6.0 │
# │      Poor │   5.4 │       8.2 │      5.0 │ 93.2 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================

# %%
########################
# 4. KNN FINAL TESTING 
########################

# BEST HYPERPARAMETERS
hp = Dict("K"=>5)

# Compute normalization parameters from TRAINING set only
normParams = calculateMinMaxNormalizationParameters(trainingInputs)
train_df = normalizeMinMax(trainingInputs, normParams)
test_df = normalizeMinMax(testInputs, normParams)

# --- Convert targets ---
train_y_cat = categorical(vec(trainingTargets))
test_y_cat  = categorical(vec(testTargets))

# Load model (insert hyperparameters manually)
model = kNNClassifier(K=5)

# --- Train machine ---
mach = machine(model, MLJ.table(train_df), train_y_cat)
MLJ.fit!(mach)
    
# --- Predict ---
ŷ = MLJ.predict(mach, MLJ.table(test_df))              # probabilistic predictions
y_pred = CategoricalArray(mode.(ŷ))         # convert to class labels
    
# --- Compute metrics ---
metrics = confusionMatrix(y_pred, test_y_cat)

printResult(:KNN, hp, metrics, label_names)
# Out:
# [ Info: Training machine(KNNClassifier(K = 5, …), …).
# =====================================================
#  Model: KNN
#  Hyperparameters: Dict("K" => 5)
# =====================================================
#  Accuracy                : 0.909
#  Error Rate              : 0.091
#  Sensitivity/Recall      : 0.909
#  Specificity             : 0.9692
#  PPV                     : 0.9087
#  NPV                     : 0.9785
#  F1 Score                : 0.9066
#
# Confusion Matrix:
# [67 0 0 36; 0 282 6 8; 0 0 383 0; 8 33 0 177]
# =====================================================
#
# ┌───────────┬──────┬───────────┬──────────┬──────┐
# │           │ Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼──────┼───────────┼──────────┼──────┤
# │      Good │   67 │         0 │        0 │   36 │
# │ Hazardous │    0 │       282 │        6 │    8 │
# │  Moderate │    0 │         0 │      383 │    0 │
# │      Poor │    8 │        33 │        0 │  177 │
# └───────────┴──────┴───────────┴──────────┴──────┘

# %% [markdown]
# # Stacking Ensemble

# %%
SVMClassifier = @load ProbabilisticSVC pkg=LIBSVM verbosity=0
DTClassifier  = @load DecisionTreeClassifier pkg=DecisionTree verbosity=0
kNNClassifier = @load KNNClassifier pkg=NearestNeighborModels verbosity=0

trainIdx, testIdx = holdOut(size(df,1), 0.2)

trainingInputs  = inputs[trainIdx, :]
testInputs      = inputs[testIdx, :]

trainingTargets = targets[trainIdx]
testTargets     = targets[testIdx]

normParams = calculateMinMaxNormalizationParameters(trainingInputs)
trainingInputs = normalizeMinMax(trainingInputs, normParams)
testInputs  = normalizeMinMax(testInputs,  normParams)

# X as DataFrame
train_df = DataFrame(trainingInputs, :auto)
test_df  = DataFrame(testInputs, :auto)

# y as categorical
train_y_cat = categorical(trainingTargets)
test_y_cat  = categorical(testTargets)

# ---- Base Models ----
base_models_dict = Dict(
    "SVM" => SVMClassifier(kernel=LIBSVM.Kernel.RadialBasis, cost=1.0, gamma=2.0),
    "DT"  => DTClassifier(max_depth=8, rng=Random.MersenneTwister(1)),
    "kNN" => kNNClassifier(K=5)
)

# Convert to NamedTuple for Stack
base_models_NT = (; (Symbol(k)=>v for (k,v) in base_models_dict)...)

# ---- Stacking Model ----
stack_model = Stack(;
    metalearner = DTClassifier(max_depth=3, rng=Random.MersenneTwister(1)),
    resampling = CV(nfolds=5, shuffle=true, rng=123),  # deterministic
    measure = accuracy, 
    base_models_NT...
)

# Train the stacking model on your train dataset
stack_mach = machine(stack_model, train_df, train_y_cat) |> MLJ.fit!

y_pred = mode.(MLJ.predict(stack_mach, test_df))
acc = MLJ.accuracy(y_pred, test_y_cat)
println("Stack ensemble accuracy = $(round(acc*100, digits=2)) %")
# Out:
# [ Info: Training machine(ProbabilisticStack(metalearner = DecisionTreeClassifier(max_depth = 3, …), …), …).
# [ Info: Training machine(:SVM, …).
# [ Info: Training machine(:DT, …).
# [ Info: Training machine(:kNN, …).
# [ Info: Training machine(:SVM, …).
# [ Info: Training machine(:DT, …).
# [ Info: Training machine(:kNN, …).
# [ Info: Training machine(:SVM, …).
# [ Info: Training machine(:DT, …).
# [ Info: Training machine(:kNN, …).
# [ Info: Training machine(:SVM, …).
# [ Info: Training machine(:DT, …).
# [ Info: Training machine(:kNN, …).
# [ Info: Training machine(:SVM, …).
# [ Info: Training machine(:DT, …).
# [ Info: Training machine(:kNN, …).
# [ Info: Training machine(:SVM, …).
# [ Info: Training machine(:DT, …).
# [ Info: Training machine(:kNN, …).
# [ Info: Training machine(:metalearner, …).
# Stack ensemble accuracy = 93.1 %
