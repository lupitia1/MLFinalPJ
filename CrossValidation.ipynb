# %% [markdown]
# # Load packages

# %%
# skip reinstalling packages we already have
using Pkg

pkgs = [
    "MLJ", "MLJBase", "MLJModels", "MLJEnsembles", "MLJLinearModels",
    "DecisionTree", "MLJDecisionTreeInterface", "NaiveBayes", 
    "MLJNaiveBayesInterface", "EvoTrees", "CategoricalArrays", "Random",
    "LIBSVM", "MLJLIBSVMInterface", "Plots", "MLJModelInterface",
    "CSV", "DataFrames", "UrlDownload", "XGBoost", "NNlib"
]

# Filter out packages already installed
missing_pkgs = filter(pkg -> !(pkg in keys(Pkg.project().dependencies)), pkgs)

if !isempty(missing_pkgs)
    println("Installing missing packages: ", missing_pkgs)
    Pkg.add(missing_pkgs)
else
    println(" All required packages are already installed.")
end
# Out:
#  All required packages are already installed.

# %%
using MLJ
using LIBSVM
using NNlib
using Flux
using Flux.Losses
using Statistics

# %%
#Load your library of functions
include("utils.jl")
# Set a global random seed for reproducibility
using Random
Random.seed!(42)
# Out:
# TaskLocalRNG()

# %% [markdown]
# # Load Data

# %%
using CSV, DataFrames, Random
using CategoricalArrays

df = CSV.read("./data/updated_pollution_dataset.csv", DataFrame)

# Some log
println("First 5 rows of df:")
show(df[1:5, :], allcols=true)

# Convert last column to categorical (in-place!)
df[!, end] = categorical(df[!, end])

# Extract the integer codes of the categories
targets = Float32.(levelcode.(df[!, end]))

# Use all columns except the last one as inputs
inputs = Matrix{Float32}(df[:, 1:end-1])

println("First 5 inputs::")
for i in 1:5
    println(inputs[i, :])
end

println("\n\nFirst 5 targets:")
println(targets[1:5])

# Extract labels (categories) as strings
label_names = levels(df[!, 10])
println("Labels: ", label_names)
# Out:
# First 5 rows of df:
# 5×10 DataFrame
#  Row │ Temperature  Humidity  PM2.5    PM10     NO2      SO2      CO       Proximity_to_Industrial_Areas  Population_Density  Air Quality
#      │ Float64      Float64   Float64  Float64  Float64  Float64  Float64  Float64                        Int64               String15
# ─────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#    1 │        29.8      59.1      5.2     17.9     18.9      9.2     1.72                            6.3                 319  Moderate
#    2 │        28.3      75.6      2.3     12.2     30.8      9.7     1.64                            6.0                 611  Moderate
#    3 │        23.1      74.7     26.7     33.8     24.4     12.6     1.63                            5.2                 619  Moderate
#    4 │        27.1      39.1      6.1      6.3     13.5      5.3     1.15                           11.1                 551  Good
#    5 │        26.5      70.7      6.9     16.0     21.9      5.6     1.01                           12.7                 303  GoodFirst 5 inputs::
# Float32
# [29.8, 59.1, 5.2, 17.9, 18.9, 9.2, 1.72, 6.3, 319.0]
# Float32[28.3, 75.6, 2.3, 12.2, 30.8, 9.7, 1.64, 6.0, 611.0]
# Float32[23.1, 74.7, 26.7, 33.8, 24.4, 12.6, 1.63, 5.2, 619.0]
# Float32[27.1, 39.1, 6.1, 6.3, 13.5, 5.3, 1.15, 11.1, 551.0]
# Float32[26.5, 70.7, 6.9, 16.0, 21.9, 5.6, 1.01, 12.7, 303.0]
#
#
# First 5 targets:
# Float32[3.0, 3.0, 3.0, 1.0, 1.0]
# Labels: String15["Good", "Hazardous", "Moderate", "Poor"]

# %%
results = Dict()
crossValidationIndices = crossvalidation(targets, 5)
# Out:
# 5000-element Vector{Int64}:
#  1
#  3
#  5
#  4
#  1
#  3
#  3
#  5
#  1
#  1
#  5
#  1
#  2
#  ⋮
#  3
#  4
#  4
#  4
#  5
#  1
#  2
#  4
#  4
#  3
#  5
#  1

# %%
function printExperimentResult(model, hyperparams, results, class_labels)
    (
        (accuracy_mean, accuracy_std),
        (error_rate_mean, error_rate_std),
        (sensitivity_mean, sensitivity_std),
        (specificity_mean, specificity_std),
        (ppv_mean, ppv_std),
        (npv_mean, npv_std),
        (f1_mean, f1_std),
        cm
    ) = results

    println("\n=====================================================")
    println(" Model: $model")
    println(" Hyperparameters: $hyperparams")
    println("=====================================================")

    println(" Accuracy (mean)               : ", round(accuracy_mean, digits=4))
    println(" Accuracy (std)                : ", round(accuracy_std, digits=4))

    println(" Error Rate (mean)             : ", round(error_rate_mean, digits=4))
    println(" Error Rate (std)              : ", round(error_rate_std, digits=4))

    println(" Sensitivity/Recall (mean)     : ", round(sensitivity_mean, digits=4))
    println(" Sensitivity/Recall (std)      : ", round(sensitivity_std,  digits=4))

    println(" Specificity (mean)            : ", round(specificity_mean, digits=4))
    println(" Specificity (std)             : ", round(specificity_std,  digits=4))

    println(" PPV (mean)                    : ", round(ppv_mean,         digits=4))
    println(" PPV (std)                     : ", round(ppv_std,          digits=4))

    println(" NPV (mean)                    : ", round(npv_mean,         digits=4))
    println(" NPV (std)                     : ", round(npv_std,          digits=4))

    println(" F1 Score (mean)               : ", round(f1_mean,          digits=4))
    println(" F1 Score (std)                : ", round(f1_std,           digits=4))

    println("\nConfusion Matrix:")
    println(cm)

    PrettyTables.pretty_table(DataFrame(cm, :auto); header=class_labels, row_labels=class_labels)

    println("=====================================================\n")
end
# Out:
# printExperimentResult (generic function with 1 method)

# %% [markdown]
# # Artificial Neural Networks

# %%
############# 1. ARTIFICIAL NEURAL NETWORKS (8+ topologies) #############
default_ann = Dict(      
    "numExecutions" => 5,
    #"transferFunctions" => [σ, σ, σ, σ],
    "maxEpochs" => 200,
    "minLoss" => 0.0,
    "learningRate" => 0.01,
    "validationRatio" => 0.1,
    "maxEpochsVal" => 20
)

ann_search_space = [
    Dict("topology"=>[4, 4]),
    Dict("topology"=>[8, 8]),
    Dict("topology"=>[16, 16]),
    Dict("topology"=>[10, 4]),
    Dict("topology"=>[10, 6, 4]),
    Dict("topology"=>[10, 8, 4]),
    Dict("topology"=>[10, 8, 6, 4]),
    Dict("topology"=>[10, 12, 6, 4])
]
# Out:
# 8-element Vector{Dict{String, Vector{Int64}}}:
#  Dict("topology" => [4, 4])
#  Dict("topology" => [8, 8])
#  Dict("topology" => [16, 16])
#  Dict("topology" => [10, 4])
#  Dict("topology" => [10, 6, 4])
#  Dict("topology" => [10, 8, 4])
#  Dict("topology" => [10, 8, 6, 4])
#  Dict("topology" => [10, 12, 6, 4])

# %%
########################
# 1. ANN GRID SEARCH
########################
ann_results = []

for hp in ann_search_space
    println("\n=== ANN experiment: topology = $(hp["topology"]) ===")
    full_hp = merge(default_ann, hp)
    res = modelCrossValidation(:ANN, full_hp, (inputs, targets), crossValidationIndices)
    push!(ann_results, (model=:ANN, hyperparams=hp, results=res))
end

results[:ANN] = ann_results
# Out:
# === ANN experiment: topology = [4, 4] ===
#
# === ANN experiment: topology = [8, 8] ===
#
# === ANN experiment: topology = [16, 16] ===
#
# === ANN experiment: topology = [10, 4] ===
#
# === ANN experiment: topology = [10, 6, 4] ===
#
# === ANN experiment: topology = [10, 8, 4] ===
#
# === ANN experiment: topology = [10, 8, 6, 4] ===
#
# === ANN experiment: topology = [10, 12, 6, 4] ===
# 8-element Vector{Any}:
#  (model = :ANN, hyperparams = Dict("topology" => [4, 4]), results = ((0.94048005f0, 0.007690985f0), (0.05952f0, 0.0076910355f0), (0.94048005f0, 0.007690985f0), (0.9826414f0, 0.0017484212f0), (0.94006604f0, 0.0076740775f0), (0.98477715f0, 0.0020668781f0), (0.94012755f0, 0.007616604f0), Float32[332.28 0.71999997 6.6 0.4; 0.6 243.96 8.2 7.2399993; 11.96 8.12 175.48001 4.44; 0.4 5.12 5.72 188.76]))
#  (model = :ANN, hyperparams = Dict("topology" => [8, 8]), results = ((0.94152004f0, 0.007279571f0), (0.058480002f0, 0.00727956f0), (0.94152004f0, 0.007279571f0), (0.98277295f0, 0.001393233f0), (0.9412157f0, 0.007079065f0), (0.9850707f0, 0.0020939773f0), (0.94120026f0, 0.007131832f0), Float32[332.03998 0.76000005 6.8 0.4; 0.68 244.6 8.12 6.6; 11.6 7.84 176.76 3.8; 0.44 5.2400002 6.2 188.12]))
#  (model = :ANN, hyperparams = Dict("topology" => [16, 16]), results = ((0.94128f0, 0.007293288f0), (0.058720004f0, 0.0072932867f0), (0.94128f0, 0.007293288f0), (0.98263663f0, 0.0014149926f0), (0.9409256f0, 0.007111212f0), (0.98513556f0, 0.0019999319f0), (0.9409067f0, 0.007165686f0), Float32[332.4 0.76 6.44 0.4; 0.76 244.31999 8.4 6.5199995; 11.8 8.12 176.16 3.9199996; 0.4 5.08 6.12 188.4]))
#  (model = :ANN, hyperparams = Dict("topology" => [10, 4]), results = ((0.94060004f0, 0.007778182f0), (0.0594f0, 0.007778176f0), (0.94060004f0, 0.007778182f0), (0.98259276f0, 0.0016513825f0), (0.9402725f0, 0.0076609543f0), (0.9846786f0, 0.0021157495f0), (0.9402938f0, 0.0076712905f0), Float32[332.0 0.71999997 6.88 0.4; 0.87999994 244.12 8.12 6.88; 11.64 8.0 176.31999 4.04; 0.44 5.4 6.0 188.16]))
#  (model = :ANN, hyperparams = Dict("topology" => [10, 6, 4]), results = ((0.9408f0, 0.0059548398f0), (0.0592f0, 0.005954831f0), (0.9408f0, 0.0059548398f0), (0.98242223f0, 0.0011053754f0), (0.9404501f0, 0.0057671084f0), (0.9848939f0, 0.0016193363f0), (0.94043034f0, 0.0058141192f0), Float32[332.27997 0.84 6.4800005 0.4; 0.91999996 244.4 8.280001 6.4; 12.0 7.84 176.0 4.16; 0.4 5.32 6.16 188.12001]))
#  (model = :ANN, hyperparams = Dict("topology" => [10, 8, 4]), results = ((0.94148f0, 0.006424297f0), (0.05852f0, 0.0064243292f0), (0.94148f0, 0.006424297f0), (0.9828041f0, 0.0011801985f0), (0.9410969f0, 0.0062706345f0), (0.9851653f0, 0.0016697497f0), (0.9411069f0, 0.006297512f0), Float32[332.52002 0.68 6.3199997 0.48000002; 0.84 243.92 8.360001 6.88; 11.6 7.72 176.43999 4.2400002; 0.4 4.92 6.08 188.6]))
#  (model = :ANN, hyperparams = Dict("topology" => [10, 8, 6, 4]), results = ((0.94148f0, 0.007484151f0), (0.05852f0, 0.0074841185f0), (0.94148f0, 0.007484151f0), (0.98289615f0, 0.0016388685f0), (0.9384767f0, 0.012153848f0), (0.9858341f0, 0.0015197311f0), (0.93957317f0, 0.0098929545f0), Float32[333.08002 0.48000002 5.9199996 0.52; 0.84 244.84 8.280001 6.04; 10.84 6.96 178.24 3.9599998; 0.35999998 8.280001 6.04 185.31999]))
#  (model = :ANN, hyperparams = Dict("topology" => [10, 12, 6, 4]), results = ((0.94475996f0, 0.006930227f0), (0.055239998f0, 0.006930225f0), (0.94475996f0, 0.006930227f0), (0.9838495f0, 0.0015279449f0), (0.9444561f0, 0.0067237406f0), (0.9861512f0, 0.0017413263f0), (0.94440746f0, 0.006837079f0), Float32[333.0 0.56000006 5.88 0.56; 0.76 244.56001 8.08 6.6; 10.76 7.0 178.04001 4.2; 0.32 4.88 5.6400003 189.16]))

# %%
for entry in results[:ANN]
    printExperimentResult(entry.model, entry.hyperparams, entry.results, label_names)
end
# Out:
# =====================================================
#  Model: ANN
#  Hyperparameters: Dict("topology" => [4, 4])
# =====================================================
#  Accuracy (mean)               : 0.9405
#  Accuracy (std)                : 0.0077
#  Error Rate (mean)             : 0.0595
#  Error Rate (std)              : 0.0077
#  Sensitivity/Recall (mean)     : 0.9405
#  Sensitivity/Recall (std)      : 0.0077
#  Specificity (mean)            : 0.9826
#  Specificity (std)             : 0.0017
#  PPV (mean)                    : 0.9401
#  PPV (std)                     : 0.0077
#  NPV (mean)                    : 0.9848
#  NPV (std)                     : 0.0021
#  F1 Score (mean)               : 0.9401
#  F1 Score (std)                : 0.0076
#
# Confusion Matrix:
# Float32[332.28 0.71999997 6.6 0.4; 0.6 243.96 8.2 7.2399993; 11.96 8.12 175.48001 4.44; 0.4 5.12 5.72 188.76]
# ┌───────────┬────────┬───────────┬──────────┬────────┐
# │           │   Good │ Hazardous │ Moderate │   Poor │
# ├───────────┼────────┼───────────┼──────────┼────────┤
# │      Good │ 332.28 │      0.72 │      6.6 │    0.4 │
# │ Hazardous │    0.6 │    243.96 │      8.2 │   7.24 │
# │  Moderate │  11.96 │      8.12 │   175.48 │   4.44 │
# │      Poor │    0.4 │      5.12 │     5.72 │ 188.76 │
# └───────────┴────────┴───────────┴──────────┴────────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN
#  Hyperparameters: Dict("topology" => [8, 8])
# =====================================================
#  Accuracy (mean)               : 0.9415
#  Accuracy (std)                : 0.0073
#  Error Rate (mean)             : 0.0585
#  Error Rate (std)              : 0.0073
#  Sensitivity/Recall (mean)     : 0.9415
#  Sensitivity/Recall (std)      : 0.0073
#  Specificity (mean)            : 0.9828
#  Specificity (std)             : 0.0014
#  PPV (mean)                    : 0.9412
#  PPV (std)                     : 0.0071
#  NPV (mean)                    : 0.9851
#  NPV (std)                     : 0.0021
#  F1 Score (mean)               : 0.9412
#  F1 Score (std)                : 0.0071
#
# Confusion Matrix:
# Float32[332.03998 0.76000005 6.8 0.4; 0.68 244.6 8.12 6.6; 11.6 7.84 176.76 3.8; 0.44 5.2400002 6.2 188.12]
# ┌───────────┬────────┬───────────┬──────────┬────────┐
# │           │   Good │ Hazardous │ Moderate │   Poor │
# ├───────────┼────────┼───────────┼──────────┼────────┤
# │      Good │ 332.04 │      0.76 │      6.8 │    0.4 │
# │ Hazardous │   0.68 │     244.6 │     8.12 │    6.6 │
# │  Moderate │   11.6 │      7.84 │   176.76 │    3.8 │
# │      Poor │   0.44 │      5.24 │      6.2 │ 188.12 │
# └───────────┴────────┴───────────┴──────────┴────────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN
#  Hyperparameters: Dict("topology" => [16, 16])
# =====================================================
#  Accuracy (mean)               : 0.9413
#  Accuracy (std)                : 0.0073
#  Error Rate (mean)             : 0.0587
#  Error Rate (std)              : 0.0073
#  Sensitivity/Recall (mean)     : 0.9413
#  Sensitivity/Recall (std)      : 0.0073
#  Specificity (mean)            : 0.9826
#  Specificity (std)             : 0.0014
#  PPV (mean)                    : 0.9409
#  PPV (std)                     : 0.0071
#  NPV (mean)                    : 0.9851
#  NPV (std)                     : 0.002
#  F1 Score (mean)               : 0.9409
#  F1 Score (std)                : 0.0072
#
# Confusion Matrix:
# Float32[332.4 0.76 6.44 0.4; 0.76 244.31999 8.4 6.5199995; 11.8 8.12 176.16 3.9199996; 0.4 5.08 6.12 188.4]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 332.4 │      0.76 │     6.44 │   0.4 │
# │ Hazardous │  0.76 │    244.32 │      8.4 │  6.52 │
# │  Moderate │  11.8 │      8.12 │   176.16 │  3.92 │
# │      Poor │   0.4 │      5.08 │     6.12 │ 188.4 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN
#  Hyperparameters: Dict("topology" => [10, 4])
# =====================================================
#  Accuracy (mean)               : 0.9406
#  Accuracy (std)                : 0.0078
#  Error Rate (mean)             : 0.0594
#  Error Rate (std)              : 0.0078
#  Sensitivity/Recall (mean)     : 0.9406
#  Sensitivity/Recall (std)      : 0.0078
#  Specificity (mean)            : 0.9826
#  Specificity (std)             : 0.0017
#  PPV (mean)                    : 0.9403
#  PPV (std)                     : 0.0077
#  NPV (mean)                    : 0.9847
#  NPV (std)                     : 0.0021
#  F1 Score (mean)               : 0.9403
#  F1 Score (std)                : 0.0077
#
# Confusion Matrix:
# Float32[332.0 0.71999997 6.88 0.4; 0.87999994 244.12 8.12 6.88; 11.64 8.0 176.31999 4.04; 0.44 5.4 6.0 188.16]
# ┌───────────┬───────┬───────────┬──────────┬────────┐
# │           │  Good │ Hazardous │ Moderate │   Poor │
# ├───────────┼───────┼───────────┼──────────┼────────┤
# │      Good │ 332.0 │      0.72 │     6.88 │    0.4 │
# │ Hazardous │  0.88 │    244.12 │     8.12 │   6.88 │
# │  Moderate │ 11.64 │       8.0 │   176.32 │   4.04 │
# │      Poor │  0.44 │       5.4 │      6.0 │ 188.16 │
# └───────────┴───────┴───────────┴──────────┴────────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN
#  Hyperparameters: Dict("topology" => [10, 6, 4])
# =====================================================
#  Accuracy (mean)               : 0.9408
#  Accuracy (std)                : 0.006
#  Error Rate (mean)             : 0.0592
#  Error Rate (std)              : 0.006
#  Sensitivity/Recall (mean)     : 0.9408
#  Sensitivity/Recall (std)      : 0.006
#  Specificity (mean)            : 0.9824
#  Specificity (std)             : 0.0011
#  PPV (mean)                    : 0.9405
#  PPV (std)                     : 0.0058
#  NPV (mean)                    : 0.9849
#  NPV (std)                     : 0.0016
#  F1 Score (mean)               : 0.9404
#  F1 Score (std)                : 0.0058
#
# Confusion Matrix:
# Float32[332.27997 0.84 6.4800005 0.4; 0.91999996 244.4 8.280001 6.4; 12.0 7.84 176.0 4.16; 0.4 5.32 6.16 188.12001]
# ┌───────────┬────────┬───────────┬──────────┬────────┐
# │           │   Good │ Hazardous │ Moderate │   Poor │
# ├───────────┼────────┼───────────┼──────────┼────────┤
# │      Good │ 332.28 │      0.84 │     6.48 │    0.4 │
# │ Hazardous │   0.92 │     244.4 │     8.28 │    6.4 │
# │  Moderate │   12.0 │      7.84 │    176.0 │   4.16 │
# │      Poor │    0.4 │      5.32 │     6.16 │ 188.12 │
# └───────────┴────────┴───────────┴──────────┴────────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN
#  Hyperparameters: Dict("topology" => [10, 8, 4])
# =====================================================
#  Accuracy (mean)               : 0.9415
#  Accuracy (std)                : 0.0064
#  Error Rate (mean)             : 0.0585
#  Error Rate (std)              : 0.0064
#  Sensitivity/Recall (mean)     : 0.9415
#  Sensitivity/Recall (std)      : 0.0064
#  Specificity (mean)            : 0.9828
#  Specificity (std)             : 0.0012
#  PPV (mean)                    : 0.9411
#  PPV (std)                     : 0.0063
#  NPV (mean)                    : 0.9852
#  NPV (std)                     : 0.0017
#  F1 Score (mean)               : 0.9411
#  F1 Score (std)                : 0.0063
#
# Confusion Matrix:
# Float32[332.52002 0.68 6.3199997 0.48000002; 0.84 243.92 8.360001 6.88; 11.6 7.72 176.43999 4.2400002; 0.4 4.92 6.08 188.6]
# ┌───────────┬────────┬───────────┬──────────┬───────┐
# │           │   Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼────────┼───────────┼──────────┼───────┤
# │      Good │ 332.52 │      0.68 │     6.32 │  0.48 │
# │ Hazardous │   0.84 │    243.92 │     8.36 │  6.88 │
# │  Moderate │   11.6 │      7.72 │   176.44 │  4.24 │
# │      Poor │    0.4 │      4.92 │     6.08 │ 188.6 │
# └───────────┴────────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN
#  Hyperparameters: Dict("topology" => [10, 8, 6, 4])
# =====================================================
#  Accuracy (mean)               : 0.9415
#  Accuracy (std)                : 0.0075
#  Error Rate (mean)             : 0.0585
#  Error Rate (std)              : 0.0075
#  Sensitivity/Recall (mean)     : 0.9415
#  Sensitivity/Recall (std)      : 0.0075
#  Specificity (mean)            : 0.9829
#  Specificity (std)             : 0.0016
#  PPV (mean)                    : 0.9385
#  PPV (std)                     : 0.0122
#  NPV (mean)                    : 0.9858
#  NPV (std)                     : 0.0015
#  F1 Score (mean)               : 0.9396
#  F1 Score (std)                : 0.0099
#
# Confusion Matrix:
# Float32[333.08002 0.48000002 5.9199996 0.52; 0.84 244.84 8.280001 6.04; 10.84 6.96 178.24 3.9599998; 0.35999998 8.280001 6.04 185.31999]
# ┌───────────┬────────┬───────────┬──────────┬────────┐
# │           │   Good │ Hazardous │ Moderate │   Poor │
# ├───────────┼────────┼───────────┼──────────┼────────┤
# │      Good │ 333.08 │      0.48 │     5.92 │   0.52 │
# │ Hazardous │   0.84 │    244.84 │     8.28 │   6.04 │
# │  Moderate │  10.84 │      6.96 │   178.24 │   3.96 │
# │      Poor │   0.36 │      8.28 │     6.04 │ 185.32 │
# └───────────┴────────┴───────────┴──────────┴────────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN
#  Hyperparameters: Dict("topology" => [10, 12, 6, 4])
# =====================================================
#  Accuracy (mean)               : 0.9448
#  Accuracy (std)                : 0.0069
#  Error Rate (mean)             : 0.0552
#  Error Rate (std)              : 0.0069
#  Sensitivity/Recall (mean)     : 0.9448
#  Sensitivity/Recall (std)      : 0.0069
#  Specificity (mean)            : 0.9838
#  Specificity (std)             : 0.0015
#  PPV (mean)                    : 0.9445
#  PPV (std)                     : 0.0067
#  NPV (mean)                    : 0.9862
#  NPV (std)                     : 0.0017
#  F1 Score (mean)               : 0.9444
#  F1 Score (std)                : 0.0068
#
# Confusion Matrix:
# Float32[333.0 0.56000006 5.88 0.56; 0.76 244.56001 8.08 6.6; 10.76 7.0 178.04001 4.2; 0.32 4.88 5.6400003 189.16]
# ┌───────────┬───────┬───────────┬──────────┬────────┐
# │           │  Good │ Hazardous │ Moderate │   Poor │
# ├───────────┼───────┼───────────┼──────────┼────────┤
# │      Good │ 333.0 │      0.56 │     5.88 │   0.56 │
# │ Hazardous │  0.76 │    244.56 │     8.08 │    6.6 │
# │  Moderate │ 10.76 │       7.0 │   178.04 │    4.2 │
# │      Poor │  0.32 │      4.88 │     5.64 │ 189.16 │
# └───────────┴───────┴───────────┴──────────┴────────┘
# =====================================================

# %% [markdown]
# # Support Vector Machines

# %%
SVMClassifier = MLJ.@load SVC pkg=LIBSVM verbosity=0
# Out:
# MLJLIBSVMInterface.SVC

# %%
############# 2. SVM (8+ configs: kernels × C) #############
default_svm = Dict(
    "gamma" => 1.0,
    "degree" => Int32(3),
    "coef0" => 0.0
)
svm_search_space = [
    Dict("kernel"=>"linear", "C"=>0.1),
    Dict("kernel"=>"linear", "C"=>1.0),
    Dict("kernel"=>"linear", "C"=>10.0),

    Dict("kernel"=>"rbf", "C"=>1.0, "gamma" => 2.0),
    Dict("kernel"=>"rbf", "C"=>10.0, "gamma" => 0.5),

    Dict("kernel"=>"sigmoid", "C"=>1.0, "gamma" => 1.0),

    Dict("kernel"=>"poly", "C"=>1.0, "degree" => 3, "gamma" => 1),
    Dict("kernel"=>"poly", "C"=>5.0, "degree" => 4, "gamma" => 0.5),
]
# Out:
# 8-element Vector{Dict{String, Any}}:
#  Dict("C" => 0.1, "kernel" => "linear")
#  Dict("C" => 1.0, "kernel" => "linear")
#  Dict("C" => 10.0, "kernel" => "linear")
#  Dict("C" => 1.0, "kernel" => "rbf", "gamma" => 2.0)
#  Dict("C" => 10.0, "kernel" => "rbf", "gamma" => 0.5)
#  Dict("C" => 1.0, "kernel" => "sigmoid", "gamma" => 1.0)
#  Dict("C" => 1.0, "kernel" => "poly", "gamma" => 1, "degree" => 3)
#  Dict("C" => 5.0, "kernel" => "poly", "gamma" => 0.5, "degree" => 4)

# %%
########################
# 2. SVM GRID SEARCH
########################
svm_results = []

for hp in svm_search_space
    println("\n=== SVM experiment: kernel=$(hp["kernel"]) C=$(get(hp,"C","-")) ===")
    full_hp = merge(default_svm, hp)
    res = modelCrossValidation(:SVC, full_hp, (inputs, targets), crossValidationIndices)
    push!(svm_results, (model=:SVC, hyperparams=hp, results=res))
end

results[:SVC] = svm_results
# Out:
# === SVM experiment: kernel=linear C=0.1 ===
#
# === SVM experiment: kernel=linear C=1.0 ===
#
# === SVM experiment: kernel=linear C=10.0 ===
#
# === SVM experiment: kernel=rbf C=1.0 ===
#
# === SVM experiment: kernel=rbf C=10.0 ===
#
# === SVM experiment: kernel=sigmoid C=1.0 ===
#
# === SVM experiment: kernel=poly C=1.0 ===
#
# === SVM experiment: kernel=poly C=5.0 ===
# 8-element Vector{Any}:
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 0.1, "kernel" => "linear"), results = ((0.9252f0, 0.0096020885f0), (0.0748f0, 0.009602084f0), (0.9252f0, 0.0096020885f0), (0.97350633f0, 0.0036459977f0), (0.9255888f0, 0.008998138f0), (0.98270977f0, 0.001990787f0), (0.92350817f0, 0.010069727f0), Float32[332.0 3.2 3.4 1.4; 0.2 241.8 9.8 8.2; 18.8 9.0 170.6 1.6; 2.0 6.8 10.4 180.8]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 1.0, "kernel" => "linear"), results = ((0.9374f0, 0.00572712f0), (0.0626f0, 0.005727128f0), (0.9374f0, 0.00572712f0), (0.9799453f0, 0.002152039f0), (0.93695223f0, 0.005510538f0), (0.98477143f0, 0.0015064947f0), (0.9366585f0, 0.005720074f0), Float32[333.4 1.0 5.4 0.2; 0.2 244.4 7.6 7.8; 15.6 8.0 173.4 3.0; 1.0 5.6 7.2 186.2]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 10.0, "kernel" => "linear"), results = ((0.94020003f0, 0.007085182f0), (0.0598f0, 0.0070851957f0), (0.94020003f0, 0.007085182f0), (0.98172456f0, 0.0019258524f0), (0.9397165f0, 0.007000149f0), (0.9850752f0, 0.0018060236f0), (0.9397174f0, 0.0070756273f0), Float32[332.4 1.0 6.4 0.2; 0.2 244.4 8.0 7.4; 13.2 7.8 175.8 3.2; 0.8 5.2 6.4 187.6]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 1.0, "kernel" => "rbf", "gamma" => 2.0), results = ((0.945f0, 0.006324549f0), (0.055f0, 0.006324555f0), (0.945f0, 0.006324549f0), (0.983123f0, 0.0012358899f0), (0.9445696f0, 0.006332185f0), (0.98680705f0, 0.0017788878f0), (0.94443214f0, 0.0062377756f0), Float32[334.6 0.6 4.6 0.2; 0.2 244.8 7.8 7.2; 13.4 7.0 176.2 3.4; 0.4 4.2 6.0 189.4]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 10.0, "kernel" => "rbf", "gamma" => 0.5), results = ((0.9436f0, 0.008324669f0), (0.0564f0, 0.008324661f0), (0.9436f0, 0.008324669f0), (0.9828722f0, 0.0017424604f0), (0.9431368f0, 0.008351876f0), (0.9862714f0, 0.0019030571f0), (0.9430677f0, 0.008295308f0), Float32[334.0 0.8 5.0 0.2; 0.2 244.6 8.2 7.0; 13.2 8.0 175.4 3.4; 0.4 4.2 5.8 189.6]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 1.0, "kernel" => "sigmoid", "gamma" => 1.0), results = ((0.5644f0, 0.0070213987f0), (0.43559998f0, 0.0070213964f0), (0.5644f0, 0.0070213987f0), (0.82825077f0, 0.0063082557f0), (0.48348936f0, 0.01013217f0), (0.86071986f0, 0.00541119f0), (0.50882685f0, 0.008228862f0), Float32[273.4 15.6 9.4 41.6; 38.8 137.4 37.8 46.0; 118.0 2.6 43.0 36.4; 53.8 7.6 28.0 110.6]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 1.0, "kernel" => "poly", "gamma" => 1, "degree" => 3), results = ((0.93780005f0, 0.0066482886f0), (0.062200002f0, 0.0066483086f0), (0.93780005f0, 0.0066482886f0), (0.97984684f0, 0.0018297349f0), (0.9371225f0, 0.0067412723f0), (0.9846138f0, 0.0019072151f0), (0.9370841f0, 0.0066035124f0), Float32[333.4 1.2 5.2 0.2; 0.2 243.6 8.6 7.6; 15.8 8.0 173.2 3.0; 1.2 4.6 6.6 187.6]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 5.0, "kernel" => "poly", "gamma" => 0.5, "degree" => 4), results = ((0.9312f0, 0.003962313f0), (0.0688f0, 0.0039623226f0), (0.9312f0, 0.003962313f0), (0.9752247f0, 0.0013001248f0), (0.9303297f0, 0.0040614516f0), (0.982052f0, 0.00085123355f0), (0.9303177f0, 0.003890932f0), Float32[329.8 4.6 4.6 1.0; 0.2 243.4 8.4 8.0; 18.2 7.2 171.6 3.0; 2.0 4.8 6.8 186.4]))

# %%
for entry in results[:SVC]
    printExperimentResult(entry.model, entry.hyperparams, entry.results, label_names)
end
# Out:
# =====================================================
#  Model: SVC
#  Hyperparameters: Dict{String, Any}("C" => 0.1, "kernel" => "linear")
# =====================================================
#  Accuracy (mean)               : 0.9252
#  Accuracy (std)                : 0.0096
#  Error Rate (mean)             : 0.0748
#  Error Rate (std)              : 0.0096
#  Sensitivity/Recall (mean)     : 0.9252
#  Sensitivity/Recall (std)      : 0.0096
#  Specificity (mean)            : 0.9735
#  Specificity (std)             : 0.0036
#  PPV (mean)                    : 0.9256
#  PPV (std)                     : 0.009
#  NPV (mean)                    : 0.9827
#  NPV (std)                     : 0.002
#  F1 Score (mean)               : 0.9235
#  F1 Score (std)                : 0.0101
#
# Confusion Matrix:
# Float32[332.0 3.2 3.4 1.4; 0.2 241.8 9.8 8.2; 18.8 9.0 170.6 1.6; 2.0 6.8 10.4 180.8]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 332.0 │       3.2 │      3.4 │   1.4 │
# │ Hazardous │   0.2 │     241.8 │      9.8 │   8.2 │
# │  Moderate │  18.8 │       9.0 │    170.6 │   1.6 │
# │      Poor │   2.0 │       6.8 │     10.4 │ 180.8 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC
#  Hyperparameters: Dict{String, Any}("C" => 1.0, "kernel" => "linear")
# =====================================================
#  Accuracy (mean)               : 0.9374
#  Accuracy (std)                : 0.0057
#  Error Rate (mean)             : 0.0626
#  Error Rate (std)              : 0.0057
#  Sensitivity/Recall (mean)     : 0.9374
#  Sensitivity/Recall (std)      : 0.0057
#  Specificity (mean)            : 0.9799
#  Specificity (std)             : 0.0022
#  PPV (mean)                    : 0.937
#  PPV (std)                     : 0.0055
#  NPV (mean)                    : 0.9848
#  NPV (std)                     : 0.0015
#  F1 Score (mean)               : 0.9367
#  F1 Score (std)                : 0.0057
#
# Confusion Matrix:
# Float32[333.4 1.0 5.4 0.2; 0.2 244.4 7.6 7.8; 15.6 8.0 173.4 3.0; 1.0 5.6 7.2 186.2]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 333.4 │       1.0 │      5.4 │   0.2 │
# │ Hazardous │   0.2 │     244.4 │      7.6 │   7.8 │
# │  Moderate │  15.6 │       8.0 │    173.4 │   3.0 │
# │      Poor │   1.0 │       5.6 │      7.2 │ 186.2 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC
#  Hyperparameters: Dict{String, Any}("C" => 10.0, "kernel" => "linear")
# =====================================================
#  Accuracy (mean)               : 0.9402
#  Accuracy (std)                : 0.0071
#  Error Rate (mean)             : 0.0598
#  Error Rate (std)              : 0.0071
#  Sensitivity/Recall (mean)     : 0.9402
#  Sensitivity/Recall (std)      : 0.0071
#  Specificity (mean)            : 0.9817
#  Specificity (std)             : 0.0019
#  PPV (mean)                    : 0.9397
#  PPV (std)                     : 0.007
#  NPV (mean)                    : 0.9851
#  NPV (std)                     : 0.0018
#  F1 Score (mean)               : 0.9397
#  F1 Score (std)                : 0.0071
#
# Confusion Matrix:
# Float32[332.4 1.0 6.4 0.2; 0.2 244.4 8.0 7.4; 13.2 7.8 175.8 3.2; 0.8 5.2 6.4 187.6]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 332.4 │       1.0 │      6.4 │   0.2 │
# │ Hazardous │   0.2 │     244.4 │      8.0 │   7.4 │
# │  Moderate │  13.2 │       7.8 │    175.8 │   3.2 │
# │      Poor │   0.8 │       5.2 │      6.4 │ 187.6 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC
#  Hyperparameters: Dict{String, Any}("C" => 1.0, "kernel" => "rbf", "gamma" => 2.0)
# =====================================================
#  Accuracy (mean)               : 0.945
#  Accuracy (std)                : 0.0063
#  Error Rate (mean)             : 0.055
#  Error Rate (std)              : 0.0063
#  Sensitivity/Recall (mean)     : 0.945
#  Sensitivity/Recall (std)      : 0.0063
#  Specificity (mean)            : 0.9831
#  Specificity (std)             : 0.0012
#  PPV (mean)                    : 0.9446
#  PPV (std)                     : 0.0063
#  NPV (mean)                    : 0.9868
#  NPV (std)                     : 0.0018
#  F1 Score (mean)               : 0.9444
#  F1 Score (std)                : 0.0062
#
# Confusion Matrix:
# Float32[334.6 0.6 4.6 0.2; 0.2 244.8 7.8 7.2; 13.4 7.0 176.2 3.4; 0.4 4.2 6.0 189.4]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 334.6 │       0.6 │      4.6 │   0.2 │
# │ Hazardous │   0.2 │     244.8 │      7.8 │   7.2 │
# │  Moderate │  13.4 │       7.0 │    176.2 │   3.4 │
# │      Poor │   0.4 │       4.2 │      6.0 │ 189.4 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC
#  Hyperparameters: Dict{String, Any}("C" => 10.0, "kernel" => "rbf", "gamma" => 0.5)
# =====================================================
#  Accuracy (mean)               : 0.9436
#  Accuracy (std)                : 0.0083
#  Error Rate (mean)             : 0.0564
#  Error Rate (std)              : 0.0083
#  Sensitivity/Recall (mean)     : 0.9436
#  Sensitivity/Recall (std)      : 0.0083
#  Specificity (mean)            : 0.9829
#  Specificity (std)             : 0.0017
#  PPV (mean)                    : 0.9431
#  PPV (std)                     : 0.0084
#  NPV (mean)                    : 0.9863
#  NPV (std)                     : 0.0019
#  F1 Score (mean)               : 0.9431
#  F1 Score (std)                : 0.0083
#
# Confusion Matrix:
# Float32[334.0 0.8 5.0 0.2; 0.2 244.6 8.2 7.0; 13.2 8.0 175.4 3.4; 0.4 4.2 5.8 189.6]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 334.0 │       0.8 │      5.0 │   0.2 │
# │ Hazardous │   0.2 │     244.6 │      8.2 │   7.0 │
# │  Moderate │  13.2 │       8.0 │    175.4 │   3.4 │
# │      Poor │   0.4 │       4.2 │      5.8 │ 189.6 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC
#  Hyperparameters: Dict{String, Any}("C" => 1.0, "kernel" => "sigmoid", "gamma" => 1.0)
# =====================================================
#  Accuracy (mean)               : 0.5644
#  Accuracy (std)                : 0.007
#  Error Rate (mean)             : 0.4356
#  Error Rate (std)              : 0.007
#  Sensitivity/Recall (mean)     : 0.5644
#  Sensitivity/Recall (std)      : 0.007
#  Specificity (mean)            : 0.8283
#  Specificity (std)             : 0.0063
#  PPV (mean)                    : 0.4835
#  PPV (std)                     : 0.0101
#  NPV (mean)                    : 0.8607
#  NPV (std)                     : 0.0054
#  F1 Score (mean)               : 0.5088
#  F1 Score (std)                : 0.0082
#
# Confusion Matrix:
# Float32[273.4 15.6 9.4 41.6; 38.8 137.4 37.8 46.0; 118.0 2.6 43.0 36.4; 53.8 7.6 28.0 110.6]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 273.4 │      15.6 │      9.4 │  41.6 │
# │ Hazardous │  38.8 │     137.4 │     37.8 │  46.0 │
# │  Moderate │ 118.0 │       2.6 │     43.0 │  36.4 │
# │      Poor │  53.8 │       7.6 │     28.0 │ 110.6 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC
#  Hyperparameters: Dict{String, Any}("C" => 1.0, "kernel" => "poly", "gamma" => 1, "degree" => 3)
# =====================================================
#  Accuracy (mean)               : 0.9378
#  Accuracy (std)                : 0.0066
#  Error Rate (mean)             : 0.0622
#  Error Rate (std)              : 0.0066
#  Sensitivity/Recall (mean)     : 0.9378
#  Sensitivity/Recall (std)      : 0.0066
#  Specificity (mean)            : 0.9798
#  Specificity (std)             : 0.0018
#  PPV (mean)                    : 0.9371
#  PPV (std)                     : 0.0067
#  NPV (mean)                    : 0.9846
#  NPV (std)                     : 0.0019
#  F1 Score (mean)               : 0.9371
#  F1 Score (std)                : 0.0066
#
# Confusion Matrix:
# Float32[333.4 1.2 5.2 0.2; 0.2 243.6 8.6 7.6; 15.8 8.0 173.2 3.0; 1.2 4.6 6.6 187.6]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 333.4 │       1.2 │      5.2 │   0.2 │
# │ Hazardous │   0.2 │     243.6 │      8.6 │   7.6 │
# │  Moderate │  15.8 │       8.0 │    173.2 │   3.0 │
# │      Poor │   1.2 │       4.6 │      6.6 │ 187.6 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC
#  Hyperparameters: Dict{String, Any}("C" => 5.0, "kernel" => "poly", "gamma" => 0.5, "degree" => 4)
# =====================================================
#  Accuracy (mean)               : 0.9312
#  Accuracy (std)                : 0.004
#  Error Rate (mean)             : 0.0688
#  Error Rate (std)              : 0.004
#  Sensitivity/Recall (mean)     : 0.9312
#  Sensitivity/Recall (std)      : 0.004
#  Specificity (mean)            : 0.9752
#  Specificity (std)             : 0.0013
#  PPV (mean)                    : 0.9303
#  PPV (std)                     : 0.0041
#  NPV (mean)                    : 0.9821
#  NPV (std)                     : 0.0009
#  F1 Score (mean)               : 0.9303
#  F1 Score (std)                : 0.0039
#
# Confusion Matrix:
# Float32[329.8 4.6 4.6 1.0; 0.2 243.4 8.4 8.0; 18.2 7.2 171.6 3.0; 2.0 4.8 6.8 186.4]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 329.8 │       4.6 │      4.6 │   1.0 │
# │ Hazardous │   0.2 │     243.4 │      8.4 │   8.0 │
# │  Moderate │  18.2 │       7.2 │    171.6 │   3.0 │
# │      Poor │   2.0 │       4.8 │      6.8 │ 186.4 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================

# %% [markdown]
# # Decission Trees

# %%
DTClassifier = MLJ.@load DecisionTreeClassifier pkg=DecisionTree verbosity=0
# Out:
# MLJDecisionTreeInterface.DecisionTreeClassifier

# %%
############# 3. DECISION TREES (6 depths) #############
default_dt = Dict(
    "rng" => Random.MersenneTwister(1)
)

dt_search_space = [
    Dict("max_depth"=>2),
    Dict("max_depth"=>3),
    Dict("max_depth"=>4),
    Dict("max_depth"=>5),
    Dict("max_depth"=>6),
    Dict("max_depth"=>8)
]
# Out:
# 6-element Vector{Dict{String, Int64}}:
#  Dict("max_depth" => 2)
#  Dict("max_depth" => 3)
#  Dict("max_depth" => 4)
#  Dict("max_depth" => 5)
#  Dict("max_depth" => 6)
#  Dict("max_depth" => 8)

# %%
########################
# 3. DECISION TREE GRID SEARCH
########################
dt_results = []

for hp in dt_search_space
    println("\n=== Decision Tree experiment: max_depth=$(hp["max_depth"]) ===")
    full_hp = merge(default_dt, hp) 
    res = modelCrossValidation(:DecisionTreeClassifier, full_hp, (inputs, targets), crossValidationIndices)
    push!(dt_results, (model=:DT, hyperparams=hp, results=res))
end

results[:DT] = dt_results
# Out:
# === Decision Tree experiment: max_depth=2 ===
#
# === Decision Tree experiment: max_depth=3 ===
#
# === Decision Tree experiment: max_depth=4 ===
#
# === Decision Tree experiment: max_depth=5 ===
#
# === Decision Tree experiment: max_depth=6 ===
#
# === Decision Tree experiment: max_depth=8 ===
# 6-element Vector{Any}:
#  (model = :DT, hyperparams = Dict("max_depth" => 2), results = ((0.8222f0, 0.0045497343f0), (0.1778f0, 0.0045497245f0), (0.8222f0, 0.0045497343f0), (0.9438714f0, 0.0021794732f0), (0.7564937f0, 0.004453325f0), (0.96373355f0, 0.0021378451f0), (0.7859414f0, 0.0045425417f0), Float32[325.0 0.6 12.6 1.8; 1.8 216.4 31.0 10.8; 32.2 22.2 144.8 0.8; 0.8 22.6 40.6 136.0]))
#  (model = :DT, hyperparams = Dict("max_depth" => 3), results = ((0.8837999f0, 0.0050695124f0), (0.11619999f0, 0.005069519f0), (0.8837999f0, 0.0050695124f0), (0.96868813f0, 0.0024017014f0), (0.8834666f0, 0.0053703277f0), (0.97072375f0, 0.0022297632f0), (0.88238287f0, 0.005320001f0), Float32[325.0 0.6 12.6 1.8; 1.2 227.0 18.8 13.0; 14.8 17.8 158.6 8.8; 0.6 10.0 16.2 173.2]))
#  (model = :DT, hyperparams = Dict("max_depth" => 4), results = ((0.8948f0, 0.00831866f0), (0.10520001f0, 0.008318653f0), (0.8948f0, 0.00831866f0), (0.97100556f0, 0.0038301658f0), (0.8956172f0, 0.008752802f0), (0.9716833f0, 0.0023273032f0), (0.8939028f0, 0.008538467f0), Float32[324.4 0.4 12.6 2.6; 2.0 232.8 16.2 9.0; 14.8 16.6 160.0 8.6; 0.6 11.8 10.0 177.6]))
#  (model = :DT, hyperparams = Dict("max_depth" => 5), results = ((0.90620005f0, 0.010894959f0), (0.0938f0, 0.010894955f0), (0.90620005f0, 0.010894959f0), (0.97245073f0, 0.00340258f0), (0.9105817f0, 0.012339629f0), (0.9761984f0, 0.003914491f0), (0.90488976f0, 0.011196614f0), Float32[325.2 0.2 13.0 1.6; 2.0 235.4 13.8 8.8; 11.8 13.6 171.0 3.6; 0.6 10.4 14.4 174.6]))
#  (model = :DT, hyperparams = Dict("max_depth" => 6), results = ((0.91380006f0, 0.01013412f0), (0.0862f0, 0.0101341f0), (0.91380006f0, 0.01013412f0), (0.97593814f0, 0.0045344057f0), (0.9145905f0, 0.010623339f0), (0.9768938f0, 0.0020045391f0), (0.9138075f0, 0.010630213f0), Float32[324.8 1.2 13.2 0.8; 0.8 239.0 10.8 9.4; 9.4 15.2 168.8 6.6; 1.2 8.2 9.4 181.2]))
#  (model = :DT, hyperparams = Dict("max_depth" => 8), results = ((0.925f0, 0.012609518f0), (0.075f0, 0.012609521f0), (0.925f0, 0.012609518f0), (0.9785f0, 0.0037787317f0), (0.9240286f0, 0.013068273f0), (0.98174125f0, 0.0025503f0), (0.9240104f0, 0.012855916f0), Float32[333.8 0.2 5.0 1.0; 0.8 238.6 10.8 9.8; 14.2 11.0 166.2 8.6; 0.8 4.6 8.2 186.4]))

# %%
for entry in results[:DT]
    printExperimentResult(entry.model, entry.hyperparams, entry.results, label_names)
end
# Out:
# =====================================================
#  Model: DT
#  Hyperparameters: Dict("max_depth" => 2)
# =====================================================
#  Accuracy (mean)               : 0.8222
#  Accuracy (std)                : 0.0045
#  Error Rate (mean)             : 0.1778
#  Error Rate (std)              : 0.0045
#  Sensitivity/Recall (mean)     : 0.8222
#  Sensitivity/Recall (std)      : 0.0045
#  Specificity (mean)            : 0.9439
#  Specificity (std)             : 0.0022
#  PPV (mean)                    : 0.7565
#  PPV (std)                     : 0.0045
#  NPV (mean)                    : 0.9637
#  NPV (std)                     : 0.0021
#  F1 Score (mean)               : 0.7859
#  F1 Score (std)                : 0.0045
#
# Confusion Matrix:
# Float32[325.0 0.6 12.6 1.8; 1.8 216.4 31.0 10.8; 32.2 22.2 144.8 0.8; 0.8 22.6 40.6 136.0]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 325.0 │       0.6 │     12.6 │   1.8 │
# │ Hazardous │   1.8 │     216.4 │     31.0 │  10.8 │
# │  Moderate │  32.2 │      22.2 │    144.8 │   0.8 │
# │      Poor │   0.8 │      22.6 │     40.6 │ 136.0 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: DT
#  Hyperparameters: Dict("max_depth" => 3)
# =====================================================
#  Accuracy (mean)               : 0.8838
#  Accuracy (std)                : 0.0051
#  Error Rate (mean)             : 0.1162
#  Error Rate (std)              : 0.0051
#  Sensitivity/Recall (mean)     : 0.8838
#  Sensitivity/Recall (std)      : 0.0051
#  Specificity (mean)            : 0.9687
#  Specificity (std)             : 0.0024
#  PPV (mean)                    : 0.8835
#  PPV (std)                     : 0.0054
#  NPV (mean)                    : 0.9707
#  NPV (std)                     : 0.0022
#  F1 Score (mean)               : 0.8824
#  F1 Score (std)                : 0.0053
#
# Confusion Matrix:
# Float32[325.0 0.6 12.6 1.8; 1.2 227.0 18.8 13.0; 14.8 17.8 158.6 8.8; 0.6 10.0 16.2 173.2]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 325.0 │       0.6 │     12.6 │   1.8 │
# │ Hazardous │   1.2 │     227.0 │     18.8 │  13.0 │
# │  Moderate │  14.8 │      17.8 │    158.6 │   8.8 │
# │      Poor │   0.6 │      10.0 │     16.2 │ 173.2 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: DT
#  Hyperparameters: Dict("max_depth" => 4)
# =====================================================
#  Accuracy (mean)               : 0.8948
#  Accuracy (std)                : 0.0083
#  Error Rate (mean)             : 0.1052
#  Error Rate (std)              : 0.0083
#  Sensitivity/Recall (mean)     : 0.8948
#  Sensitivity/Recall (std)      : 0.0083
#  Specificity (mean)            : 0.971
#  Specificity (std)             : 0.0038
#  PPV (mean)                    : 0.8956
#  PPV (std)                     : 0.0088
#  NPV (mean)                    : 0.9717
#  NPV (std)                     : 0.0023
#  F1 Score (mean)               : 0.8939
#  F1 Score (std)                : 0.0085
#
# Confusion Matrix:
# Float32[324.4 0.4 12.6 2.6; 2.0 232.8 16.2 9.0; 14.8 16.6 160.0 8.6; 0.6 11.8 10.0 177.6]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 324.4 │       0.4 │     12.6 │   2.6 │
# │ Hazardous │   2.0 │     232.8 │     16.2 │   9.0 │
# │  Moderate │  14.8 │      16.6 │    160.0 │   8.6 │
# │      Poor │   0.6 │      11.8 │     10.0 │ 177.6 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: DT
#  Hyperparameters: Dict("max_depth" => 5)
# =====================================================
#  Accuracy (mean)               : 0.9062
#  Accuracy (std)                : 0.0109
#  Error Rate (mean)             : 0.0938
#  Error Rate (std)              : 0.0109
#  Sensitivity/Recall (mean)     : 0.9062
#  Sensitivity/Recall (std)      : 0.0109
#  Specificity (mean)            : 0.9725
#  Specificity (std)             : 0.0034
#  PPV (mean)                    : 0.9106
#  PPV (std)                     : 0.0123
#  NPV (mean)                    : 0.9762
#  NPV (std)                     : 0.0039
#  F1 Score (mean)               : 0.9049
#  F1 Score (std)                : 0.0112
#
# Confusion Matrix:
# Float32[325.2 0.2 13.0 1.6; 2.0 235.4 13.8 8.8; 11.8 13.6 171.0 3.6; 0.6 10.4 14.4 174.6]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 325.2 │       0.2 │     13.0 │   1.6 │
# │ Hazardous │   2.0 │     235.4 │     13.8 │   8.8 │
# │  Moderate │  11.8 │      13.6 │    171.0 │   3.6 │
# │      Poor │   0.6 │      10.4 │     14.4 │ 174.6 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: DT
#  Hyperparameters: Dict("max_depth" => 6)
# =====================================================
#  Accuracy (mean)               : 0.9138
#  Accuracy (std)                : 0.0101
#  Error Rate (mean)             : 0.0862
#  Error Rate (std)              : 0.0101
#  Sensitivity/Recall (mean)     : 0.9138
#  Sensitivity/Recall (std)      : 0.0101
#  Specificity (mean)            : 0.9759
#  Specificity (std)             : 0.0045
#  PPV (mean)                    : 0.9146
#  PPV (std)                     : 0.0106
#  NPV (mean)                    : 0.9769
#  NPV (std)                     : 0.002
#  F1 Score (mean)               : 0.9138
#  F1 Score (std)                : 0.0106
#
# Confusion Matrix:
# Float32[324.8 1.2 13.2 0.8; 0.8 239.0 10.8 9.4; 9.4 15.2 168.8 6.6; 1.2 8.2 9.4 181.2]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 324.8 │       1.2 │     13.2 │   0.8 │
# │ Hazardous │   0.8 │     239.0 │     10.8 │   9.4 │
# │  Moderate │   9.4 │      15.2 │    168.8 │   6.6 │
# │      Poor │   1.2 │       8.2 │      9.4 │ 181.2 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: DT
#  Hyperparameters: Dict("max_depth" => 8)
# =====================================================
#  Accuracy (mean)               : 0.925
#  Accuracy (std)                : 0.0126
#  Error Rate (mean)             : 0.075
#  Error Rate (std)              : 0.0126
#  Sensitivity/Recall (mean)     : 0.925
#  Sensitivity/Recall (std)      : 0.0126
#  Specificity (mean)            : 0.9785
#  Specificity (std)             : 0.0038
#  PPV (mean)                    : 0.924
#  PPV (std)                     : 0.0131
#  NPV (mean)                    : 0.9817
#  NPV (std)                     : 0.0026
#  F1 Score (mean)               : 0.924
#  F1 Score (std)                : 0.0129
#
# Confusion Matrix:
# Float32[333.8 0.2 5.0 1.0; 0.8 238.6 10.8 9.8; 14.2 11.0 166.2 8.6; 0.8 4.6 8.2 186.4]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 333.8 │       0.2 │      5.0 │   1.0 │
# │ Hazardous │   0.8 │     238.6 │     10.8 │   9.8 │
# │  Moderate │  14.2 │      11.0 │    166.2 │   8.6 │
# │      Poor │   0.8 │       4.6 │      8.2 │ 186.4 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================

# %% [markdown]
# # K-Nearest Neighbors

# %%
kNNClassifier = MLJ.@load KNNClassifier pkg=NearestNeighborModels verbosity=0
# Out:
# NearestNeighborModels.KNNClassifier

# %%
############# 4. kNN (6 values) #############
knn_search_space = [
    Dict("K"=>1),
    Dict("K"=>3),
    Dict("K"=>5),
    Dict("K"=>7),
    Dict("K"=>9),
    Dict("K"=>11)
]
# Out:
# 6-element Vector{Dict{String, Int64}}:
#  Dict("K" => 1)
#  Dict("K" => 3)
#  Dict("K" => 5)
#  Dict("K" => 7)
#  Dict("K" => 9)
#  Dict("K" => 11)

# %%
########################
# 4. KNN GRID SEARCH
########################
knn_results = []

for hp in knn_search_space
    println("\n=== kNN experiment: K=$(hp["K"]) ===")
    res = modelCrossValidation(:KNeighborsClassifier, hp, (inputs, targets), crossValidationIndices)
    push!(knn_results, (model=:KNN, hyperparams=hp, results=res))
end

results[:KNN] = knn_results
# Out:
# === kNN experiment: K=1 ===
#
# === kNN experiment: K=3 ===
#
# === kNN experiment: K=5 ===
#
# === kNN experiment: K=7 ===
#
# === kNN experiment: K=9 ===
#
# === kNN experiment: K=11 ===
# 6-element Vector{Any}:
#  (model = :KNN, hyperparams = Dict("K" => 1), results = ((0.9122f0, 0.0056745023f0), (0.0878f0, 0.0056745037f0), (0.9122f0, 0.0056745023f0), (0.97318095f0, 0.0014626426f0), (0.9104317f0, 0.005780211f0), (0.97883034f0, 0.0013779422f0), (0.9107488f0, 0.0059098597f0), Float32[330.8 1.2 6.2 1.8; 0.2 238.6 13.0 8.2; 19.0 11.6 162.4 7.0; 1.0 7.8 10.8 180.4]))
#  (model = :KNN, hyperparams = Dict("K" => 3), results = ((0.92399997f0, 0.0075166505f0), (0.076f0, 0.0075166477f0), (0.92399997f0, 0.0075166505f0), (0.9755238f0, 0.0017911857f0), (0.92290366f0, 0.0071387487f0), (0.98230803f0, 0.0011934639f0), (0.9225222f0, 0.007936818f0), Float32[332.6 1.0 4.4 2.0; 0.2 241.4 10.0 8.4; 18.4 9.6 167.2 4.8; 1.0 6.0 10.2 182.8]))
#  (model = :KNN, hyperparams = Dict("K" => 5), results = ((0.92840004f0, 0.007956126f0), (0.0716f0, 0.0079561295f0), (0.92840004f0, 0.007956126f0), (0.9760127f0, 0.002605206f0), (0.92752886f0, 0.007603931f0), (0.98378193f0, 0.0013056949f0), (0.92684996f0, 0.008474432f0), Float32[334.2 1.6 2.6 1.6; 0.2 240.8 9.6 9.4; 18.0 9.6 169.4 3.0; 0.8 5.8 9.4 184.0]))
#  (model = :KNN, hyperparams = Dict("K" => 7), results = ((0.9302f0, 0.005761945f0), (0.0698f0, 0.0057619438f0), (0.9302f0, 0.005761945f0), (0.97635955f0, 0.0015427754f0), (0.9294324f0, 0.005841935f0), (0.98428935f0, 0.0013044842f0), (0.92873067f0, 0.0059564034f0), Float32[334.6 1.4 2.4 1.6; 0.0 241.6 10.4 8.0; 18.4 8.4 170.6 2.6; 1.0 5.8 9.8 183.4]))
#  (model = :KNN, hyperparams = Dict("K" => 9), results = ((0.9274f0, 0.004979962f0), (0.07259999f0, 0.0049799606f0), (0.9274f0, 0.004979962f0), (0.97503644f0, 0.0014321342f0), (0.9268789f0, 0.0046470677f0), (0.9837483f0, 0.001051754f0), (0.9257247f0, 0.005188086f0), Float32[334.0 2.2 2.2 1.6; 0.0 241.4 10.6 8.0; 19.6 8.8 169.2 2.4; 1.0 6.2 10.0 182.8]))
#  (model = :KNN, hyperparams = Dict("K" => 11), results = ((0.92700005f0, 0.004062033f0), (0.073f0, 0.004062018f0), (0.92700005f0, 0.004062033f0), (0.97507143f0, 0.0012966313f0), (0.9264598f0, 0.003666201f0), (0.98375684f0, 0.0008189011f0), (0.9252621f0, 0.004263357f0), Float32[334.2 2.0 2.2 1.6; 0.0 240.4 11.4 8.2; 18.8 8.2 170.2 2.8; 1.0 6.4 10.4 182.2]))

# %%
for entry in results[:KNN]
    printExperimentResult(entry.model, entry.hyperparams, entry.results, label_names)
end
# Out:
# =====================================================
#  Model: KNN
#  Hyperparameters: Dict("K" => 1)
# =====================================================
#  Accuracy (mean)               : 0.9122
#  Accuracy (std)                : 0.0057
#  Error Rate (mean)             : 0.0878
#  Error Rate (std)              : 0.0057
#  Sensitivity/Recall (mean)     : 0.9122
#  Sensitivity/Recall (std)      : 0.0057
#  Specificity (mean)            : 0.9732
#  Specificity (std)             : 0.0015
#  PPV (mean)                    : 0.9104
#  PPV (std)                     : 0.0058
#  NPV (mean)                    : 0.9788
#  NPV (std)                     : 0.0014
#  F1 Score (mean)               : 0.9107
#  F1 Score (std)                : 0.0059
#
# Confusion Matrix:
# Float32[330.8 1.2 6.2 1.8; 0.2 238.6 13.0 8.2; 19.0 11.6 162.4 7.0; 1.0 7.8 10.8 180.4]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 330.8 │       1.2 │      6.2 │   1.8 │
# │ Hazardous │   0.2 │     238.6 │     13.0 │   8.2 │
# │  Moderate │  19.0 │      11.6 │    162.4 │   7.0 │
# │      Poor │   1.0 │       7.8 │     10.8 │ 180.4 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN
#  Hyperparameters: Dict("K" => 3)
# =====================================================
#  Accuracy (mean)               : 0.924
#  Accuracy (std)                : 0.0075
#  Error Rate (mean)             : 0.076
#  Error Rate (std)              : 0.0075
#  Sensitivity/Recall (mean)     : 0.924
#  Sensitivity/Recall (std)      : 0.0075
#  Specificity (mean)            : 0.9755
#  Specificity (std)             : 0.0018
#  PPV (mean)                    : 0.9229
#  PPV (std)                     : 0.0071
#  NPV (mean)                    : 0.9823
#  NPV (std)                     : 0.0012
#  F1 Score (mean)               : 0.9225
#  F1 Score (std)                : 0.0079
#
# Confusion Matrix:
# Float32[332.6 1.0 4.4 2.0; 0.2 241.4 10.0 8.4; 18.4 9.6 167.2 4.8; 1.0 6.0 10.2 182.8]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 332.6 │       1.0 │      4.4 │   2.0 │
# │ Hazardous │   0.2 │     241.4 │     10.0 │   8.4 │
# │  Moderate │  18.4 │       9.6 │    167.2 │   4.8 │
# │      Poor │   1.0 │       6.0 │     10.2 │ 182.8 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN
#  Hyperparameters: Dict("K" => 5)
# =====================================================
#  Accuracy (mean)               : 0.9284
#  Accuracy (std)                : 0.008
#  Error Rate (mean)             : 0.0716
#  Error Rate (std)              : 0.008
#  Sensitivity/Recall (mean)     : 0.9284
#  Sensitivity/Recall (std)      : 0.008
#  Specificity (mean)            : 0.976
#  Specificity (std)             : 0.0026
#  PPV (mean)                    : 0.9275
#  PPV (std)                     : 0.0076
#  NPV (mean)                    : 0.9838
#  NPV (std)                     : 0.0013
#  F1 Score (mean)               : 0.9268
#  F1 Score (std)                : 0.0085
#
# Confusion Matrix:
# Float32[334.2 1.6 2.6 1.6; 0.2 240.8 9.6 9.4; 18.0 9.6 169.4 3.0; 0.8 5.8 9.4 184.0]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 334.2 │       1.6 │      2.6 │   1.6 │
# │ Hazardous │   0.2 │     240.8 │      9.6 │   9.4 │
# │  Moderate │  18.0 │       9.6 │    169.4 │   3.0 │
# │      Poor │   0.8 │       5.8 │      9.4 │ 184.0 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN
#  Hyperparameters: Dict("K" => 7)
# =====================================================
#  Accuracy (mean)               : 0.9302
#  Accuracy (std)                : 0.0058
#  Error Rate (mean)             : 0.0698
#  Error Rate (std)              : 0.0058
#  Sensitivity/Recall (mean)     : 0.9302
#  Sensitivity/Recall (std)      : 0.0058
#  Specificity (mean)            : 0.9764
#  Specificity (std)             : 0.0015
#  PPV (mean)                    : 0.9294
#  PPV (std)                     : 0.0058
#  NPV (mean)                    : 0.9843
#  NPV (std)                     : 0.0013
#  F1 Score (mean)               : 0.9287
#  F1 Score (std)                : 0.006
#
# Confusion Matrix:
# Float32[334.6 1.4 2.4 1.6; 0.0 241.6 10.4 8.0; 18.4 8.4 170.6 2.6; 1.0 5.8 9.8 183.4]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 334.6 │       1.4 │      2.4 │   1.6 │
# │ Hazardous │   0.0 │     241.6 │     10.4 │   8.0 │
# │  Moderate │  18.4 │       8.4 │    170.6 │   2.6 │
# │      Poor │   1.0 │       5.8 │      9.8 │ 183.4 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN
#  Hyperparameters: Dict("K" => 9)
# =====================================================
#  Accuracy (mean)               : 0.9274
#  Accuracy (std)                : 0.005
#  Error Rate (mean)             : 0.0726
#  Error Rate (std)              : 0.005
#  Sensitivity/Recall (mean)     : 0.9274
#  Sensitivity/Recall (std)      : 0.005
#  Specificity (mean)            : 0.975
#  Specificity (std)             : 0.0014
#  PPV (mean)                    : 0.9269
#  PPV (std)                     : 0.0046
#  NPV (mean)                    : 0.9837
#  NPV (std)                     : 0.0011
#  F1 Score (mean)               : 0.9257
#  F1 Score (std)                : 0.0052
#
# Confusion Matrix:
# Float32[334.0 2.2 2.2 1.6; 0.0 241.4 10.6 8.0; 19.6 8.8 169.2 2.4; 1.0 6.2 10.0 182.8]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 334.0 │       2.2 │      2.2 │   1.6 │
# │ Hazardous │   0.0 │     241.4 │     10.6 │   8.0 │
# │  Moderate │  19.6 │       8.8 │    169.2 │   2.4 │
# │      Poor │   1.0 │       6.2 │     10.0 │ 182.8 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN
#  Hyperparameters: Dict("K" => 11)
# =====================================================
#  Accuracy (mean)               : 0.927
#  Accuracy (std)                : 0.0041
#  Error Rate (mean)             : 0.073
#  Error Rate (std)              : 0.0041
#  Sensitivity/Recall (mean)     : 0.927
#  Sensitivity/Recall (std)      : 0.0041
#  Specificity (mean)            : 0.9751
#  Specificity (std)             : 0.0013
#  PPV (mean)                    : 0.9265
#  PPV (std)                     : 0.0037
#  NPV (mean)                    : 0.9838
#  NPV (std)                     : 0.0008
#  F1 Score (mean)               : 0.9253
#  F1 Score (std)                : 0.0043
#
# Confusion Matrix:
# Float32[334.2 2.0 2.2 1.6; 0.0 240.4 11.4 8.2; 18.8 8.2 170.2 2.8; 1.0 6.4 10.4 182.2]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 334.2 │       2.0 │      2.2 │   1.6 │
# │ Hazardous │   0.0 │     240.4 │     11.4 │   8.2 │
# │  Moderate │  18.8 │       8.2 │    170.2 │   2.8 │
# │      Poor │   1.0 │       6.4 │     10.4 │ 182.2 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================

# %% [markdown]
# # Stacking Ensemble

# %%
SVMClassifier = @load ProbabilisticSVC pkg=LIBSVM verbosity=0
DTClassifier  = @load DecisionTreeClassifier pkg=DecisionTree verbosity=0
kNNClassifier = @load KNNClassifier pkg=NearestNeighborModels verbosity=0

trainIdx, testIdx = holdOut(size(df,1), 0.2)

trainingInputs  = inputs[trainIdx, :]
testInputs      = inputs[testIdx, :]

trainingTargets = targets[trainIdx]
testTargets     = targets[testIdx]

# X as DataFrame
train_df = DataFrame(trainingInputs, :auto)
test_df  = DataFrame(testInputs, :auto)

# y as categorical
train_y_cat = categorical(trainingTargets)
test_y_cat  = categorical(testTargets)

# ---- Base Models ----
base_models_dict = Dict(
    "SVM" => SVMClassifier(kernel=LIBSVM.Kernel.RadialBasis, cost=1.0, gamma=2.0),
    "DT"  => DTClassifier(max_depth=8, rng=Random.MersenneTwister(1)),
    "kNN" => kNNClassifier(K=7)
)

# Convert to NamedTuple for Stack
base_models_NT = (; (Symbol(k)=>v for (k,v) in base_models_dict)...)

# ---- Stacking Model ----
stack_model = Stack(;
    metalearner = DTClassifier(max_depth=3, rng=Random.MersenneTwister(1)),
    resampling = CV(nfolds=5, shuffle=true, rng=123),  # deterministic
    measure = accuracy, 
    base_models_NT...
)

# Train the stacking model on your train dataset
stack_mach = machine(stack_model, train_df, train_y_cat) |> MLJ.fit!

y_pred = mode.(MLJ.predict(stack_mach, test_df))
acc = MLJ.accuracy(y_pred, test_y_cat)
println("Stack ensemble accuracy = $(round(acc*100, digits=2)) %")
# Out:
# [ Info: Training machine(ProbabilisticStack(metalearner = DecisionTreeClassifier(max_depth = 3, …), …), …).
# [ Info: Training machine(:SVM, …).
# [ Info: Training machine(:DT, …).
# [ Info: Training machine(:kNN, …).
# [ Info: Training machine(:SVM, …).
# [ Info: Training machine(:DT, …).
# [ Info: Training machine(:kNN, …).
# [ Info: Training machine(:SVM, …).
# [ Info: Training machine(:DT, …).
# [ Info: Training machine(:kNN, …).
# [ Info: Training machine(:SVM, …).
# [ Info: Training machine(:DT, …).
# [ Info: Training machine(:kNN, …).
# [ Info: Training machine(:SVM, …).
# [ Info: Training machine(:DT, …).
# [ Info: Training machine(:kNN, …).
# [ Info: Training machine(:SVM, …).
# [ Info: Training machine(:DT, …).
# [ Info: Training machine(:kNN, …).
# [ Info: Training machine(:metalearner, …).
# Stack ensemble accuracy = 91.7 %
