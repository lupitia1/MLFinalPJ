# %% [markdown]
# # Load packages

# %%
# skip reinstalling packages we already have
using Pkg

pkgs = [
    "MLJ", "MLJBase", "MLJModels", "MLJEnsembles", "MLJLinearModels",
    "DecisionTree", "MLJDecisionTreeInterface", "NaiveBayes", 
    "MLJNaiveBayesInterface", "EvoTrees", "CategoricalArrays", "Random",
    "LIBSVM", "MLJLIBSVMInterface", "Plots", "MLJModelInterface",
    "CSV", "DataFrames", "UrlDownload", "XGBoost", "NNlib"
]

# Filter out packages already installed
missing_pkgs = filter(pkg -> !(pkg in keys(Pkg.project().dependencies)), pkgs)

if !isempty(missing_pkgs)
    println("Installing missing packages: ", missing_pkgs)
    Pkg.add(missing_pkgs)
else
    println(" All required packages are already installed.")
end
# Out:
#  All required packages are already installed.

# %%
using MLJ
using MLJBase
using LIBSVM
using NNlib
using Flux
using Flux.Losses
using Statistics
# Out:
# [ Info: Precompiling MLJ [add582a8-e3ab-11e8-2d5e-e98b27df1bc7]

# %%
# Load PCA
PCA_model = MLJ.@load PCA pkg="MultivariateStats"
# Out:
# [ Info: For silent loading, specify `verbosity=0`.
# import MLJMultivariateStatsInterface ✔
# MLJMultivariateStatsInterface.PCA

# %%
#Load your library of functions
include("utils.jl")
# Set a global random seed for reproducibility
using Random
Random.seed!(42)
# Out:
# TaskLocalRNG()

# %% [markdown]
# # Load Data

# %%
using CSV, DataFrames, Random
using CategoricalArrays

df = CSV.read("./data/updated_pollution_dataset.csv", DataFrame)

# Some log
println("First 5 rows of df:")
show(df[1:5, :], allcols=true)


# Convert last column to categorical (in-place!)
df[!, end] = categorical(df[!, end])

# Extract the integer codes of the categories
targets = Float32.(levelcode.(df[!, end]))

# Use all columns except the last one as inputs
inputs = Matrix{Float32}(df[:, 1:end-1])

println("First 5 inputs::")
for i in 1:5
    println(inputs[i, :])
end

println("\n\nFirst 5 targets:")
println(targets[1:5])

# Extract labels (categories) as strings
label_names = levels(df[!, 10])
println("Labels: ", label_names)
# Out:
# First 5 rows of df:
# 5×10 DataFrame
#  Row │ Temperature  Humidity  PM2.5    PM10     NO2      SO2      CO       Proximity_to_Industrial_Areas  Population_Density  Air Quality
#      │ Float64      Float64   Float64  Float64  Float64  Float64  Float64  Float64                        Int64               String15
# ─────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#    1 │        29.8      59.1      5.2     17.9     18.9      9.2     1.72                            6.3                 319  Moderate
#    2 │        28.3      75.6      2.3     12.2     30.8      9.7     1.64                            6.0                 611  Moderate
#    3 │        23.1      74.7     26.7     33.8     24.4     12.6     1.63                            5.2                 619  Moderate
#    4 │        27.1      39.1      6.1      6.3     13.5      5.3     1.15                           11.1                 551  Good
#    5 │        26.5      70.7      6.9     16.0     21.9      5.6     1.01                           12.7                 303  GoodFirst 5 inputs::
# Float32[29.8, 59.1, 5.2, 17.9, 18.9, 9.2, 1.72, 6.3, 319.0]
# Float32[28.3, 75.6, 2.3, 12.2, 30.8, 9.7, 1.64, 6.0, 611.0]
# Float32[23.1, 74.7, 26.7, 33.8, 24.4, 12.6, 1.63, 5.2, 619.0]
# Float32[27.1, 39.1, 6.1, 6.3, 13.5, 5.3, 1.15, 11.1, 551.0]
# Float32[26.5, 70.7, 6.9, 16.0, 21.9, 5.6, 1.01, 12.7, 303.0]
#
#
# First 5 targets:
# Float32[3.0, 3.0, 3.0, 1.0, 1.0]
# Labels: String15["Good", "Hazardous", "Moderate", "Poor"]

# %%
results = Dict()
dimsPCA = [6,7,8]
crossValidationIndices = crossvalidation(targets, 5)
# Out:
# 5000-element Vector{Int64}:
#  1
#  3
#  5
#  4
#  1
#  3
#  3
#  5
#  1
#  1
#  5
#  1
#  2
#  ⋮
#  3
#  4
#  4
#  4
#  5
#  1
#  2
#  4
#  4
#  3
#  5
#  1

# %%
function printExperimentResult(model, hyperparams, dimPCA, results, class_labels)
    (
        (accuracy_mean, accuracy_std),
        (error_rate_mean, error_rate_std),
        (sensitivity_mean, sensitivity_std),
        (specificity_mean, specificity_std),
        (ppv_mean, ppv_std),
        (npv_mean, npv_std),
        (f1_mean, f1_std),
        cm
    ) = results

    println("\n=====================================================")
    println(" Model: $model | PCA outdim: $dimPCA")
    println(" Hyperparameters: $hyperparams")
    println("=====================================================")

    println(" Accuracy (mean)               : ", round(accuracy_mean, digits=4))
    println(" Accuracy (std)                : ", round(accuracy_std, digits=4))

    println(" Error Rate (mean)             : ", round(error_rate_mean, digits=4))
    println(" Error Rate (std)              : ", round(error_rate_std, digits=4))

    println(" Sensitivity/Recall (mean)     : ", round(sensitivity_mean, digits=4))
    println(" Sensitivity/Recall (std)      : ", round(sensitivity_std,  digits=4))

    println(" Specificity (mean)            : ", round(specificity_mean, digits=4))
    println(" Specificity (std)             : ", round(specificity_std,  digits=4))

    println(" PPV (mean)                    : ", round(ppv_mean,         digits=4))
    println(" PPV (std)                     : ", round(ppv_std,          digits=4))

    println(" NPV (mean)                    : ", round(npv_mean,         digits=4))
    println(" NPV (std)                     : ", round(npv_std,          digits=4))

    println(" F1 Score (mean)               : ", round(f1_mean,          digits=4))
    println(" F1 Score (std)                : ", round(f1_std,           digits=4))

    println("\nConfusion Matrix:")
    println(cm)

    PrettyTables.pretty_table(DataFrame(cm, :auto); header=class_labels, row_labels=class_labels)

    println("=====================================================\n")
end
# Out:
# printExperimentResult (generic function with 1 method)

# %% [markdown]
# # Artificial Neural Networks

# %%
############# 1. ARTIFICIAL NEURAL NETWORKS (8+ topologies) #############
default_ann = Dict(      
    "numExecutions" => 5,
    #"transferFunctions" => [σ, σ, σ, σ],
    "maxEpochs" => 200,
    "minLoss" => 0.0,
    "learningRate" => 0.01,
    "validationRatio" => 0.1,
    "maxEpochsVal" => 20
)

ann_search_space = [
    Dict("topology"=>[4, 4]),
    Dict("topology"=>[8, 8]),
    Dict("topology"=>[16, 16]),
    Dict("topology"=>[10, 4]),
    Dict("topology"=>[10, 6, 4]),
    Dict("topology"=>[10, 8, 4]),
    Dict("topology"=>[10, 8, 6, 4]),
    Dict("topology"=>[10, 12, 6, 4])
]
# Out:
# 8-element Vector{Dict{String, Vector{Int64}}}:
#  Dict("topology" => [4, 4])
#  Dict("topology" => [8, 8])
#  Dict("topology" => [16, 16])
#  Dict("topology" => [10, 4])
#  Dict("topology" => [10, 6, 4])
#  Dict("topology" => [10, 8, 4])
#  Dict("topology" => [10, 8, 6, 4])
#  Dict("topology" => [10, 12, 6, 4])

# %%
########################
# 1. ANN GRID SEARCH
########################
ann_results = []

for hp in ann_search_space
    for dim in dimsPCA
        println("\n=== ANN experiment: topology = $(hp["topology"]) | PCA maxoutdim = $(dim) ===")
        full_hp = merge(default_ann, hp)
        res = modelCrossValidationPCA(:ANN, full_hp, (inputs, targets), crossValidationIndices, dim)
        push!(ann_results, (model=:ANN, hyperparams=hp, dimPCA=dim, results=res))
    end
end

results[:ANN] = ann_results
# Out:
# === ANN experiment: topology = [4, 4] | PCA maxoutdim = 6 ===
#
# === ANN experiment: topology = [4, 4] | PCA maxoutdim = 7 ===
#
# === ANN experiment: topology = [4, 4] | PCA maxoutdim = 8 ===
#
# === ANN experiment: topology = [8, 8] | PCA maxoutdim = 6 ===
#
# === ANN experiment: topology = [8, 8] | PCA maxoutdim = 7 ===
#
# === ANN experiment: topology = [8, 8] | PCA maxoutdim = 8 ===
#
# === ANN experiment: topology = [16, 16] | PCA maxoutdim = 6 ===
#
# === ANN experiment: topology = [16, 16] | PCA maxoutdim = 7 ===
#
# === ANN experiment: topology = [16, 16] | PCA maxoutdim = 8 ===
#
# === ANN experiment: topology = [10, 4] | PCA maxoutdim = 6 ===
#
# === ANN experiment: topology = [10, 4] | PCA maxoutdim = 7 ===
#
# === ANN experiment: topology = [10, 4] | PCA maxoutdim = 8 ===
#
# === ANN experiment: topology = [10, 6, 4] | PCA maxoutdim = 6 ===
#
# === ANN experiment: topology = [10, 6, 4] | PCA maxoutdim = 7 ===
#
# === ANN experiment: topology = [10, 6, 4] | PCA maxoutdim = 8 ===
#
# === ANN experiment: topology = [10, 8, 4] | PCA maxoutdim = 6 ===
#
# === ANN experiment: topology = [10, 8, 4] | PCA maxoutdim = 7 ===
#
# === ANN experiment: topology = [10, 8, 4] | PCA maxoutdim = 8 ===
#
# === ANN experiment: topology = [10, 8, 6, 4] | PCA maxoutdim = 6 ===
#
# === ANN experiment: topology = [10, 8, 6, 4] | PCA maxoutdim = 7 ===
#
# === ANN experiment: topology = [10, 8, 6, 4] | PCA maxoutdim = 8 ===
#
# === ANN experiment: topology = [10, 12, 6, 4] | PCA maxoutdim = 6 ===
#
# === ANN experiment: topology = [10, 12, 6, 4] | PCA maxoutdim = 7 ===
#
# === ANN experiment: topology = [10, 12, 6, 4] | PCA maxoutdim = 8 ===
# 24-element Vector{Any}:
#  (model = :ANN, hyperparams = Dict("topology" => [4, 4]), dimPCA = 6, results = ((0.94048005f0, 0.007690985f0), (0.05952f0, 0.0076910355f0), (0.94048005f0, 0.007690985f0), (0.9826414f0, 0.0017484212f0), (0.94006604f0, 0.0076740775f0), (0.98477715f0, 0.0020668781f0), (0.94012755f0, 0.007616604f0), Float32[332.28 0.71999997 6.6 0.4; 0.6 243.96 8.2 7.2399993; 11.96 8.12 175.48001 4.44; 0.4 5.12 5.72 188.76]))
#  (model = :ANN, hyperparams = Dict("topology" => [4, 4]), dimPCA = 7, results = ((0.93992007f0, 0.0068317014f0), (0.060080003f0, 0.006831693f0), (0.93992007f0, 0.0068317014f0), (0.9822475f0, 0.0011926473f0), (0.93978006f0, 0.0071935887f0), (0.98485124f0, 0.0018926415f0), (0.9393891f0, 0.0066998834f0), Float32[332.76 0.76 6.0799994 0.4; 0.64 243.8 8.280001 7.28; 12.559999 7.96 175.92001 3.56; 0.44 5.16 6.96 187.44]))
#  (model = :ANN, hyperparams = Dict("topology" => [4, 4]), dimPCA = 8, results = ((0.93776f0, 0.010603237f0), (0.062240005f0, 0.010603208f0), (0.93776f0, 0.010603237f0), (0.9817678f0, 0.0028817006f0), (0.93454474f0, 0.01534999f0), (0.98461926f0, 0.002154687f0), (0.9358554f0, 0.013085337f0), Float32[332.48 0.8 6.32 0.4; 0.6 243.96 7.8 7.6399994; 12.160001 11.36 172.36002 4.12; 0.44 4.96 5.6400003 188.95999]))
#  (model = :ANN, hyperparams = Dict("topology" => [8, 8]), dimPCA = 6, results = ((0.94116f0, 0.007893549f0), (0.05884f0, 0.007893542f0), (0.94116f0, 0.007893549f0), (0.9826439f0, 0.001689101f0), (0.9408628f0, 0.007728359f0), (0.984925f0, 0.0021647662f0), (0.9408413f0, 0.0077802083f0), Float32[332.12 0.71999997 6.7599998 0.4; 0.8 244.4 8.160001 6.6400003; 11.68 8.04 176.56001 3.7199998; 0.4 5.44 6.0800004 188.08]))
#  (model = :ANN, hyperparams = Dict("topology" => [8, 8]), dimPCA = 7, results = ((0.94092f0, 0.008366139f0), (0.059079997f0, 0.008366123f0), (0.94092f0, 0.008366139f0), (0.98261577f0, 0.0018001158f0), (0.9406401f0, 0.008206714f0), (0.98492336f0, 0.0022689921f0), (0.94059354f0, 0.008253382f0), Float32[332.24 0.64 6.72 0.4; 0.91999996 244.16 8.280001 6.6400003; 11.64 8.12 176.56001 3.6800003; 0.4 5.2799997 6.3599997 187.96]))
#  (model = :ANN, hyperparams = Dict("topology" => [8, 8]), dimPCA = 8, results = ((0.94136f0, 0.007899864f0), (0.058639996f0, 0.007899876f0), (0.94136f0, 0.007899864f0), (0.98276377f0, 0.0016532037f0), (0.9410949f0, 0.0076807565f0), (0.9850771f0, 0.0021686496f0), (0.9410454f0, 0.0077682245f0), Float32[332.15997 0.68 6.7599998 0.4; 0.71999997 244.31999 8.360001 6.6; 11.4 8.04 176.88 3.6799998; 0.4 5.3599997 6.2400002 188.0]))
#  (model = :ANN, hyperparams = Dict("topology" => [16, 16]), dimPCA = 6, results = ((0.9420401f0, 0.007506513f0), (0.057960004f0, 0.0075065303f0), (0.9420401f0, 0.007506513f0), (0.98288536f0, 0.001367503f0), (0.94171536f0, 0.007268917f0), (0.98530275f0, 0.002037679f0), (0.94170207f0, 0.007370015f0), Float32[332.2 0.8 6.6 0.4; 0.64 244.55998 8.440001 6.3599997; 11.5199995 7.6800003 177.0 3.8; 0.4 5.2400002 6.08 188.28]))
#  (model = :ANN, hyperparams = Dict("topology" => [16, 16]), dimPCA = 7, results = ((0.94140005f0, 0.007363403f0), (0.0586f0, 0.0073634265f0), (0.94140005f0, 0.007363403f0), (0.9828111f0, 0.0014584193f0), (0.94105226f0, 0.0072122663f0), (0.9850955f0, 0.0020148568f0), (0.94105816f0, 0.007241932f0), Float32[332.32 0.64 6.6399994 0.4; 0.76000005 244.6 8.280001 6.3599997; 11.639999 8.08 176.2 4.0800004; 0.4 5.2400002 6.0800004 188.28]))
#  (model = :ANN, hyperparams = Dict("topology" => [16, 16]), dimPCA = 8, results = ((0.94164f0, 0.007449043f0), (0.05836f0, 0.0074490285f0), (0.94164f0, 0.007449043f0), (0.982883f0, 0.0015929776f0), (0.94130313f0, 0.007230791f0), (0.98520887f0, 0.0020710519f0), (0.94130296f0, 0.0073206183f0), Float32[332.27997 0.72 6.6 0.4; 0.76000005 244.23999 8.36 6.6399994; 11.2 7.839999 177.04001 3.9199996; 0.4 5.2799997 6.2400002 188.07999]))
#  (model = :ANN, hyperparams = Dict("topology" => [10, 4]), dimPCA = 6, results = ((0.93579996f0, 0.013194722f0), (0.0642f0, 0.013194694f0), (0.93579996f0, 0.013194722f0), (0.9811015f0, 0.0032860986f0), (0.93339854f0, 0.018362708f0), (0.98430794f0, 0.0022928892f0), (0.9335424f0, 0.016237002f0), Float32[332.36 0.8 6.44 0.4; 0.8 240.43999 11.280001 7.4800005; 12.12 9.2 174.36 4.3199997; 0.4 5.0 5.96 188.64]))
#  (model = :ANN, hyperparams = Dict("topology" => [10, 4]), dimPCA = 7, results = ((0.94064f0, 0.0077542174f0), (0.059360005f0, 0.0077542257f0), (0.94064f0, 0.0077542174f0), (0.9825386f0, 0.0016977789f0), (0.940331f0, 0.007646142f0), (0.98466873f0, 0.0022190677f0), (0.9403203f0, 0.007629015f0), Float32[332.12 0.71999997 6.7600007 0.4; 0.84 244.04 8.16 6.9600005; 12.0 7.8 176.2 4.0; 0.4 5.28 6.04 188.28]))
#  (model = :ANN, hyperparams = Dict("topology" => [10, 4]), dimPCA = 8, results = ((0.94083995f0, 0.007946589f0), (0.05916f0, 0.007946574f0), (0.94083995f0, 0.007946589f0), (0.98260677f0, 0.0017247285f0), (0.940472f0, 0.007830915f0), (0.9847973f0, 0.0022771654f0), (0.94050646f0, 0.007827921f0), Float32[332.24 0.71999997 6.6399994 0.4; 0.87999994 244.35999 7.96 6.8; 12.0 8.0 175.96 4.04; 0.4 5.28 6.04 188.28]))
#  (model = :ANN, hyperparams = Dict("topology" => [10, 6, 4]), dimPCA = 6, results = ((0.94268f0, 0.006769926f0), (0.05732f0, 0.0067699323f0), (0.94268f0, 0.006769926f0), (0.98298275f0, 0.0011932742f0), (0.9423191f0, 0.006613545f0), (0.98559743f0, 0.0018087146f0), (0.94228566f0, 0.0066435933f0), Float32[332.84 0.71999997 6.04 0.4; 0.76000005 244.23999 8.4 6.6; 11.68 7.4 177.24 3.6799998; 0.4 5.0 6.2400002 188.36002]))
#  (model = :ANN, hyperparams = Dict("topology" => [10, 6, 4]), dimPCA = 7, results = ((0.9417199f0, 0.0066326964f0), (0.058280002f0, 0.0066326503f0), (0.9417199f0, 0.0066326964f0), (0.9827134f0, 0.0012609138f0), (0.94130594f0, 0.006477872f0), (0.985336f0, 0.0017397349f0), (0.94130576f0, 0.006525382f0), Float32[333.0 0.76 5.84 0.4; 0.8 244.4 8.24 6.56; 12.08 7.6400003 176.15999 4.12; 0.4 5.1600003 6.2799997 188.16]))
#  (model = :ANN, hyperparams = Dict("topology" => [10, 6, 4]), dimPCA = 8, results = ((0.94236004f0, 0.006227983f0), (0.057639997f0, 0.006228f0), (0.94236004f0, 0.006227983f0), (0.9829718f0, 0.0010685216f0), (0.9419719f0, 0.006079877f0), (0.98543054f0, 0.0015058263f0), (0.9419812f0, 0.0061321226f0), Float32[332.84 0.68 6.08 0.4; 0.84 244.23999 8.4 6.5199995; 11.4800005 7.44 177.0 4.08; 0.44 5.2 6.08 188.28]))
#  (model = :ANN, hyperparams = Dict("topology" => [10, 8, 4]), dimPCA = 6, results = ((0.94156f0, 0.0073653376f0), (0.05844f0, 0.0073653245f0), (0.94156f0, 0.0073653376f0), (0.9828614f0, 0.0015759971f0), (0.94122535f0, 0.0072135674f0), (0.9851762f0, 0.0019307695f0), (0.9411925f0, 0.0072511774f0), Float32[332.4 0.84 6.3599997 0.4; 0.84 244.2 8.4 6.5600004; 11.5199995 7.84 176.31999 4.32; 0.35999998 5.04 5.96 188.63998]))
#  (model = :ANN, hyperparams = Dict("topology" => [10, 8, 4]), dimPCA = 7, results = ((0.94215995f0, 0.006299812f0), (0.05784f0, 0.0062998408f0), (0.94215995f0, 0.006299812f0), (0.9830559f0, 0.0010795323f0), (0.9418166f0, 0.006052515f0), (0.98541194f0, 0.0017100205f0), (0.9417942f0, 0.006140887f0), Float32[332.52 0.71999997 6.3599997 0.4; 0.84 244.16 8.280001 6.72; 11.24 7.7600007 176.87999 4.12; 0.4 4.88 6.12 188.6]))
#  (model = :ANN, hyperparams = Dict("topology" => [10, 8, 4]), dimPCA = 8, results = ((0.94184f0, 0.006007341f0), (0.05816f0, 0.0060073286f0), (0.94184f0, 0.006007341f0), (0.9828949f0, 0.0011479813f0), (0.9414614f0, 0.0058248746f0), (0.98525846f0, 0.0015808977f0), (0.9414612f0, 0.005883239f0), Float32[332.72003 0.67999995 6.16 0.44; 0.88 244.31998 8.2 6.6; 11.599999 7.72 176.28 4.4; 0.44 4.96 6.08 188.51999]))
#  (model = :ANN, hyperparams = Dict("topology" => [10, 8, 6, 4]), dimPCA = 6, results = ((0.94167995f0, 0.012644832f0), (0.058320004f0, 0.012644843f0), (0.94167995f0, 0.012644832f0), (0.9831168f0, 0.0030732874f0), (0.93881035f0, 0.018191848f0), (0.985906f0, 0.0022168688f0), (0.9398392f0, 0.015794264f0), Float32[333.48 0.4 5.72 0.4; 0.84 241.31999 11.280001 6.56; 11.199999 6.44 178.07999 4.28; 0.24000001 5.1600003 5.8 188.8]))
#  (model = :ANN, hyperparams = Dict("topology" => [10, 8, 6, 4]), dimPCA = 7, results = ((0.94184f0, 0.012751784f0), (0.05816f0, 0.012751784f0), (0.94184f0, 0.012751784f0), (0.983102f0, 0.0029979178f0), (0.93903923f0, 0.018105472f0), (0.98581886f0, 0.002335449f0), (0.94002974f0, 0.015857045f0), Float32[332.84 0.4 6.2 0.56; 0.84 241.6 11.2 6.3599997; 10.68 6.8 178.4 4.12; 0.36 4.84 5.8 189.00002]))
#  (model = :ANN, hyperparams = Dict("topology" => [10, 8, 6, 4]), dimPCA = 8, results = ((0.94408f0, 0.007655856f0), (0.055920005f0, 0.0076558497f0), (0.94408f0, 0.007655856f0), (0.98369706f0, 0.0017260488f0), (0.9437523f0, 0.0074960305f0), (0.9859489f0, 0.00207794f0), (0.9437339f0, 0.007549722f0), Float32[332.91998 0.4 6.24 0.44; 0.88 244.56001 8.08 6.4800005; 10.88 7.2 177.84 4.0800004; 0.36 4.96 5.92 188.76001]))
#  (model = :ANN, hyperparams = Dict("topology" => [10, 12, 6, 4]), dimPCA = 6, results = ((0.94404f0, 0.0067740735f0), (0.05596f0, 0.0067740697f0), (0.94404f0, 0.0067740735f0), (0.98371f0, 0.0016136979f0), (0.9437133f0, 0.0066337828f0), (0.9860511f0, 0.0018135719f0), (0.94366133f0, 0.006681489f0), Float32[333.24 0.32 6.0 0.44; 0.88 244.6 8.160001 6.3599997; 11.079999 7.2 177.43999 4.2799997; 0.32 4.88 6.04 188.76]))
#  (model = :ANN, hyperparams = Dict("topology" => [10, 12, 6, 4]), dimPCA = 7, results = ((0.94428f0, 0.0071142116f0), (0.05572f0, 0.007114213f0), (0.94428f0, 0.0071142116f0), (0.98386204f0, 0.0020490394f0), (0.94401836f0, 0.00696953f0), (0.98596793f0, 0.0018155485f0), (0.94395334f0, 0.007075787f0), Float32[332.8 0.44 6.16 0.6; 0.96000004 243.96 8.52 6.56; 9.960001 7.2400002 178.56 4.2400002; 0.32 5.0 5.7200003 188.95999]))
#  (model = :ANN, hyperparams = Dict("topology" => [10, 12, 6, 4]), dimPCA = 8, results = ((0.94448006f0, 0.007332951f0), (0.055519998f0, 0.0073329397f0), (0.94448006f0, 0.007332951f0), (0.9837263f0, 0.0018120373f0), (0.94408447f0, 0.0072655794f0), (0.9861286f0, 0.0017873156f0), (0.94409627f0, 0.007292637f0), Float32[333.4 0.36 5.72 0.52; 0.76 244.36002 8.4800005 6.4; 10.960001 7.0 177.76 4.28; 0.32 5.0800004 5.6400003 188.96]))

# %%
for entry in results[:ANN]
    printExperimentResult(entry.model, entry.hyperparams, entry.dimPCA, entry.results, label_names)
end
# Out:
# =====================================================
#  Model: ANN | PCA outdim: 6
#  Hyperparameters: Dict("topology" => [4, 4])
# =====================================================
#  Accuracy (mean)               : 0.9405
#  Accuracy (std)                : 0.0077
#  Error Rate (mean)             : 0.0595
#  Error Rate (std)              : 0.0077
#  Sensitivity/Recall (mean)     : 0.9405
#  Sensitivity/Recall (std)      : 0.0077
#  Specificity (mean)            : 0.9826
#  Specificity (std)             : 0.0017
#  PPV (mean)                    : 0.9401
#  PPV (std)                     : 0.0077
#  NPV (mean)                    : 0.9848
#  NPV (std)                     : 0.0021
#  F1 Score (mean)               : 0.9401
#  F1 Score (std)                : 0.0076
#
# Confusion Matrix:
# Float32[332.28 0.71999997 6.6 0.4; 0.6 243.96 8.2 7.2399993; 11.96 8.12 175.48001 4.44; 0.4 5.12 5.72 188.76]
# ┌───────────┬────────┬───────────┬──────────┬────────┐
# │           │   Good │ Hazardous │ Moderate │   Poor │
# ├───────────┼────────┼───────────┼──────────┼────────┤
# │      Good │ 332.28 │      0.72 │      6.6 │    0.4 │
# │ Hazardous │    0.6 │    243.96 │      8.2 │   7.24 │
# │  Moderate │  11.96 │      8.12 │   175.48 │   4.44 │
# │      Poor │    0.4 │      5.12 │     5.72 │ 188.76 │
# └───────────┴────────┴───────────┴──────────┴────────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 7
#  Hyperparameters: Dict("topology" => [4, 4])
# =====================================================
#  Accuracy (mean)               : 0.9399
#  Accuracy (std)                : 0.0068
#  Error Rate (mean)             : 0.0601
#  Error Rate (std)              : 0.0068
#  Sensitivity/Recall (mean)     : 0.9399
#  Sensitivity/Recall (std)      : 0.0068
#  Specificity (mean)            : 0.9822
#  Specificity (std)             : 0.0012
#  PPV (mean)                    : 0.9398
#  PPV (std)                     : 0.0072
#  NPV (mean)                    : 0.9849
#  NPV (std)                     : 0.0019
#  F1 Score (mean)               : 0.9394
#  F1 Score (std)                : 0.0067
#
# Confusion Matrix:
# Float32[332.76 0.76 6.0799994 0.4; 0.64 243.8 8.280001 7.28; 12.559999 7.96 175.92001 3.56; 0.44 5.16 6.96 187.44]
# ┌───────────┬────────┬───────────┬──────────┬────────┐
# │           │   Good │ Hazardous │ Moderate │   Poor │
# ├───────────┼────────┼───────────┼──────────┼────────┤
# │      Good │ 332.76 │      0.76 │     6.08 │    0.4 │
# │ Hazardous │   0.64 │     243.8 │     8.28 │   7.28 │
# │  Moderate │  12.56 │      7.96 │   175.92 │   3.56 │
# │      Poor │   0.44 │      5.16 │     6.96 │ 187.44 │
# └───────────┴────────┴───────────┴──────────┴────────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 8
#  Hyperparameters: Dict("topology" => [4, 4])
# =====================================================
#  Accuracy (mean)               : 0.9378
#  Accuracy (std)                : 0.0106
#  Error Rate (mean)             : 0.0622
#  Error Rate (std)              : 0.0106
#  Sensitivity/Recall (mean)     : 0.9378
#  Sensitivity/Recall (std)      : 0.0106
#  Specificity (mean)            : 0.9818
#  Specificity (std)             : 0.0029
#  PPV (mean)                    : 0.9345
#  PPV (std)                     : 0.0153
#  NPV (mean)                    : 0.9846
#  NPV (std)                     : 0.0022
#  F1 Score (mean)               : 0.9359
#  F1 Score (std)                : 0.0131
#
# Confusion Matrix:
# Float32[332.48 0.8 6.32 0.4; 0.6 243.96 7.8 7.6399994; 12.160001 11.36 172.36002 4.12; 0.44 4.96 5.6400003 188.95999]
# ┌───────────┬────────┬───────────┬──────────┬────────┐
# │           │   Good │ Hazardous │ Moderate │   Poor │
# ├───────────┼────────┼───────────┼──────────┼────────┤
# │      Good │ 332.48 │       0.8 │     6.32 │    0.4 │
# │ Hazardous │    0.6 │    243.96 │      7.8 │   7.64 │
# │  Moderate │  12.16 │     11.36 │   172.36 │   4.12 │
# │      Poor │   0.44 │      4.96 │     5.64 │ 188.96 │
# └───────────┴────────┴───────────┴──────────┴────────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 6
#  Hyperparameters: Dict("topology" => [8, 8])
# =====================================================
#  Accuracy (mean)               : 0.9412
#  Accuracy (std)                : 0.0079
#  Error Rate (mean)             : 0.0588
#  Error Rate (std)              : 0.0079
#  Sensitivity/Recall (mean)     : 0.9412
#  Sensitivity/Recall (std)      : 0.0079
#  Specificity (mean)            : 0.9826
#  Specificity (std)             : 0.0017
#  PPV (mean)                    : 0.9409
#  PPV (std)                     : 0.0077
#  NPV (mean)                    : 0.9849
#  NPV (std)                     : 0.0022
#  F1 Score (mean)               : 0.9408
#  F1 Score (std)                : 0.0078
#
# Confusion Matrix:
# Float32[332.12 0.71999997 6.7599998 0.4; 0.8 244.4 8.160001 6.6400003; 11.68 8.04 176.56001 3.7199998; 0.4 5.44 6.0800004 188.08]
# ┌───────────┬────────┬───────────┬──────────┬────────┐
# │           │   Good │ Hazardous │ Moderate │   Poor │
# ├───────────┼────────┼───────────┼──────────┼────────┤
# │      Good │ 332.12 │      0.72 │     6.76 │    0.4 │
# │ Hazardous │    0.8 │     244.4 │     8.16 │   6.64 │
# │  Moderate │  11.68 │      8.04 │   176.56 │   3.72 │
# │      Poor │    0.4 │      5.44 │     6.08 │ 188.08 │
# └───────────┴────────┴───────────┴──────────┴────────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 7
#  Hyperparameters: Dict("topology" => [8, 8])
# =====================================================
#  Accuracy (mean)               : 0.9409
#  Accuracy (std)                : 0.0084
#  Error Rate (mean)             : 0.0591
#  Error Rate (std)              : 0.0084
#  Sensitivity/Recall (mean)     : 0.9409
#  Sensitivity/Recall (std)      : 0.0084
#  Specificity (mean)            : 0.9826
#  Specificity (std)             : 0.0018
#  PPV (mean)                    : 0.9406
#  PPV (std)                     : 0.0082
#  NPV (mean)                    : 0.9849
#  NPV (std)                     : 0.0023
#  F1 Score (mean)               : 0.9406
#  F1 Score (std)                : 0.0083
#
# Confusion Matrix:
# Float32[332.24 0.64 6.72 0.4; 0.91999996 244.16 8.280001 6.6400003; 11.64 8.12 176.56001 3.6800003; 0.4 5.2799997 6.3599997 187.96]
# ┌───────────┬────────┬───────────┬──────────┬────────┐
# │           │   Good │ Hazardous │ Moderate │   Poor │
# ├───────────┼────────┼───────────┼──────────┼────────┤
# │      Good │ 332.24 │      0.64 │     6.72 │    0.4 │
# │ Hazardous │   0.92 │    244.16 │     8.28 │   6.64 │
# │  Moderate │  11.64 │      8.12 │   176.56 │   3.68 │
# │      Poor │    0.4 │      5.28 │     6.36 │ 187.96 │
# └───────────┴────────┴───────────┴──────────┴────────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 8
#  Hyperparameters: Dict("topology" => [8, 8])
# =====================================================
#  Accuracy (mean)               : 0.9414
#  Accuracy (std)                : 0.0079
#  Error Rate (mean)             : 0.0586
#  Error Rate (std)              : 0.0079
#  Sensitivity/Recall (mean)     : 0.9414
#  Sensitivity/Recall (std)      : 0.0079
#  Specificity (mean)            : 0.9828
#  Specificity (std)             : 0.0017
#  PPV (mean)                    : 0.9411
#  PPV (std)                     : 0.0077
#  NPV (mean)                    : 0.9851
#  NPV (std)                     : 0.0022
#  F1 Score (mean)               : 0.941
#  F1 Score (std)                : 0.0078
#
# Confusion Matrix:
# Float32[332.15997 0.68 6.7599998 0.4; 0.71999997 244.31999 8.360001 6.6; 11.4 8.04 176.88 3.6799998; 0.4 5.3599997 6.2400002 188.0]
# ┌───────────┬────────┬───────────┬──────────┬───────┐
# │           │   Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼────────┼───────────┼──────────┼───────┤
# │      Good │ 332.16 │      0.68 │     6.76 │   0.4 │
# │ Hazardous │   0.72 │    244.32 │     8.36 │   6.6 │
# │  Moderate │   11.4 │      8.04 │   176.88 │  3.68 │
# │      Poor │    0.4 │      5.36 │     6.24 │ 188.0 │
# └───────────┴────────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 6
#  Hyperparameters: Dict("topology" => [16, 16])
# =====================================================
#  Accuracy (mean)               : 0.942
#  Accuracy (std)                : 0.0075
#  Error Rate (mean)             : 0.058
#  Error Rate (std)              : 0.0075
#  Sensitivity/Recall (mean)     : 0.942
#  Sensitivity/Recall (std)      : 0.0075
#  Specificity (mean)            : 0.9829
#  Specificity (std)             : 0.0014
#  PPV (mean)                    : 0.9417
#  PPV (std)                     : 0.0073
#  NPV (mean)                    : 0.9853
#  NPV (std)                     : 0.002
#  F1 Score (mean)               : 0.9417
#  F1 Score (std)                : 0.0074
#
# Confusion Matrix:
# Float32[332.2 0.8 6.6 0.4; 0.64 244.55998 8.440001 6.3599997; 11.5199995 7.6800003 177.0 3.8; 0.4 5.2400002 6.08 188.28]
# ┌───────────┬───────┬───────────┬──────────┬────────┐
# │           │  Good │ Hazardous │ Moderate │   Poor │
# ├───────────┼───────┼───────────┼──────────┼────────┤
# │      Good │ 332.2 │       0.8 │      6.6 │    0.4 │
# │ Hazardous │  0.64 │    244.56 │     8.44 │   6.36 │
# │  Moderate │ 11.52 │      7.68 │    177.0 │    3.8 │
# │      Poor │   0.4 │      5.24 │     6.08 │ 188.28 │
# └───────────┴───────┴───────────┴──────────┴────────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 7
#  Hyperparameters: Dict("topology" => [16, 16])
# =====================================================
#  Accuracy (mean)               : 0.9414
#  Accuracy (std)                : 0.0074
#  Error Rate (mean)             : 0.0586
#  Error Rate (std)              : 0.0074
#  Sensitivity/Recall (mean)     : 0.9414
#  Sensitivity/Recall (std)      : 0.0074
#  Specificity (mean)            : 0.9828
#  Specificity (std)             : 0.0015
#  PPV (mean)                    : 0.9411
#  PPV (std)                     : 0.0072
#  NPV (mean)                    : 0.9851
#  NPV (std)                     : 0.002
#  F1 Score (mean)               : 0.9411
#  F1 Score (std)                : 0.0072
#
# Confusion Matrix:
# Float32[332.32 0.64 6.6399994 0.4; 0.76000005 244.6 8.280001 6.3599997; 11.639999 8.08 176.2 4.0800004; 0.4 5.2400002 6.0800004 188.28]
# ┌───────────┬────────┬───────────┬──────────┬────────┐
# │           │   Good │ Hazardous │ Moderate │   Poor │
# ├───────────┼────────┼───────────┼──────────┼────────┤
# │      Good │ 332.32 │      0.64 │     6.64 │    0.4 │
# │ Hazardous │   0.76 │     244.6 │     8.28 │   6.36 │
# │  Moderate │  11.64 │      8.08 │    176.2 │   4.08 │
# │      Poor │    0.4 │      5.24 │     6.08 │ 188.28 │
# └───────────┴────────┴───────────┴──────────┴────────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 8
#  Hyperparameters: Dict("topology" => [16, 16])
# =====================================================
#  Accuracy (mean)               : 0.9416
#  Accuracy (std)                : 0.0074
#  Error Rate (mean)             : 0.0584
#  Error Rate (std)              : 0.0074
#  Sensitivity/Recall (mean)     : 0.9416
#  Sensitivity/Recall (std)      : 0.0074
#  Specificity (mean)            : 0.9829
#  Specificity (std)             : 0.0016
#  PPV (mean)                    : 0.9413
#  PPV (std)                     : 0.0072
#  NPV (mean)                    : 0.9852
#  NPV (std)                     : 0.0021
#  F1 Score (mean)               : 0.9413
#  F1 Score (std)                : 0.0073
#
# Confusion Matrix:
# Float32[332.27997 0.72 6.6 0.4; 0.76000005 244.23999 8.36 6.6399994; 11.2 7.839999 177.04001 3.9199996; 0.4 5.2799997 6.2400002 188.07999]
# ┌───────────┬────────┬───────────┬──────────┬────────┐
# │           │   Good │ Hazardous │ Moderate │   Poor │
# ├───────────┼────────┼───────────┼──────────┼────────┤
# │      Good │ 332.28 │      0.72 │      6.6 │    0.4 │
# │ Hazardous │   0.76 │    244.24 │     8.36 │   6.64 │
# │  Moderate │   11.2 │      7.84 │   177.04 │   3.92 │
# │      Poor │    0.4 │      5.28 │     6.24 │ 188.08 │
# └───────────┴────────┴───────────┴──────────┴────────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 6
#  Hyperparameters: Dict("topology" => [10, 4])
# =====================================================
#  Accuracy (mean)               : 0.9358
#  Accuracy (std)                : 0.0132
#  Error Rate (mean)             : 0.0642
#  Error Rate (std)              : 0.0132
#  Sensitivity/Recall (mean)     : 0.9358
#  Sensitivity/Recall (std)      : 0.0132
#  Specificity (mean)            : 0.9811
#  Specificity (std)             : 0.0033
#  PPV (mean)                    : 0.9334
#  PPV (std)                     : 0.0184
#  NPV (mean)                    : 0.9843
#  NPV (std)                     : 0.0023
#  F1 Score (mean)               : 0.9335
#  F1 Score (std)                : 0.0162
#
# Confusion Matrix:
# Float32[332.36 0.8 6.44 0.4; 0.8 240.43999 11.280001 7.4800005; 12.12 9.2 174.36 4.3199997; 0.4 5.0 5.96 188.64]
# ┌───────────┬────────┬───────────┬──────────┬────────┐
# │           │   Good │ Hazardous │ Moderate │   Poor │
# ├───────────┼────────┼───────────┼──────────┼────────┤
# │      Good │ 332.36 │       0.8 │     6.44 │    0.4 │
# │ Hazardous │    0.8 │    240.44 │    11.28 │   7.48 │
# │  Moderate │  12.12 │       9.2 │   174.36 │   4.32 │
# │      Poor │    0.4 │       5.0 │     5.96 │ 188.64 │
# └───────────┴────────┴───────────┴──────────┴────────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 7
#  Hyperparameters: Dict("topology" => [10, 4])
# =====================================================
#  Accuracy (mean)               : 0.9406
#  Accuracy (std)                : 0.0078
#  Error Rate (mean)             : 0.0594
#  Error Rate (std)              : 0.0078
#  Sensitivity/Recall (mean)     : 0.9406
#  Sensitivity/Recall (std)      : 0.0078
#  Specificity (mean)            : 0.9825
#  Specificity (std)             : 0.0017
#  PPV (mean)                    : 0.9403
#  PPV (std)                     : 0.0076
#  NPV (mean)                    : 0.9847
#  NPV (std)                     : 0.0022
#  F1 Score (mean)               : 0.9403
#  F1 Score (std)                : 0.0076
#
# Confusion Matrix:
# Float32[332.12 0.71999997 6.7600007 0.4; 0.84 244.04 8.16 6.9600005; 12.0 7.8 176.2 4.0; 0.4 5.28 6.04 188.28]
# ┌───────────┬────────┬───────────┬──────────┬────────┐
# │           │   Good │ Hazardous │ Moderate │   Poor │
# ├───────────┼────────┼───────────┼──────────┼────────┤
# │      Good │ 332.12 │      0.72 │     6.76 │    0.4 │
# │ Hazardous │   0.84 │    244.04 │     8.16 │   6.96 │
# │  Moderate │   12.0 │       7.8 │    176.2 │    4.0 │
# │      Poor │    0.4 │      5.28 │     6.04 │ 188.28 │
# └───────────┴────────┴───────────┴──────────┴────────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 8
#  Hyperparameters: Dict("topology" => [10, 4])
# =====================================================
#  Accuracy (mean)               : 0.9408
#  Accuracy (std)                : 0.0079
#  Error Rate (mean)             : 0.0592
#  Error Rate (std)              : 0.0079
#  Sensitivity/Recall (mean)     : 0.9408
#  Sensitivity/Recall (std)      : 0.0079
#  Specificity (mean)            : 0.9826
#  Specificity (std)             : 0.0017
#  PPV (mean)                    : 0.9405
#  PPV (std)                     : 0.0078
#  NPV (mean)                    : 0.9848
#  NPV (std)                     : 0.0023
#  F1 Score (mean)               : 0.9405
#  F1 Score (std)                : 0.0078
#
# Confusion Matrix:
# Float32[332.24 0.71999997 6.6399994 0.4; 0.87999994 244.35999 7.96 6.8; 12.0 8.0 175.96 4.04; 0.4 5.28 6.04 188.28]
# ┌───────────┬────────┬───────────┬──────────┬────────┐
# │           │   Good │ Hazardous │ Moderate │   Poor │
# ├───────────┼────────┼───────────┼──────────┼────────┤
# │      Good │ 332.24 │      0.72 │     6.64 │    0.4 │
# │ Hazardous │   0.88 │    244.36 │     7.96 │    6.8 │
# │  Moderate │   12.0 │       8.0 │   175.96 │   4.04 │
# │      Poor │    0.4 │      5.28 │     6.04 │ 188.28 │
# └───────────┴────────┴───────────┴──────────┴────────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 6
#  Hyperparameters: Dict("topology" => [10, 6, 4])
# =====================================================
#  Accuracy (mean)               : 0.9427
#  Accuracy (std)                : 0.0068
#  Error Rate (mean)             : 0.0573
#  Error Rate (std)              : 0.0068
#  Sensitivity/Recall (mean)     : 0.9427
#  Sensitivity/Recall (std)      : 0.0068
#  Specificity (mean)            : 0.983
#  Specificity (std)             : 0.0012
#  PPV (mean)                    : 0.9423
#  PPV (std)                     : 0.0066
#  NPV (mean)                    : 0.9856
#  NPV (std)                     : 0.0018
#  F1 Score (mean)               : 0.9423
#  F1 Score (std)                : 0.0066
#
# Confusion Matrix:
# Float32[332.84 0.71999997 6.04 0.4; 0.76000005 244.23999 8.4 6.6; 11.68 7.4 177.24 3.6799998; 0.4 5.0 6.2400002 188.36002]
# ┌───────────┬────────┬───────────┬──────────┬────────┐
# │           │   Good │ Hazardous │ Moderate │   Poor │
# ├───────────┼────────┼───────────┼──────────┼────────┤
# │      Good │ 332.84 │      0.72 │     6.04 │    0.4 │
# │ Hazardous │   0.76 │    244.24 │      8.4 │    6.6 │
# │  Moderate │  11.68 │       7.4 │   177.24 │   3.68 │
# │      Poor │    0.4 │       5.0 │     6.24 │ 188.36 │
# └───────────┴────────┴───────────┴──────────┴────────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 7
#  Hyperparameters: Dict("topology" => [10, 6, 4])
# =====================================================
#  Accuracy (mean)               : 0.9417
#  Accuracy (std)                : 0.0066
#  Error Rate (mean)             : 0.0583
#  Error Rate (std)              : 0.0066
#  Sensitivity/Recall (mean)     : 0.9417
#  Sensitivity/Recall (std)      : 0.0066
#  Specificity (mean)            : 0.9827
#  Specificity (std)             : 0.0013
#  PPV (mean)                    : 0.9413
#  PPV (std)                     : 0.0065
#  NPV (mean)                    : 0.9853
#  NPV (std)                     : 0.0017
#  F1 Score (mean)               : 0.9413
#  F1 Score (std)                : 0.0065
#
# Confusion Matrix:
# Float32[333.0 0.76 5.84 0.4; 0.8 244.4 8.24 6.56; 12.08 7.6400003 176.15999 4.12; 0.4 5.1600003 6.2799997 188.16]
# ┌───────────┬───────┬───────────┬──────────┬────────┐
# │           │  Good │ Hazardous │ Moderate │   Poor │
# ├───────────┼───────┼───────────┼──────────┼────────┤
# │      Good │ 333.0 │      0.76 │     5.84 │    0.4 │
# │ Hazardous │   0.8 │     244.4 │     8.24 │   6.56 │
# │  Moderate │ 12.08 │      7.64 │   176.16 │   4.12 │
# │      Poor │   0.4 │      5.16 │     6.28 │ 188.16 │
# └───────────┴───────┴───────────┴──────────┴────────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 8
#  Hyperparameters: Dict("topology" => [10, 6, 4])
# =====================================================
#  Accuracy (mean)               : 0.9424
#  Accuracy (std)                : 0.0062
#  Error Rate (mean)             : 0.0576
#  Error Rate (std)              : 0.0062
#  Sensitivity/Recall (mean)     : 0.9424
#  Sensitivity/Recall (std)      : 0.0062
#  Specificity (mean)            : 0.983
#  Specificity (std)             : 0.0011
#  PPV (mean)                    : 0.942
#  PPV (std)                     : 0.0061
#  NPV (mean)                    : 0.9854
#  NPV (std)                     : 0.0015
#  F1 Score (mean)               : 0.942
#  F1 Score (std)                : 0.0061
#
# Confusion Matrix:
# Float32[332.84 0.68 6.08 0.4; 0.84 244.23999 8.4 6.5199995; 11.4800005 7.44 177.0 4.08; 0.44 5.2 6.08 188.28]
# ┌───────────┬────────┬───────────┬──────────┬────────┐
# │           │   Good │ Hazardous │ Moderate │   Poor │
# ├───────────┼────────┼───────────┼──────────┼────────┤
# │      Good │ 332.84 │      0.68 │     6.08 │    0.4 │
# │ Hazardous │   0.84 │    244.24 │      8.4 │   6.52 │
# │  Moderate │  11.48 │      7.44 │    177.0 │   4.08 │
# │      Poor │   0.44 │       5.2 │     6.08 │ 188.28 │
# └───────────┴────────┴───────────┴──────────┴────────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 6
#  Hyperparameters: Dict("topology" => [10, 8, 4])
# =====================================================
#  Accuracy (mean)               : 0.9416
#  Accuracy (std)                : 0.0074
#  Error Rate (mean)             : 0.0584
#  Error Rate (std)              : 0.0074
#  Sensitivity/Recall (mean)     : 0.9416
#  Sensitivity/Recall (std)      : 0.0074
#  Specificity (mean)            : 0.9829
#  Specificity (std)             : 0.0016
#  PPV (mean)                    : 0.9412
#  PPV (std)                     : 0.0072
#  NPV (mean)                    : 0.9852
#  NPV (std)                     : 0.0019
#  F1 Score (mean)               : 0.9412
#  F1 Score (std)                : 0.0073
#
# Confusion Matrix:
# Float32[332.4 0.84 6.3599997 0.4; 0.84 244.2 8.4 6.5600004; 11.5199995 7.84 176.31999 4.32; 0.35999998 5.04 5.96 188.63998]
# ┌───────────┬───────┬───────────┬──────────┬────────┐
# │           │  Good │ Hazardous │ Moderate │   Poor │
# ├───────────┼───────┼───────────┼──────────┼────────┤
# │      Good │ 332.4 │      0.84 │     6.36 │    0.4 │
# │ Hazardous │  0.84 │     244.2 │      8.4 │   6.56 │
# │  Moderate │ 11.52 │      7.84 │   176.32 │   4.32 │
# │      Poor │  0.36 │      5.04 │     5.96 │ 188.64 │
# └───────────┴───────┴───────────┴──────────┴────────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 7
#  Hyperparameters: Dict("topology" => [10, 8, 4])
# =====================================================
#  Accuracy (mean)               : 0.9422
#  Accuracy (std)                : 0.0063
#  Error Rate (mean)             : 0.0578
#  Error Rate (std)              : 0.0063
#  Sensitivity/Recall (mean)     : 0.9422
#  Sensitivity/Recall (std)      : 0.0063
#  Specificity (mean)            : 0.9831
#  Specificity (std)             : 0.0011
#  PPV (mean)                    : 0.9418
#  PPV (std)                     : 0.0061
#  NPV (mean)                    : 0.9854
#  NPV (std)                     : 0.0017
#  F1 Score (mean)               : 0.9418
#  F1 Score (std)                : 0.0061
#
# Confusion Matrix:
# Float32[332.52 0.71999997 6.3599997 0.4; 0.84 244.16 8.280001 6.72; 11.24 7.7600007 176.87999 4.12; 0.4 4.88 6.12 188.6]
# ┌───────────┬────────┬───────────┬──────────┬───────┐
# │           │   Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼────────┼───────────┼──────────┼───────┤
# │      Good │ 332.52 │      0.72 │     6.36 │   0.4 │
# │ Hazardous │   0.84 │    244.16 │     8.28 │  6.72 │
# │  Moderate │  11.24 │      7.76 │   176.88 │  4.12 │
# │      Poor │    0.4 │      4.88 │     6.12 │ 188.6 │
# └───────────┴────────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 8
#  Hyperparameters: Dict("topology" => [10, 8, 4])
# =====================================================
#  Accuracy (mean)               : 0.9418
#  Accuracy (std)                : 0.006
#  Error Rate (mean)             : 0.0582
#  Error Rate (std)              : 0.006
#  Sensitivity/Recall (mean)     : 0.9418
#  Sensitivity/Recall (std)      : 0.006
#  Specificity (mean)            : 0.9829
#  Specificity (std)             : 0.0011
#  PPV (mean)                    : 0.9415
#  PPV (std)                     : 0.0058
#  NPV (mean)                    : 0.9853
#  NPV (std)                     : 0.0016
#  F1 Score (mean)               : 0.9415
#  F1 Score (std)                : 0.0059
#
# Confusion Matrix:
# Float32[332.72003 0.67999995 6.16 0.44; 0.88 244.31998 8.2 6.6; 11.599999 7.72 176.28 4.4; 0.44 4.96 6.08 188.51999]
# ┌───────────┬────────┬───────────┬──────────┬────────┐
# │           │   Good │ Hazardous │ Moderate │   Poor │
# ├───────────┼────────┼───────────┼──────────┼────────┤
# │      Good │ 332.72 │      0.68 │     6.16 │   0.44 │
# │ Hazardous │   0.88 │    244.32 │      8.2 │    6.6 │
# │  Moderate │   11.6 │      7.72 │   176.28 │    4.4 │
# │      Poor │   0.44 │      4.96 │     6.08 │ 188.52 │
# └───────────┴────────┴───────────┴──────────┴────────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 6
#  Hyperparameters: Dict("topology" => [10, 8, 6, 4])
# =====================================================
#  Accuracy (mean)               : 0.9417
#  Accuracy (std)                : 0.0126
#  Error Rate (mean)             : 0.0583
#  Error Rate (std)              : 0.0126
#  Sensitivity/Recall (mean)     : 0.9417
#  Sensitivity/Recall (std)      : 0.0126
#  Specificity (mean)            : 0.9831
#  Specificity (std)             : 0.0031
#  PPV (mean)                    : 0.9388
#  PPV (std)                     : 0.0182
#  NPV (mean)                    : 0.9859
#  NPV (std)                     : 0.0022
#  F1 Score (mean)               : 0.9398
#  F1 Score (std)                : 0.0158
#
# Confusion Matrix:
# Float32[333.48 0.4 5.72 0.4; 0.84 241.31999 11.280001 6.56; 11.199999 6.44 178.07999 4.28; 0.24000001 5.1600003 5.8 188.8]
# ┌───────────┬────────┬───────────┬──────────┬───────┐
# │           │   Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼────────┼───────────┼──────────┼───────┤
# │      Good │ 333.48 │       0.4 │     5.72 │   0.4 │
# │ Hazardous │   0.84 │    241.32 │    11.28 │  6.56 │
# │  Moderate │   11.2 │      6.44 │   178.08 │  4.28 │
# │      Poor │   0.24 │      5.16 │      5.8 │ 188.8 │
# └───────────┴────────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 7
#  Hyperparameters: Dict("topology" => [10, 8, 6, 4])
# =====================================================
#  Accuracy (mean)               : 0.9418
#  Accuracy (std)                : 0.0128
#  Error Rate (mean)             : 0.0582
#  Error Rate (std)              : 0.0128
#  Sensitivity/Recall (mean)     : 0.9418
#  Sensitivity/Recall (std)      : 0.0128
#  Specificity (mean)            : 0.9831
#  Specificity (std)             : 0.003
#  PPV (mean)                    : 0.939
#  PPV (std)                     : 0.0181
#  NPV (mean)                    : 0.9858
#  NPV (std)                     : 0.0023
#  F1 Score (mean)               : 0.94
#  F1 Score (std)                : 0.0159
#
# Confusion Matrix:
# Float32[332.84 0.4 6.2 0.56; 0.84 241.6 11.2 6.3599997; 10.68 6.8 178.4 4.12; 0.36 4.84 5.8 189.00002]
# ┌───────────┬────────┬───────────┬──────────┬───────┐
# │           │   Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼────────┼───────────┼──────────┼───────┤
# │      Good │ 332.84 │       0.4 │      6.2 │  0.56 │
# │ Hazardous │   0.84 │     241.6 │     11.2 │  6.36 │
# │  Moderate │  10.68 │       6.8 │    178.4 │  4.12 │
# │      Poor │   0.36 │      4.84 │      5.8 │ 189.0 │
# └───────────┴────────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 8
#  Hyperparameters: Dict("topology" => [10, 8, 6, 4])
# =====================================================
#  Accuracy (mean)               : 0.9441
#  Accuracy (std)                : 0.0077
#  Error Rate (mean)             : 0.0559
#  Error Rate (std)              : 0.0077
#  Sensitivity/Recall (mean)     : 0.9441
#  Sensitivity/Recall (std)      : 0.0077
#  Specificity (mean)            : 0.9837
#  Specificity (std)             : 0.0017
#  PPV (mean)                    : 0.9438
#  PPV (std)                     : 0.0075
#  NPV (mean)                    : 0.9859
#  NPV (std)                     : 0.0021
#  F1 Score (mean)               : 0.9437
#  F1 Score (std)                : 0.0075
#
# Confusion Matrix:
# Float32[332.91998 0.4 6.24 0.44; 0.88 244.56001 8.08 6.4800005; 10.88 7.2 177.84 4.0800004; 0.36 4.96 5.92 188.76001]
# ┌───────────┬────────┬───────────┬──────────┬────────┐
# │           │   Good │ Hazardous │ Moderate │   Poor │
# ├───────────┼────────┼───────────┼──────────┼────────┤
# │      Good │ 332.92 │       0.4 │     6.24 │   0.44 │
# │ Hazardous │   0.88 │    244.56 │     8.08 │   6.48 │
# │  Moderate │  10.88 │       7.2 │   177.84 │   4.08 │
# │      Poor │   0.36 │      4.96 │     5.92 │ 188.76 │
# └───────────┴────────┴───────────┴──────────┴────────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 6
#  Hyperparameters: Dict("topology" => [10, 12, 6, 4])
# =====================================================
#  Accuracy (mean)               : 0.944
#  Accuracy (std)                : 0.0068
#  Error Rate (mean)             : 0.056
#  Error Rate (std)              : 0.0068
#  Sensitivity/Recall (mean)     : 0.944
#  Sensitivity/Recall (std)      : 0.0068
#  Specificity (mean)            : 0.9837
#  Specificity (std)             : 0.0016
#  PPV (mean)                    : 0.9437
#  PPV (std)                     : 0.0066
#  NPV (mean)                    : 0.9861
#  NPV (std)                     : 0.0018
#  F1 Score (mean)               : 0.9437
#  F1 Score (std)                : 0.0067
#
# Confusion Matrix:
# Float32[333.24 0.32 6.0 0.44; 0.88 244.6 8.160001 6.3599997; 11.079999 7.2 177.43999 4.2799997; 0.32 4.88 6.04 188.76]
# ┌───────────┬────────┬───────────┬──────────┬────────┐
# │           │   Good │ Hazardous │ Moderate │   Poor │
# ├───────────┼────────┼───────────┼──────────┼────────┤
# │      Good │ 333.24 │      0.32 │      6.0 │   0.44 │
# │ Hazardous │   0.88 │     244.6 │     8.16 │   6.36 │
# │  Moderate │  11.08 │       7.2 │   177.44 │   4.28 │
# │      Poor │   0.32 │      4.88 │     6.04 │ 188.76 │
# └───────────┴────────┴───────────┴──────────┴────────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 7
#  Hyperparameters: Dict("topology" => [10, 12, 6, 4])
# =====================================================
#  Accuracy (mean)               : 0.9443
#  Accuracy (std)                : 0.0071
#  Error Rate (mean)             : 0.0557
#  Error Rate (std)              : 0.0071
#  Sensitivity/Recall (mean)     : 0.9443
#  Sensitivity/Recall (std)      : 0.0071
#  Specificity (mean)            : 0.9839
#  Specificity (std)             : 0.002
#  PPV (mean)                    : 0.944
#  PPV (std)                     : 0.007
#  NPV (mean)                    : 0.986
#  NPV (std)                     : 0.0018
#  F1 Score (mean)               : 0.944
#  F1 Score (std)                : 0.0071
#
# Confusion Matrix:
# Float32[332.8 0.44 6.16 0.6; 0.96000004 243.96 8.52 6.56; 9.960001 7.2400002 178.56 4.2400002; 0.32 5.0 5.7200003 188.95999]
# ┌───────────┬───────┬───────────┬──────────┬────────┐
# │           │  Good │ Hazardous │ Moderate │   Poor │
# ├───────────┼───────┼───────────┼──────────┼────────┤
# │      Good │ 332.8 │      0.44 │     6.16 │    0.6 │
# │ Hazardous │  0.96 │    243.96 │     8.52 │   6.56 │
# │  Moderate │  9.96 │      7.24 │   178.56 │   4.24 │
# │      Poor │  0.32 │       5.0 │     5.72 │ 188.96 │
# └───────────┴───────┴───────────┴──────────┴────────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 8
#  Hyperparameters: Dict("topology" => [10, 12, 6, 4])
# =====================================================
#  Accuracy (mean)               : 0.9445
#  Accuracy (std)                : 0.0073
#  Error Rate (mean)             : 0.0555
#  Error Rate (std)              : 0.0073
#  Sensitivity/Recall (mean)     : 0.9445
#  Sensitivity/Recall (std)      : 0.0073
#  Specificity (mean)            : 0.9837
#  Specificity (std)             : 0.0018
#  PPV (mean)                    : 0.9441
#  PPV (std)                     : 0.0073
#  NPV (mean)                    : 0.9861
#  NPV (std)                     : 0.0018
#  F1 Score (mean)               : 0.9441
#  F1 Score (std)                : 0.0073
#
# Confusion Matrix:
# Float32[333.4 0.36 5.72 0.52; 0.76 244.36002 8.4800005 6.4; 10.960001 7.0 177.76 4.28; 0.32 5.0800004 5.6400003 188.96]
# ┌───────────┬───────┬───────────┬──────────┬────────┐
# │           │  Good │ Hazardous │ Moderate │   Poor │
# ├───────────┼───────┼───────────┼──────────┼────────┤
# │      Good │ 333.4 │      0.36 │     5.72 │   0.52 │
# │ Hazardous │  0.76 │    244.36 │     8.48 │    6.4 │
# │  Moderate │ 10.96 │       7.0 │   177.76 │   4.28 │
# │      Poor │  0.32 │      5.08 │     5.64 │ 188.96 │
# └───────────┴───────┴───────────┴──────────┴────────┘
# =====================================================

# %% [markdown]
# # Support Vector Machines

# %%
SVMClassifier = MLJ.@load SVC pkg=LIBSVM verbosity=0
# Out:
# MLJLIBSVMInterface.SVC

# %%
############# 2. SVM (8+ configs: kernels × C) #############
default_svm = Dict(
    "gamma" => 1.0,
    "degree" => 3,
    "coef0" => 0.0
)

svm_search_space = [
    Dict("kernel"=>"linear",  "C"=>0.1),
    Dict("kernel"=>"linear",  "C"=>1.0),
    Dict("kernel"=>"linear",  "C"=>10.0),
    Dict("kernel"=>"rbf",     "C"=>1.0, "gamma"=>2.0),
    Dict("kernel"=>"rbf",     "C"=>10.0,"gamma"=>0.5),
    Dict("kernel"=>"sigmoid", "C"=>1.0, "gamma"=>1.0),
    Dict("kernel"=>"poly",    "C"=>1.0, "degree"=>3, "gamma"=>1.0),
    Dict("kernel"=>"poly",    "C"=>5.0, "degree"=>4, "gamma"=>0.5),
]
# Out:
# 8-element Vector{Dict{String, Any}}:
#  Dict("C" => 0.1, "kernel" => "linear")
#  Dict("C" => 1.0, "kernel" => "linear")
#  Dict("C" => 10.0, "kernel" => "linear")
#  Dict("C" => 1.0, "kernel" => "rbf", "gamma" => 2.0)
#  Dict("C" => 10.0, "kernel" => "rbf", "gamma" => 0.5)
#  Dict("C" => 1.0, "kernel" => "sigmoid", "gamma" => 1.0)
#  Dict("C" => 1.0, "kernel" => "poly", "gamma" => 1.0, "degree" => 3)
#  Dict("C" => 5.0, "kernel" => "poly", "gamma" => 0.5, "degree" => 4)

# %%
########################
# 2. SVM GRID SEARCH
########################
svm_results = []

for hp in svm_search_space
    for dim in dimsPCA
        println("\n=== SVM experiment: kernel=$(hp["kernel"]) C=$(get(hp,"C","-")) | PCA maxoutdim = $(dim) ===")
        full_hp = merge(default_svm, hp)
        res = modelCrossValidationPCA(:SVC, full_hp, (inputs, targets), crossValidationIndices, dim)
        push!(svm_results, (model=:SVC, hyperparams=hp, dimPCA=dim, results=res))
    end
end

results[:SVC] = svm_results
# Out:
# === SVM experiment: kernel=linear C=0.1 | PCA maxoutdim = 6 ===
#
# === SVM experiment: kernel=linear C=0.1 | PCA maxoutdim = 7 ===
#
# === SVM experiment: kernel=linear C=0.1 | PCA maxoutdim = 8 ===
#
# === SVM experiment: kernel=linear C=1.0 | PCA maxoutdim = 6 ===
#
# === SVM experiment: kernel=linear C=1.0 | PCA maxoutdim = 7 ===
#
# === SVM experiment: kernel=linear C=1.0 | PCA maxoutdim = 8 ===
#
# === SVM experiment: kernel=linear C=10.0 | PCA maxoutdim = 6 ===
#
# === SVM experiment: kernel=linear C=10.0 | PCA maxoutdim = 7 ===
#
# === SVM experiment: kernel=linear C=10.0 | PCA maxoutdim = 8 ===
#
# === SVM experiment: kernel=rbf C=1.0 | PCA maxoutdim = 6 ===
#
# === SVM experiment: kernel=rbf C=1.0 | PCA maxoutdim = 7 ===
#
# === SVM experiment: kernel=rbf C=1.0 | PCA maxoutdim = 8 ===
#
# === SVM experiment: kernel=rbf C=10.0 | PCA maxoutdim = 6 ===
#
# === SVM experiment: kernel=rbf C=10.0 | PCA maxoutdim = 7 ===
#
# === SVM experiment: kernel=rbf C=10.0 | PCA maxoutdim = 8 ===
#
# === SVM experiment: kernel=sigmoid C=1.0 | PCA maxoutdim = 6 ===
#
# === SVM experiment: kernel=sigmoid C=1.0 | PCA maxoutdim = 7 ===
#
# === SVM experiment: kernel=sigmoid C=1.0 | PCA maxoutdim = 8 ===
#
# === SVM experiment: kernel=poly C=1.0 | PCA maxoutdim = 6 ===
#
# === SVM experiment: kernel=poly C=1.0 | PCA maxoutdim = 7 ===
#
# === SVM experiment: kernel=poly C=1.0 | PCA maxoutdim = 8 ===
#
# === SVM experiment: kernel=poly C=5.0 | PCA maxoutdim = 6 ===
#
# === SVM experiment: kernel=poly C=5.0 | PCA maxoutdim = 7 ===
#
# === SVM experiment: kernel=poly C=5.0 | PCA maxoutdim = 8 ===
# 24-element Vector{Any}:
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 0.1, "kernel" => "linear"), dimPCA = 6, results = ((0.9195999f0, 0.009423383f0), (0.080400005f0, 0.009423374f0), (0.9195999f0, 0.009423383f0), (0.9710825f0, 0.0037891099f0), (0.9199994f0, 0.008790069f0), (0.9810745f0, 0.0022209468f0), (0.91775674f0, 0.009813511f0), Float32[330.2 4.0 4.2 1.6; 0.2 240.2 10.6 9.0; 19.2 9.0 170.0 1.8; 2.4 7.2 11.2 179.2]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 0.1, "kernel" => "linear"), dimPCA = 7, results = ((0.92080003f0, 0.010686428f0), (0.0792f0, 0.01068644f0), (0.92080003f0, 0.010686428f0), (0.97122383f0, 0.0043843295f0), (0.9211836f0, 0.010112118f0), (0.98120815f0, 0.0025284868f0), (0.91903895f0, 0.011139641f0), Float32[330.2 4.0 4.2 1.6; 0.2 241.0 9.8 9.0; 19.8 8.8 169.6 1.8; 2.6 6.8 10.6 180.0]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 0.1, "kernel" => "linear"), dimPCA = 8, results = ((0.92480004f0, 0.009444583f0), (0.0752f0, 0.009444576f0), (0.92480004f0, 0.009444583f0), (0.97346985f0, 0.0035542073f0), (0.9251591f0, 0.008913112f0), (0.98260003f0, 0.0020032465f0), (0.92310584f0, 0.009878529f0), Float32[331.8 3.2 3.6 1.4; 0.2 241.8 9.8 8.2; 18.6 9.2 170.6 1.6; 2.0 7.0 10.4 180.6]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 1.0, "kernel" => "linear"), dimPCA = 6, results = ((0.93299997f0, 0.008746429f0), (0.067f0, 0.0087464275f0), (0.93299997f0, 0.008746429f0), (0.97754765f0, 0.0034386416f0), (0.93251705f0, 0.0083931275f0), (0.9833845f0, 0.0020942513f0), (0.9321022f0, 0.008999404f0), Float32[330.4 2.4 6.4 0.8; 0.4 242.4 8.4 8.8; 15.2 7.8 173.6 3.4; 1.4 5.0 7.0 186.6]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 1.0, "kernel" => "linear"), dimPCA = 7, results = ((0.9332f0, 0.009093944f0), (0.0668f0, 0.009093953f0), (0.9332f0, 0.009093944f0), (0.9777444f0, 0.0031013635f0), (0.932876f0, 0.008638319f0), (0.9834383f0, 0.0021604728f0), (0.93236893f0, 0.009197279f0), Float32[331.0 2.0 6.2 0.8; 0.4 242.4 8.0 9.2; 16.0 7.6 173.2 3.2; 1.2 5.2 7.0 186.6]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 1.0, "kernel" => "linear"), dimPCA = 8, results = ((0.93520004f0, 0.005263071f0), (0.0648f0, 0.005263079f0), (0.93520004f0, 0.005263071f0), (0.9791889f0, 0.0019815045f0), (0.9348813f0, 0.0048132967f0), (0.9842211f0, 0.0014605136f0), (0.9344314f0, 0.005167214f0), Float32[332.8 1.0 6.0 0.2; 0.2 243.8 8.0 8.0; 16.2 8.0 172.6 3.2; 1.0 5.6 7.4 186.0]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 10.0, "kernel" => "linear"), dimPCA = 6, results = ((0.9322001f0, 0.008700585f0), (0.0678f0, 0.008700576f0), (0.9322001f0, 0.008700585f0), (0.9783039f0, 0.0033745756f0), (0.9316734f0, 0.008549421f0), (0.9825155f0, 0.0022856686f0), (0.9315602f0, 0.008793553f0), Float32[329.8 2.2 7.4 0.6; 0.6 242.2 8.0 9.2; 14.6 8.2 173.6 3.6; 1.2 5.8 6.4 186.6]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 10.0, "kernel" => "linear"), dimPCA = 7, results = ((0.93439996f0, 0.009044345f0), (0.0656f0, 0.009044334f0), (0.93439996f0, 0.009044345f0), (0.97957623f0, 0.0033690713f0), (0.9340178f0, 0.008761294f0), (0.9833085f0, 0.0022117924f0), (0.933848f0, 0.009123408f0), Float32[331.0 1.2 7.6 0.2; 0.4 243.6 7.2 8.8; 14.4 8.4 173.2 4.0; 1.0 6.0 6.4 186.6]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 10.0, "kernel" => "linear"), dimPCA = 8, results = ((0.93640006f0, 0.008142491f0), (0.0636f0, 0.008142481f0), (0.93640006f0, 0.008142491f0), (0.9805921f0, 0.0024116433f0), (0.9359125f0, 0.008144789f0), (0.98408854f0, 0.002334362f0), (0.9358462f0, 0.008076648f0), Float32[332.8 0.8 6.2 0.2; 0.2 243.2 8.6 8.0; 14.4 8.2 174.2 3.2; 1.0 6.0 6.8 186.2]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 1.0, "kernel" => "rbf", "gamma" => 2.0), dimPCA = 6, results = ((0.93740004f0, 0.006655817f0), (0.0626f0, 0.006655824f0), (0.93740004f0, 0.006655817f0), (0.9801754f0, 0.0024339443f0), (0.93690795f0, 0.0063669225f0), (0.98475707f0, 0.0018456472f0), (0.9366827f0, 0.006702897f0), Float32[331.0 2.0 6.6 0.4; 0.2 243.8 7.6 8.4; 13.2 8.2 175.0 3.6; 0.8 4.8 6.8 187.6]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 1.0, "kernel" => "rbf", "gamma" => 2.0), dimPCA = 7, results = ((0.93999994f0, 0.0065192124f0), (0.059999995f0, 0.006519201f0), (0.93999994f0, 0.0065192124f0), (0.98084927f0, 0.0018959906f0), (0.9396842f0, 0.006189164f0), (0.98512965f0, 0.0017899716f0), (0.9393932f0, 0.0064516948f0), Float32[331.6 1.6 6.2 0.6; 0.4 244.4 7.6 7.6; 13.4 7.8 175.4 3.4; 0.8 4.6 6.0 188.6]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 1.0, "kernel" => "rbf", "gamma" => 2.0), dimPCA = 8, results = ((0.943f0, 0.00674537f0), (0.057f0, 0.0067453682f0), (0.943f0, 0.00674537f0), (0.9826865f0, 0.0011892277f0), (0.94263476f0, 0.006768912f0), (0.9863818f0, 0.0019890445f0), (0.9424197f0, 0.006626756f0), Float32[334.0 0.6 5.2 0.2; 0.2 245.0 7.8 7.0; 13.4 7.8 175.2 3.6; 0.4 4.4 6.4 188.8]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 10.0, "kernel" => "rbf", "gamma" => 0.5), dimPCA = 6, results = ((0.93640006f0, 0.008264388f0), (0.063599996f0, 0.008264382f0), (0.93640006f0, 0.008264388f0), (0.9797349f0, 0.0023636222f0), (0.9358096f0, 0.00809648f0), (0.9840201f0, 0.0024023612f0), (0.9357499f0, 0.008225026f0), Float32[330.4 2.0 7.0 0.6; 0.4 243.6 7.8 8.2; 14.2 8.0 174.2 3.6; 0.8 5.0 6.0 188.2]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 10.0, "kernel" => "rbf", "gamma" => 0.5), dimPCA = 7, results = ((0.93920004f0, 0.007854931f0), (0.060799997f0, 0.007854934f0), (0.93920004f0, 0.007854931f0), (0.9807445f0, 0.0023753182f0), (0.93865746f0, 0.007715486f0), (0.98489857f0, 0.0019372335f0), (0.93857557f0, 0.007896205f0), Float32[331.8 1.6 6.2 0.4; 0.4 244.2 7.8 7.6; 14.2 7.6 174.6 3.6; 0.8 4.8 5.8 188.6]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 10.0, "kernel" => "rbf", "gamma" => 0.5), dimPCA = 8, results = ((0.94060004f0, 0.0057271183f0), (0.059400003f0, 0.0057271286f0), (0.94060004f0, 0.0057271183f0), (0.98165f0, 0.0014608843f0), (0.94035465f0, 0.0053676153f0), (0.9856142f0, 0.0014510222f0), (0.9399992f0, 0.005632248f0), Float32[333.6 0.8 5.4 0.2; 0.2 244.0 8.0 7.8; 13.8 8.0 174.8 3.4; 0.4 4.8 6.6 188.2]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 1.0, "kernel" => "sigmoid", "gamma" => 1.0), dimPCA = 6, results = ((0.93299997f0, 0.008746439f0), (0.066999994f0, 0.0087464275f0), (0.93299997f0, 0.008746439f0), (0.9776667f0, 0.0032427977f0), (0.9324029f0, 0.008611399f0), (0.9831392f0, 0.002028955f0), (0.93214464f0, 0.008953779f0), Float32[330.2 2.4 6.6 0.8; 0.4 242.2 8.4 9.0; 15.2 8.0 173.2 3.6; 1.4 4.6 6.6 187.4]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 1.0, "kernel" => "sigmoid", "gamma" => 1.0), dimPCA = 7, results = ((0.93299997f0, 0.008455782f0), (0.066999994f0, 0.008455767f0), (0.93299997f0, 0.008455782f0), (0.9780159f0, 0.0030190134f0), (0.9324633f0, 0.008338141f0), (0.9831219f0, 0.0019833667f0), (0.9321839f0, 0.008610759f0), Float32[330.8 2.0 6.4 0.8; 0.4 243.0 7.4 9.2; 15.8 8.4 172.0 3.8; 1.2 5.0 6.6 187.2]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 1.0, "kernel" => "sigmoid", "gamma" => 1.0), dimPCA = 8, results = ((0.93439996f0, 0.0061886953f0), (0.0656f0, 0.0061886995f0), (0.93439996f0, 0.0061886953f0), (0.97923887f0, 0.00190348f0), (0.93381786f0, 0.0060754367f0), (0.9839033f0, 0.0018369127f0), (0.9336318f0, 0.006074664f0), Float32[332.8 1.0 6.0 0.2; 0.2 243.4 8.0 8.4; 16.2 8.6 172.0 3.2; 1.0 5.4 7.4 186.2]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 1.0, "kernel" => "poly", "gamma" => 1.0, "degree" => 3), dimPCA = 6, results = ((0.77120006f0, 0.01649849f0), (0.22880001f0, 0.016498484f0), (0.77120006f0, 0.01649849f0), (0.9082802f0, 0.007516502f0), (0.8290288f0, 0.0101573095f0), (0.9192522f0, 0.0059213047f0), (0.7691617f0, 0.016893696f0), Float32[302.8 0.4 17.6 19.2; 37.4 174.6 25.0 23.0; 63.8 7.4 125.8 3.0; 17.4 5.0 9.6 168.0]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 1.0, "kernel" => "poly", "gamma" => 1.0, "degree" => 3), dimPCA = 7, results = ((0.7728f0, 0.016146194f0), (0.22719999f0, 0.016146205f0), (0.7728f0, 0.016146194f0), (0.9089936f0, 0.00738599f0), (0.83020127f0, 0.009663338f0), (0.919679f0, 0.006069558f0), (0.7709363f0, 0.016137557f0), Float32[303.2 0.4 17.4 19.0; 37.6 174.6 24.8 23.0; 63.0 7.6 126.4 3.0; 17.2 5.0 9.2 168.6]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 1.0, "kernel" => "poly", "gamma" => 1.0, "degree" => 3), dimPCA = 8, results = ((0.7762f0, 0.015188818f0), (0.22380002f0, 0.015188814f0), (0.7762f0, 0.015188818f0), (0.9102167f0, 0.007078481f0), (0.8326608f0, 0.009145356f0), (0.9207999f0, 0.0056140902f0), (0.77447045f0, 0.015537499f0), Float32[303.6 0.4 17.4 18.6; 36.4 175.2 25.6 22.8; 62.2 7.2 128.2 2.4; 17.2 4.8 8.8 169.2]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 5.0, "kernel" => "poly", "gamma" => 0.5, "degree" => 4), dimPCA = 6, results = ((0.454f0, 0.0031622746f0), (0.546f0, 0.0031622746f0), (0.454f0, 0.0031622746f0), (0.6367222f0, 0.0018592317f0), (0.2915225f0, 0.0546957f0), (0.863719f0, 0.0033472215f0), (0.3083642f0, 0.0034048606f0), Float32[160.0 120.0 0.0 60.0; 79.2 171.4 0.0 9.4; 69.6 80.6 10.0 39.8; 69.8 17.6 0.0 112.6]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 5.0, "kernel" => "poly", "gamma" => 0.5, "degree" => 4), dimPCA = 7, results = ((0.45479998f0, 0.003962325f0), (0.5452f0, 0.003962336f0), (0.45479998f0, 0.003962325f0), (0.63714445f0, 0.0026186693f0), (0.29204148f0, 0.05450832f0), (0.86385214f0, 0.0031782424f0), (0.30920795f0, 0.004162033f0), Float32[160.0 120.0 0.0 60.0; 79.4 171.4 0.0 9.2; 69.4 80.6 10.2 39.8; 70.0 16.8 0.0 113.2]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 5.0, "kernel" => "poly", "gamma" => 0.5, "degree" => 4), dimPCA = 8, results = ((0.4558f0, 0.0035637019f0), (0.5442f0, 0.0035637128f0), (0.4558f0, 0.0035637019f0), (0.63781106f0, 0.00254575f0), (0.2923206f0, 0.054227613f0), (0.8653364f0, 0.0003407528f0), (0.31013155f0, 0.0030632918f0), Float32[160.0 120.0 0.0 60.0; 79.4 172.2 0.0 8.4; 69.6 80.4 10.0 40.0; 69.4 17.0 0.0 113.6]))

# %%
for entry in results[:SVC]
    printExperimentResult(entry.model, entry.hyperparams, entry.dimPCA, entry.results, label_names)
end
# Out:
# =====================================================
#  Model: SVC | PCA outdim: 6
#  Hyperparameters: Dict{String, Any}("C" => 0.1, "kernel" => "linear")
# =====================================================
#  Accuracy (mean)               : 0.9196
#  Accuracy (std)                : 0.0094
#  Error Rate (mean)             : 0.0804
#  Error Rate (std)              : 0.0094
#  Sensitivity/Recall (mean)     : 0.9196
#  Sensitivity/Recall (std)      : 0.0094
#  Specificity (mean)            : 0.9711
#  Specificity (std)             : 0.0038
#  PPV (mean)                    : 0.92
#  PPV (std)                     : 0.0088
#  NPV (mean)                    : 0.9811
#  NPV (std)                     : 0.0022
#  F1 Score (mean)               : 0.9178
#  F1 Score (std)                : 0.0098
#
# Confusion Matrix:
# Float32[330.2 4.0 4.2 1.6; 0.2 240.2 10.6 9.0; 19.2 9.0 170.0 1.8; 2.4 7.2 11.2 179.2]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 330.2 │       4.0 │      4.2 │   1.6 │
# │ Hazardous │   0.2 │     240.2 │     10.6 │   9.0 │
# │  Moderate │  19.2 │       9.0 │    170.0 │   1.8 │
# │      Poor │   2.4 │       7.2 │     11.2 │ 179.2 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 7
#  Hyperparameters: Dict{String, Any}("C" => 0.1, "kernel" => "linear")
# =====================================================
#  Accuracy (mean)               : 0.9208
#  Accuracy (std)                : 0.0107
#  Error Rate (mean)             : 0.0792
#  Error Rate (std)              : 0.0107
#  Sensitivity/Recall (mean)     : 0.9208
#  Sensitivity/Recall (std)      : 0.0107
#  Specificity (mean)            : 0.9712
#  Specificity (std)             : 0.0044
#  PPV (mean)                    : 0.9212
#  PPV (std)                     : 0.0101
#  NPV (mean)                    : 0.9812
#  NPV (std)                     : 0.0025
#  F1 Score (mean)               : 0.919
#  F1 Score (std)                : 0.0111
#
# Confusion Matrix:
# Float32[330.2 4.0 4.2 1.6; 0.2 241.0 9.8 9.0; 19.8 8.8 169.6 1.8; 2.6 6.8 10.6 180.0]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 330.2 │       4.0 │      4.2 │   1.6 │
# │ Hazardous │   0.2 │     241.0 │      9.8 │   9.0 │
# │  Moderate │  19.8 │       8.8 │    169.6 │   1.8 │
# │      Poor │   2.6 │       6.8 │     10.6 │ 180.0 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 8
#  Hyperparameters: Dict{String, Any}("C" => 0.1, "kernel" => "linear")
# =====================================================
#  Accuracy (mean)               : 0.9248
#  Accuracy (std)                : 0.0094
#  Error Rate (mean)             : 0.0752
#  Error Rate (std)              : 0.0094
#  Sensitivity/Recall (mean)     : 0.9248
#  Sensitivity/Recall (std)      : 0.0094
#  Specificity (mean)            : 0.9735
#  Specificity (std)             : 0.0036
#  PPV (mean)                    : 0.9252
#  PPV (std)                     : 0.0089
#  NPV (mean)                    : 0.9826
#  NPV (std)                     : 0.002
#  F1 Score (mean)               : 0.9231
#  F1 Score (std)                : 0.0099
#
# Confusion Matrix:
# Float32[331.8 3.2 3.6 1.4; 0.2 241.8 9.8 8.2; 18.6 9.2 170.6 1.6; 2.0 7.0 10.4 180.6]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 331.8 │       3.2 │      3.6 │   1.4 │
# │ Hazardous │   0.2 │     241.8 │      9.8 │   8.2 │
# │  Moderate │  18.6 │       9.2 │    170.6 │   1.6 │
# │      Poor │   2.0 │       7.0 │     10.4 │ 180.6 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 6
#  Hyperparameters: Dict{String, Any}("C" => 1.0, "kernel" => "linear")
# =====================================================
#  Accuracy (mean)               : 0.933
#  Accuracy (std)                : 0.0087
#  Error Rate (mean)             : 0.067
#  Error Rate (std)              : 0.0087
#  Sensitivity/Recall (mean)     : 0.933
#  Sensitivity/Recall (std)      : 0.0087
#  Specificity (mean)            : 0.9775
#  Specificity (std)             : 0.0034
#  PPV (mean)                    : 0.9325
#  PPV (std)                     : 0.0084
#  NPV (mean)                    : 0.9834
#  NPV (std)                     : 0.0021
#  F1 Score (mean)               : 0.9321
#  F1 Score (std)                : 0.009
#
# Confusion Matrix:
# Float32[330.4 2.4 6.4 0.8; 0.4 242.4 8.4 8.8; 15.2 7.8 173.6 3.4; 1.4 5.0 7.0 186.6]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 330.4 │       2.4 │      6.4 │   0.8 │
# │ Hazardous │   0.4 │     242.4 │      8.4 │   8.8 │
# │  Moderate │  15.2 │       7.8 │    173.6 │   3.4 │
# │      Poor │   1.4 │       5.0 │      7.0 │ 186.6 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 7
#  Hyperparameters: Dict{String, Any}("C" => 1.0, "kernel" => "linear")
# =====================================================
#  Accuracy (mean)               : 0.9332
#  Accuracy (std)                : 0.0091
#  Error Rate (mean)             : 0.0668
#  Error Rate (std)              : 0.0091
#  Sensitivity/Recall (mean)     : 0.9332
#  Sensitivity/Recall (std)      : 0.0091
#  Specificity (mean)            : 0.9777
#  Specificity (std)             : 0.0031
#  PPV (mean)                    : 0.9329
#  PPV (std)                     : 0.0086
#  NPV (mean)                    : 0.9834
#  NPV (std)                     : 0.0022
#  F1 Score (mean)               : 0.9324
#  F1 Score (std)                : 0.0092
#
# Confusion Matrix:
# Float32[331.0 2.0 6.2 0.8; 0.4 242.4 8.0 9.2; 16.0 7.6 173.2 3.2; 1.2 5.2 7.0 186.6]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 331.0 │       2.0 │      6.2 │   0.8 │
# │ Hazardous │   0.4 │     242.4 │      8.0 │   9.2 │
# │  Moderate │  16.0 │       7.6 │    173.2 │   3.2 │
# │      Poor │   1.2 │       5.2 │      7.0 │ 186.6 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 8
#  Hyperparameters: Dict{String, Any}("C" => 1.0, "kernel" => "linear")
# =====================================================
#  Accuracy (mean)               : 0.9352
#  Accuracy (std)                : 0.0053
#  Error Rate (mean)             : 0.0648
#  Error Rate (std)              : 0.0053
#  Sensitivity/Recall (mean)     : 0.9352
#  Sensitivity/Recall (std)      : 0.0053
#  Specificity (mean)            : 0.9792
#  Specificity (std)             : 0.002
#  PPV (mean)                    : 0.9349
#  PPV (std)                     : 0.0048
#  NPV (mean)                    : 0.9842
#  NPV (std)                     : 0.0015
#  F1 Score (mean)               : 0.9344
#  F1 Score (std)                : 0.0052
#
# Confusion Matrix:
# Float32[332.8 1.0 6.0 0.2; 0.2 243.8 8.0 8.0; 16.2 8.0 172.6 3.2; 1.0 5.6 7.4 186.0]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 332.8 │       1.0 │      6.0 │   0.2 │
# │ Hazardous │   0.2 │     243.8 │      8.0 │   8.0 │
# │  Moderate │  16.2 │       8.0 │    172.6 │   3.2 │
# │      Poor │   1.0 │       5.6 │      7.4 │ 186.0 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 6
#  Hyperparameters: Dict{String, Any}("C" => 10.0, "kernel" => "linear")
# =====================================================
#  Accuracy (mean)               : 0.9322
#  Accuracy (std)                : 0.0087
#  Error Rate (mean)             : 0.0678
#  Error Rate (std)              : 0.0087
#  Sensitivity/Recall (mean)     : 0.9322
#  Sensitivity/Recall (std)      : 0.0087
#  Specificity (mean)            : 0.9783
#  Specificity (std)             : 0.0034
#  PPV (mean)                    : 0.9317
#  PPV (std)                     : 0.0085
#  NPV (mean)                    : 0.9825
#  NPV (std)                     : 0.0023
#  F1 Score (mean)               : 0.9316
#  F1 Score (std)                : 0.0088
#
# Confusion Matrix:
# Float32[329.8 2.2 7.4 0.6; 0.6 242.2 8.0 9.2; 14.6 8.2 173.6 3.6; 1.2 5.8 6.4 186.6]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 329.8 │       2.2 │      7.4 │   0.6 │
# │ Hazardous │   0.6 │     242.2 │      8.0 │   9.2 │
# │  Moderate │  14.6 │       8.2 │    173.6 │   3.6 │
# │      Poor │   1.2 │       5.8 │      6.4 │ 186.6 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 7
#  Hyperparameters: Dict{String, Any}("C" => 10.0, "kernel" => "linear")
# =====================================================
#  Accuracy (mean)               : 0.9344
#  Accuracy (std)                : 0.009
#  Error Rate (mean)             : 0.0656
#  Error Rate (std)              : 0.009
#  Sensitivity/Recall (mean)     : 0.9344
#  Sensitivity/Recall (std)      : 0.009
#  Specificity (mean)            : 0.9796
#  Specificity (std)             : 0.0034
#  PPV (mean)                    : 0.934
#  PPV (std)                     : 0.0088
#  NPV (mean)                    : 0.9833
#  NPV (std)                     : 0.0022
#  F1 Score (mean)               : 0.9338
#  F1 Score (std)                : 0.0091
#
# Confusion Matrix:
# Float32[331.0 1.2 7.6 0.2; 0.4 243.6 7.2 8.8; 14.4 8.4 173.2 4.0; 1.0 6.0 6.4 186.6]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 331.0 │       1.2 │      7.6 │   0.2 │
# │ Hazardous │   0.4 │     243.6 │      7.2 │   8.8 │
# │  Moderate │  14.4 │       8.4 │    173.2 │   4.0 │
# │      Poor │   1.0 │       6.0 │      6.4 │ 186.6 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 8
#  Hyperparameters: Dict{String, Any}("C" => 10.0, "kernel" => "linear")
# =====================================================
#  Accuracy (mean)               : 0.9364
#  Accuracy (std)                : 0.0081
#  Error Rate (mean)             : 0.0636
#  Error Rate (std)              : 0.0081
#  Sensitivity/Recall (mean)     : 0.9364
#  Sensitivity/Recall (std)      : 0.0081
#  Specificity (mean)            : 0.9806
#  Specificity (std)             : 0.0024
#  PPV (mean)                    : 0.9359
#  PPV (std)                     : 0.0081
#  NPV (mean)                    : 0.9841
#  NPV (std)                     : 0.0023
#  F1 Score (mean)               : 0.9358
#  F1 Score (std)                : 0.0081
#
# Confusion Matrix:
# Float32[332.8 0.8 6.2 0.2; 0.2 243.2 8.6 8.0; 14.4 8.2 174.2 3.2; 1.0 6.0 6.8 186.2]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 332.8 │       0.8 │      6.2 │   0.2 │
# │ Hazardous │   0.2 │     243.2 │      8.6 │   8.0 │
# │  Moderate │  14.4 │       8.2 │    174.2 │   3.2 │
# │      Poor │   1.0 │       6.0 │      6.8 │ 186.2 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 6
#  Hyperparameters: Dict{String, Any}("C" => 1.0, "kernel" => "rbf", "gamma" => 2.0)
# =====================================================
#  Accuracy (mean)               : 0.9374
#  Accuracy (std)                : 0.0067
#  Error Rate (mean)             : 0.0626
#  Error Rate (std)              : 0.0067
#  Sensitivity/Recall (mean)     : 0.9374
#  Sensitivity/Recall (std)      : 0.0067
#  Specificity (mean)            : 0.9802
#  Specificity (std)             : 0.0024
#  PPV (mean)                    : 0.9369
#  PPV (std)                     : 0.0064
#  NPV (mean)                    : 0.9848
#  NPV (std)                     : 0.0018
#  F1 Score (mean)               : 0.9367
#  F1 Score (std)                : 0.0067
#
# Confusion Matrix:
# Float32[331.0 2.0 6.6 0.4; 0.2 243.8 7.6 8.4; 13.2 8.2 175.0 3.6; 0.8 4.8 6.8 187.6]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 331.0 │       2.0 │      6.6 │   0.4 │
# │ Hazardous │   0.2 │     243.8 │      7.6 │   8.4 │
# │  Moderate │  13.2 │       8.2 │    175.0 │   3.6 │
# │      Poor │   0.8 │       4.8 │      6.8 │ 187.6 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 7
#  Hyperparameters: Dict{String, Any}("C" => 1.0, "kernel" => "rbf", "gamma" => 2.0)
# =====================================================
#  Accuracy (mean)               : 0.94
#  Accuracy (std)                : 0.0065
#  Error Rate (mean)             : 0.06
#  Error Rate (std)              : 0.0065
#  Sensitivity/Recall (mean)     : 0.94
#  Sensitivity/Recall (std)      : 0.0065
#  Specificity (mean)            : 0.9808
#  Specificity (std)             : 0.0019
#  PPV (mean)                    : 0.9397
#  PPV (std)                     : 0.0062
#  NPV (mean)                    : 0.9851
#  NPV (std)                     : 0.0018
#  F1 Score (mean)               : 0.9394
#  F1 Score (std)                : 0.0065
#
# Confusion Matrix:
# Float32[331.6 1.6 6.2 0.6; 0.4 244.4 7.6 7.6; 13.4 7.8 175.4 3.4; 0.8 4.6 6.0 188.6]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 331.6 │       1.6 │      6.2 │   0.6 │
# │ Hazardous │   0.4 │     244.4 │      7.6 │   7.6 │
# │  Moderate │  13.4 │       7.8 │    175.4 │   3.4 │
# │      Poor │   0.8 │       4.6 │      6.0 │ 188.6 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 8
#  Hyperparameters: Dict{String, Any}("C" => 1.0, "kernel" => "rbf", "gamma" => 2.0)
# =====================================================
#  Accuracy (mean)               : 0.943
#  Accuracy (std)                : 0.0067
#  Error Rate (mean)             : 0.057
#  Error Rate (std)              : 0.0067
#  Sensitivity/Recall (mean)     : 0.943
#  Sensitivity/Recall (std)      : 0.0067
#  Specificity (mean)            : 0.9827
#  Specificity (std)             : 0.0012
#  PPV (mean)                    : 0.9426
#  PPV (std)                     : 0.0068
#  NPV (mean)                    : 0.9864
#  NPV (std)                     : 0.002
#  F1 Score (mean)               : 0.9424
#  F1 Score (std)                : 0.0066
#
# Confusion Matrix:
# Float32[334.0 0.6 5.2 0.2; 0.2 245.0 7.8 7.0; 13.4 7.8 175.2 3.6; 0.4 4.4 6.4 188.8]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 334.0 │       0.6 │      5.2 │   0.2 │
# │ Hazardous │   0.2 │     245.0 │      7.8 │   7.0 │
# │  Moderate │  13.4 │       7.8 │    175.2 │   3.6 │
# │      Poor │   0.4 │       4.4 │      6.4 │ 188.8 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 6
#  Hyperparameters: Dict{String, Any}("C" => 10.0, "kernel" => "rbf", "gamma" => 0.5)
# =====================================================
#  Accuracy (mean)               : 0.9364
#  Accuracy (std)                : 0.0083
#  Error Rate (mean)             : 0.0636
#  Error Rate (std)              : 0.0083
#  Sensitivity/Recall (mean)     : 0.9364
#  Sensitivity/Recall (std)      : 0.0083
#  Specificity (mean)            : 0.9797
#  Specificity (std)             : 0.0024
#  PPV (mean)                    : 0.9358
#  PPV (std)                     : 0.0081
#  NPV (mean)                    : 0.984
#  NPV (std)                     : 0.0024
#  F1 Score (mean)               : 0.9357
#  F1 Score (std)                : 0.0082
#
# Confusion Matrix:
# Float32[330.4 2.0 7.0 0.6; 0.4 243.6 7.8 8.2; 14.2 8.0 174.2 3.6; 0.8 5.0 6.0 188.2]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 330.4 │       2.0 │      7.0 │   0.6 │
# │ Hazardous │   0.4 │     243.6 │      7.8 │   8.2 │
# │  Moderate │  14.2 │       8.0 │    174.2 │   3.6 │
# │      Poor │   0.8 │       5.0 │      6.0 │ 188.2 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 7
#  Hyperparameters: Dict{String, Any}("C" => 10.0, "kernel" => "rbf", "gamma" => 0.5)
# =====================================================
#  Accuracy (mean)               : 0.9392
#  Accuracy (std)                : 0.0079
#  Error Rate (mean)             : 0.0608
#  Error Rate (std)              : 0.0079
#  Sensitivity/Recall (mean)     : 0.9392
#  Sensitivity/Recall (std)      : 0.0079
#  Specificity (mean)            : 0.9807
#  Specificity (std)             : 0.0024
#  PPV (mean)                    : 0.9387
#  PPV (std)                     : 0.0077
#  NPV (mean)                    : 0.9849
#  NPV (std)                     : 0.0019
#  F1 Score (mean)               : 0.9386
#  F1 Score (std)                : 0.0079
#
# Confusion Matrix:
# Float32[331.8 1.6 6.2 0.4; 0.4 244.2 7.8 7.6; 14.2 7.6 174.6 3.6; 0.8 4.8 5.8 188.6]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 331.8 │       1.6 │      6.2 │   0.4 │
# │ Hazardous │   0.4 │     244.2 │      7.8 │   7.6 │
# │  Moderate │  14.2 │       7.6 │    174.6 │   3.6 │
# │      Poor │   0.8 │       4.8 │      5.8 │ 188.6 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 8
#  Hyperparameters: Dict{String, Any}("C" => 10.0, "kernel" => "rbf", "gamma" => 0.5)
# =====================================================
#  Accuracy (mean)               : 0.9406
#  Accuracy (std)                : 0.0057
#  Error Rate (mean)             : 0.0594
#  Error Rate (std)              : 0.0057
#  Sensitivity/Recall (mean)     : 0.9406
#  Sensitivity/Recall (std)      : 0.0057
#  Specificity (mean)            : 0.9816
#  Specificity (std)             : 0.0015
#  PPV (mean)                    : 0.9404
#  PPV (std)                     : 0.0054
#  NPV (mean)                    : 0.9856
#  NPV (std)                     : 0.0015
#  F1 Score (mean)               : 0.94
#  F1 Score (std)                : 0.0056
#
# Confusion Matrix:
# Float32[333.6 0.8 5.4 0.2; 0.2 244.0 8.0 7.8; 13.8 8.0 174.8 3.4; 0.4 4.8 6.6 188.2]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 333.6 │       0.8 │      5.4 │   0.2 │
# │ Hazardous │   0.2 │     244.0 │      8.0 │   7.8 │
# │  Moderate │  13.8 │       8.0 │    174.8 │   3.4 │
# │      Poor │   0.4 │       4.8 │      6.6 │ 188.2 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 6
#  Hyperparameters: Dict{String, Any}("C" => 1.0, "kernel" => "sigmoid", "gamma" => 1.0)
# =====================================================
#  Accuracy (mean)               : 0.933
#  Accuracy (std)                : 0.0087
#  Error Rate (mean)             : 0.067
#  Error Rate (std)              : 0.0087
#  Sensitivity/Recall (mean)     : 0.933
#  Sensitivity/Recall (std)      : 0.0087
#  Specificity (mean)            : 0.9777
#  Specificity (std)             : 0.0032
#  PPV (mean)                    : 0.9324
#  PPV (std)                     : 0.0086
#  NPV (mean)                    : 0.9831
#  NPV (std)                     : 0.002
#  F1 Score (mean)               : 0.9321
#  F1 Score (std)                : 0.009
#
# Confusion Matrix:
# Float32[330.2 2.4 6.6 0.8; 0.4 242.2 8.4 9.0; 15.2 8.0 173.2 3.6; 1.4 4.6 6.6 187.4]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 330.2 │       2.4 │      6.6 │   0.8 │
# │ Hazardous │   0.4 │     242.2 │      8.4 │   9.0 │
# │  Moderate │  15.2 │       8.0 │    173.2 │   3.6 │
# │      Poor │   1.4 │       4.6 │      6.6 │ 187.4 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 7
#  Hyperparameters: Dict{String, Any}("C" => 1.0, "kernel" => "sigmoid", "gamma" => 1.0)
# =====================================================
#  Accuracy (mean)               : 0.933
#  Accuracy (std)                : 0.0085
#  Error Rate (mean)             : 0.067
#  Error Rate (std)              : 0.0085
#  Sensitivity/Recall (mean)     : 0.933
#  Sensitivity/Recall (std)      : 0.0085
#  Specificity (mean)            : 0.978
#  Specificity (std)             : 0.003
#  PPV (mean)                    : 0.9325
#  PPV (std)                     : 0.0083
#  NPV (mean)                    : 0.9831
#  NPV (std)                     : 0.002
#  F1 Score (mean)               : 0.9322
#  F1 Score (std)                : 0.0086
#
# Confusion Matrix:
# Float32[330.8 2.0 6.4 0.8; 0.4 243.0 7.4 9.2; 15.8 8.4 172.0 3.8; 1.2 5.0 6.6 187.2]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 330.8 │       2.0 │      6.4 │   0.8 │
# │ Hazardous │   0.4 │     243.0 │      7.4 │   9.2 │
# │  Moderate │  15.8 │       8.4 │    172.0 │   3.8 │
# │      Poor │   1.2 │       5.0 │      6.6 │ 187.2 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 8
#  Hyperparameters: Dict{String, Any}("C" => 1.0, "kernel" => "sigmoid", "gamma" => 1.0)
# =====================================================
#  Accuracy (mean)               : 0.9344
#  Accuracy (std)                : 0.0062
#  Error Rate (mean)             : 0.0656
#  Error Rate (std)              : 0.0062
#  Sensitivity/Recall (mean)     : 0.9344
#  Sensitivity/Recall (std)      : 0.0062
#  Specificity (mean)            : 0.9792
#  Specificity (std)             : 0.0019
#  PPV (mean)                    : 0.9338
#  PPV (std)                     : 0.0061
#  NPV (mean)                    : 0.9839
#  NPV (std)                     : 0.0018
#  F1 Score (mean)               : 0.9336
#  F1 Score (std)                : 0.0061
#
# Confusion Matrix:
# Float32[332.8 1.0 6.0 0.2; 0.2 243.4 8.0 8.4; 16.2 8.6 172.0 3.2; 1.0 5.4 7.4 186.2]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 332.8 │       1.0 │      6.0 │   0.2 │
# │ Hazardous │   0.2 │     243.4 │      8.0 │   8.4 │
# │  Moderate │  16.2 │       8.6 │    172.0 │   3.2 │
# │      Poor │   1.0 │       5.4 │      7.4 │ 186.2 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 6
#  Hyperparameters: Dict{String, Any}("C" => 1.0, "kernel" => "poly", "gamma" => 1.0, "degree" => 3)
# =====================================================
#  Accuracy (mean)               : 0.7712
#  Accuracy (std)                : 0.0165
#  Error Rate (mean)             : 0.2288
#  Error Rate (std)              : 0.0165
#  Sensitivity/Recall (mean)     : 0.7712
#  Sensitivity/Recall (std)      : 0.0165
#  Specificity (mean)            : 0.9083
#  Specificity (std)             : 0.0075
#  PPV (mean)                    : 0.829
#  PPV (std)                     : 0.0102
#  NPV (mean)                    : 0.9193
#  NPV (std)                     : 0.0059
#  F1 Score (mean)               : 0.7692
#  F1 Score (std)                : 0.0169
#
# Confusion Matrix:
# Float32[302.8 0.4 17.6 19.2; 37.4 174.6 25.0 23.0; 63.8 7.4 125.8 3.0; 17.4 5.0 9.6 168.0]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 302.8 │       0.4 │     17.6 │  19.2 │
# │ Hazardous │  37.4 │     174.6 │     25.0 │  23.0 │
# │  Moderate │  63.8 │       7.4 │    125.8 │   3.0 │
# │      Poor │  17.4 │       5.0 │      9.6 │ 168.0 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 7
#  Hyperparameters: Dict{String, Any}("C" => 1.0, "kernel" => "poly", "gamma" => 1.0, "degree" => 3)
# =====================================================
#  Accuracy (mean)               : 0.7728
#  Accuracy (std)                : 0.0161
#  Error Rate (mean)             : 0.2272
#  Error Rate (std)              : 0.0161
#  Sensitivity/Recall (mean)     : 0.7728
#  Sensitivity/Recall (std)      : 0.0161
#  Specificity (mean)            : 0.909
#  Specificity (std)             : 0.0074
#  PPV (mean)                    : 0.8302
#  PPV (std)                     : 0.0097
#  NPV (mean)                    : 0.9197
#  NPV (std)                     : 0.0061
#  F1 Score (mean)               : 0.7709
#  F1 Score (std)                : 0.0161
#
# Confusion Matrix:
# Float32[303.2 0.4 17.4 19.0; 37.6 174.6 24.8 23.0; 63.0 7.6 126.4 3.0; 17.2 5.0 9.2 168.6]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 303.2 │       0.4 │     17.4 │  19.0 │
# │ Hazardous │  37.6 │     174.6 │     24.8 │  23.0 │
# │  Moderate │  63.0 │       7.6 │    126.4 │   3.0 │
# │      Poor │  17.2 │       5.0 │      9.2 │ 168.6 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 8
#  Hyperparameters: Dict{String, Any}("C" => 1.0, "kernel" => "poly", "gamma" => 1.0, "degree" => 3)
# =====================================================
#  Accuracy (mean)               : 0.7762
#  Accuracy (std)                : 0.0152
#  Error Rate (mean)             : 0.2238
#  Error Rate (std)              : 0.0152
#  Sensitivity/Recall (mean)     : 0.7762
#  Sensitivity/Recall (std)      : 0.0152
#  Specificity (mean)            : 0.9102
#  Specificity (std)             : 0.0071
#  PPV (mean)                    : 0.8327
#  PPV (std)                     : 0.0091
#  NPV (mean)                    : 0.9208
#  NPV (std)                     : 0.0056
#  F1 Score (mean)               : 0.7745
#  F1 Score (std)                : 0.0155
#
# Confusion Matrix:
# Float32[303.6 0.4 17.4 18.6; 36.4 175.2 25.6 22.8; 62.2 7.2 128.2 2.4; 17.2 4.8 8.8 169.2]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 303.6 │       0.4 │     17.4 │  18.6 │
# │ Hazardous │  36.4 │     175.2 │     25.6 │  22.8 │
# │  Moderate │  62.2 │       7.2 │    128.2 │   2.4 │
# │      Poor │  17.2 │       4.8 │      8.8 │ 169.2 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 6
#  Hyperparameters: Dict{String, Any}("C" => 5.0, "kernel" => "poly", "gamma" => 0.5, "degree" => 4)
# =====================================================
#  Accuracy (mean)               : 0.454
#  Accuracy (std)                : 0.0032
#  Error Rate (mean)             : 0.546
#  Error Rate (std)              : 0.0032
#  Sensitivity/Recall (mean)     : 0.454
#  Sensitivity/Recall (std)      : 0.0032
#  Specificity (mean)            : 0.6367
#  Specificity (std)             : 0.0019
#  PPV (mean)                    : 0.2915
#  PPV (std)                     : 0.0547
#  NPV (mean)                    : 0.8637
#  NPV (std)                     : 0.0033
#  F1 Score (mean)               : 0.3084
#  F1 Score (std)                : 0.0034
#
# Confusion Matrix:
# Float32[160.0 120.0 0.0 60.0; 79.2 171.4 0.0 9.4; 69.6 80.6 10.0 39.8; 69.8 17.6 0.0 112.6]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 160.0 │     120.0 │      0.0 │  60.0 │
# │ Hazardous │  79.2 │     171.4 │      0.0 │   9.4 │
# │  Moderate │  69.6 │      80.6 │     10.0 │  39.8 │
# │      Poor │  69.8 │      17.6 │      0.0 │ 112.6 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 7
#  Hyperparameters: Dict{String, Any}("C" => 5.0, "kernel" => "poly", "gamma" => 0.5, "degree" => 4)
# =====================================================
#  Accuracy (mean)               : 0.4548
#  Accuracy (std)                : 0.004
#  Error Rate (mean)             : 0.5452
#  Error Rate (std)              : 0.004
#  Sensitivity/Recall (mean)     : 0.4548
#  Sensitivity/Recall (std)      : 0.004
#  Specificity (mean)            : 0.6371
#  Specificity (std)             : 0.0026
#  PPV (mean)                    : 0.292
#  PPV (std)                     : 0.0545
#  NPV (mean)                    : 0.8639
#  NPV (std)                     : 0.0032
#  F1 Score (mean)               : 0.3092
#  F1 Score (std)                : 0.0042
#
# Confusion Matrix:
# Float32[160.0 120.0 0.0 60.0; 79.4 171.4 0.0 9.2; 69.4 80.6 10.2 39.8; 70.0 16.8 0.0 113.2]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 160.0 │     120.0 │      0.0 │  60.0 │
# │ Hazardous │  79.4 │     171.4 │      0.0 │   9.2 │
# │  Moderate │  69.4 │      80.6 │     10.2 │  39.8 │
# │      Poor │  70.0 │      16.8 │      0.0 │ 113.2 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 8
#  Hyperparameters: Dict{String, Any}("C" => 5.0, "kernel" => "poly", "gamma" => 0.5, "degree" => 4)
# =====================================================
#  Accuracy (mean)               : 0.4558
#  Accuracy (std)                : 0.0036
#  Error Rate (mean)             : 0.5442
#  Error Rate (std)              : 0.0036
#  Sensitivity/Recall (mean)     : 0.4558
#  Sensitivity/Recall (std)      : 0.0036
#  Specificity (mean)            : 0.6378
#  Specificity (std)             : 0.0025
#  PPV (mean)                    : 0.2923
#  PPV (std)                     : 0.0542
#  NPV (mean)                    : 0.8653
#  NPV (std)                     : 0.0003
#  F1 Score (mean)               : 0.3101
#  F1 Score (std)                : 0.0031
#
# Confusion Matrix:
# Float32[160.0 120.0 0.0 60.0; 79.4 172.2 0.0 8.4; 69.6 80.4 10.0 40.0; 69.4 17.0 0.0 113.6]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 160.0 │     120.0 │      0.0 │  60.0 │
# │ Hazardous │  79.4 │     172.2 │      0.0 │   8.4 │
# │  Moderate │  69.6 │      80.4 │     10.0 │  40.0 │
# │      Poor │  69.4 │      17.0 │      0.0 │ 113.6 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================

# %% [markdown]
# # Decission Trees

# %%
DTClassifier = MLJ.@load DecisionTreeClassifier pkg=DecisionTree verbosity=0
# Out:
# MLJDecisionTreeInterface.DecisionTreeClassifier

# %%
############# 3. DECISION TREES (6 depths) #############
default_dt = Dict(
    "rng" => Random.MersenneTwister(1)
)

dt_search_space = [
    Dict("max_depth"=>2),
    Dict("max_depth"=>3),
    Dict("max_depth"=>4),
    Dict("max_depth"=>5),
    Dict("max_depth"=>6),
    Dict("max_depth"=>8)
]
# Out:
# 6-element Vector{Dict{String, Int64}}:
#  Dict("max_depth" => 2)
#  Dict("max_depth" => 3)
#  Dict("max_depth" => 4)
#  Dict("max_depth" => 5)
#  Dict("max_depth" => 6)
#  Dict("max_depth" => 8)

# %%
########################
# 3. DECISION TREE GRID SEARCH
########################
dt_results = []

for hp in dt_search_space
    for dim in dimsPCA
        println("\n=== Decision Tree experiment: max_depth=$(hp["max_depth"]) | PCA maxoutdim = $(dim) ===")
        full_hp = merge(default_dt, hp)
        res = modelCrossValidationPCA(:DecisionTreeClassifier, full_hp, (inputs, targets), crossValidationIndices, dim)
        push!(dt_results, (model=:DT, hyperparams=hp, dimPCA=dim, results=res))
    end
end

results[:DT] = dt_results
# Out:
# === Decision Tree experiment: max_depth=2 | PCA maxoutdim = 6 ===
#
# === Decision Tree experiment: max_depth=2 | PCA maxoutdim = 7 ===
#
# === Decision Tree experiment: max_depth=2 | PCA maxoutdim = 8 ===
#
# === Decision Tree experiment: max_depth=3 | PCA maxoutdim = 6 ===
#
# === Decision Tree experiment: max_depth=3 | PCA maxoutdim = 7 ===
#
# === Decision Tree experiment: max_depth=3 | PCA maxoutdim = 8 ===
#
# === Decision Tree experiment: max_depth=4 | PCA maxoutdim = 6 ===
#
# === Decision Tree experiment: max_depth=4 | PCA maxoutdim = 7 ===
#
# === Decision Tree experiment: max_depth=4 | PCA maxoutdim = 8 ===
#
# === Decision Tree experiment: max_depth=5 | PCA maxoutdim = 6 ===
#
# === Decision Tree experiment: max_depth=5 | PCA maxoutdim = 7 ===
#
# === Decision Tree experiment: max_depth=5 | PCA maxoutdim = 8 ===
#
# === Decision Tree experiment: max_depth=6 | PCA maxoutdim = 6 ===
#
# === Decision Tree experiment: max_depth=6 | PCA maxoutdim = 7 ===
#
# === Decision Tree experiment: max_depth=6 | PCA maxoutdim = 8 ===
#
# === Decision Tree experiment: max_depth=8 | PCA maxoutdim = 6 ===
#
# === Decision Tree experiment: max_depth=8 | PCA maxoutdim = 7 ===
#
# === Decision Tree experiment: max_depth=8 | PCA maxoutdim = 8 ===
# 18-element Vector{Any}:
#  (model = :DT, hyperparams = Dict("max_depth" => 2), dimPCA = 6, results = ((0.83219993f0, 0.0054497677f0), (0.16780001f0, 0.0054497714f0), (0.83219993f0, 0.0054497677f0), (0.94234765f0, 0.0018211625f0), (0.7638066f0, 0.0061601675f0), (0.96546876f0, 0.0011020584f0), (0.7940912f0, 0.005148579f0), Float32[319.4 8.2 7.2 5.2; 0.8 226.8 24.6 7.8; 27.4 21.0 151.6 0.0; 3.8 21.8 40.0 134.4]))
#  (model = :DT, hyperparams = Dict("max_depth" => 2), dimPCA = 7, results = ((0.83219993f0, 0.0054497677f0), (0.16780001f0, 0.0054497714f0), (0.83219993f0, 0.0054497677f0), (0.94234765f0, 0.0018211625f0), (0.7638066f0, 0.0061601675f0), (0.96546876f0, 0.0011020584f0), (0.7940912f0, 0.005148579f0), Float32[319.4 8.2 7.2 5.2; 0.8 226.8 24.6 7.8; 27.4 21.0 151.6 0.0; 3.8 21.8 40.0 134.4]))
#  (model = :DT, hyperparams = Dict("max_depth" => 2), dimPCA = 8, results = ((0.83219993f0, 0.0054497677f0), (0.16780001f0, 0.0054497714f0), (0.83219993f0, 0.0054497677f0), (0.94234765f0, 0.0018211625f0), (0.7638066f0, 0.0061601675f0), (0.96546876f0, 0.0011020584f0), (0.7940912f0, 0.005148579f0), Float32[319.4 8.2 7.2 5.2; 0.8 226.8 24.6 7.8; 27.4 21.0 151.6 0.0; 3.8 21.8 40.0 134.4]))
#  (model = :DT, hyperparams = Dict("max_depth" => 3), dimPCA = 6, results = ((0.9103999f0, 0.004827013f0), (0.089600004f0, 0.0048270086f0), (0.9103999f0, 0.004827013f0), (0.96983016f0, 0.0025741593f0), (0.9102656f0, 0.004390337f0), (0.97503775f0, 0.0018103148f0), (0.90898335f0, 0.0050847237f0), Float32[327.2 2.4 7.6 2.8; 3.0 235.8 9.6 11.6; 23.8 10.2 160.0 6.0; 1.0 6.0 5.6 187.4]))
#  (model = :DT, hyperparams = Dict("max_depth" => 3), dimPCA = 7, results = ((0.9103999f0, 0.004827013f0), (0.089600004f0, 0.0048270086f0), (0.9103999f0, 0.004827013f0), (0.96983016f0, 0.0025741593f0), (0.9102656f0, 0.004390337f0), (0.97503775f0, 0.0018103148f0), (0.90898335f0, 0.0050847237f0), Float32[327.2 2.4 7.6 2.8; 3.0 235.8 9.6 11.6; 23.8 10.2 160.0 6.0; 1.0 6.0 5.6 187.4]))
#  (model = :DT, hyperparams = Dict("max_depth" => 3), dimPCA = 8, results = ((0.9103999f0, 0.004827013f0), (0.089600004f0, 0.0048270086f0), (0.9103999f0, 0.004827013f0), (0.96983016f0, 0.0025741593f0), (0.9102656f0, 0.004390337f0), (0.97503775f0, 0.0018103148f0), (0.90898335f0, 0.0050847237f0), Float32[327.2 2.4 7.6 2.8; 3.0 235.8 9.6 11.6; 23.8 10.2 160.0 6.0; 1.0 6.0 5.6 187.4]))
#  (model = :DT, hyperparams = Dict("max_depth" => 4), dimPCA = 6, results = ((0.91380006f0, 0.00653453f0), (0.0862f0, 0.006534524f0), (0.91380006f0, 0.00653453f0), (0.97390634f0, 0.002015421f0), (0.9154504f0, 0.004706984f0), (0.9742853f0, 0.002503891f0), (0.9139454f0, 0.006210473f0), Float32[318.6 2.6 16.8 2.0; 1.4 243.4 7.6 7.6; 13.4 11.8 168.8 6.0; 1.2 10.2 5.6 183.0]))
#  (model = :DT, hyperparams = Dict("max_depth" => 4), dimPCA = 7, results = ((0.91380006f0, 0.00653453f0), (0.0862f0, 0.006534524f0), (0.91380006f0, 0.00653453f0), (0.97390634f0, 0.002015421f0), (0.9154504f0, 0.004706984f0), (0.9742853f0, 0.002503891f0), (0.9139454f0, 0.006210473f0), Float32[318.6 2.6 16.8 2.0; 1.4 243.4 7.6 7.6; 13.4 11.8 168.8 6.0; 1.2 10.2 5.6 183.0]))
#  (model = :DT, hyperparams = Dict("max_depth" => 4), dimPCA = 8, results = ((0.9154f0, 0.0055045495f0), (0.084599994f0, 0.005504545f0), (0.9154f0, 0.0055045495f0), (0.97412777f0, 0.0018265652f0), (0.9161847f0, 0.0044646403f0), (0.9750975f0, 0.0031941284f0), (0.9152918f0, 0.0051852358f0), Float32[318.6 2.6 17.0 1.8; 1.6 241.4 7.6 9.4; 13.2 11.8 169.0 6.0; 1.2 6.8 5.6 186.4]))
#  (model = :DT, hyperparams = Dict("max_depth" => 5), dimPCA = 6, results = ((0.91919994f0, 0.0063796723f0), (0.0808f0, 0.006379654f0), (0.91919994f0, 0.0063796723f0), (0.9748357f0, 0.002288297f0), (0.91849107f0, 0.0067718886f0), (0.97757226f0, 0.0013052266f0), (0.9184534f0, 0.0065470007f0), Float32[327.4 2.2 9.2 1.2; 1.4 239.2 9.6 9.8; 17.2 10.2 166.6 6.0; 1.8 6.6 5.6 186.0]))
#  (model = :DT, hyperparams = Dict("max_depth" => 5), dimPCA = 7, results = ((0.919f0, 0.0063639777f0), (0.08100001f0, 0.0063639604f0), (0.919f0, 0.0063639777f0), (0.9745119f0, 0.0020786833f0), (0.91812694f0, 0.006686433f0), (0.9776844f0, 0.0013695984f0), (0.91819686f0, 0.0065000835f0), Float32[326.4 2.4 9.2 2.0; 1.2 239.4 9.6 9.8; 17.2 10.2 166.6 6.0; 1.2 6.6 5.6 186.6]))
#  (model = :DT, hyperparams = Dict("max_depth" => 5), dimPCA = 8, results = ((0.92139995f0, 0.005770628f0), (0.078600004f0, 0.005770615f0), (0.92139995f0, 0.005770628f0), (0.9755206f0, 0.0024087846f0), (0.92122424f0, 0.0055141137f0), (0.97803324f0, 0.0013038227f0), (0.92083037f0, 0.0058615776f0), Float32[326.6 1.6 9.6 2.2; 1.8 241.0 7.6 9.6; 15.8 11.0 167.2 6.0; 1.0 6.8 5.6 186.6]))
#  (model = :DT, hyperparams = Dict("max_depth" => 6), dimPCA = 6, results = ((0.9176f0, 0.0077652973f0), (0.0824f0, 0.007765308f0), (0.9176f0, 0.0077652973f0), (0.97384053f0, 0.00152358f0), (0.9178004f0, 0.007834953f0), (0.9763479f0, 0.0027455306f0), (0.91716325f0, 0.007498428f0), Float32[322.4 2.6 12.8 2.2; 2.0 240.6 10.6 6.8; 14.2 10.0 170.6 5.2; 1.4 8.4 6.2 184.0]))
#  (model = :DT, hyperparams = Dict("max_depth" => 6), dimPCA = 7, results = ((0.91800004f0, 0.007968676f0), (0.082f0, 0.007968689f0), (0.91800004f0, 0.007968676f0), (0.97446823f0, 0.0016211979f0), (0.9183444f0, 0.0077321064f0), (0.97663844f0, 0.003202276f0), (0.91761035f0, 0.0075482405f0), Float32[323.2 2.2 13.0 1.6; 1.8 240.8 10.4 7.0; 14.6 10.0 170.2 5.2; 1.4 8.6 6.2 183.8]))
#  (model = :DT, hyperparams = Dict("max_depth" => 6), dimPCA = 8, results = ((0.92039996f0, 0.0048785284f0), (0.0796f0, 0.0048785233f0), (0.92039996f0, 0.0048785284f0), (0.97488964f0, 0.0006411739f0), (0.92135316f0, 0.0052930173f0), (0.9774024f0, 0.002684266f0), (0.9200392f0, 0.0044224937f0), Float32[322.6 2.0 13.0 2.4; 1.4 242.0 10.2 6.4; 13.2 9.0 175.2 2.6; 1.2 8.4 9.8 180.6]))
#  (model = :DT, hyperparams = Dict("max_depth" => 8), dimPCA = 6, results = ((0.91760004f0, 0.005594644f0), (0.0824f0, 0.005594639f0), (0.91760004f0, 0.005594644f0), (0.9735548f0, 0.0011246335f0), (0.9178116f0, 0.0048829666f0), (0.9769743f0, 0.0008788252f0), (0.91713494f0, 0.005552969f0), Float32[325.2 3.0 10.6 1.2; 1.8 240.6 9.8 7.8; 15.8 10.6 168.8 4.8; 1.4 8.2 7.4 183.0]))
#  (model = :DT, hyperparams = Dict("max_depth" => 8), dimPCA = 7, results = ((0.917f0, 0.003741673f0), (0.083000004f0, 0.0037416583f0), (0.917f0, 0.003741673f0), (0.97328174f0, 0.0009320845f0), (0.9173845f0, 0.0028794992f0), (0.9773059f0, 0.0011260508f0), (0.9163624f0, 0.0034919218f0), Float32[326.6 2.6 9.4 1.4; 1.8 241.0 9.4 7.8; 17.4 11.0 166.4 5.2; 1.2 8.4 7.4 183.0]))
#  (model = :DT, hyperparams = Dict("max_depth" => 8), dimPCA = 8, results = ((0.9184f0, 0.011502187f0), (0.081599995f0, 0.011502173f0), (0.9184f0, 0.011502187f0), (0.9741634f0, 0.0033976694f0), (0.9189445f0, 0.010291375f0), (0.9778517f0, 0.0026728087f0), (0.91765726f0, 0.011877995f0), Float32[325.4 2.2 10.2 2.2; 1.2 240.6 10.6 7.6; 14.4 12.6 167.6 5.4; 0.8 7.8 6.6 184.8]))

# %%
for entry in results[:DT]
    printExperimentResult(entry.model, entry.hyperparams, entry.dimPCA, entry.results, label_names)
end
# Out:
# =====================================================
#  Model: DT | PCA outdim: 6
#  Hyperparameters: Dict("max_depth" => 2)
# =====================================================
#  Accuracy (mean)               : 0.8322
#  Accuracy (std)                : 0.0054
#  Error Rate (mean)             : 0.1678
#  Error Rate (std)              : 0.0054
#  Sensitivity/Recall (mean)     : 0.8322
#  Sensitivity/Recall (std)      : 0.0054
#  Specificity (mean)            : 0.9423
#  Specificity (std)             : 0.0018
#  PPV (mean)                    : 0.7638
#  PPV (std)                     : 0.0062
#  NPV (mean)                    : 0.9655
#  NPV (std)                     : 0.0011
#  F1 Score (mean)               : 0.7941
#  F1 Score (std)                : 0.0051
#
# Confusion Matrix:
# Float32[319.4 8.2 7.2 5.2; 0.8 226.8 24.6 7.8; 27.4 21.0 151.6 0.0; 3.8 21.8 40.0 134.4]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 319.4 │       8.2 │      7.2 │   5.2 │
# │ Hazardous │   0.8 │     226.8 │     24.6 │   7.8 │
# │  Moderate │  27.4 │      21.0 │    151.6 │   0.0 │
# │      Poor │   3.8 │      21.8 │     40.0 │ 134.4 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: DT | PCA outdim: 7
#  Hyperparameters: Dict("max_depth" => 2)
# =====================================================
#  Accuracy (mean)               : 0.8322
#  Accuracy (std)                : 0.0054
#  Error Rate (mean)             : 0.1678
#  Error Rate (std)              : 0.0054
#  Sensitivity/Recall (mean)     : 0.8322
#  Sensitivity/Recall (std)      : 0.0054
#  Specificity (mean)            : 0.9423
#  Specificity (std)             : 0.0018
#  PPV (mean)                    : 0.7638
#  PPV (std)                     : 0.0062
#  NPV (mean)                    : 0.9655
#  NPV (std)                     : 0.0011
#  F1 Score (mean)               : 0.7941
#  F1 Score (std)                : 0.0051
#
# Confusion Matrix:
# Float32[319.4 8.2 7.2 5.2; 0.8 226.8 24.6 7.8; 27.4 21.0 151.6 0.0; 3.8 21.8 40.0 134.4]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 319.4 │       8.2 │      7.2 │   5.2 │
# │ Hazardous │   0.8 │     226.8 │     24.6 │   7.8 │
# │  Moderate │  27.4 │      21.0 │    151.6 │   0.0 │
# │      Poor │   3.8 │      21.8 │     40.0 │ 134.4 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: DT | PCA outdim: 8
#  Hyperparameters: Dict("max_depth" => 2)
# =====================================================
#  Accuracy (mean)               : 0.8322
#  Accuracy (std)                : 0.0054
#  Error Rate (mean)             : 0.1678
#  Error Rate (std)              : 0.0054
#  Sensitivity/Recall (mean)     : 0.8322
#  Sensitivity/Recall (std)      : 0.0054
#  Specificity (mean)            : 0.9423
#  Specificity (std)             : 0.0018
#  PPV (mean)                    : 0.7638
#  PPV (std)                     : 0.0062
#  NPV (mean)                    : 0.9655
#  NPV (std)                     : 0.0011
#  F1 Score (mean)               : 0.7941
#  F1 Score (std)                : 0.0051
#
# Confusion Matrix:
# Float32[319.4 8.2 7.2 5.2; 0.8 226.8 24.6 7.8; 27.4 21.0 151.6 0.0; 3.8 21.8 40.0 134.4]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 319.4 │       8.2 │      7.2 │   5.2 │
# │ Hazardous │   0.8 │     226.8 │     24.6 │   7.8 │
# │  Moderate │  27.4 │      21.0 │    151.6 │   0.0 │
# │      Poor │   3.8 │      21.8 │     40.0 │ 134.4 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: DT | PCA outdim: 6
#  Hyperparameters: Dict("max_depth" => 3)
# =====================================================
#  Accuracy (mean)               : 0.9104
#  Accuracy (std)                : 0.0048
#  Error Rate (mean)             : 0.0896
#  Error Rate (std)              : 0.0048
#  Sensitivity/Recall (mean)     : 0.9104
#  Sensitivity/Recall (std)      : 0.0048
#  Specificity (mean)            : 0.9698
#  Specificity (std)             : 0.0026
#  PPV (mean)                    : 0.9103
#  PPV (std)                     : 0.0044
#  NPV (mean)                    : 0.975
#  NPV (std)                     : 0.0018
#  F1 Score (mean)               : 0.909
#  F1 Score (std)                : 0.0051
#
# Confusion Matrix:
# Float32[327.2 2.4 7.6 2.8; 3.0 235.8 9.6 11.6; 23.8 10.2 160.0 6.0; 1.0 6.0 5.6 187.4]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 327.2 │       2.4 │      7.6 │   2.8 │
# │ Hazardous │   3.0 │     235.8 │      9.6 │  11.6 │
# │  Moderate │  23.8 │      10.2 │    160.0 │   6.0 │
# │      Poor │   1.0 │       6.0 │      5.6 │ 187.4 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: DT | PCA outdim: 7
#  Hyperparameters: Dict("max_depth" => 3)
# =====================================================
#  Accuracy (mean)               : 0.9104
#  Accuracy (std)                : 0.0048
#  Error Rate (mean)             : 0.0896
#  Error Rate (std)              : 0.0048
#  Sensitivity/Recall (mean)     : 0.9104
#  Sensitivity/Recall (std)      : 0.0048
#  Specificity (mean)            : 0.9698
#  Specificity (std)             : 0.0026
#  PPV (mean)                    : 0.9103
#  PPV (std)                     : 0.0044
#  NPV (mean)                    : 0.975
#  NPV (std)                     : 0.0018
#  F1 Score (mean)               : 0.909
#  F1 Score (std)                : 0.0051
#
# Confusion Matrix:
# Float32[327.2 2.4 7.6 2.8; 3.0 235.8 9.6 11.6; 23.8 10.2 160.0 6.0; 1.0 6.0 5.6 187.4]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 327.2 │       2.4 │      7.6 │   2.8 │
# │ Hazardous │   3.0 │     235.8 │      9.6 │  11.6 │
# │  Moderate │  23.8 │      10.2 │    160.0 │   6.0 │
# │      Poor │   1.0 │       6.0 │      5.6 │ 187.4 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: DT | PCA outdim: 8
#  Hyperparameters: Dict("max_depth" => 3)
# =====================================================
#  Accuracy (mean)               : 0.9104
#  Accuracy (std)                : 0.0048
#  Error Rate (mean)             : 0.0896
#  Error Rate (std)              : 0.0048
#  Sensitivity/Recall (mean)     : 0.9104
#  Sensitivity/Recall (std)      : 0.0048
#  Specificity (mean)            : 0.9698
#  Specificity (std)             : 0.0026
#  PPV (mean)                    : 0.9103
#  PPV (std)                     : 0.0044
#  NPV (mean)                    : 0.975
#  NPV (std)                     : 0.0018
#  F1 Score (mean)               : 0.909
#  F1 Score (std)                : 0.0051
#
# Confusion Matrix:
# Float32[327.2 2.4 7.6 2.8; 3.0 235.8 9.6 11.6; 23.8 10.2 160.0 6.0; 1.0 6.0 5.6 187.4]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 327.2 │       2.4 │      7.6 │   2.8 │
# │ Hazardous │   3.0 │     235.8 │      9.6 │  11.6 │
# │  Moderate │  23.8 │      10.2 │    160.0 │   6.0 │
# │      Poor │   1.0 │       6.0 │      5.6 │ 187.4 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: DT | PCA outdim: 6
#  Hyperparameters: Dict("max_depth" => 4)
# =====================================================
#  Accuracy (mean)               : 0.9138
#  Accuracy (std)                : 0.0065
#  Error Rate (mean)             : 0.0862
#  Error Rate (std)              : 0.0065
#  Sensitivity/Recall (mean)     : 0.9138
#  Sensitivity/Recall (std)      : 0.0065
#  Specificity (mean)            : 0.9739
#  Specificity (std)             : 0.002
#  PPV (mean)                    : 0.9155
#  PPV (std)                     : 0.0047
#  NPV (mean)                    : 0.9743
#  NPV (std)                     : 0.0025
#  F1 Score (mean)               : 0.9139
#  F1 Score (std)                : 0.0062
#
# Confusion Matrix:
# Float32[318.6 2.6 16.8 2.0; 1.4 243.4 7.6 7.6; 13.4 11.8 168.8 6.0; 1.2 10.2 5.6 183.0]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 318.6 │       2.6 │     16.8 │   2.0 │
# │ Hazardous │   1.4 │     243.4 │      7.6 │   7.6 │
# │  Moderate │  13.4 │      11.8 │    168.8 │   6.0 │
# │      Poor │   1.2 │      10.2 │      5.6 │ 183.0 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: DT | PCA outdim: 7
#  Hyperparameters: Dict("max_depth" => 4)
# =====================================================
#  Accuracy (mean)               : 0.9138
#  Accuracy (std)                : 0.0065
#  Error Rate (mean)             : 0.0862
#  Error Rate (std)              : 0.0065
#  Sensitivity/Recall (mean)     : 0.9138
#  Sensitivity/Recall (std)      : 0.0065
#  Specificity (mean)            : 0.9739
#  Specificity (std)             : 0.002
#  PPV (mean)                    : 0.9155
#  PPV (std)                     : 0.0047
#  NPV (mean)                    : 0.9743
#  NPV (std)                     : 0.0025
#  F1 Score (mean)               : 0.9139
#  F1 Score (std)                : 0.0062
#
# Confusion Matrix:
# Float32[318.6 2.6 16.8 2.0; 1.4 243.4 7.6 7.6; 13.4 11.8 168.8 6.0; 1.2 10.2 5.6 183.0]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 318.6 │       2.6 │     16.8 │   2.0 │
# │ Hazardous │   1.4 │     243.4 │      7.6 │   7.6 │
# │  Moderate │  13.4 │      11.8 │    168.8 │   6.0 │
# │      Poor │   1.2 │      10.2 │      5.6 │ 183.0 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: DT | PCA outdim: 8
#  Hyperparameters: Dict("max_depth" => 4)
# =====================================================
#  Accuracy (mean)               : 0.9154
#  Accuracy (std)                : 0.0055
#  Error Rate (mean)             : 0.0846
#  Error Rate (std)              : 0.0055
#  Sensitivity/Recall (mean)     : 0.9154
#  Sensitivity/Recall (std)      : 0.0055
#  Specificity (mean)            : 0.9741
#  Specificity (std)             : 0.0018
#  PPV (mean)                    : 0.9162
#  PPV (std)                     : 0.0045
#  NPV (mean)                    : 0.9751
#  NPV (std)                     : 0.0032
#  F1 Score (mean)               : 0.9153
#  F1 Score (std)                : 0.0052
#
# Confusion Matrix:
# Float32[318.6 2.6 17.0 1.8; 1.6 241.4 7.6 9.4; 13.2 11.8 169.0 6.0; 1.2 6.8 5.6 186.4]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 318.6 │       2.6 │     17.0 │   1.8 │
# │ Hazardous │   1.6 │     241.4 │      7.6 │   9.4 │
# │  Moderate │  13.2 │      11.8 │    169.0 │   6.0 │
# │      Poor │   1.2 │       6.8 │      5.6 │ 186.4 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: DT | PCA outdim: 6
#  Hyperparameters: Dict("max_depth" => 5)
# =====================================================
#  Accuracy (mean)               : 0.9192
#  Accuracy (std)                : 0.0064
#  Error Rate (mean)             : 0.0808
#  Error Rate (std)              : 0.0064
#  Sensitivity/Recall (mean)     : 0.9192
#  Sensitivity/Recall (std)      : 0.0064
#  Specificity (mean)            : 0.9748
#  Specificity (std)             : 0.0023
#  PPV (mean)                    : 0.9185
#  PPV (std)                     : 0.0068
#  NPV (mean)                    : 0.9776
#  NPV (std)                     : 0.0013
#  F1 Score (mean)               : 0.9185
#  F1 Score (std)                : 0.0065
#
# Confusion Matrix:
# Float32[327.4 2.2 9.2 1.2; 1.4 239.2 9.6 9.8; 17.2 10.2 166.6 6.0; 1.8 6.6 5.6 186.0]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 327.4 │       2.2 │      9.2 │   1.2 │
# │ Hazardous │   1.4 │     239.2 │      9.6 │   9.8 │
# │  Moderate │  17.2 │      10.2 │    166.6 │   6.0 │
# │      Poor │   1.8 │       6.6 │      5.6 │ 186.0 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: DT | PCA outdim: 7
#  Hyperparameters: Dict("max_depth" => 5)
# =====================================================
#  Accuracy (mean)               : 0.919
#  Accuracy (std)                : 0.0064
#  Error Rate (mean)             : 0.081
#  Error Rate (std)              : 0.0064
#  Sensitivity/Recall (mean)     : 0.919
#  Sensitivity/Recall (std)      : 0.0064
#  Specificity (mean)            : 0.9745
#  Specificity (std)             : 0.0021
#  PPV (mean)                    : 0.9181
#  PPV (std)                     : 0.0067
#  NPV (mean)                    : 0.9777
#  NPV (std)                     : 0.0014
#  F1 Score (mean)               : 0.9182
#  F1 Score (std)                : 0.0065
#
# Confusion Matrix:
# Float32[326.4 2.4 9.2 2.0; 1.2 239.4 9.6 9.8; 17.2 10.2 166.6 6.0; 1.2 6.6 5.6 186.6]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 326.4 │       2.4 │      9.2 │   2.0 │
# │ Hazardous │   1.2 │     239.4 │      9.6 │   9.8 │
# │  Moderate │  17.2 │      10.2 │    166.6 │   6.0 │
# │      Poor │   1.2 │       6.6 │      5.6 │ 186.6 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: DT | PCA outdim: 8
#  Hyperparameters: Dict("max_depth" => 5)
# =====================================================
#  Accuracy (mean)               : 0.9214
#  Accuracy (std)                : 0.0058
#  Error Rate (mean)             : 0.0786
#  Error Rate (std)              : 0.0058
#  Sensitivity/Recall (mean)     : 0.9214
#  Sensitivity/Recall (std)      : 0.0058
#  Specificity (mean)            : 0.9755
#  Specificity (std)             : 0.0024
#  PPV (mean)                    : 0.9212
#  PPV (std)                     : 0.0055
#  NPV (mean)                    : 0.978
#  NPV (std)                     : 0.0013
#  F1 Score (mean)               : 0.9208
#  F1 Score (std)                : 0.0059
#
# Confusion Matrix:
# Float32[326.6 1.6 9.6 2.2; 1.8 241.0 7.6 9.6; 15.8 11.0 167.2 6.0; 1.0 6.8 5.6 186.6]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 326.6 │       1.6 │      9.6 │   2.2 │
# │ Hazardous │   1.8 │     241.0 │      7.6 │   9.6 │
# │  Moderate │  15.8 │      11.0 │    167.2 │   6.0 │
# │      Poor │   1.0 │       6.8 │      5.6 │ 186.6 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: DT | PCA outdim: 6
#  Hyperparameters: Dict("max_depth" => 6)
# =====================================================
#  Accuracy (mean)               : 0.9176
#  Accuracy (std)                : 0.0078
#  Error Rate (mean)             : 0.0824
#  Error Rate (std)              : 0.0078
#  Sensitivity/Recall (mean)     : 0.9176
#  Sensitivity/Recall (std)      : 0.0078
#  Specificity (mean)            : 0.9738
#  Specificity (std)             : 0.0015
#  PPV (mean)                    : 0.9178
#  PPV (std)                     : 0.0078
#  NPV (mean)                    : 0.9763
#  NPV (std)                     : 0.0027
#  F1 Score (mean)               : 0.9172
#  F1 Score (std)                : 0.0075
#
# Confusion Matrix:
# Float32[322.4 2.6 12.8 2.2; 2.0 240.6 10.6 6.8; 14.2 10.0 170.6 5.2; 1.4 8.4 6.2 184.0]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 322.4 │       2.6 │     12.8 │   2.2 │
# │ Hazardous │   2.0 │     240.6 │     10.6 │   6.8 │
# │  Moderate │  14.2 │      10.0 │    170.6 │   5.2 │
# │      Poor │   1.4 │       8.4 │      6.2 │ 184.0 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: DT | PCA outdim: 7
#  Hyperparameters: Dict("max_depth" => 6)
# =====================================================
#  Accuracy (mean)               : 0.918
#  Accuracy (std)                : 0.008
#  Error Rate (mean)             : 0.082
#  Error Rate (std)              : 0.008
#  Sensitivity/Recall (mean)     : 0.918
#  Sensitivity/Recall (std)      : 0.008
#  Specificity (mean)            : 0.9745
#  Specificity (std)             : 0.0016
#  PPV (mean)                    : 0.9183
#  PPV (std)                     : 0.0077
#  NPV (mean)                    : 0.9766
#  NPV (std)                     : 0.0032
#  F1 Score (mean)               : 0.9176
#  F1 Score (std)                : 0.0075
#
# Confusion Matrix:
# Float32[323.2 2.2 13.0 1.6; 1.8 240.8 10.4 7.0; 14.6 10.0 170.2 5.2; 1.4 8.6 6.2 183.8]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 323.2 │       2.2 │     13.0 │   1.6 │
# │ Hazardous │   1.8 │     240.8 │     10.4 │   7.0 │
# │  Moderate │  14.6 │      10.0 │    170.2 │   5.2 │
# │      Poor │   1.4 │       8.6 │      6.2 │ 183.8 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: DT | PCA outdim: 8
#  Hyperparameters: Dict("max_depth" => 6)
# =====================================================
#  Accuracy (mean)               : 0.9204
#  Accuracy (std)                : 0.0049
#  Error Rate (mean)             : 0.0796
#  Error Rate (std)              : 0.0049
#  Sensitivity/Recall (mean)     : 0.9204
#  Sensitivity/Recall (std)      : 0.0049
#  Specificity (mean)            : 0.9749
#  Specificity (std)             : 0.0006
#  PPV (mean)                    : 0.9214
#  PPV (std)                     : 0.0053
#  NPV (mean)                    : 0.9774
#  NPV (std)                     : 0.0027
#  F1 Score (mean)               : 0.92
#  F1 Score (std)                : 0.0044
#
# Confusion Matrix:
# Float32[322.6 2.0 13.0 2.4; 1.4 242.0 10.2 6.4; 13.2 9.0 175.2 2.6; 1.2 8.4 9.8 180.6]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 322.6 │       2.0 │     13.0 │   2.4 │
# │ Hazardous │   1.4 │     242.0 │     10.2 │   6.4 │
# │  Moderate │  13.2 │       9.0 │    175.2 │   2.6 │
# │      Poor │   1.2 │       8.4 │      9.8 │ 180.6 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: DT | PCA outdim: 6
#  Hyperparameters: Dict("max_depth" => 8)
# =====================================================
#  Accuracy (mean)               : 0.9176
#  Accuracy (std)                : 0.0056
#  Error Rate (mean)             : 0.0824
#  Error Rate (std)              : 0.0056
#  Sensitivity/Recall (mean)     : 0.9176
#  Sensitivity/Recall (std)      : 0.0056
#  Specificity (mean)            : 0.9736
#  Specificity (std)             : 0.0011
#  PPV (mean)                    : 0.9178
#  PPV (std)                     : 0.0049
#  NPV (mean)                    : 0.977
#  NPV (std)                     : 0.0009
#  F1 Score (mean)               : 0.9171
#  F1 Score (std)                : 0.0056
#
# Confusion Matrix:
# Float32[325.2 3.0 10.6 1.2; 1.8 240.6 9.8 7.8; 15.8 10.6 168.8 4.8; 1.4 8.2 7.4 183.0]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 325.2 │       3.0 │     10.6 │   1.2 │
# │ Hazardous │   1.8 │     240.6 │      9.8 │   7.8 │
# │  Moderate │  15.8 │      10.6 │    168.8 │   4.8 │
# │      Poor │   1.4 │       8.2 │      7.4 │ 183.0 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: DT | PCA outdim: 7
#  Hyperparameters: Dict("max_depth" => 8)
# =====================================================
#  Accuracy (mean)               : 0.917
#  Accuracy (std)                : 0.0037
#  Error Rate (mean)             : 0.083
#  Error Rate (std)              : 0.0037
#  Sensitivity/Recall (mean)     : 0.917
#  Sensitivity/Recall (std)      : 0.0037
#  Specificity (mean)            : 0.9733
#  Specificity (std)             : 0.0009
#  PPV (mean)                    : 0.9174
#  PPV (std)                     : 0.0029
#  NPV (mean)                    : 0.9773
#  NPV (std)                     : 0.0011
#  F1 Score (mean)               : 0.9164
#  F1 Score (std)                : 0.0035
#
# Confusion Matrix:
# Float32[326.6 2.6 9.4 1.4; 1.8 241.0 9.4 7.8; 17.4 11.0 166.4 5.2; 1.2 8.4 7.4 183.0]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 326.6 │       2.6 │      9.4 │   1.4 │
# │ Hazardous │   1.8 │     241.0 │      9.4 │   7.8 │
# │  Moderate │  17.4 │      11.0 │    166.4 │   5.2 │
# │      Poor │   1.2 │       8.4 │      7.4 │ 183.0 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: DT | PCA outdim: 8
#  Hyperparameters: Dict("max_depth" => 8)
# =====================================================
#  Accuracy (mean)               : 0.9184
#  Accuracy (std)                : 0.0115
#  Error Rate (mean)             : 0.0816
#  Error Rate (std)              : 0.0115
#  Sensitivity/Recall (mean)     : 0.9184
#  Sensitivity/Recall (std)      : 0.0115
#  Specificity (mean)            : 0.9742
#  Specificity (std)             : 0.0034
#  PPV (mean)                    : 0.9189
#  PPV (std)                     : 0.0103
#  NPV (mean)                    : 0.9779
#  NPV (std)                     : 0.0027
#  F1 Score (mean)               : 0.9177
#  F1 Score (std)                : 0.0119
#
# Confusion Matrix:
# Float32[325.4 2.2 10.2 2.2; 1.2 240.6 10.6 7.6; 14.4 12.6 167.6 5.4; 0.8 7.8 6.6 184.8]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 325.4 │       2.2 │     10.2 │   2.2 │
# │ Hazardous │   1.2 │     240.6 │     10.6 │   7.6 │
# │  Moderate │  14.4 │      12.6 │    167.6 │   5.4 │
# │      Poor │   0.8 │       7.8 │      6.6 │ 184.8 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================

# %% [markdown]
# # K-Nearest Neighbors

# %%
kNNClassifier = MLJ.@load KNNClassifier pkg=NearestNeighborModels verbosity=0
# Out:
# NearestNeighborModels.KNNClassifier

# %%
############# 4. kNN (6 values) #############
knn_search_space = [
    Dict("K"=>1),
    Dict("K"=>3),
    Dict("K"=>5),
    Dict("K"=>7),
    Dict("K"=>9),
    Dict("K"=>11)
]
# Out:
# 6-element Vector{Dict{String, Int64}}:
#  Dict("K" => 1)
#  Dict("K" => 3)
#  Dict("K" => 5)
#  Dict("K" => 7)
#  Dict("K" => 9)
#  Dict("K" => 11)

# %%
########################
# 4. KNN GRID SEARCH
########################
knn_results = []

for hp in knn_search_space
    for dim in dimsPCA
        println("\n=== kNN experiment: K=$(hp["K"]) | PCA maxoutdim = $(dim) ===")
        res = modelCrossValidationPCA(:KNeighborsClassifier, hp, (inputs, targets), crossValidationIndices, dim)
        push!(knn_results, (model=:KNN, hyperparams=hp, dimPCA=dim, results=res))
    end
end

results[:KNN] = knn_results
# Out:
# === kNN experiment: K=1 | PCA maxoutdim = 6 ===
#
# === kNN experiment: K=1 | PCA maxoutdim = 7 ===
#
# === kNN experiment: K=1 | PCA maxoutdim = 8 ===
#
# === kNN experiment: K=3 | PCA maxoutdim = 6 ===
#
# === kNN experiment: K=3 | PCA maxoutdim = 7 ===
#
# === kNN experiment: K=3 | PCA maxoutdim = 8 ===
#
# === kNN experiment: K=5 | PCA maxoutdim = 6 ===
#
# === kNN experiment: K=5 | PCA maxoutdim = 7 ===
#
# === kNN experiment: K=5 | PCA maxoutdim = 8 ===
#
# === kNN experiment: K=7 | PCA maxoutdim = 6 ===
#
# === kNN experiment: K=7 | PCA maxoutdim = 7 ===
#
# === kNN experiment: K=7 | PCA maxoutdim = 8 ===
#
# === kNN experiment: K=9 | PCA maxoutdim = 6 ===
#
# === kNN experiment: K=9 | PCA maxoutdim = 7 ===
#
# === kNN experiment: K=9 | PCA maxoutdim = 8 ===
#
# === kNN experiment: K=11 | PCA maxoutdim = 6 ===
#
# === kNN experiment: K=11 | PCA maxoutdim = 7 ===
#
# === kNN experiment: K=11 | PCA maxoutdim = 8 ===
# 18-element Vector{Any}:
#  (model = :KNN, hyperparams = Dict("K" => 1), dimPCA = 6, results = ((0.9094f0, 0.005319782f0), (0.0906f0, 0.005319774f0), (0.9094f0, 0.005319782f0), (0.97251666f0, 0.0018988046f0), (0.9086259f0, 0.00518439f0), (0.97641736f0, 0.00093733f0), (0.9085716f0, 0.005451446f0), Float32[327.6 2.8 8.8 0.8; 0.8 237.4 12.8 9.0; 16.2 13.6 164.2 6.0; 1.4 8.2 10.2 180.2]))
#  (model = :KNN, hyperparams = Dict("K" => 1), dimPCA = 7, results = ((0.9118f0, 0.00554077f0), (0.0882f0, 0.005540759f0), (0.9118f0, 0.00554077f0), (0.9731444f0, 0.0025371849f0), (0.91048753f0, 0.0060021915f0), (0.9779686f0, 0.0012446409f0), (0.9105797f0, 0.006166984f0), Float32[329.6 1.2 8.2 1.0; 0.8 236.8 12.6 9.8; 18.4 13.2 162.4 6.0; 1.2 6.4 9.4 183.0]))
#  (model = :KNN, hyperparams = Dict("K" => 1), dimPCA = 8, results = ((0.91120005f0, 0.0055856993f0), (0.0888f0, 0.0055856947f0), (0.91120005f0, 0.0055856993f0), (0.97299445f0, 0.0014615624f0), (0.90951043f0, 0.0056554712f0), (0.9785203f0, 0.0012908599f0), (0.9097663f0, 0.0057968423f0), Float32[330.4 1.2 6.6 1.8; 0.2 238.4 13.4 8.0; 19.0 12.2 161.6 7.2; 1.0 7.8 10.4 180.8]))
#  (model = :KNN, hyperparams = Dict("K" => 3), dimPCA = 6, results = ((0.9274f0, 0.005272582f0), (0.0726f0, 0.0052725715f0), (0.9274f0, 0.005272582f0), (0.97681427f0, 0.00074991677f0), (0.9270094f0, 0.0055329753f0), (0.98203963f0, 0.0021882537f0), (0.92650855f0, 0.0050672595f0), Float32[329.6 2.2 7.4 0.8; 0.6 242.4 9.4 7.6; 15.2 10.0 171.8 3.0; 0.8 6.4 9.2 183.6]))
#  (model = :KNN, hyperparams = Dict("K" => 3), dimPCA = 7, results = ((0.926f0, 0.0058736657f0), (0.074f0, 0.0058736703f0), (0.926f0, 0.0058736657f0), (0.9761468f0, 0.002312451f0), (0.9251598f0, 0.005393791f0), (0.98217213f0, 0.0011734694f0), (0.9248446f0, 0.0061802254f0), Float32[331.6 1.8 5.4 1.2; 0.2 241.4 10.0 8.4; 16.6 9.4 169.8 4.2; 1.4 6.6 8.8 183.2]))
#  (model = :KNN, hyperparams = Dict("K" => 3), dimPCA = 8, results = ((0.9252f0, 0.008288527f0), (0.0748f0, 0.008288546f0), (0.9252f0, 0.008288527f0), (0.97592306f0, 0.0023809585f0), (0.9242934f0, 0.007692905f0), (0.98263776f0, 0.0012986836f0), (0.9237461f0, 0.0087973755f0), Float32[332.8 0.8 4.4 2.0; 0.2 241.6 9.6 8.6; 17.8 9.6 167.8 4.8; 1.0 5.8 10.2 183.0]))
#  (model = :KNN, hyperparams = Dict("K" => 5), dimPCA = 6, results = ((0.93299997f0, 0.0059581883f0), (0.067f0, 0.005958188f0), (0.93299997f0, 0.0059581883f0), (0.97789687f0, 0.001181881f0), (0.9325388f0, 0.0068525337f0), (0.98400724f0, 0.0018737765f0), (0.9319805f0, 0.0059626116f0), Float32[331.8 2.4 5.0 0.8; 0.4 243.0 9.0 7.6; 16.0 8.2 172.6 3.2; 0.6 5.8 8.0 185.6]))
#  (model = :KNN, hyperparams = Dict("K" => 5), dimPCA = 7, results = ((0.92960006f0, 0.0069137425f0), (0.0704f0, 0.006913755f0), (0.92960006f0, 0.0069137425f0), (0.97638416f0, 0.002669647f0), (0.92906666f0, 0.0064019514f0), (0.98381835f0, 0.00093439093f0), (0.928181f0, 0.0073966393f0), Float32[333.8 2.2 3.0 1.0; 0.2 242.8 8.8 8.2; 17.6 9.2 169.6 3.6; 1.0 5.4 10.2 183.4]))
#  (model = :KNN, hyperparams = Dict("K" => 5), dimPCA = 8, results = ((0.92840004f0, 0.0074027055f0), (0.0716f0, 0.0074027013f0), (0.92840004f0, 0.0074027055f0), (0.97604847f0, 0.0024033072f0), (0.92751884f0, 0.0069749476f0), (0.98367465f0, 0.0012404588f0), (0.9269015f0, 0.007832941f0), Float32[334.0 1.6 2.8 1.6; 0.2 241.2 9.6 9.0; 18.0 9.4 169.4 3.2; 0.8 6.0 9.4 183.8]))
#  (model = :KNN, hyperparams = Dict("K" => 7), dimPCA = 6, results = ((0.93380004f0, 0.00752993f0), (0.0662f0, 0.0075299395f0), (0.93380004f0, 0.00752993f0), (0.97769994f0, 0.001946105f0), (0.9334974f0, 0.008062843f0), (0.9847318f0, 0.0017883282f0), (0.93257886f0, 0.0078014606f0), Float32[333.2 2.2 3.8 0.8; 0.2 243.2 8.8 7.8; 16.6 8.2 172.4 2.8; 0.6 5.2 9.2 185.0]))
#  (model = :KNN, hyperparams = Dict("K" => 7), dimPCA = 7, results = ((0.92960006f0, 0.0063482206f0), (0.0704f0, 0.006348227f0), (0.92960006f0, 0.0063482206f0), (0.9761143f0, 0.0021696736f0), (0.92892903f0, 0.006245945f0), (0.98391044f0, 0.0009175351f0), (0.9281286f0, 0.006748142f0), Float32[333.4 2.4 3.0 1.2; 0.2 242.0 9.0 8.8; 17.8 8.2 170.6 3.4; 0.8 5.6 10.0 183.6]))
#  (model = :KNN, hyperparams = Dict("K" => 7), dimPCA = 8, results = ((0.93f0, 0.0052440534f0), (0.07000001f0, 0.005244043f0), (0.93f0, 0.0052440534f0), (0.9761508f0, 0.0015270113f0), (0.9292615f0, 0.0051901075f0), (0.9841879f0, 0.0012280361f0), (0.92853117f0, 0.005415375f0), Float32[334.2 1.8 2.4 1.6; 0.0 241.4 10.4 8.2; 18.2 8.2 171.2 2.4; 1.0 5.8 10.0 183.2]))
#  (model = :KNN, hyperparams = Dict("K" => 9), dimPCA = 6, results = ((0.9342f0, 0.007661605f0), (0.065799996f0, 0.0076615927f0), (0.9342f0, 0.007661605f0), (0.9775659f0, 0.0020398523f0), (0.9340046f0, 0.007863037f0), (0.9847609f0, 0.0018054603f0), (0.9329858f0, 0.007863104f0), Float32[332.6 2.6 3.8 1.0; 0.2 242.4 9.4 8.0; 16.2 8.4 172.8 2.6; 0.6 5.4 7.6 186.4]))
#  (model = :KNN, hyperparams = Dict("K" => 9), dimPCA = 7, results = ((0.929f0, 0.0068190796f0), (0.071f0, 0.0068190903f0), (0.929f0, 0.0068190796f0), (0.9754842f0, 0.002351997f0), (0.92828864f0, 0.0067928475f0), (0.98367673f0, 0.0012258893f0), (0.9274682f0, 0.007149852f0), Float32[333.2 2.6 3.0 1.2; 0.0 242.6 9.6 7.8; 19.0 8.8 169.4 2.8; 1.4 6.0 8.8 183.8]))
#  (model = :KNN, hyperparams = Dict("K" => 9), dimPCA = 8, results = ((0.9276f0, 0.0057271193f0), (0.0724f0, 0.0057271267f0), (0.9276f0, 0.0057271193f0), (0.97517776f0, 0.0015771207f0), (0.9269682f0, 0.0053525837f0), (0.9837467f0, 0.0011328411f0), (0.9259426f0, 0.0060045538f0), Float32[334.0 2.2 2.2 1.6; 0.0 241.0 10.8 8.2; 19.4 9.0 169.2 2.4; 1.0 6.0 9.6 183.4]))
#  (model = :KNN, hyperparams = Dict("K" => 11), dimPCA = 6, results = ((0.9337999f0, 0.0072938264f0), (0.0662f0, 0.007293831f0), (0.9337999f0, 0.0072938264f0), (0.9772555f0, 0.0015147815f0), (0.9336994f0, 0.007325773f0), (0.98445845f0, 0.001755555f0), (0.9326495f0, 0.0074241613f0), Float32[332.2 2.4 4.2 1.2; 0.2 242.0 10.0 7.8; 17.0 7.8 173.0 2.2; 0.6 5.0 7.8 186.6]))
#  (model = :KNN, hyperparams = Dict("K" => 11), dimPCA = 7, results = ((0.92959994f0, 0.005770615f0), (0.0704f0, 0.005770613f0), (0.92959994f0, 0.005770615f0), (0.97553885f0, 0.0024411492f0), (0.9294093f0, 0.0051500965f0), (0.98403853f0, 0.0011133333f0), (0.9280475f0, 0.0060458663f0), Float32[333.6 2.8 2.4 1.2; 0.0 243.8 8.2 8.0; 18.8 8.8 169.8 2.6; 1.2 6.6 9.8 182.4]))
#  (model = :KNN, hyperparams = Dict("K" => 11), dimPCA = 8, results = ((0.9268001f0, 0.0045497334f0), (0.0732f0, 0.004549725f0), (0.9268001f0, 0.0045497334f0), (0.9750492f0, 0.0014849375f0), (0.9262394f0, 0.004014633f0), (0.98367083f0, 0.0009909802f0), (0.92506754f0, 0.0047397004f0), Float32[334.0 2.0 2.4 1.6; 0.0 240.6 11.4 8.0; 18.6 8.6 169.8 3.0; 1.2 6.4 10.0 182.4]))

# %%
for entry in results[:KNN]
    printExperimentResult(entry.model, entry.hyperparams, entry.dimPCA, entry.results, label_names)
end
# Out:
# =====================================================
#  Model: KNN | PCA outdim: 6
#  Hyperparameters: Dict("K" => 1)
# =====================================================
#  Accuracy (mean)               : 0.9094
#  Accuracy (std)                : 0.0053
#  Error Rate (mean)             : 0.0906
#  Error Rate (std)              : 0.0053
#  Sensitivity/Recall (mean)     : 0.9094
#  Sensitivity/Recall (std)      : 0.0053
#  Specificity (mean)            : 0.9725
#  Specificity (std)             : 0.0019
#  PPV (mean)                    : 0.9086
#  PPV (std)                     : 0.0052
#  NPV (mean)                    : 0.9764
#  NPV (std)                     : 0.0009
#  F1 Score (mean)               : 0.9086
#  F1 Score (std)                : 0.0055
#
# Confusion Matrix:
# Float32[327.6 2.8 8.8 0.8; 0.8 237.4 12.8 9.0; 16.2 13.6 164.2 6.0; 1.4 8.2 10.2 180.2]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 327.6 │       2.8 │      8.8 │   0.8 │
# │ Hazardous │   0.8 │     237.4 │     12.8 │   9.0 │
# │  Moderate │  16.2 │      13.6 │    164.2 │   6.0 │
# │      Poor │   1.4 │       8.2 │     10.2 │ 180.2 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN | PCA outdim: 7
#  Hyperparameters: Dict("K" => 1)
# =====================================================
#  Accuracy (mean)               : 0.9118
#  Accuracy (std)                : 0.0055
#  Error Rate (mean)             : 0.0882
#  Error Rate (std)              : 0.0055
#  Sensitivity/Recall (mean)     : 0.9118
#  Sensitivity/Recall (std)      : 0.0055
#  Specificity (mean)            : 0.9731
#  Specificity (std)             : 0.0025
#  PPV (mean)                    : 0.9105
#  PPV (std)                     : 0.006
#  NPV (mean)                    : 0.978
#  NPV (std)                     : 0.0012
#  F1 Score (mean)               : 0.9106
#  F1 Score (std)                : 0.0062
#
# Confusion Matrix:
# Float32[329.6 1.2 8.2 1.0; 0.8 236.8 12.6 9.8; 18.4 13.2 162.4 6.0; 1.2 6.4 9.4 183.0]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 329.6 │       1.2 │      8.2 │   1.0 │
# │ Hazardous │   0.8 │     236.8 │     12.6 │   9.8 │
# │  Moderate │  18.4 │      13.2 │    162.4 │   6.0 │
# │      Poor │   1.2 │       6.4 │      9.4 │ 183.0 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN | PCA outdim: 8
#  Hyperparameters: Dict("K" => 1)
# =====================================================
#  Accuracy (mean)               : 0.9112
#  Accuracy (std)                : 0.0056
#  Error Rate (mean)             : 0.0888
#  Error Rate (std)              : 0.0056
#  Sensitivity/Recall (mean)     : 0.9112
#  Sensitivity/Recall (std)      : 0.0056
#  Specificity (mean)            : 0.973
#  Specificity (std)             : 0.0015
#  PPV (mean)                    : 0.9095
#  PPV (std)                     : 0.0057
#  NPV (mean)                    : 0.9785
#  NPV (std)                     : 0.0013
#  F1 Score (mean)               : 0.9098
#  F1 Score (std)                : 0.0058
#
# Confusion Matrix:
# Float32[330.4 1.2 6.6 1.8; 0.2 238.4 13.4 8.0; 19.0 12.2 161.6 7.2; 1.0 7.8 10.4 180.8]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 330.4 │       1.2 │      6.6 │   1.8 │
# │ Hazardous │   0.2 │     238.4 │     13.4 │   8.0 │
# │  Moderate │  19.0 │      12.2 │    161.6 │   7.2 │
# │      Poor │   1.0 │       7.8 │     10.4 │ 180.8 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN | PCA outdim: 6
#  Hyperparameters: Dict("K" => 3)
# =====================================================
#  Accuracy (mean)               : 0.9274
#  Accuracy (std)                : 0.0053
#  Error Rate (mean)             : 0.0726
#  Error Rate (std)              : 0.0053
#  Sensitivity/Recall (mean)     : 0.9274
#  Sensitivity/Recall (std)      : 0.0053
#  Specificity (mean)            : 0.9768
#  Specificity (std)             : 0.0007
#  PPV (mean)                    : 0.927
#  PPV (std)                     : 0.0055
#  NPV (mean)                    : 0.982
#  NPV (std)                     : 0.0022
#  F1 Score (mean)               : 0.9265
#  F1 Score (std)                : 0.0051
#
# Confusion Matrix:
# Float32[329.6 2.2 7.4 0.8; 0.6 242.4 9.4 7.6; 15.2 10.0 171.8 3.0; 0.8 6.4 9.2 183.6]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 329.6 │       2.2 │      7.4 │   0.8 │
# │ Hazardous │   0.6 │     242.4 │      9.4 │   7.6 │
# │  Moderate │  15.2 │      10.0 │    171.8 │   3.0 │
# │      Poor │   0.8 │       6.4 │      9.2 │ 183.6 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN | PCA outdim: 7
#  Hyperparameters: Dict("K" => 3)
# =====================================================
#  Accuracy (mean)               : 0.926
#  Accuracy (std)                : 0.0059
#  Error Rate (mean)             : 0.074
#  Error Rate (std)              : 0.0059
#  Sensitivity/Recall (mean)     : 0.926
#  Sensitivity/Recall (std)      : 0.0059
#  Specificity (mean)            : 0.9761
#  Specificity (std)             : 0.0023
#  PPV (mean)                    : 0.9252
#  PPV (std)                     : 0.0054
#  NPV (mean)                    : 0.9822
#  NPV (std)                     : 0.0012
#  F1 Score (mean)               : 0.9248
#  F1 Score (std)                : 0.0062
#
# Confusion Matrix:
# Float32[331.6 1.8 5.4 1.2; 0.2 241.4 10.0 8.4; 16.6 9.4 169.8 4.2; 1.4 6.6 8.8 183.2]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 331.6 │       1.8 │      5.4 │   1.2 │
# │ Hazardous │   0.2 │     241.4 │     10.0 │   8.4 │
# │  Moderate │  16.6 │       9.4 │    169.8 │   4.2 │
# │      Poor │   1.4 │       6.6 │      8.8 │ 183.2 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN | PCA outdim: 8
#  Hyperparameters: Dict("K" => 3)
# =====================================================
#  Accuracy (mean)               : 0.9252
#  Accuracy (std)                : 0.0083
#  Error Rate (mean)             : 0.0748
#  Error Rate (std)              : 0.0083
#  Sensitivity/Recall (mean)     : 0.9252
#  Sensitivity/Recall (std)      : 0.0083
#  Specificity (mean)            : 0.9759
#  Specificity (std)             : 0.0024
#  PPV (mean)                    : 0.9243
#  PPV (std)                     : 0.0077
#  NPV (mean)                    : 0.9826
#  NPV (std)                     : 0.0013
#  F1 Score (mean)               : 0.9237
#  F1 Score (std)                : 0.0088
#
# Confusion Matrix:
# Float32[332.8 0.8 4.4 2.0; 0.2 241.6 9.6 8.6; 17.8 9.6 167.8 4.8; 1.0 5.8 10.2 183.0]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 332.8 │       0.8 │      4.4 │   2.0 │
# │ Hazardous │   0.2 │     241.6 │      9.6 │   8.6 │
# │  Moderate │  17.8 │       9.6 │    167.8 │   4.8 │
# │      Poor │   1.0 │       5.8 │     10.2 │ 183.0 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN | PCA outdim: 6
#  Hyperparameters: Dict("K" => 5)
# =====================================================
#  Accuracy (mean)               : 0.933
#  Accuracy (std)                : 0.006
#  Error Rate (mean)             : 0.067
#  Error Rate (std)              : 0.006
#  Sensitivity/Recall (mean)     : 0.933
#  Sensitivity/Recall (std)      : 0.006
#  Specificity (mean)            : 0.9779
#  Specificity (std)             : 0.0012
#  PPV (mean)                    : 0.9325
#  PPV (std)                     : 0.0069
#  NPV (mean)                    : 0.984
#  NPV (std)                     : 0.0019
#  F1 Score (mean)               : 0.932
#  F1 Score (std)                : 0.006
#
# Confusion Matrix:
# Float32[331.8 2.4 5.0 0.8; 0.4 243.0 9.0 7.6; 16.0 8.2 172.6 3.2; 0.6 5.8 8.0 185.6]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 331.8 │       2.4 │      5.0 │   0.8 │
# │ Hazardous │   0.4 │     243.0 │      9.0 │   7.6 │
# │  Moderate │  16.0 │       8.2 │    172.6 │   3.2 │
# │      Poor │   0.6 │       5.8 │      8.0 │ 185.6 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN | PCA outdim: 7
#  Hyperparameters: Dict("K" => 5)
# =====================================================
#  Accuracy (mean)               : 0.9296
#  Accuracy (std)                : 0.0069
#  Error Rate (mean)             : 0.0704
#  Error Rate (std)              : 0.0069
#  Sensitivity/Recall (mean)     : 0.9296
#  Sensitivity/Recall (std)      : 0.0069
#  Specificity (mean)            : 0.9764
#  Specificity (std)             : 0.0027
#  PPV (mean)                    : 0.9291
#  PPV (std)                     : 0.0064
#  NPV (mean)                    : 0.9838
#  NPV (std)                     : 0.0009
#  F1 Score (mean)               : 0.9282
#  F1 Score (std)                : 0.0074
#
# Confusion Matrix:
# Float32[333.8 2.2 3.0 1.0; 0.2 242.8 8.8 8.2; 17.6 9.2 169.6 3.6; 1.0 5.4 10.2 183.4]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 333.8 │       2.2 │      3.0 │   1.0 │
# │ Hazardous │   0.2 │     242.8 │      8.8 │   8.2 │
# │  Moderate │  17.6 │       9.2 │    169.6 │   3.6 │
# │      Poor │   1.0 │       5.4 │     10.2 │ 183.4 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN | PCA outdim: 8
#  Hyperparameters: Dict("K" => 5)
# =====================================================
#  Accuracy (mean)               : 0.9284
#  Accuracy (std)                : 0.0074
#  Error Rate (mean)             : 0.0716
#  Error Rate (std)              : 0.0074
#  Sensitivity/Recall (mean)     : 0.9284
#  Sensitivity/Recall (std)      : 0.0074
#  Specificity (mean)            : 0.976
#  Specificity (std)             : 0.0024
#  PPV (mean)                    : 0.9275
#  PPV (std)                     : 0.007
#  NPV (mean)                    : 0.9837
#  NPV (std)                     : 0.0012
#  F1 Score (mean)               : 0.9269
#  F1 Score (std)                : 0.0078
#
# Confusion Matrix:
# Float32[334.0 1.6 2.8 1.6; 0.2 241.2 9.6 9.0; 18.0 9.4 169.4 3.2; 0.8 6.0 9.4 183.8]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 334.0 │       1.6 │      2.8 │   1.6 │
# │ Hazardous │   0.2 │     241.2 │      9.6 │   9.0 │
# │  Moderate │  18.0 │       9.4 │    169.4 │   3.2 │
# │      Poor │   0.8 │       6.0 │      9.4 │ 183.8 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN | PCA outdim: 6
#  Hyperparameters: Dict("K" => 7)
# =====================================================
#  Accuracy (mean)               : 0.9338
#  Accuracy (std)                : 0.0075
#  Error Rate (mean)             : 0.0662
#  Error Rate (std)              : 0.0075
#  Sensitivity/Recall (mean)     : 0.9338
#  Sensitivity/Recall (std)      : 0.0075
#  Specificity (mean)            : 0.9777
#  Specificity (std)             : 0.0019
#  PPV (mean)                    : 0.9335
#  PPV (std)                     : 0.0081
#  NPV (mean)                    : 0.9847
#  NPV (std)                     : 0.0018
#  F1 Score (mean)               : 0.9326
#  F1 Score (std)                : 0.0078
#
# Confusion Matrix:
# Float32[333.2 2.2 3.8 0.8; 0.2 243.2 8.8 7.8; 16.6 8.2 172.4 2.8; 0.6 5.2 9.2 185.0]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 333.2 │       2.2 │      3.8 │   0.8 │
# │ Hazardous │   0.2 │     243.2 │      8.8 │   7.8 │
# │  Moderate │  16.6 │       8.2 │    172.4 │   2.8 │
# │      Poor │   0.6 │       5.2 │      9.2 │ 185.0 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN | PCA outdim: 7
#  Hyperparameters: Dict("K" => 7)
# =====================================================
#  Accuracy (mean)               : 0.9296
#  Accuracy (std)                : 0.0063
#  Error Rate (mean)             : 0.0704
#  Error Rate (std)              : 0.0063
#  Sensitivity/Recall (mean)     : 0.9296
#  Sensitivity/Recall (std)      : 0.0063
#  Specificity (mean)            : 0.9761
#  Specificity (std)             : 0.0022
#  PPV (mean)                    : 0.9289
#  PPV (std)                     : 0.0062
#  NPV (mean)                    : 0.9839
#  NPV (std)                     : 0.0009
#  F1 Score (mean)               : 0.9281
#  F1 Score (std)                : 0.0067
#
# Confusion Matrix:
# Float32[333.4 2.4 3.0 1.2; 0.2 242.0 9.0 8.8; 17.8 8.2 170.6 3.4; 0.8 5.6 10.0 183.6]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 333.4 │       2.4 │      3.0 │   1.2 │
# │ Hazardous │   0.2 │     242.0 │      9.0 │   8.8 │
# │  Moderate │  17.8 │       8.2 │    170.6 │   3.4 │
# │      Poor │   0.8 │       5.6 │     10.0 │ 183.6 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN | PCA outdim: 8
#  Hyperparameters: Dict("K" => 7)
# =====================================================
#  Accuracy (mean)               : 0.93
#  Accuracy (std)                : 0.0052
#  Error Rate (mean)             : 0.07
#  Error Rate (std)              : 0.0052
#  Sensitivity/Recall (mean)     : 0.93
#  Sensitivity/Recall (std)      : 0.0052
#  Specificity (mean)            : 0.9762
#  Specificity (std)             : 0.0015
#  PPV (mean)                    : 0.9293
#  PPV (std)                     : 0.0052
#  NPV (mean)                    : 0.9842
#  NPV (std)                     : 0.0012
#  F1 Score (mean)               : 0.9285
#  F1 Score (std)                : 0.0054
#
# Confusion Matrix:
# Float32[334.2 1.8 2.4 1.6; 0.0 241.4 10.4 8.2; 18.2 8.2 171.2 2.4; 1.0 5.8 10.0 183.2]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 334.2 │       1.8 │      2.4 │   1.6 │
# │ Hazardous │   0.0 │     241.4 │     10.4 │   8.2 │
# │  Moderate │  18.2 │       8.2 │    171.2 │   2.4 │
# │      Poor │   1.0 │       5.8 │     10.0 │ 183.2 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN | PCA outdim: 6
#  Hyperparameters: Dict("K" => 9)
# =====================================================
#  Accuracy (mean)               : 0.9342
#  Accuracy (std)                : 0.0077
#  Error Rate (mean)             : 0.0658
#  Error Rate (std)              : 0.0077
#  Sensitivity/Recall (mean)     : 0.9342
#  Sensitivity/Recall (std)      : 0.0077
#  Specificity (mean)            : 0.9776
#  Specificity (std)             : 0.002
#  PPV (mean)                    : 0.934
#  PPV (std)                     : 0.0079
#  NPV (mean)                    : 0.9848
#  NPV (std)                     : 0.0018
#  F1 Score (mean)               : 0.933
#  F1 Score (std)                : 0.0079
#
# Confusion Matrix:
# Float32[332.6 2.6 3.8 1.0; 0.2 242.4 9.4 8.0; 16.2 8.4 172.8 2.6; 0.6 5.4 7.6 186.4]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 332.6 │       2.6 │      3.8 │   1.0 │
# │ Hazardous │   0.2 │     242.4 │      9.4 │   8.0 │
# │  Moderate │  16.2 │       8.4 │    172.8 │   2.6 │
# │      Poor │   0.6 │       5.4 │      7.6 │ 186.4 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN | PCA outdim: 7
#  Hyperparameters: Dict("K" => 9)
# =====================================================
#  Accuracy (mean)               : 0.929
#  Accuracy (std)                : 0.0068
#  Error Rate (mean)             : 0.071
#  Error Rate (std)              : 0.0068
#  Sensitivity/Recall (mean)     : 0.929
#  Sensitivity/Recall (std)      : 0.0068
#  Specificity (mean)            : 0.9755
#  Specificity (std)             : 0.0024
#  PPV (mean)                    : 0.9283
#  PPV (std)                     : 0.0068
#  NPV (mean)                    : 0.9837
#  NPV (std)                     : 0.0012
#  F1 Score (mean)               : 0.9275
#  F1 Score (std)                : 0.0071
#
# Confusion Matrix:
# Float32[333.2 2.6 3.0 1.2; 0.0 242.6 9.6 7.8; 19.0 8.8 169.4 2.8; 1.4 6.0 8.8 183.8]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 333.2 │       2.6 │      3.0 │   1.2 │
# │ Hazardous │   0.0 │     242.6 │      9.6 │   7.8 │
# │  Moderate │  19.0 │       8.8 │    169.4 │   2.8 │
# │      Poor │   1.4 │       6.0 │      8.8 │ 183.8 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN | PCA outdim: 8
#  Hyperparameters: Dict("K" => 9)
# =====================================================
#  Accuracy (mean)               : 0.9276
#  Accuracy (std)                : 0.0057
#  Error Rate (mean)             : 0.0724
#  Error Rate (std)              : 0.0057
#  Sensitivity/Recall (mean)     : 0.9276
#  Sensitivity/Recall (std)      : 0.0057
#  Specificity (mean)            : 0.9752
#  Specificity (std)             : 0.0016
#  PPV (mean)                    : 0.927
#  PPV (std)                     : 0.0054
#  NPV (mean)                    : 0.9837
#  NPV (std)                     : 0.0011
#  F1 Score (mean)               : 0.9259
#  F1 Score (std)                : 0.006
#
# Confusion Matrix:
# Float32[334.0 2.2 2.2 1.6; 0.0 241.0 10.8 8.2; 19.4 9.0 169.2 2.4; 1.0 6.0 9.6 183.4]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 334.0 │       2.2 │      2.2 │   1.6 │
# │ Hazardous │   0.0 │     241.0 │     10.8 │   8.2 │
# │  Moderate │  19.4 │       9.0 │    169.2 │   2.4 │
# │      Poor │   1.0 │       6.0 │      9.6 │ 183.4 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN | PCA outdim: 6
#  Hyperparameters: Dict("K" => 11)
# =====================================================
#  Accuracy (mean)               : 0.9338
#  Accuracy (std)                : 0.0073
#  Error Rate (mean)             : 0.0662
#  Error Rate (std)              : 0.0073
#  Sensitivity/Recall (mean)     : 0.9338
#  Sensitivity/Recall (std)      : 0.0073
#  Specificity (mean)            : 0.9773
#  Specificity (std)             : 0.0015
#  PPV (mean)                    : 0.9337
#  PPV (std)                     : 0.0073
#  NPV (mean)                    : 0.9845
#  NPV (std)                     : 0.0018
#  F1 Score (mean)               : 0.9326
#  F1 Score (std)                : 0.0074
#
# Confusion Matrix:
# Float32[332.2 2.4 4.2 1.2; 0.2 242.0 10.0 7.8; 17.0 7.8 173.0 2.2; 0.6 5.0 7.8 186.6]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 332.2 │       2.4 │      4.2 │   1.2 │
# │ Hazardous │   0.2 │     242.0 │     10.0 │   7.8 │
# │  Moderate │  17.0 │       7.8 │    173.0 │   2.2 │
# │      Poor │   0.6 │       5.0 │      7.8 │ 186.6 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN | PCA outdim: 7
#  Hyperparameters: Dict("K" => 11)
# =====================================================
#  Accuracy (mean)               : 0.9296
#  Accuracy (std)                : 0.0058
#  Error Rate (mean)             : 0.0704
#  Error Rate (std)              : 0.0058
#  Sensitivity/Recall (mean)     : 0.9296
#  Sensitivity/Recall (std)      : 0.0058
#  Specificity (mean)            : 0.9755
#  Specificity (std)             : 0.0024
#  PPV (mean)                    : 0.9294
#  PPV (std)                     : 0.0052
#  NPV (mean)                    : 0.984
#  NPV (std)                     : 0.0011
#  F1 Score (mean)               : 0.928
#  F1 Score (std)                : 0.006
#
# Confusion Matrix:
# Float32[333.6 2.8 2.4 1.2; 0.0 243.8 8.2 8.0; 18.8 8.8 169.8 2.6; 1.2 6.6 9.8 182.4]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 333.6 │       2.8 │      2.4 │   1.2 │
# │ Hazardous │   0.0 │     243.8 │      8.2 │   8.0 │
# │  Moderate │  18.8 │       8.8 │    169.8 │   2.6 │
# │      Poor │   1.2 │       6.6 │      9.8 │ 182.4 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN | PCA outdim: 8
#  Hyperparameters: Dict("K" => 11)
# =====================================================
#  Accuracy (mean)               : 0.9268
#  Accuracy (std)                : 0.0045
#  Error Rate (mean)             : 0.0732
#  Error Rate (std)              : 0.0045
#  Sensitivity/Recall (mean)     : 0.9268
#  Sensitivity/Recall (std)      : 0.0045
#  Specificity (mean)            : 0.975
#  Specificity (std)             : 0.0015
#  PPV (mean)                    : 0.9262
#  PPV (std)                     : 0.004
#  NPV (mean)                    : 0.9837
#  NPV (std)                     : 0.001
#  F1 Score (mean)               : 0.9251
#  F1 Score (std)                : 0.0047
#
# Confusion Matrix:
# Float32[334.0 2.0 2.4 1.6; 0.0 240.6 11.4 8.0; 18.6 8.6 169.8 3.0; 1.2 6.4 10.0 182.4]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 334.0 │       2.0 │      2.4 │   1.6 │
# │ Hazardous │   0.0 │     240.6 │     11.4 │   8.0 │
# │  Moderate │  18.6 │       8.6 │    169.8 │   3.0 │
# │      Poor │   1.2 │       6.4 │     10.0 │ 182.4 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================

# %% [markdown]
# # Stacking Ensemble

# %%
SVMClassifier = @load ProbabilisticSVC pkg=LIBSVM verbosity=0
DTClassifier  = @load DecisionTreeClassifier pkg=DecisionTree verbosity=0
kNNClassifier = @load KNNClassifier pkg=NearestNeighborModels verbosity=0
PCA = MLJ.@load PCA pkg="MultivariateStats" verbosity=0

trainIdx, testIdx = holdOut(size(df,1), 0.2)

trainingInputs  = inputs[trainIdx, :]
testInputs      = inputs[testIdx, :]

trainingTargets = targets[trainIdx]
testTargets     = targets[testIdx]

# X as DataFrame
train_df = DataFrame(trainingInputs, :auto)
test_df  = DataFrame(testInputs, :auto)

# y as categorical
train_y_cat = categorical(trainingTargets)
test_y_cat  = categorical(testTargets)

# ---- Base Models ----
svm_pca = Pipeline(
    pca = PCA(maxoutdim=8),
    model = SVMClassifier(kernel=LIBSVM.Kernel.RadialBasis, cost=1.0, gamma=2.0)
)

dt_pca = Pipeline(
    pca = PCA(maxoutdim=8),
    model = DTClassifier(max_depth=5)
)

knn_pca = Pipeline(
    pca = PCA(maxoutdim=6),
    model = kNNClassifier(K=9)
)

# ---- Stacking Model ----
stack_model = Stack(;
    metalearner = DTClassifier(max_depth=3, rng=Random.MersenneTwister(1)),
    resampling = CV(nfolds=5, shuffle=true, rng=123),
    measure = accuracy, 
    svm = svm_pca,
    knn = knn_pca,
    dt = dt_pca
)

# Train the stacking model on your train dataset
stack_mach = machine(stack_model, train_df, train_y_cat) |> MLJ.fit!

y_pred = mode.(MLJ.predict(stack_mach, test_df))
acc = MLJ.accuracy(y_pred, test_y_cat)
println("Stack ensemble accuracy = $(round(acc*100, digits=2)) %")
# Out:
# Stack ensemble accuracy = 62.5 %
# ┌ Warning: Could not infer input_scitype of the stack
# └ @ MLJBase ~/.julia/packages/MLJBase/GY2fM/src/composition/models/stacking.jl:187
# [ Info: Training machine(ProbabilisticStack(metalearner = DecisionTreeClassifier(max_depth = 3, …), …), …).
# [ Info: Training machine(:svm, …).
# [ Info: Training machine(:knn, …).
# [ Info: Training machine(:dt, …).
# [ Info: Training machine(:svm, …).
# [ Info: Training machine(:knn, …).
# [ Info: Training machine(:dt, …).
# [ Info: Training machine(:svm, …).
# [ Info: Training machine(:knn, …).
# [ Info: Training machine(:dt, …).
# [ Info: Training machine(:svm, …).
# [ Info: Training machine(:knn, …).
# [ Info: Training machine(:dt, …).
# [ Info: Training machine(:svm, …).
# [ Info: Training machine(:knn, …).
# [ Info: Training machine(:dt, …).
# [ Info: Training machine(:svm, …).
# [ Info: Training machine(:knn, …).
# [ Info: Training machine(:dt, …).
# [ Info: Training machine(:pca, …).
# [ Info: Training machine(:pca, …).
# [ Info: Training machine(:pca, …).
# [ Info: Training machine(:pca, …).
# [ Info: Training machine(:pca, …).
# [ Info: Training machine(:pca, …).
# [ Info: Training machine(:pca, …).
# [ Info: Training machine(:pca, …).
# [ Info: Training machine(:pca, …).
# [ Info: Training machine(:pca, …).
# [ Info: Training machine(:pca, …).
# [ Info: Training machine(:pca, …).
# [ Info: Training machine(:pca, …).
# [ Info: Training machine(:pca, …).
# [ Info: Training machine(:pca, …).
# [ Info: Training machine(:pca, …).
# [ Info: Training machine(:pca, …).
# [ Info: Training machine(:model, …).
# [ Info: Training machine(:pca, …).
# [ Info: Training machine(:model, …).
# [ Info: Training machine(:model, …).
# [ Info: Training machine(:model, …).
# [ Info: Training machine(:model, …).
# [ Info: Training machine(:model, …).
# [ Info: Training machine(:model, …).
# [ Info: Training machine(:model, …).
# [ Info: Training machine(:model, …).
# [ Info: Training machine(:model, …).
# [ Info: Training machine(:model, …).
# [ Info: Training machine(:model, …).
# [ Info: Training machine(:model, …).
# [ Info: Training machine(:model, …).
# [ Info: Training machine(:model, …).
# [ Info: Training machine(:model, …).
# [ Info: Training machine(:model, …).
# [ Info: Training machine(:model, …).
# [ Info: Training machine(:metalearner, …).
