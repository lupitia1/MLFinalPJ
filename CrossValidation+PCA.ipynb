# %% [markdown]
# # Load packages

# %%
# skip reinstalling packages we already have
using Pkg

pkgs = [
    "MLJ", "MLJBase", "MLJModels", "MLJEnsembles", "MLJLinearModels",
    "DecisionTree", "MLJDecisionTreeInterface", "NaiveBayes", 
    "MLJNaiveBayesInterface", "EvoTrees", "CategoricalArrays", "Random",
    "LIBSVM", "MLJLIBSVMInterface", "Plots", "MLJModelInterface",
    "CSV", "DataFrames", "UrlDownload", "XGBoost", "NNlib"
]

# Filter out packages already installed
missing_pkgs = filter(pkg -> !(pkg in keys(Pkg.project().dependencies)), pkgs)

if !isempty(missing_pkgs)
    println("Installing missing packages: ", missing_pkgs)
    Pkg.add(missing_pkgs)
else
    println(" All required packages are already installed.")
end
# Out:
#  All required packages are already installed.

# %%
using MLJ
using MLJBase
using LIBSVM
using NNlib
using Flux
using Flux.Losses
using Statistics

# %%
# Load PCA
PCA_model = MLJ.@load PCA pkg="MultivariateStats"
# Out:
# import MLJMultivariateStatsInterface ✔
# [ Info: For silent loading, specify `verbosity=0`.
# MLJMultivariateStatsInterface.PCA

# %%
#Load your library of functions
include("utils.jl")
# Set a global random seed for reproducibility
using Random
Random.seed!(42)
# Out:
# TaskLocalRNG()

# %% [markdown]
# # Load Data

# %%
using CSV, DataFrames, Random
using CategoricalArrays

df = CSV.read("./data/updated_pollution_dataset.csv", DataFrame)

# Some log
println("First 5 rows of df:")
show(df[1:5, :], allcols=true)


# Convert last column to categorical (in-place!)
df[!, end] = categorical(df[!, end])

# Extract the integer codes of the categories
targets = Float32.(levelcode.(df[!, end]))

# Use all columns except the last one as inputs
inputs = Matrix{Float32}(df[:, 1:end-1])

println("First 5 inputs::")
for i in 1:5
    println(inputs[i, :])
end

println("\n\nFirst 5 targets:")
println(targets[1:5])

# Extract labels (categories) as strings
label_names = levels(df[!, 10])
println("Labels: ", label_names)
# Out:
# First 5 rows of df:
# 5×10 DataFrame
#  Row │ Temperature  Humidity  PM2.5    PM10     NO2      SO2      CO       Proximity_to_Industrial_Areas  Population_Density  Air Quality
#      │ Float64      Float64   Float64  Float64  Float64  Float64  Float64  Float64                        Int64               String15
# ─────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#    1 │        29.8      59.1      5.2     17.9     18.9      9.2     1.72                            6.3                 319  Moderate
#    2 │        28.3      75.6      2.3     12.2     30.8      9.7     1.64                            6.0                 611  Moderate
#    3 │        23.1      74.7     26.7     33.8     24.4     12.6     1.63                            5.2                 619  Moderate
#    4 │        27.1      39.1      6.1      6.3     13.5      5.3     1.15                           11.1                 551  Good
#    5 │        26.5      70.7      6.9     16.0     21.9      5.6     1.01                           12.7                 303  GoodFirst 5 inputs::
# Float32
# [29.8, 59.1, 5.2, 17.9, 18.9, 9.2, 1.72, 6.3, 319.0]
# Float32[28.3, 75.6, 2.3, 12.2, 30.8, 9.7, 1.64, 6.0, 611.0]
# Float32[23.1, 74.7, 26.7, 33.8, 24.4, 12.6, 1.63, 5.2, 619.0]
# Float32[27.1, 39.1, 6.1, 6.3, 13.5, 5.3, 1.15, 11.1, 551.0]
# Float32[26.5, 70.7, 6.9, 16.0, 21.9, 5.6, 1.01, 12.7, 303.0]
#
#
# First 5 targets:
# Float32[3.0, 3.0, 3.0, 1.0, 1.0]
# Labels: String15["Good", "Hazardous", "Moderate", "Poor"]

# %% [markdown]
# # Split train-test datasets

# %%
trainIdx, testIdx = holdOut(size(df,1), 0.2)

trainingInputs  = inputs[trainIdx, :]
testInputs      = inputs[testIdx, :]

trainingTargets = targets[trainIdx]
testTargets     = targets[testIdx]
# Out:
# 1000-element Vector{Float32}:
#  2.0
#  3.0
#  1.0
#  2.0
#  1.0
#  1.0
#  4.0
#  4.0
#  2.0
#  1.0
#  3.0
#  1.0
#  4.0
#  ⋮
#  3.0
#  1.0
#  1.0
#  1.0
#  1.0
#  4.0
#  4.0
#  3.0
#  3.0
#  2.0
#  1.0
#  3.0

# %%
results = Dict()
dimsPCA = [6,7,8]
crossValidationIndices = crossvalidation(trainingTargets, 5)
# Out:
# 4000-element Vector{Int64}:
#  5
#  5
#  3
#  2
#  2
#  1
#  2
#  1
#  3
#  2
#  1
#  2
#  3
#  ⋮
#  1
#  3
#  2
#  3
#  4
#  4
#  4
#  4
#  4
#  3
#  5
#  5

# %%
function printExperimentResult(model, hyperparams, dimPCA, results, class_labels)
    (
        (accuracy_mean, accuracy_std),
        (error_rate_mean, error_rate_std),
        (sensitivity_mean, sensitivity_std),
        (specificity_mean, specificity_std),
        (ppv_mean, ppv_std),
        (npv_mean, npv_std),
        (f1_mean, f1_std),
        cm
    ) = results

    println("\n=====================================================")
    println(" Model: $model | PCA outdim: $dimPCA")
    println(" Hyperparameters: $hyperparams")
    println("=====================================================")

    println(" Accuracy (mean)               : ", round(accuracy_mean, digits=4))
    println(" Accuracy (std)                : ", round(accuracy_std, digits=4))

    println(" Error Rate (mean)             : ", round(error_rate_mean, digits=4))
    println(" Error Rate (std)              : ", round(error_rate_std, digits=4))

    println(" Sensitivity/Recall (mean)     : ", round(sensitivity_mean, digits=4))
    println(" Sensitivity/Recall (std)      : ", round(sensitivity_std,  digits=4))

    println(" Specificity (mean)            : ", round(specificity_mean, digits=4))
    println(" Specificity (std)             : ", round(specificity_std,  digits=4))

    println(" PPV (mean)                    : ", round(ppv_mean,         digits=4))
    println(" PPV (std)                     : ", round(ppv_std,          digits=4))

    println(" NPV (mean)                    : ", round(npv_mean,         digits=4))
    println(" NPV (std)                     : ", round(npv_std,          digits=4))

    println(" F1 Score (mean)               : ", round(f1_mean,          digits=4))
    println(" F1 Score (std)                : ", round(f1_std,           digits=4))

    println("\nConfusion Matrix:")
    println(cm)

    PrettyTables.pretty_table(DataFrame(cm, :auto); header=class_labels, row_labels=class_labels)

    println("=====================================================\n")
end
# Out:
# printExperimentResult (generic function with 1 method)

# %% [markdown]
# # Artificial Neural Networks

# %%
############# 1. ARTIFICIAL NEURAL NETWORKS (8+ topologies) #############
default_ann = Dict(      
    "numExecutions" => 5,
    #"transferFunctions" => [σ, σ, σ, σ],
    "maxEpochs" => 200,
    "minLoss" => 0.0,
    "learningRate" => 0.01,
    "validationRatio" => 0.1,
    "maxEpochsVal" => 20
)

ann_search_space = [
    Dict("topology"=>[4, 4]),
    Dict("topology"=>[8, 8]),
    Dict("topology"=>[16, 16]),
    Dict("topology"=>[10, 4]),
    Dict("topology"=>[10, 6, 4]),
    Dict("topology"=>[10, 8, 4]),
    Dict("topology"=>[10, 8, 6, 4]),
    Dict("topology"=>[10, 12, 6, 4])
]
# Out:
# 8-element Vector{Dict{String, Vector{Int64}}}:
#  Dict("topology" => [4, 4])
#  Dict("topology" => [8, 8])
#  Dict("topology" => [16, 16])
#  Dict("topology" => [10, 4])
#  Dict("topology" => [10, 6, 4])
#  Dict("topology" => [10, 8, 4])
#  Dict("topology" => [10, 8, 6, 4])
#  Dict("topology" => [10, 12, 6, 4])

# %%
########################
# 1. ANN GRID SEARCH
########################
ann_results = []

for hp in ann_search_space
    for dim in dimsPCA
        println("\n=== ANN experiment: topology = $(hp["topology"]) | PCA maxoutdim = $(dim) ===")
        full_hp = merge(default_ann, hp)
        res = modelCrossValidationPCA(:ANN, full_hp, (trainingInputs, trainingTargets), crossValidationIndices, dim)
        push!(ann_results, (model=:ANN, hyperparams=hp, dimPCA=dim, results=res))
    end
end

results[:ANN] = ann_results
# Out:
# === ANN experiment: topology = [4, 4] | PCA maxoutdim = 6 ===
#
# === ANN experiment: topology = [4, 4] | PCA maxoutdim = 7 ===
#
# === ANN experiment: topology = [4, 4] | PCA maxoutdim = 8 ===
#
# === ANN experiment: topology = [8, 8] | PCA maxoutdim = 6 ===
#
# === ANN experiment: topology = [8, 8] | PCA maxoutdim = 7 ===
#
# === ANN experiment: topology = [8, 8] | PCA maxoutdim = 8 ===
#
# === ANN experiment: topology = [16, 16] | PCA maxoutdim = 6 ===
#
# === ANN experiment: topology = [16, 16] | PCA maxoutdim = 7 ===
#
# === ANN experiment: topology = [16, 16] | PCA maxoutdim = 8 ===
#
# === ANN experiment: topology = [10, 4] | PCA maxoutdim = 6 ===
#
# === ANN experiment: topology = [10, 4] | PCA maxoutdim = 7 ===
#
# === ANN experiment: topology = [10, 4] | PCA maxoutdim = 8 ===
#
# === ANN experiment: topology = [10, 6, 4] | PCA maxoutdim = 6 ===
#
# === ANN experiment: topology = [10, 6, 4] | PCA maxoutdim = 7 ===
#
# === ANN experiment: topology = [10, 6, 4] | PCA maxoutdim = 8 ===
#
# === ANN experiment: topology = [10, 8, 4] | PCA maxoutdim = 6 ===
#
# === ANN experiment: topology = [10, 8, 4] | PCA maxoutdim = 7 ===
#
# === ANN experiment: topology = [10, 8, 4] | PCA maxoutdim = 8 ===
#
# === ANN experiment: topology = [10, 8, 6, 4] | PCA maxoutdim = 6 ===
#
# === ANN experiment: topology = [10, 8, 6, 4] | PCA maxoutdim = 7 ===
#
# === ANN experiment: topology = [10, 8, 6, 4] | PCA maxoutdim = 8 ===
#
# === ANN experiment: topology = [10, 12, 6, 4] | PCA maxoutdim = 6 ===
#
# === ANN experiment: topology = [10, 12, 6, 4] | PCA maxoutdim = 7 ===
#
# === ANN experiment: topology = [10, 12, 6, 4] | PCA maxoutdim = 8 ===
# 24-element Vector{Any}:
#  (model = :ANN, hyperparams = Dict("topology" => [4, 4]), dimPCA = 6, results = ((0.94074315f0, 0.0042731683f0), (0.059256874f0, 0.0042731655f0), (0.94074315f0, 0.0042731683f0), (0.98274595f0, 0.0025842295f0), (0.9379606f0, 0.009482839f0), (0.98563397f0, 0.0011026161f0), (0.9388195f0, 0.007021723f0), Float32[267.36002 0.52 2.76 2.76; 3.64 173.36002 9.72 4.4800005; 2.3200002 4.0 211.23999 6.04; 2.76 4.5199995 3.8799999 100.64]))
#  (model = :ANN, hyperparams = Dict("topology" => [4, 4]), dimPCA = 7, results = ((0.9431449f0, 0.004030533f0), (0.05685513f0, 0.0040305755f0), (0.9431449f0, 0.004030533f0), (0.9833366f0, 0.0019408528f0), (0.9432856f0, 0.004718385f0), (0.9857807f0, 0.0011526846f0), (0.942704f0, 0.0039187265f0), Float32[267.28 0.64 2.72 2.76; 3.48 175.16 7.84 4.72; 2.4 3.8799999 211.16 6.16; 2.84 4.12 3.92 100.920006]))
#  (model = :ANN, hyperparams = Dict("topology" => [4, 4]), dimPCA = 8, results = ((0.9441973f0, 0.0050831344f0), (0.055802684f0, 0.00508313f0), (0.9441973f0, 0.0050831344f0), (0.9837362f0, 0.0010953664f0), (0.9442957f0, 0.0058708363f0), (0.9860219f0, 0.001004399f0), (0.9437647f0, 0.005113399f0), Float32[266.84 0.6 3.08 2.8799999; 3.44 175.88 7.0800004 4.8; 2.1200001 4.16 211.76001 5.56; 2.76 4.0 4.16 100.880005]))
#  (model = :ANN, hyperparams = Dict("topology" => [8, 8]), dimPCA = 6, results = ((0.9440479f0, 0.0040120003f0), (0.055952124f0, 0.0040119938f0), (0.9440479f0, 0.0040120003f0), (0.98385173f0, 0.0011023928f0), (0.9440559f0, 0.004771492f0), (0.98608273f0, 0.000705025f0), (0.9436577f0, 0.0040776213f0), Float32[267.44 0.6 2.6 2.76; 3.36 175.84 7.44 4.56; 2.28 3.9599998 212.08 5.28; 2.84 4.68 4.4 99.88]))
#  (model = :ANN, hyperparams = Dict("topology" => [8, 8]), dimPCA = 7, results = ((0.9432969f0, 0.0042228387f0), (0.05670306f0, 0.0042228764f0), (0.9432969f0, 0.0042228387f0), (0.9836863f0, 0.0010890851f0), (0.9433093f0, 0.0049757627f0), (0.98589545f0, 0.0007600718f0), (0.94291353f0, 0.0043005208f0), Float32[267.52 0.6 2.56 2.72; 3.44 175.8 7.3599997 4.6; 2.3200002 4.04 211.68001 5.56; 2.8400002 4.88 4.44 99.64]))
#  (model = :ANN, hyperparams = Dict("topology" => [8, 8]), dimPCA = 8, results = ((0.9440486f0, 0.0039484384f0), (0.055951435f0, 0.0039484277f0), (0.9440486f0, 0.0039484384f0), (0.9839322f0, 0.0009532382f0), (0.9440402f0, 0.0047509084f0), (0.98609066f0, 0.00079637143f0), (0.9436699f0, 0.0040145987f0), Float32[267.44 0.6 2.56 2.8; 3.4 175.96 7.3599997 4.48; 2.3600001 4.04 212.04001 5.16; 2.76 4.84 4.4 99.799995]))
#  (model = :ANN, hyperparams = Dict("topology" => [16, 16]), dimPCA = 6, results = ((0.9438984f0, 0.004434496f0), (0.05610162f0, 0.0044345125f0), (0.9438984f0, 0.004434496f0), (0.9838821f0, 0.0011235917f0), (0.9437958f0, 0.0051364815f0), (0.98613757f0, 0.00094469584f0), (0.94350463f0, 0.0044782246f0), Float32[267.4 0.6 2.6 2.8; 3.2399998 176.44 7.12 4.4; 2.32 4.2 211.72 5.3599997; 2.96 5.04 4.2400002 99.55999]))
#  (model = :ANN, hyperparams = Dict("topology" => [16, 16]), dimPCA = 7, results = ((0.9440471f0, 0.004602563f0), (0.055952936f0, 0.004602587f0), (0.9440471f0, 0.004602563f0), (0.98394126f0, 0.0013460165f0), (0.9440118f0, 0.005278745f0), (0.98616207f0, 0.0010398482f0), (0.94366866f0, 0.004622418f0), Float32[267.56 0.6 2.6 2.6399999; 3.12 176.4 7.2799997 4.4; 2.3600001 4.16 211.64001 5.44; 2.92 5.0 4.2400002 99.64]))
#  (model = :ANN, hyperparams = Dict("topology" => [16, 16]), dimPCA = 8, results = ((0.9433974f0, 0.004353141f0), (0.05660256f0, 0.0043531545f0), (0.9433974f0, 0.004353141f0), (0.9836105f0, 0.0013948538f0), (0.9433794f0, 0.0051789028f0), (0.9860023f0, 0.0009680481f0), (0.94298583f0, 0.0044383244f0), Float32[267.63998 0.6 2.48 2.68; 3.44 175.87999 7.4 4.48; 2.44 4.08 211.76001 5.32; 2.96 5.04 4.3599997 99.439995]))
#  (model = :ANN, hyperparams = Dict("topology" => [10, 4]), dimPCA = 6, results = ((0.9397419f0, 0.005731668f0), (0.06025813f0, 0.005731679f0), (0.9397419f0, 0.005731668f0), (0.98268926f0, 0.0030607292f0), (0.93694746f0, 0.011012239f0), (0.9854886f0, 0.0010437614f0), (0.9378089f0, 0.008674218f0), Float32[267.4 0.6 2.6 2.8; 3.48 173.12 9.92 4.6800003; 2.28 4.0 211.04 6.28; 2.88 4.56 4.12 100.240005]))
#  ⋮
#  (model = :ANN, hyperparams = Dict("topology" => [10, 8, 4]), dimPCA = 6, results = ((0.9423989f0, 0.0060521686f0), (0.05760113f0, 0.0060521467f0), (0.9423989f0, 0.0060521686f0), (0.9835375f0, 0.0016080302f0), (0.94233876f0, 0.0066469777f0), (0.9857259f0, 0.001400141f0), (0.9419955f0, 0.0061254567f0), Float32[267.32 0.6 2.8 2.6799998; 3.16 176.4 7.0 4.6400003; 2.8 4.32 210.84 5.6400003; 2.92 5.28 4.2400002 99.36]))
#  (model = :ANN, hyperparams = Dict("topology" => [10, 8, 4]), dimPCA = 7, results = ((0.94319755f0, 0.0052329814f0), (0.05680244f0, 0.00523299f0), (0.94319755f0, 0.0052329814f0), (0.9836601f0, 0.0015199627f0), (0.9431923f0, 0.0058493703f0), (0.9859856f0, 0.0012576056f0), (0.942774f0, 0.0052810037f0), Float32[267.8 0.52 2.56 2.52; 3.2400002 176.07999 7.2799997 4.6; 2.6799998 4.4 210.95999 5.56; 2.9199998 5.04 4.12 99.72]))
#  (model = :ANN, hyperparams = Dict("topology" => [10, 8, 4]), dimPCA = 8, results = ((0.94259614f0, 0.0047555687f0), (0.057403874f0, 0.004755557f0), (0.94259614f0, 0.0047555687f0), (0.9834617f0, 0.0016792094f0), (0.94259727f0, 0.005459339f0), (0.98588383f0, 0.0010188211f0), (0.9421544f0, 0.004807069f0), Float32[267.36002 0.56 2.72 2.76; 3.2 175.84 7.6399994 4.52; 2.3200002 4.08 211.31999 5.88; 2.96 5.16 4.12 99.560005]))
#  (model = :ANN, hyperparams = Dict("topology" => [10, 8, 6, 4]), dimPCA = 6, results = ((0.94529784f0, 0.005790063f0), (0.054702174f0, 0.0057900613f0), (0.94529784f0, 0.005790063f0), (0.9841609f0, 0.0013917049f0), (0.9452325f0, 0.006402974f0), (0.9866624f0, 0.0014352655f0), (0.9448637f0, 0.005838229f0), Float32[267.8 0.44 2.76 2.4; 3.16 176.88 6.6800003 4.48; 2.24 4.32 211.8 5.2400002; 3.0 4.96 4.0800004 99.759995]))
#  (model = :ANN, hyperparams = Dict("topology" => [10, 8, 6, 4]), dimPCA = 7, results = ((0.94634706f0, 0.0074595604f0), (0.05365299f0, 0.0074595716f0), (0.94634706f0, 0.0074595604f0), (0.9846349f0, 0.0018208388f0), (0.9462105f0, 0.0077594183f0), (0.98706996f0, 0.0015700128f0), (0.945906f0, 0.007575851f0), Float32[267.8 0.4 2.9199998 2.2800002; 2.96 177.51999 6.56 4.16; 2.28 3.9599998 212.23999 5.12; 2.9599998 5.32 4.0 99.520004]))
#  (model = :ANN, hyperparams = Dict("topology" => [10, 8, 6, 4]), dimPCA = 8, results = ((0.94564676f0, 0.00695756f0), (0.054353178f0, 0.0069575985f0), (0.94564676f0, 0.00695756f0), (0.98450387f0, 0.0016446341f0), (0.94555485f0, 0.0074783787f0), (0.9867772f0, 0.0017561206f0), (0.9452573f0, 0.006989945f0), Float32[267.88 0.4 2.6799998 2.44; 2.88 177.4 6.4800005 4.44; 2.48 4.2799997 211.43999 5.4; 2.96 5.08 3.9599998 99.8]))
#  (model = :ANN, hyperparams = Dict("topology" => [10, 12, 6, 4]), dimPCA = 6, results = ((0.9458949f0, 0.006660557f0), (0.05410505f0, 0.0066605867f0), (0.9458949f0, 0.006660557f0), (0.984558f0, 0.00173971f0), (0.94582623f0, 0.00714849f0), (0.98672944f0, 0.0017090337f0), (0.9455183f0, 0.0066855317f0), Float32[267.52 0.32 2.92 2.64; 2.72 177.76 6.56 4.16; 2.32 4.2 211.68001 5.4; 2.72 5.0800004 4.2400002 99.76]))
#  (model = :ANN, hyperparams = Dict("topology" => [10, 12, 6, 4]), dimPCA = 7, results = ((0.94279563f0, 0.0104873385f0), (0.057204373f0, 0.010487328f0), (0.94279563f0, 0.0104873385f0), (0.9837392f0, 0.0030726478f0), (0.94015884f0, 0.01641214f0), (0.98655474f0, 0.0018118811f0), (0.94087994f0, 0.013674707f0), Float32[267.72 0.48000002 2.76 2.44; 2.9199998 177.36002 6.6799994 4.2400002; 2.2 4.2400002 212.0 5.16; 3.0 7.5199995 4.12 97.159996]))
#  (model = :ANN, hyperparams = Dict("topology" => [10, 12, 6, 4]), dimPCA = 8, results = ((0.9465977f0, 0.004657953f0), (0.053402357f0, 0.0046579815f0), (0.9465977f0, 0.004657953f0), (0.9847466f0, 0.0017851674f0), (0.9466031f0, 0.005260817f0), (0.9869386f0, 0.0012045617f0), (0.9462f0, 0.004745194f0), Float32[267.76 0.56 2.7199998 2.3600001; 2.76 177.4 6.6 4.44; 2.32 3.8799999 212.2 5.2; 2.92 4.7599998 4.2 99.92]))

# %%
for entry in results[:ANN]
    printExperimentResult(entry.model, entry.hyperparams, entry.dimPCA, entry.results, label_names)
end
# Out:
# =====================================================
#  Model: ANN | PCA outdim: 6
#  Hyperparameters: Dict("topology" => [4, 4])
# =====================================================
#  Accuracy (mean)               : 0.9407
#  Accuracy (std)                : 0.0043
#  Error Rate (mean)             : 0.0593
#  Error Rate (std)              : 0.0043
#  Sensitivity/Recall (mean)     : 0.9407
#  Sensitivity/Recall (std)      : 0.0043
#  Specificity (mean)            : 0.9827
#  Specificity (std)             : 0.0026
#  PPV (mean)                    : 0.938
#  PPV (std)                     : 0.0095
#  NPV (mean)                    : 0.9856
#  NPV (std)                     : 0.0011
#  F1 Score (mean)               : 0.9388
#  F1 Score (std)                : 0.007
#
# Confusion Matrix:
# Float32[267.36002 0.52 2.76 2.76; 3.64 173.36002 9.72 4.4800005; 2.3200002 4.0 211.23999 6.04; 2.76 4.5199995 3.8799999 100.64]
# ┌───────────┬────────┬───────────┬──────────┬────────┐
# │           │   Good │ Hazardous │ Moderate │   Poor │
# ├───────────┼────────┼───────────┼──────────┼────────┤
# │      Good │ 267.36 │      0.52 │     2.76 │   2.76 │
# │ Hazardous │   3.64 │    173.36 │     9.72 │   4.48 │
# │  Moderate │   2.32 │       4.0 │   211.24 │   6.04 │
# │      Poor │   2.76 │      4.52 │     3.88 │ 100.64 │
# └───────────┴────────┴───────────┴──────────┴────────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 7
#  Hyperparameters: Dict("topology" => [4, 4])
# =====================================================
#  Accuracy (mean)               : 0.9431
#  Accuracy (std)                : 0.004
#  Error Rate (mean)             : 0.0569
#  Error Rate (std)              : 0.004
#  Sensitivity/Recall (mean)     : 0.9431
#  Sensitivity/Recall (std)      : 0.004
#  Specificity (mean)            : 0.9833
#  Specificity (std)             : 0.0019
#  PPV (mean)                    : 0.9433
#  PPV (std)                     : 0.0047
#  NPV (mean)                    : 0.9858
#  NPV (std)                     : 0.0012
#  F1 Score (mean)               : 0.9427
#  F1 Score (std)                : 0.0039
#
# Confusion Matrix:
# Float32[267.28 0.64 2.72 2.76; 3.48 175.16 7.84 4.72; 2.4 3.8799999 211.16 6.16; 2.84 4.12 3.92 100.920006]
# ┌───────────┬────────┬───────────┬──────────┬────────┐
# │           │   Good │ Hazardous │ Moderate │   Poor │
# ├───────────┼────────┼───────────┼──────────┼────────┤
# │      Good │ 267.28 │      0.64 │     2.72 │   2.76 │
# │ Hazardous │   3.48 │    175.16 │     7.84 │   4.72 │
# │  Moderate │    2.4 │      3.88 │   211.16 │   6.16 │
# │      Poor │   2.84 │      4.12 │     3.92 │ 100.92 │
# └───────────┴────────┴───────────┴──────────┴────────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 8
#  Hyperparameters: Dict("topology" => [4, 4])
# =====================================================
#  Accuracy (mean)               : 0.9442
#  Accuracy (std)                : 0.0051
#  Error Rate (mean)             : 0.0558
#  Error Rate (std)              : 0.0051
#  Sensitivity/Recall (mean)     : 0.9442
#  Sensitivity/Recall (std)      : 0.0051
#  Specificity (mean)            : 0.9837
#  Specificity (std)             : 0.0011
#  PPV (mean)                    : 0.9443
#  PPV (std)                     : 0.0059
#  NPV (mean)                    : 0.986
#  NPV (std)                     : 0.001
#  F1 Score (mean)               : 0.9438
#  F1 Score (std)                : 0.0051
#
# Confusion Matrix:
# Float32[266.84 0.6 3.08 2.8799999; 3.44 175.88 7.0800004 4.8; 2.1200001 4.16 211.76001 5.56; 2.76 4.0 4.16 100.880005]
# ┌───────────┬────────┬───────────┬──────────┬────────┐
# │           │   Good │ Hazardous │ Moderate │   Poor │
# ├───────────┼────────┼───────────┼──────────┼────────┤
# │      Good │ 266.84 │       0.6 │     3.08 │   2.88 │
# │ Hazardous │   3.44 │    175.88 │     7.08 │    4.8 │
# │  Moderate │   2.12 │      4.16 │   211.76 │   5.56 │
# │      Poor │   2.76 │       4.0 │     4.16 │ 100.88 │
# └───────────┴────────┴───────────┴──────────┴────────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 6
#  Hyperparameters: Dict("topology" => [8, 8])
# =====================================================
#  Accuracy (mean)               : 0.944
#  Accuracy (std)                : 0.004
#  Error Rate (mean)             : 0.056
#  Error Rate (std)              : 0.004
#  Sensitivity/Recall (mean)     : 0.944
#  Sensitivity/Recall (std)      : 0.004
#  Specificity (mean)            : 0.9839
#  Specificity (std)             : 0.0011
#  PPV (mean)                    : 0.9441
#  PPV (std)                     : 0.0048
#  NPV (mean)                    : 0.9861
#  NPV (std)                     : 0.0007
#  F1 Score (mean)               : 0.9437
#  F1 Score (std)                : 0.0041
#
# Confusion Matrix:
# Float32[267.44 0.6 2.6 2.76; 3.36 175.84 7.44 4.56; 2.28 3.9599998 212.08 5.28; 2.84 4.68 4.4 99.88]
# ┌───────────┬────────┬───────────┬──────────┬───────┐
# │           │   Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼────────┼───────────┼──────────┼───────┤
# │      Good │ 267.44 │       0.6 │      2.6 │  2.76 │
# │ Hazardous │   3.36 │    175.84 │     7.44 │  4.56 │
# │  Moderate │   2.28 │      3.96 │   212.08 │  5.28 │
# │      Poor │   2.84 │      4.68 │      4.4 │ 99.88 │
# └───────────┴────────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 7
#  Hyperparameters: Dict("topology" => [8, 8])
# =====================================================
#  Accuracy (mean)               : 0.9433
#  Accuracy (std)                : 0.0042
#  Error Rate (mean)             : 0.0567
#  Error Rate (std)              : 0.0042
#  Sensitivity/Recall (mean)     : 0.9433
#  Sensitivity/Recall (std)      : 0.0042
#  Specificity (mean)            : 0.9837
#  Specificity (std)             : 0.0011
#  PPV (mean)                    : 0.9433
#  PPV (std)                     : 0.005
#  NPV (mean)                    : 0.9859
#  NPV (std)                     : 0.0008
#  F1 Score (mean)               : 0.9429
#  F1 Score (std)                : 0.0043
#
# Confusion Matrix:
# Float32[267.52 0.6 2.56 2.72; 3.44 175.8 7.3599997 4.6; 2.3200002 4.04 211.68001 5.56; 2.8400002 4.88 4.44 99.64]
# ┌───────────┬────────┬───────────┬──────────┬───────┐
# │           │   Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼────────┼───────────┼──────────┼───────┤
# │      Good │ 267.52 │       0.6 │     2.56 │  2.72 │
# │ Hazardous │   3.44 │     175.8 │     7.36 │   4.6 │
# │  Moderate │   2.32 │      4.04 │   211.68 │  5.56 │
# │      Poor │   2.84 │      4.88 │     4.44 │ 99.64 │
# └───────────┴────────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 8
#  Hyperparameters: Dict("topology" => [8, 8])
# =====================================================
#  Accuracy (mean)               : 0.944
#  Accuracy (std)                : 0.0039
#  Error Rate (mean)             : 0.056
#  Error Rate (std)              : 0.0039
#  Sensitivity/Recall (mean)     : 0.944
#  Sensitivity/Recall (std)      : 0.0039
#  Specificity (mean)            : 0.9839
#  Specificity (std)             : 0.001
#  PPV (mean)                    : 0.944
#  PPV (std)                     : 0.0048
#  NPV (mean)                    : 0.9861
#  NPV (std)                     : 0.0008
#  F1 Score (mean)               : 0.9437
#  F1 Score (std)                : 0.004
#
# Confusion Matrix:
# Float32[267.44 0.6 2.56 2.8; 3.4 175.96 7.3599997 4.48; 2.3600001 4.04 212.04001 5.16; 2.76 4.84 4.4 99.799995]
# ┌───────────┬────────┬───────────┬──────────┬──────┐
# │           │   Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼────────┼───────────┼──────────┼──────┤
# │      Good │ 267.44 │       0.6 │     2.56 │  2.8 │
# │ Hazardous │    3.4 │    175.96 │     7.36 │ 4.48 │
# │  Moderate │   2.36 │      4.04 │   212.04 │ 5.16 │
# │      Poor │   2.76 │      4.84 │      4.4 │ 99.8 │
# └───────────┴────────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 6
#  Hyperparameters: Dict("topology" => [16, 16])
# =====================================================
#  Accuracy (mean)               : 0.9439
#  Accuracy (std)                : 0.0044
#  Error Rate (mean)             : 0.0561
#  Error Rate (std)              : 0.0044
#  Sensitivity/Recall (mean)     : 0.9439
#  Sensitivity/Recall (std)      : 0.0044
#  Specificity (mean)            : 0.9839
#  Specificity (std)             : 0.0011
#  PPV (mean)                    : 0.9438
#  PPV (std)                     : 0.0051
#  NPV (mean)                    : 0.9861
#  NPV (std)                     : 0.0009
#  F1 Score (mean)               : 0.9435
#  F1 Score (std)                : 0.0045
#
# Confusion Matrix:
# Float32[267.4 0.6 2.6 2.8; 3.2399998 176.44 7.12 4.4; 2.32 4.2 211.72 5.3599997; 2.96 5.04 4.2400002 99.55999]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 267.4 │       0.6 │      2.6 │   2.8 │
# │ Hazardous │  3.24 │    176.44 │     7.12 │   4.4 │
# │  Moderate │  2.32 │       4.2 │   211.72 │  5.36 │
# │      Poor │  2.96 │      5.04 │     4.24 │ 99.56 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 7
#  Hyperparameters: Dict("topology" => [16, 16])
# =====================================================
#  Accuracy (mean)               : 0.944
#  Accuracy (std)                : 0.0046
#  Error Rate (mean)             : 0.056
#  Error Rate (std)              : 0.0046
#  Sensitivity/Recall (mean)     : 0.944
#  Sensitivity/Recall (std)      : 0.0046
#  Specificity (mean)            : 0.9839
#  Specificity (std)             : 0.0013
#  PPV (mean)                    : 0.944
#  PPV (std)                     : 0.0053
#  NPV (mean)                    : 0.9862
#  NPV (std)                     : 0.001
#  F1 Score (mean)               : 0.9437
#  F1 Score (std)                : 0.0046
#
# Confusion Matrix:
# Float32[267.56 0.6 2.6 2.6399999; 3.12 176.4 7.2799997 4.4; 2.3600001 4.16 211.64001 5.44; 2.92 5.0 4.2400002 99.64]
# ┌───────────┬────────┬───────────┬──────────┬───────┐
# │           │   Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼────────┼───────────┼──────────┼───────┤
# │      Good │ 267.56 │       0.6 │      2.6 │  2.64 │
# │ Hazardous │   3.12 │     176.4 │     7.28 │   4.4 │
# │  Moderate │   2.36 │      4.16 │   211.64 │  5.44 │
# │      Poor │   2.92 │       5.0 │     4.24 │ 99.64 │
# └───────────┴────────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 8
#  Hyperparameters: Dict("topology" => [16, 16])
# =====================================================
#  Accuracy (mean)               : 0.9434
#  Accuracy (std)                : 0.0044
#  Error Rate (mean)             : 0.0566
#  Error Rate (std)              : 0.0044
#  Sensitivity/Recall (mean)     : 0.9434
#  Sensitivity/Recall (std)      : 0.0044
#  Specificity (mean)            : 0.9836
#  Specificity (std)             : 0.0014
#  PPV (mean)                    : 0.9434
#  PPV (std)                     : 0.0052
#  NPV (mean)                    : 0.986
#  NPV (std)                     : 0.001
#  F1 Score (mean)               : 0.943
#  F1 Score (std)                : 0.0044
#
# Confusion Matrix:
# Float32[267.63998 0.6 2.48 2.68; 3.44 175.87999 7.4 4.48; 2.44 4.08 211.76001 5.32; 2.96 5.04 4.3599997 99.439995]
# ┌───────────┬────────┬───────────┬──────────┬───────┐
# │           │   Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼────────┼───────────┼──────────┼───────┤
# │      Good │ 267.64 │       0.6 │     2.48 │  2.68 │
# │ Hazardous │   3.44 │    175.88 │      7.4 │  4.48 │
# │  Moderate │   2.44 │      4.08 │   211.76 │  5.32 │
# │      Poor │   2.96 │      5.04 │     4.36 │ 99.44 │
# └───────────┴────────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 6
#  Hyperparameters: Dict("topology" => [10, 4])
# =====================================================
#  Accuracy (mean)               : 0.9397
#  Accuracy (std)                : 0.0057
#  Error Rate (mean)             : 0.0603
#  Error Rate (std)              : 0.0057
#  Sensitivity/Recall (mean)     : 0.9397
#  Sensitivity/Recall (std)      : 0.0057
#  Specificity (mean)            : 0.9827
#  Specificity (std)             : 0.0031
#  PPV (mean)                    : 0.9369
#  PPV (std)                     : 0.011
#  NPV (mean)                    : 0.9855
#  NPV (std)                     : 0.001
#  F1 Score (mean)               : 0.9378
#  F1 Score (std)                : 0.0087
#
# Confusion Matrix:
# Float32[267.4 0.6 2.6 2.8; 3.48 173.12 9.92 4.6800003; 2.28 4.0 211.04 6.28; 2.88 4.56 4.12 100.240005]
# ┌───────────┬───────┬───────────┬──────────┬────────┐
# │           │  Good │ Hazardous │ Moderate │   Poor │
# ├───────────┼───────┼───────────┼──────────┼────────┤
# │      Good │ 267.4 │       0.6 │      2.6 │    2.8 │
# │ Hazardous │  3.48 │    173.12 │     9.92 │   4.68 │
# │  Moderate │  2.28 │       4.0 │   211.04 │   6.28 │
# │      Poor │  2.88 │      4.56 │     4.12 │ 100.24 │
# └───────────┴───────┴───────────┴──────────┴────────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 7
#  Hyperparameters: Dict("topology" => [10, 4])
# =====================================================
#  Accuracy (mean)               : 0.9428
#  Accuracy (std)                : 0.0046
#  Error Rate (mean)             : 0.0572
#  Error Rate (std)              : 0.0046
#  Sensitivity/Recall (mean)     : 0.9428
#  Sensitivity/Recall (std)      : 0.0046
#  Specificity (mean)            : 0.9834
#  Specificity (std)             : 0.0011
#  PPV (mean)                    : 0.9428
#  PPV (std)                     : 0.0053
#  NPV (mean)                    : 0.9858
#  NPV (std)                     : 0.0008
#  F1 Score (mean)               : 0.9424
#  F1 Score (std)                : 0.0046
#
# Confusion Matrix:
# Float32[267.2 0.6 2.9199998 2.6799998; 3.48 175.56 7.44 4.7200003; 2.1200001 4.0 211.63998 5.84; 2.9599998 4.6800003 4.3199997 99.840004]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 267.2 │       0.6 │     2.92 │  2.68 │
# │ Hazardous │  3.48 │    175.56 │     7.44 │  4.72 │
# │  Moderate │  2.12 │       4.0 │   211.64 │  5.84 │
# │      Poor │  2.96 │      4.68 │     4.32 │ 99.84 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 8
#  Hyperparameters: Dict("topology" => [10, 4])
# =====================================================
#  Accuracy (mean)               : 0.9434
#  Accuracy (std)                : 0.0048
#  Error Rate (mean)             : 0.0566
#  Error Rate (std)              : 0.0048
#  Sensitivity/Recall (mean)     : 0.9434
#  Sensitivity/Recall (std)      : 0.0048
#  Specificity (mean)            : 0.9837
#  Specificity (std)             : 0.0015
#  PPV (mean)                    : 0.9435
#  PPV (std)                     : 0.0055
#  NPV (mean)                    : 0.9858
#  NPV (std)                     : 0.0009
#  F1 Score (mean)               : 0.943
#  F1 Score (std)                : 0.0048
#
# Confusion Matrix:
# Float32[267.44 0.6 2.56 2.8; 3.4 175.76001 7.3599997 4.68; 2.28 3.9599998 211.44002 5.92; 2.92 4.3599997 4.44 100.08]
# ┌───────────┬────────┬───────────┬──────────┬────────┐
# │           │   Good │ Hazardous │ Moderate │   Poor │
# ├───────────┼────────┼───────────┼──────────┼────────┤
# │      Good │ 267.44 │       0.6 │     2.56 │    2.8 │
# │ Hazardous │    3.4 │    175.76 │     7.36 │   4.68 │
# │  Moderate │   2.28 │      3.96 │   211.44 │   5.92 │
# │      Poor │   2.92 │      4.36 │     4.44 │ 100.08 │
# └───────────┴────────┴───────────┴──────────┴────────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 6
#  Hyperparameters: Dict("topology" => [10, 6, 4])
# =====================================================
#  Accuracy (mean)               : 0.9427
#  Accuracy (std)                : 0.0058
#  Error Rate (mean)             : 0.0573
#  Error Rate (std)              : 0.0058
#  Sensitivity/Recall (mean)     : 0.9427
#  Sensitivity/Recall (std)      : 0.0058
#  Specificity (mean)            : 0.9835
#  Specificity (std)             : 0.0018
#  PPV (mean)                    : 0.9426
#  PPV (std)                     : 0.0064
#  NPV (mean)                    : 0.986
#  NPV (std)                     : 0.0015
#  F1 Score (mean)               : 0.9423
#  F1 Score (std)                : 0.0058
#
# Confusion Matrix:
# Float32[267.32 0.6 2.88 2.6; 2.8799999 176.68 7.2400002 4.4; 2.6 4.2400002 211.0 5.7599998; 2.96 5.44 4.2400002 99.159996]
# ┌───────────┬────────┬───────────┬──────────┬───────┐
# │           │   Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼────────┼───────────┼──────────┼───────┤
# │      Good │ 267.32 │       0.6 │     2.88 │   2.6 │
# │ Hazardous │   2.88 │    176.68 │     7.24 │   4.4 │
# │  Moderate │    2.6 │      4.24 │    211.0 │  5.76 │
# │      Poor │   2.96 │      5.44 │     4.24 │ 99.16 │
# └───────────┴────────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 7
#  Hyperparameters: Dict("topology" => [10, 6, 4])
# =====================================================
#  Accuracy (mean)               : 0.9433
#  Accuracy (std)                : 0.0049
#  Error Rate (mean)             : 0.0567
#  Error Rate (std)              : 0.0049
#  Sensitivity/Recall (mean)     : 0.9433
#  Sensitivity/Recall (std)      : 0.0049
#  Specificity (mean)            : 0.9837
#  Specificity (std)             : 0.0014
#  PPV (mean)                    : 0.9432
#  PPV (std)                     : 0.0056
#  NPV (mean)                    : 0.9861
#  NPV (std)                     : 0.001
#  F1 Score (mean)               : 0.9429
#  F1 Score (std)                : 0.005
#
# Confusion Matrix:
# Float32[267.52 0.56 2.6799998 2.6399999; 3.2 176.28 7.16 4.56; 2.44 4.2 211.36002 5.6; 3.0 5.08 4.2400002 99.479996]
# ┌───────────┬────────┬───────────┬──────────┬───────┐
# │           │   Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼────────┼───────────┼──────────┼───────┤
# │      Good │ 267.52 │      0.56 │     2.68 │  2.64 │
# │ Hazardous │    3.2 │    176.28 │     7.16 │  4.56 │
# │  Moderate │   2.44 │       4.2 │   211.36 │   5.6 │
# │      Poor │    3.0 │      5.08 │     4.24 │ 99.48 │
# └───────────┴────────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 8
#  Hyperparameters: Dict("topology" => [10, 6, 4])
# =====================================================
#  Accuracy (mean)               : 0.9427
#  Accuracy (std)                : 0.0047
#  Error Rate (mean)             : 0.0573
#  Error Rate (std)              : 0.0047
#  Sensitivity/Recall (mean)     : 0.9427
#  Sensitivity/Recall (std)      : 0.0047
#  Specificity (mean)            : 0.9835
#  Specificity (std)             : 0.0013
#  PPV (mean)                    : 0.9426
#  PPV (std)                     : 0.0053
#  NPV (mean)                    : 0.9858
#  NPV (std)                     : 0.0012
#  F1 Score (mean)               : 0.9423
#  F1 Score (std)                : 0.0047
#
# Confusion Matrix:
# Float32[267.24 0.52 2.84 2.8; 3.1599998 176.23999 7.2400002 4.56; 2.6 4.2 211.27998 5.52; 3.0 5.2799997 4.12 99.4]
# ┌───────────┬────────┬───────────┬──────────┬──────┐
# │           │   Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼────────┼───────────┼──────────┼──────┤
# │      Good │ 267.24 │      0.52 │     2.84 │  2.8 │
# │ Hazardous │   3.16 │    176.24 │     7.24 │ 4.56 │
# │  Moderate │    2.6 │       4.2 │   211.28 │ 5.52 │
# │      Poor │    3.0 │      5.28 │     4.12 │ 99.4 │
# └───────────┴────────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 6
#  Hyperparameters: Dict("topology" => [10, 8, 4])
# =====================================================
#  Accuracy (mean)               : 0.9424
#  Accuracy (std)                : 0.0061
#  Error Rate (mean)             : 0.0576
#  Error Rate (std)              : 0.0061
#  Sensitivity/Recall (mean)     : 0.9424
#  Sensitivity/Recall (std)      : 0.0061
#  Specificity (mean)            : 0.9835
#  Specificity (std)             : 0.0016
#  PPV (mean)                    : 0.9423
#  PPV (std)                     : 0.0066
#  NPV (mean)                    : 0.9857
#  NPV (std)                     : 0.0014
#  F1 Score (mean)               : 0.942
#  F1 Score (std)                : 0.0061
#
# Confusion Matrix:
# Float32[267.32 0.6 2.8 2.6799998; 3.16 176.4 7.0 4.6400003; 2.8 4.32 210.84 5.6400003; 2.92 5.28 4.2400002 99.36]
# ┌───────────┬────────┬───────────┬──────────┬───────┐
# │           │   Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼────────┼───────────┼──────────┼───────┤
# │      Good │ 267.32 │       0.6 │      2.8 │  2.68 │
# │ Hazardous │   3.16 │     176.4 │      7.0 │  4.64 │
# │  Moderate │    2.8 │      4.32 │   210.84 │  5.64 │
# │      Poor │   2.92 │      5.28 │     4.24 │ 99.36 │
# └───────────┴────────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 7
#  Hyperparameters: Dict("topology" => [10, 8, 4])
# =====================================================
#  Accuracy (mean)               : 0.9432
#  Accuracy (std)                : 0.0052
#  Error Rate (mean)             : 0.0568
#  Error Rate (std)              : 0.0052
#  Sensitivity/Recall (mean)     : 0.9432
#  Sensitivity/Recall (std)      : 0.0052
#  Specificity (mean)            : 0.9837
#  Specificity (std)             : 0.0015
#  PPV (mean)                    : 0.9432
#  PPV (std)                     : 0.0058
#  NPV (mean)                    : 0.986
#  NPV (std)                     : 0.0013
#  F1 Score (mean)               : 0.9428
#  F1 Score (std)                : 0.0053
#
# Confusion Matrix:
# Float32[267.8 0.52 2.56 2.52; 3.2400002 176.07999 7.2799997 4.6; 2.6799998 4.4 210.95999 5.56; 2.9199998 5.04 4.12 99.72]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 267.8 │      0.52 │     2.56 │  2.52 │
# │ Hazardous │  3.24 │    176.08 │     7.28 │   4.6 │
# │  Moderate │  2.68 │       4.4 │   210.96 │  5.56 │
# │      Poor │  2.92 │      5.04 │     4.12 │ 99.72 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 8
#  Hyperparameters: Dict("topology" => [10, 8, 4])
# =====================================================
#  Accuracy (mean)               : 0.9426
#  Accuracy (std)                : 0.0048
#  Error Rate (mean)             : 0.0574
#  Error Rate (std)              : 0.0048
#  Sensitivity/Recall (mean)     : 0.9426
#  Sensitivity/Recall (std)      : 0.0048
#  Specificity (mean)            : 0.9835
#  Specificity (std)             : 0.0017
#  PPV (mean)                    : 0.9426
#  PPV (std)                     : 0.0055
#  NPV (mean)                    : 0.9859
#  NPV (std)                     : 0.001
#  F1 Score (mean)               : 0.9422
#  F1 Score (std)                : 0.0048
#
# Confusion Matrix:
# Float32[267.36002 0.56 2.72 2.76; 3.2 175.84 7.6399994 4.52; 2.3200002 4.08 211.31999 5.88; 2.96 5.16 4.12 99.560005]
# ┌───────────┬────────┬───────────┬──────────┬───────┐
# │           │   Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼────────┼───────────┼──────────┼───────┤
# │      Good │ 267.36 │      0.56 │     2.72 │  2.76 │
# │ Hazardous │    3.2 │    175.84 │     7.64 │  4.52 │
# │  Moderate │   2.32 │      4.08 │   211.32 │  5.88 │
# │      Poor │   2.96 │      5.16 │     4.12 │ 99.56 │
# └───────────┴────────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 6
#  Hyperparameters: Dict("topology" => [10, 8, 6, 4])
# =====================================================
#  Accuracy (mean)               : 0.9453
#  Accuracy (std)                : 0.0058
#  Error Rate (mean)             : 0.0547
#  Error Rate (std)              : 0.0058
#  Sensitivity/Recall (mean)     : 0.9453
#  Sensitivity/Recall (std)      : 0.0058
#  Specificity (mean)            : 0.9842
#  Specificity (std)             : 0.0014
#  PPV (mean)                    : 0.9452
#  PPV (std)                     : 0.0064
#  NPV (mean)                    : 0.9867
#  NPV (std)                     : 0.0014
#  F1 Score (mean)               : 0.9449
#  F1 Score (std)                : 0.0058
#
# Confusion Matrix:
# Float32[267.8 0.44 2.76 2.4; 3.16 176.88 6.6800003 4.48; 2.24 4.32 211.8 5.2400002; 3.0 4.96 4.0800004 99.759995]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 267.8 │      0.44 │     2.76 │   2.4 │
# │ Hazardous │  3.16 │    176.88 │     6.68 │  4.48 │
# │  Moderate │  2.24 │      4.32 │    211.8 │  5.24 │
# │      Poor │   3.0 │      4.96 │     4.08 │ 99.76 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 7
#  Hyperparameters: Dict("topology" => [10, 8, 6, 4])
# =====================================================
#  Accuracy (mean)               : 0.9463
#  Accuracy (std)                : 0.0075
#  Error Rate (mean)             : 0.0537
#  Error Rate (std)              : 0.0075
#  Sensitivity/Recall (mean)     : 0.9463
#  Sensitivity/Recall (std)      : 0.0075
#  Specificity (mean)            : 0.9846
#  Specificity (std)             : 0.0018
#  PPV (mean)                    : 0.9462
#  PPV (std)                     : 0.0078
#  NPV (mean)                    : 0.9871
#  NPV (std)                     : 0.0016
#  F1 Score (mean)               : 0.9459
#  F1 Score (std)                : 0.0076
#
# Confusion Matrix:
# Float32[267.8 0.4 2.9199998 2.2800002; 2.96 177.51999 6.56 4.16; 2.28 3.9599998 212.23999 5.12; 2.9599998 5.32 4.0 99.520004]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 267.8 │       0.4 │     2.92 │  2.28 │
# │ Hazardous │  2.96 │    177.52 │     6.56 │  4.16 │
# │  Moderate │  2.28 │      3.96 │   212.24 │  5.12 │
# │      Poor │  2.96 │      5.32 │      4.0 │ 99.52 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 8
#  Hyperparameters: Dict("topology" => [10, 8, 6, 4])
# =====================================================
#  Accuracy (mean)               : 0.9456
#  Accuracy (std)                : 0.007
#  Error Rate (mean)             : 0.0544
#  Error Rate (std)              : 0.007
#  Sensitivity/Recall (mean)     : 0.9456
#  Sensitivity/Recall (std)      : 0.007
#  Specificity (mean)            : 0.9845
#  Specificity (std)             : 0.0016
#  PPV (mean)                    : 0.9456
#  PPV (std)                     : 0.0075
#  NPV (mean)                    : 0.9868
#  NPV (std)                     : 0.0018
#  F1 Score (mean)               : 0.9453
#  F1 Score (std)                : 0.007
#
# Confusion Matrix:
# Float32[267.88 0.4 2.6799998 2.44; 2.88 177.4 6.4800005 4.44; 2.48 4.2799997 211.43999 5.4; 2.96 5.08 3.9599998 99.8]
# ┌───────────┬────────┬───────────┬──────────┬──────┐
# │           │   Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼────────┼───────────┼──────────┼──────┤
# │      Good │ 267.88 │       0.4 │     2.68 │ 2.44 │
# │ Hazardous │   2.88 │     177.4 │     6.48 │ 4.44 │
# │  Moderate │   2.48 │      4.28 │   211.44 │  5.4 │
# │      Poor │   2.96 │      5.08 │     3.96 │ 99.8 │
# └───────────┴────────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 6
#  Hyperparameters: Dict("topology" => [10, 12, 6, 4])
# =====================================================
#  Accuracy (mean)               : 0.9459
#  Accuracy (std)                : 0.0067
#  Error Rate (mean)             : 0.0541
#  Error Rate (std)              : 0.0067
#  Sensitivity/Recall (mean)     : 0.9459
#  Sensitivity/Recall (std)      : 0.0067
#  Specificity (mean)            : 0.9846
#  Specificity (std)             : 0.0017
#  PPV (mean)                    : 0.9458
#  PPV (std)                     : 0.0071
#  NPV (mean)                    : 0.9867
#  NPV (std)                     : 0.0017
#  F1 Score (mean)               : 0.9455
#  F1 Score (std)                : 0.0067
#
# Confusion Matrix:
# Float32[267.52 0.32 2.92 2.64; 2.72 177.76 6.56 4.16; 2.32 4.2 211.68001 5.4; 2.72 5.0800004 4.2400002 99.76]
# ┌───────────┬────────┬───────────┬──────────┬───────┐
# │           │   Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼────────┼───────────┼──────────┼───────┤
# │      Good │ 267.52 │      0.32 │     2.92 │  2.64 │
# │ Hazardous │   2.72 │    177.76 │     6.56 │  4.16 │
# │  Moderate │   2.32 │       4.2 │   211.68 │   5.4 │
# │      Poor │   2.72 │      5.08 │     4.24 │ 99.76 │
# └───────────┴────────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 7
#  Hyperparameters: Dict("topology" => [10, 12, 6, 4])
# =====================================================
#  Accuracy (mean)               : 0.9428
#  Accuracy (std)                : 0.0105
#  Error Rate (mean)             : 0.0572
#  Error Rate (std)              : 0.0105
#  Sensitivity/Recall (mean)     : 0.9428
#  Sensitivity/Recall (std)      : 0.0105
#  Specificity (mean)            : 0.9837
#  Specificity (std)             : 0.0031
#  PPV (mean)                    : 0.9402
#  PPV (std)                     : 0.0164
#  NPV (mean)                    : 0.9866
#  NPV (std)                     : 0.0018
#  F1 Score (mean)               : 0.9409
#  F1 Score (std)                : 0.0137
#
# Confusion Matrix:
# Float32[267.72 0.48000002 2.76 2.44; 2.9199998 177.36002 6.6799994 4.2400002; 2.2 4.2400002 212.0 5.16; 3.0 7.5199995 4.12 97.159996]
# ┌───────────┬────────┬───────────┬──────────┬───────┐
# │           │   Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼────────┼───────────┼──────────┼───────┤
# │      Good │ 267.72 │      0.48 │     2.76 │  2.44 │
# │ Hazardous │   2.92 │    177.36 │     6.68 │  4.24 │
# │  Moderate │    2.2 │      4.24 │    212.0 │  5.16 │
# │      Poor │    3.0 │      7.52 │     4.12 │ 97.16 │
# └───────────┴────────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: ANN | PCA outdim: 8
#  Hyperparameters: Dict("topology" => [10, 12, 6, 4])
# =====================================================
#  Accuracy (mean)               : 0.9466
#  Accuracy (std)                : 0.0047
#  Error Rate (mean)             : 0.0534
#  Error Rate (std)              : 0.0047
#  Sensitivity/Recall (mean)     : 0.9466
#  Sensitivity/Recall (std)      : 0.0047
#  Specificity (mean)            : 0.9847
#  Specificity (std)             : 0.0018
#  PPV (mean)                    : 0.9466
#  PPV (std)                     : 0.0053
#  NPV (mean)                    : 0.9869
#  NPV (std)                     : 0.0012
#  F1 Score (mean)               : 0.9462
#  F1 Score (std)                : 0.0047
#
# Confusion Matrix:
# Float32[267.76 0.56 2.7199998 2.3600001; 2.76 177.4 6.6 4.44; 2.32 3.8799999 212.2 5.2; 2.92 4.7599998 4.2 99.92]
# ┌───────────┬────────┬───────────┬──────────┬───────┐
# │           │   Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼────────┼───────────┼──────────┼───────┤
# │      Good │ 267.76 │      0.56 │     2.72 │  2.36 │
# │ Hazardous │   2.76 │     177.4 │      6.6 │  4.44 │
# │  Moderate │   2.32 │      3.88 │    212.2 │   5.2 │
# │      Poor │   2.92 │      4.76 │      4.2 │ 99.92 │
# └───────────┴────────┴───────────┴──────────┴───────┘
# =====================================================

# %%
########################
# 1. ANN FINAL TESTING
########################

# BEST HYPERPARAMETERS
topology = [10, 12, 6, 4]

hp = Dict(      
    "numExecutions" => 5,
    "maxEpochs" => 200,
    "minLoss" => 0.0,
    "learningRate" => 0.01,
    "validationRatio" => 0.1,
    "maxEpochsVal" => 20
)

learningRate = hp["learningRate"]
epochs = hp["maxEpochs"]
validationRatio = hp["validationRatio"]

dimPCA = 8

# ============================
# NORMALIZATION
# ============================
normParams = calculateMinMaxNormalizationParameters(trainingInputs)
norm_train_inputs = normalizeMinMax(trainingInputs, normParams)
norm_test_inputs  = normalizeMinMax(testInputs,  normParams)

# ============================
# PCA
# ============================
pca_model = PCA_model(maxoutdim=dimPCA)
pca_mach = machine(pca_model, MLJ.table(norm_train_inputs))
MLJ.fit!(pca_mach, verbosity=0)

trainValInputs = MLJBase.matrix(MLJBase.transform(pca_mach, MLJ.table(norm_train_inputs)))
testInputsPCA  = MLJBase.matrix(MLJBase.transform(pca_mach, MLJ.table(norm_test_inputs)))

# ============================
# CREATE VALIDATION SPLIT
# ============================
N = size(inputs, 1)
nTrainVal = size(trainValInputs, 1)

nVal = Int(floor(validationRatio * N))
realValidationRatio = nVal / nTrainVal

(train_idx, val_idx) = holdOut(nTrainVal, realValidationRatio)

trainInputsPCA = trainValInputs[train_idx, :]
valInputsPCA   = trainValInputs[val_idx, :]

# ============================
# ONE–HOT ENCODING FOR TARGETS
# ============================
trainTargetsVec = trainingTargets[train_idx]
valTargetsVec   = trainingTargets[val_idx]
testTargetsVec  = testTargets

trainTargetsOH = Matrix(oneHotEncoding(vec(trainTargetsVec), sort(levels(categorical(trainingTargets)))))
valTargetsOH   = Matrix(oneHotEncoding(vec(valTargetsVec),   sort(levels(categorical(trainingTargets)))))
testTargetsOH  = Matrix(oneHotEncoding(vec(testTargetsVec),  sort(levels(categorical(trainingTargets)))))

# ============================
# TRAIN ANN
# ============================
finalAnn, trainLoss, valLoss, testLoss = trainClassANN(
    topology,
    (trainInputsPCA, trainTargetsOH),
    validationDataset = (valInputsPCA, valTargetsOH),
    testDataset = (testInputsPCA, testTargetsOH),
    maxEpochs = hp["maxEpochs"],
    minLoss = hp["minLoss"],
    learningRate = hp["learningRate"],
    maxEpochsVal = hp["maxEpochsVal"],
    showText = false
)

# ============================
# PREDICTION
# ============================
testOutputs = finalAnn(testInputsPCA')
testPredictions = classifyOutputs(testOutputs')   # boolean matrix (N × classes)

# ============================
# METRICS
# ============================
metrics = confusionMatrix(testPredictions, testTargetsOH)

printPCAANNResult(
    :ANN,
    Dict("topology" => topology),
    metrics,
    dimPCA,
    label_names
)
# Out:
# =====================================================
#  Model: ANN   | PCA outdim = 8
#  Hyperparameters: Dict("topology" => [10, 12, 6, 4])
# =====================================================
#  Accuracy                : 0.803
#  Error Rate              : 0.197
#  Sensitivity/Recall      : 0.803
#  Specificity             : 0.9308
#  PPV                     : 0.7262
#  NPV                     : 0.9625
#  F1 Score                : 0.7597
#
# Confusion Matrix:
# [383 0 0 0; 0 0 4 99; 2 0 294 0; 0 0 92 126]
# =====================================================
#
# ┌───────────┬──────┬───────────┬──────────┬──────┐
# │           │ Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼──────┼───────────┼──────────┼──────┤
# │      Good │  383 │         0 │        0 │    0 │
# │ Hazardous │    0 │         0 │        4 │   99 │
# │  Moderate │    2 │         0 │      294 │    0 │
# │      Poor │    0 │         0 │       92 │  126 │
# └───────────┴──────┴───────────┴──────────┴──────┘

# %% [markdown]
# # Support Vector Machines

# %%
SVMClassifier = MLJ.@load SVC pkg=LIBSVM verbosity=0
# Out:
# MLJLIBSVMInterface.SVC

# %%
############# 2. SVM (8+ configs: kernels × C) #############
default_svm = Dict(
    "gamma" => 1.0,
    "degree" => 3,
    "coef0" => 0.0
)

svm_search_space = [
    Dict("kernel"=>"linear",  "C"=>0.1),
    Dict("kernel"=>"linear",  "C"=>1.0),
    Dict("kernel"=>"linear",  "C"=>10.0),
    Dict("kernel"=>"rbf",     "C"=>1.0, "gamma"=>2.0),
    Dict("kernel"=>"rbf",     "C"=>10.0,"gamma"=>0.5),
    Dict("kernel"=>"sigmoid", "C"=>1.0, "gamma"=>1.0),
    Dict("kernel"=>"poly",    "C"=>1.0, "degree"=>3, "gamma"=>1.0),
    Dict("kernel"=>"poly",    "C"=>5.0, "degree"=>4, "gamma"=>0.5),
]
# Out:
# 8-element Vector{Dict{String, Any}}:
#  Dict("C" => 0.1, "kernel" => "linear")
#  Dict("C" => 1.0, "kernel" => "linear")
#  Dict("C" => 10.0, "kernel" => "linear")
#  Dict("C" => 1.0, "kernel" => "rbf", "gamma" => 2.0)
#  Dict("C" => 10.0, "kernel" => "rbf", "gamma" => 0.5)
#  Dict("C" => 1.0, "kernel" => "sigmoid", "gamma" => 1.0)
#  Dict("C" => 1.0, "kernel" => "poly", "gamma" => 1.0, "degree" => 3)
#  Dict("C" => 5.0, "kernel" => "poly", "gamma" => 0.5, "degree" => 4)

# %%
########################
# 2. SVM GRID SEARCH
########################
svm_results = []

for hp in svm_search_space
    for dim in dimsPCA
        println("\n=== SVM experiment: kernel=$(hp["kernel"]) C=$(get(hp,"C","-")) | PCA maxoutdim = $(dim) ===")
        full_hp = merge(default_svm, hp)
        res = modelCrossValidationPCA(:SVC, full_hp, (trainingInputs, trainingTargets), crossValidationIndices, dim)
        push!(svm_results, (model=:SVC, hyperparams=hp, dimPCA=dim, results=res))
    end
end

results[:SVC] = svm_results
# Out:
# === SVM experiment: kernel=linear C=0.1 | PCA maxoutdim = 6 ===
#
# === SVM experiment: kernel=linear C=0.1 | PCA maxoutdim = 7 ===
#
# === SVM experiment: kernel=linear C=0.1 | PCA maxoutdim = 8 ===
#
# === SVM experiment: kernel=linear C=1.0 | PCA maxoutdim = 6 ===
#
# === SVM experiment: kernel=linear C=1.0 | PCA maxoutdim = 7 ===
#
# === SVM experiment: kernel=linear C=1.0 | PCA maxoutdim = 8 ===
#
# === SVM experiment: kernel=linear C=10.0 | PCA maxoutdim = 6 ===
#
# === SVM experiment: kernel=linear C=10.0 | PCA maxoutdim = 7 ===
#
# === SVM experiment: kernel=linear C=10.0 | PCA maxoutdim = 8 ===
#
# === SVM experiment: kernel=rbf C=1.0 | PCA maxoutdim = 6 ===
#
# === SVM experiment: kernel=rbf C=1.0 | PCA maxoutdim = 7 ===
#
# === SVM experiment: kernel=rbf C=1.0 | PCA maxoutdim = 8 ===
#
# === SVM experiment: kernel=rbf C=10.0 | PCA maxoutdim = 6 ===
#
# === SVM experiment: kernel=rbf C=10.0 | PCA maxoutdim = 7 ===
#
# === SVM experiment: kernel=rbf C=10.0 | PCA maxoutdim = 8 ===
#
# === SVM experiment: kernel=sigmoid C=1.0 | PCA maxoutdim = 6 ===
#
# === SVM experiment: kernel=sigmoid C=1.0 | PCA maxoutdim = 7 ===
#
# === SVM experiment: kernel=sigmoid C=1.0 | PCA maxoutdim = 8 ===
#
# === SVM experiment: kernel=poly C=1.0 | PCA maxoutdim = 6 ===
#
# === SVM experiment: kernel=poly C=1.0 | PCA maxoutdim = 7 ===
#
# === SVM experiment: kernel=poly C=1.0 | PCA maxoutdim = 8 ===
#
# === SVM experiment: kernel=poly C=5.0 | PCA maxoutdim = 6 ===
#
# === SVM experiment: kernel=poly C=5.0 | PCA maxoutdim = 7 ===
#
# === SVM experiment: kernel=poly C=5.0 | PCA maxoutdim = 8 ===
# 24-element Vector{Any}:
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 0.1, "kernel" => "linear"), dimPCA = 6, results = ((0.92324656f0, 0.0020554946f0), (0.07675346f0, 0.0020554904f0), (0.92324656f0, 0.0020554946f0), (0.97217834f0, 0.001171714f0), (0.9237992f0, 0.002822116f0), (0.9826236f0, 0.0012845783f0), (0.92127085f0, 0.0025471877f0), Float32[267.6 0.0 5.2 0.6; 6.0 173.2 10.4 1.6; 3.0 6.6 208.2 5.8; 5.8 9.8 6.6 89.6]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 0.1, "kernel" => "linear"), dimPCA = 7, results = ((0.92374563f0, 0.0026537161f0), (0.0762544f0, 0.0026537185f0), (0.92374563f0, 0.0026537161f0), (0.972314f0, 0.0017245684f0), (0.92419225f0, 0.0026806244f0), (0.9825177f0, 0.0015376173f0), (0.9219354f0, 0.0028004707f0), Float32[267.4 0.0 5.4 0.6; 6.0 174.0 9.6 1.6; 2.8 6.6 207.8 6.4; 6.0 9.2 6.8 89.8]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 0.1, "kernel" => "linear"), dimPCA = 8, results = ((0.9304966f0, 0.005035769f0), (0.06950344f0, 0.005035765f0), (0.9304966f0, 0.005035769f0), (0.9750918f0, 0.00083392154f0), (0.9309021f0, 0.005551302f0), (0.9843459f0, 0.0011032501f0), (0.9289301f0, 0.0056161913f0), Float32[268.0 0.2 4.8 0.4; 5.4 175.8 8.6 1.4; 2.4 6.4 209.0 5.8; 5.0 8.8 6.4 91.6]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 1.0, "kernel" => "linear"), dimPCA = 6, results = ((0.93849754f0, 0.0049978425f0), (0.061502464f0, 0.004997858f0), (0.93849754f0, 0.0049978425f0), (0.9793928f0, 0.0011244746f0), (0.93783855f0, 0.00570292f0), (0.9853784f0, 0.0015006412f0), (0.93756664f0, 0.0051846732f0), Float32[268.6 0.0 3.6 1.2; 4.4 175.4 8.0 3.4; 2.6 6.0 209.2 5.8; 3.4 5.8 5.0 97.6]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 1.0, "kernel" => "linear"), dimPCA = 7, results = ((0.93949854f0, 0.0042330525f0), (0.060501516f0, 0.004233061f0), (0.93949854f0, 0.0042330525f0), (0.9797754f0, 0.00096131186f0), (0.93891275f0, 0.004644075f0), (0.98518276f0, 0.0007585129f0), (0.93872964f0, 0.004489246f0), Float32[268.4 0.2 3.6 1.2; 4.4 176.2 7.2 3.4; 2.0 5.8 210.2 5.6; 3.8 6.0 5.2 96.8]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 1.0, "kernel" => "linear"), dimPCA = 8, results = ((0.93974876f0, 0.004301031f0), (0.060251206f0, 0.004301039f0), (0.93974876f0, 0.004301031f0), (0.9806975f0, 0.00081677263f0), (0.9391247f0, 0.0047371173f0), (0.9855671f0, 0.0009888937f0), (0.9389989f0, 0.0044740476f0), Float32[267.8 0.4 3.6 1.6; 4.4 176.6 6.8 3.4; 2.6 5.6 210.0 5.4; 3.6 5.6 5.2 97.4]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 10.0, "kernel" => "linear"), dimPCA = 6, results = ((0.9377478f0, 0.0057938383f0), (0.062252156f0, 0.0057938383f0), (0.9377478f0, 0.0057938383f0), (0.9800309f0, 0.000959878f0), (0.93719846f0, 0.0062891776f0), (0.9845089f0, 0.0013644216f0), (0.9370449f0, 0.0059400965f0), Float32[267.0 0.4 3.8 2.2; 4.2 175.4 7.8 3.8; 2.8 5.4 209.8 5.6; 3.0 5.4 5.4 98.0]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 10.0, "kernel" => "linear"), dimPCA = 7, results = ((0.93899536f0, 0.0051840297f0), (0.061004646f0, 0.0051840423f0), (0.93899536f0, 0.0051840297f0), (0.98069304f0, 0.00092245726f0), (0.9384905f0, 0.005428934f0), (0.9848892f0, 0.001478883f0), (0.93834335f0, 0.005228417f0), Float32[267.8 0.2 3.4 2.0; 4.6 175.8 7.2 3.6; 2.6 5.8 209.6 5.6; 3.2 5.4 5.2 98.0]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 10.0, "kernel" => "linear"), dimPCA = 8, results = ((0.93950003f0, 0.007107928f0), (0.06049996f0, 0.0071079354f0), (0.93950003f0, 0.007107928f0), (0.981651f0, 0.0013353983f0), (0.93896437f0, 0.0077079744f0), (0.9848589f0, 0.0014592184f0), (0.93894464f0, 0.0072743716f0), Float32[266.4 0.8 3.6 2.6; 4.0 176.4 6.6 4.2; 3.0 5.4 209.8 5.4; 3.0 4.6 5.2 99.0]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 1.0, "kernel" => "rbf", "gamma" => 2.0), dimPCA = 6, results = ((0.9364969f0, 0.005080002f0), (0.063503094f0, 0.005079991f0), (0.9364969f0, 0.005080002f0), (0.97999877f0, 0.0011945332f0), (0.9358355f0, 0.005512678f0), (0.98454535f0, 0.0016590175f0), (0.9357279f0, 0.005104914f0), Float32[267.2 0.2 3.8 2.2; 4.2 175.4 7.8 3.8; 2.4 5.8 209.4 6.0; 3.2 5.8 5.6 97.2]))
#  ⋮
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 1.0, "kernel" => "sigmoid", "gamma" => 1.0), dimPCA = 6, results = ((0.93974507f0, 0.006644192f0), (0.060254954f0, 0.0066441977f0), (0.93974507f0, 0.006644192f0), (0.97968215f0, 0.0013524357f0), (0.93909895f0, 0.007274738f0), (0.98538077f0, 0.0017260943f0), (0.93889654f0, 0.006785872f0), Float32[268.6 0.0 3.6 1.2; 4.4 175.8 7.6 3.4; 2.6 6.0 208.8 6.2; 3.2 5.2 4.8 98.6]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 1.0, "kernel" => "sigmoid", "gamma" => 1.0), dimPCA = 7, results = ((0.94074535f0, 0.004804917f0), (0.059254635f0, 0.0048049176f0), (0.94074535f0, 0.004804917f0), (0.98014545f0, 0.0009524673f0), (0.94015455f0, 0.0049974467f0), (0.9852697f0, 0.0010365265f0), (0.94001424f0, 0.0049119457f0), Float32[268.4 0.2 3.6 1.2; 4.4 176.4 6.8 3.6; 2.0 6.0 210.0 5.6; 3.6 5.2 5.2 97.8]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 1.0, "kernel" => "sigmoid", "gamma" => 1.0), dimPCA = 8, results = ((0.9394991f0, 0.0056498153f0), (0.060500897f0, 0.0056498186f0), (0.9394991f0, 0.0056498153f0), (0.9809124f0, 0.0006961732f0), (0.93873656f0, 0.006174267f0), (0.98546827f0, 0.0010839243f0), (0.93874997f0, 0.005845831f0), Float32[267.6 0.4 3.6 1.8; 4.2 176.8 6.4 3.8; 2.6 5.6 209.6 5.8; 3.6 5.4 5.2 97.6]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 1.0, "kernel" => "poly", "gamma" => 1.0, "degree" => 3), dimPCA = 6, results = ((0.7622527f0, 0.013131017f0), (0.23774727f0, 0.0131310215f0), (0.7622527f0, 0.013131017f0), (0.903746f0, 0.0071157403f0), (0.82575023f0, 0.00399283f0), (0.9155386f0, 0.007047242f0), (0.7598612f0, 0.012317559f0), Float32[210.8 11.8 33.4 17.4; 17.6 131.2 40.6 1.8; 15.2 16.2 172.6 19.6; 3.6 7.4 5.6 95.2]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 1.0, "kernel" => "poly", "gamma" => 1.0, "degree" => 3), dimPCA = 7, results = ((0.7642528f0, 0.013571526f0), (0.23574726f0, 0.013571532f0), (0.7642528f0, 0.013571526f0), (0.9047061f0, 0.0070582735f0), (0.8260826f0, 0.006417134f0), (0.91609067f0, 0.0069970037f0), (0.76199186f0, 0.013263597f0), Float32[211.4 11.8 33.0 17.2; 16.8 132.8 39.4 2.2; 15.2 16.2 172.6 19.6; 3.8 7.8 5.6 94.6]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 1.0, "kernel" => "poly", "gamma" => 1.0, "degree" => 3), dimPCA = 8, results = ((0.7675046f0, 0.012111973f0), (0.23249538f0, 0.012111981f0), (0.7675046f0, 0.012111973f0), (0.9059391f0, 0.0066183233f0), (0.82927257f0, 0.0050120363f0), (0.91675967f0, 0.006779293f0), (0.765386f0, 0.011557806f0), Float32[211.8 11.8 32.8 17.0; 16.8 133.6 38.4 2.4; 15.0 16.0 173.0 19.6; 3.4 7.6 5.2 95.6]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 5.0, "kernel" => "poly", "gamma" => 0.5, "degree" => 4), dimPCA = 6, results = ((0.45874947f0, 0.0014801065f0), (0.5412505f0, 0.0014801099f0), (0.45874947f0, 0.0014801065f0), (0.6334401f0, 0.0014548762f0), (0.3092426f0, 0.08678108f0), (0.8665031f0, 0.00025655422f0), (0.31273013f0, 0.002376263f0), Float32[193.8 31.4 48.2 0.0; 85.6 74.2 30.6 0.8; 110.4 48.2 64.8 0.2; 62.8 7.4 7.4 34.2]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 5.0, "kernel" => "poly", "gamma" => 0.5, "degree" => 4), dimPCA = 7, results = ((0.46049762f0, 0.0019002593f0), (0.5395024f0, 0.0019002656f0), (0.46049762f0, 0.0019002593f0), (0.6344837f0, 0.001993281f0), (0.3100335f0, 0.086867705f0), (0.86667997f0, 0.00039693335f0), (0.31456167f0, 0.0030334673f0), Float32[193.8 31.4 48.2 0.0; 86.0 74.0 30.6 0.6; 110.4 48.2 64.8 0.2; 62.2 7.0 6.8 35.8]))
#  (model = :SVC, hyperparams = Dict{String, Any}("C" => 5.0, "kernel" => "poly", "gamma" => 0.5, "degree" => 4), dimPCA = 8, results = ((0.45925012f0, 0.0037788139f0), (0.54074985f0, 0.003778831f0), (0.45925012f0, 0.0037788139f0), (0.63363826f0, 0.003113197f0), (0.3098261f0, 0.086978555f0), (0.8665554f0, 0.0005191928f0), (0.3132682f0, 0.004539172f0), Float32[193.8 31.4 48.2 0.0; 86.6 73.4 30.6 0.6; 110.4 48.2 64.8 0.2; 61.8 7.8 6.8 35.4]))

# %%
for entry in results[:SVC]
    printExperimentResult(entry.model, entry.hyperparams, entry.dimPCA, entry.results, label_names)
end
# Out:
# =====================================================
#  Model: SVC | PCA outdim: 6
#  Hyperparameters: Dict{String, Any}("C" => 0.1, "kernel" => "linear")
# =====================================================
#  Accuracy (mean)               : 0.9232
#  Accuracy (std)                : 0.0021
#  Error Rate (mean)             : 0.0768
#  Error Rate (std)              : 0.0021
#  Sensitivity/Recall (mean)     : 0.9232
#  Sensitivity/Recall (std)      : 0.0021
#  Specificity (mean)            : 0.9722
#  Specificity (std)             : 0.0012
#  PPV (mean)                    : 0.9238
#  PPV (std)                     : 0.0028
#  NPV (mean)                    : 0.9826
#  NPV (std)                     : 0.0013
#  F1 Score (mean)               : 0.9213
#  F1 Score (std)                : 0.0025
#
# Confusion Matrix:
# Float32[267.6 0.0 5.2 0.6; 6.0 173.2 10.4 1.6; 3.0 6.6 208.2 5.8; 5.8 9.8 6.6 89.6]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 267.6 │       0.0 │      5.2 │  0.6 │
# │ Hazardous │   6.0 │     173.2 │     10.4 │  1.6 │
# │  Moderate │   3.0 │       6.6 │    208.2 │  5.8 │
# │      Poor │   5.8 │       9.8 │      6.6 │ 89.6 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 7
#  Hyperparameters: Dict{String, Any}("C" => 0.1, "kernel" => "linear")
# =====================================================
#  Accuracy (mean)               : 0.9237
#  Accuracy (std)                : 0.0027
#  Error Rate (mean)             : 0.0763
#  Error Rate (std)              : 0.0027
#  Sensitivity/Recall (mean)     : 0.9237
#  Sensitivity/Recall (std)      : 0.0027
#  Specificity (mean)            : 0.9723
#  Specificity (std)             : 0.0017
#  PPV (mean)                    : 0.9242
#  PPV (std)                     : 0.0027
#  NPV (mean)                    : 0.9825
#  NPV (std)                     : 0.0015
#  F1 Score (mean)               : 0.9219
#  F1 Score (std)                : 0.0028
#
# Confusion Matrix:
# Float32[267.4 0.0 5.4 0.6; 6.0 174.0 9.6 1.6; 2.8 6.6 207.8 6.4; 6.0 9.2 6.8 89.8]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 267.4 │       0.0 │      5.4 │  0.6 │
# │ Hazardous │   6.0 │     174.0 │      9.6 │  1.6 │
# │  Moderate │   2.8 │       6.6 │    207.8 │  6.4 │
# │      Poor │   6.0 │       9.2 │      6.8 │ 89.8 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 8
#  Hyperparameters: Dict{String, Any}("C" => 0.1, "kernel" => "linear")
# =====================================================
#  Accuracy (mean)               : 0.9305
#  Accuracy (std)                : 0.005
#  Error Rate (mean)             : 0.0695
#  Error Rate (std)              : 0.005
#  Sensitivity/Recall (mean)     : 0.9305
#  Sensitivity/Recall (std)      : 0.005
#  Specificity (mean)            : 0.9751
#  Specificity (std)             : 0.0008
#  PPV (mean)                    : 0.9309
#  PPV (std)                     : 0.0056
#  NPV (mean)                    : 0.9843
#  NPV (std)                     : 0.0011
#  F1 Score (mean)               : 0.9289
#  F1 Score (std)                : 0.0056
#
# Confusion Matrix:
# Float32[268.0 0.2 4.8 0.4; 5.4 175.8 8.6 1.4; 2.4 6.4 209.0 5.8; 5.0 8.8 6.4 91.6]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 268.0 │       0.2 │      4.8 │  0.4 │
# │ Hazardous │   5.4 │     175.8 │      8.6 │  1.4 │
# │  Moderate │   2.4 │       6.4 │    209.0 │  5.8 │
# │      Poor │   5.0 │       8.8 │      6.4 │ 91.6 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 6
#  Hyperparameters: Dict{String, Any}("C" => 1.0, "kernel" => "linear")
# =====================================================
#  Accuracy (mean)               : 0.9385
#  Accuracy (std)                : 0.005
#  Error Rate (mean)             : 0.0615
#  Error Rate (std)              : 0.005
#  Sensitivity/Recall (mean)     : 0.9385
#  Sensitivity/Recall (std)      : 0.005
#  Specificity (mean)            : 0.9794
#  Specificity (std)             : 0.0011
#  PPV (mean)                    : 0.9378
#  PPV (std)                     : 0.0057
#  NPV (mean)                    : 0.9854
#  NPV (std)                     : 0.0015
#  F1 Score (mean)               : 0.9376
#  F1 Score (std)                : 0.0052
#
# Confusion Matrix:
# Float32[268.6 0.0 3.6 1.2; 4.4 175.4 8.0 3.4; 2.6 6.0 209.2 5.8; 3.4 5.8 5.0 97.6]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 268.6 │       0.0 │      3.6 │  1.2 │
# │ Hazardous │   4.4 │     175.4 │      8.0 │  3.4 │
# │  Moderate │   2.6 │       6.0 │    209.2 │  5.8 │
# │      Poor │   3.4 │       5.8 │      5.0 │ 97.6 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 7
#  Hyperparameters: Dict{String, Any}("C" => 1.0, "kernel" => "linear")
# =====================================================
#  Accuracy (mean)               : 0.9395
#  Accuracy (std)                : 0.0042
#  Error Rate (mean)             : 0.0605
#  Error Rate (std)              : 0.0042
#  Sensitivity/Recall (mean)     : 0.9395
#  Sensitivity/Recall (std)      : 0.0042
#  Specificity (mean)            : 0.9798
#  Specificity (std)             : 0.001
#  PPV (mean)                    : 0.9389
#  PPV (std)                     : 0.0046
#  NPV (mean)                    : 0.9852
#  NPV (std)                     : 0.0008
#  F1 Score (mean)               : 0.9387
#  F1 Score (std)                : 0.0045
#
# Confusion Matrix:
# Float32[268.4 0.2 3.6 1.2; 4.4 176.2 7.2 3.4; 2.0 5.8 210.2 5.6; 3.8 6.0 5.2 96.8]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 268.4 │       0.2 │      3.6 │  1.2 │
# │ Hazardous │   4.4 │     176.2 │      7.2 │  3.4 │
# │  Moderate │   2.0 │       5.8 │    210.2 │  5.6 │
# │      Poor │   3.8 │       6.0 │      5.2 │ 96.8 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 8
#  Hyperparameters: Dict{String, Any}("C" => 1.0, "kernel" => "linear")
# =====================================================
#  Accuracy (mean)               : 0.9397
#  Accuracy (std)                : 0.0043
#  Error Rate (mean)             : 0.0603
#  Error Rate (std)              : 0.0043
#  Sensitivity/Recall (mean)     : 0.9397
#  Sensitivity/Recall (std)      : 0.0043
#  Specificity (mean)            : 0.9807
#  Specificity (std)             : 0.0008
#  PPV (mean)                    : 0.9391
#  PPV (std)                     : 0.0047
#  NPV (mean)                    : 0.9856
#  NPV (std)                     : 0.001
#  F1 Score (mean)               : 0.939
#  F1 Score (std)                : 0.0045
#
# Confusion Matrix:
# Float32[267.8 0.4 3.6 1.6; 4.4 176.6 6.8 3.4; 2.6 5.6 210.0 5.4; 3.6 5.6 5.2 97.4]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 267.8 │       0.4 │      3.6 │  1.6 │
# │ Hazardous │   4.4 │     176.6 │      6.8 │  3.4 │
# │  Moderate │   2.6 │       5.6 │    210.0 │  5.4 │
# │      Poor │   3.6 │       5.6 │      5.2 │ 97.4 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 6
#  Hyperparameters: Dict{String, Any}("C" => 10.0, "kernel" => "linear")
# =====================================================
#  Accuracy (mean)               : 0.9377
#  Accuracy (std)                : 0.0058
#  Error Rate (mean)             : 0.0623
#  Error Rate (std)              : 0.0058
#  Sensitivity/Recall (mean)     : 0.9377
#  Sensitivity/Recall (std)      : 0.0058
#  Specificity (mean)            : 0.98
#  Specificity (std)             : 0.001
#  PPV (mean)                    : 0.9372
#  PPV (std)                     : 0.0063
#  NPV (mean)                    : 0.9845
#  NPV (std)                     : 0.0014
#  F1 Score (mean)               : 0.937
#  F1 Score (std)                : 0.0059
#
# Confusion Matrix:
# Float32[267.0 0.4 3.8 2.2; 4.2 175.4 7.8 3.8; 2.8 5.4 209.8 5.6; 3.0 5.4 5.4 98.0]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 267.0 │       0.4 │      3.8 │  2.2 │
# │ Hazardous │   4.2 │     175.4 │      7.8 │  3.8 │
# │  Moderate │   2.8 │       5.4 │    209.8 │  5.6 │
# │      Poor │   3.0 │       5.4 │      5.4 │ 98.0 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 7
#  Hyperparameters: Dict{String, Any}("C" => 10.0, "kernel" => "linear")
# =====================================================
#  Accuracy (mean)               : 0.939
#  Accuracy (std)                : 0.0052
#  Error Rate (mean)             : 0.061
#  Error Rate (std)              : 0.0052
#  Sensitivity/Recall (mean)     : 0.939
#  Sensitivity/Recall (std)      : 0.0052
#  Specificity (mean)            : 0.9807
#  Specificity (std)             : 0.0009
#  PPV (mean)                    : 0.9385
#  PPV (std)                     : 0.0054
#  NPV (mean)                    : 0.9849
#  NPV (std)                     : 0.0015
#  F1 Score (mean)               : 0.9383
#  F1 Score (std)                : 0.0052
#
# Confusion Matrix:
# Float32[267.8 0.2 3.4 2.0; 4.6 175.8 7.2 3.6; 2.6 5.8 209.6 5.6; 3.2 5.4 5.2 98.0]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 267.8 │       0.2 │      3.4 │  2.0 │
# │ Hazardous │   4.6 │     175.8 │      7.2 │  3.6 │
# │  Moderate │   2.6 │       5.8 │    209.6 │  5.6 │
# │      Poor │   3.2 │       5.4 │      5.2 │ 98.0 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 8
#  Hyperparameters: Dict{String, Any}("C" => 10.0, "kernel" => "linear")
# =====================================================
#  Accuracy (mean)               : 0.9395
#  Accuracy (std)                : 0.0071
#  Error Rate (mean)             : 0.0605
#  Error Rate (std)              : 0.0071
#  Sensitivity/Recall (mean)     : 0.9395
#  Sensitivity/Recall (std)      : 0.0071
#  Specificity (mean)            : 0.9817
#  Specificity (std)             : 0.0013
#  PPV (mean)                    : 0.939
#  PPV (std)                     : 0.0077
#  NPV (mean)                    : 0.9849
#  NPV (std)                     : 0.0015
#  F1 Score (mean)               : 0.9389
#  F1 Score (std)                : 0.0073
#
# Confusion Matrix:
# Float32[266.4 0.8 3.6 2.6; 4.0 176.4 6.6 4.2; 3.0 5.4 209.8 5.4; 3.0 4.6 5.2 99.0]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 266.4 │       0.8 │      3.6 │  2.6 │
# │ Hazardous │   4.0 │     176.4 │      6.6 │  4.2 │
# │  Moderate │   3.0 │       5.4 │    209.8 │  5.4 │
# │      Poor │   3.0 │       4.6 │      5.2 │ 99.0 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 6
#  Hyperparameters: Dict{String, Any}("C" => 1.0, "kernel" => "rbf", "gamma" => 2.0)
# =====================================================
#  Accuracy (mean)               : 0.9365
#  Accuracy (std)                : 0.0051
#  Error Rate (mean)             : 0.0635
#  Error Rate (std)              : 0.0051
#  Sensitivity/Recall (mean)     : 0.9365
#  Sensitivity/Recall (std)      : 0.0051
#  Specificity (mean)            : 0.98
#  Specificity (std)             : 0.0012
#  PPV (mean)                    : 0.9358
#  PPV (std)                     : 0.0055
#  NPV (mean)                    : 0.9845
#  NPV (std)                     : 0.0017
#  F1 Score (mean)               : 0.9357
#  F1 Score (std)                : 0.0051
#
# Confusion Matrix:
# Float32[267.2 0.2 3.8 2.2; 4.2 175.4 7.8 3.8; 2.4 5.8 209.4 6.0; 3.2 5.8 5.6 97.2]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 267.2 │       0.2 │      3.8 │  2.2 │
# │ Hazardous │   4.2 │     175.4 │      7.8 │  3.8 │
# │  Moderate │   2.4 │       5.8 │    209.4 │  6.0 │
# │      Poor │   3.2 │       5.8 │      5.6 │ 97.2 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 7
#  Hyperparameters: Dict{String, Any}("C" => 1.0, "kernel" => "rbf", "gamma" => 2.0)
# =====================================================
#  Accuracy (mean)               : 0.942
#  Accuracy (std)                : 0.0039
#  Error Rate (mean)             : 0.058
#  Error Rate (std)              : 0.0039
#  Sensitivity/Recall (mean)     : 0.942
#  Sensitivity/Recall (std)      : 0.0039
#  Specificity (mean)            : 0.9815
#  Specificity (std)             : 0.0018
#  PPV (mean)                    : 0.9414
#  PPV (std)                     : 0.004
#  NPV (mean)                    : 0.9858
#  NPV (std)                     : 0.0018
#  F1 Score (mean)               : 0.9413
#  F1 Score (std)                : 0.0037
#
# Confusion Matrix:
# Float32[267.4 0.2 3.8 2.0; 4.0 177.2 6.8 3.2; 2.2 5.6 210.2 5.6; 2.8 5.2 5.0 98.8]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 267.4 │       0.2 │      3.8 │  2.0 │
# │ Hazardous │   4.0 │     177.2 │      6.8 │  3.2 │
# │  Moderate │   2.2 │       5.6 │    210.2 │  5.6 │
# │      Poor │   2.8 │       5.2 │      5.0 │ 98.8 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 8
#  Hyperparameters: Dict{String, Any}("C" => 1.0, "kernel" => "rbf", "gamma" => 2.0)
# =====================================================
#  Accuracy (mean)               : 0.9463
#  Accuracy (std)                : 0.0042
#  Error Rate (mean)             : 0.0537
#  Error Rate (std)              : 0.0042
#  Sensitivity/Recall (mean)     : 0.9463
#  Sensitivity/Recall (std)      : 0.0042
#  Specificity (mean)            : 0.9837
#  Specificity (std)             : 0.001
#  PPV (mean)                    : 0.9457
#  PPV (std)                     : 0.0046
#  NPV (mean)                    : 0.9873
#  NPV (std)                     : 0.0012
#  F1 Score (mean)               : 0.9457
#  F1 Score (std)                : 0.0042
#
# Confusion Matrix:
# Float32[267.4 0.4 3.4 2.2; 3.4 177.6 6.6 3.6; 2.0 5.0 211.8 4.8; 3.0 4.6 4.0 100.2]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 267.4 │       0.4 │      3.4 │   2.2 │
# │ Hazardous │   3.4 │     177.6 │      6.6 │   3.6 │
# │  Moderate │   2.0 │       5.0 │    211.8 │   4.8 │
# │      Poor │   3.0 │       4.6 │      4.0 │ 100.2 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 6
#  Hyperparameters: Dict{String, Any}("C" => 10.0, "kernel" => "rbf", "gamma" => 0.5)
# =====================================================
#  Accuracy (mean)               : 0.9373
#  Accuracy (std)                : 0.0048
#  Error Rate (mean)             : 0.0627
#  Error Rate (std)              : 0.0048
#  Sensitivity/Recall (mean)     : 0.9373
#  Sensitivity/Recall (std)      : 0.0048
#  Specificity (mean)            : 0.9803
#  Specificity (std)             : 0.0016
#  PPV (mean)                    : 0.9368
#  PPV (std)                     : 0.0052
#  NPV (mean)                    : 0.9845
#  NPV (std)                     : 0.0019
#  F1 Score (mean)               : 0.9365
#  F1 Score (std)                : 0.0048
#
# Confusion Matrix:
# Float32[267.0 0.2 3.8 2.4; 4.4 175.4 7.2 4.2; 2.8 5.8 209.2 5.8; 3.2 5.2 5.2 98.2]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 267.0 │       0.2 │      3.8 │  2.4 │
# │ Hazardous │   4.4 │     175.4 │      7.2 │  4.2 │
# │  Moderate │   2.8 │       5.8 │    209.2 │  5.8 │
# │      Poor │   3.2 │       5.2 │      5.2 │ 98.2 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 7
#  Hyperparameters: Dict{String, Any}("C" => 10.0, "kernel" => "rbf", "gamma" => 0.5)
# =====================================================
#  Accuracy (mean)               : 0.9407
#  Accuracy (std)                : 0.0053
#  Error Rate (mean)             : 0.0593
#  Error Rate (std)              : 0.0053
#  Sensitivity/Recall (mean)     : 0.9407
#  Sensitivity/Recall (std)      : 0.0053
#  Specificity (mean)            : 0.9814
#  Specificity (std)             : 0.0019
#  PPV (mean)                    : 0.9403
#  PPV (std)                     : 0.0056
#  NPV (mean)                    : 0.9854
#  NPV (std)                     : 0.0021
#  F1 Score (mean)               : 0.9401
#  F1 Score (std)                : 0.0052
#
# Confusion Matrix:
# Float32[267.6 0.2 3.4 2.2; 4.0 176.4 7.2 3.6; 2.8 5.6 209.6 5.6; 2.8 5.2 4.8 99.0]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 267.6 │       0.2 │      3.4 │  2.2 │
# │ Hazardous │   4.0 │     176.4 │      7.2 │  3.6 │
# │  Moderate │   2.8 │       5.6 │    209.6 │  5.6 │
# │      Poor │   2.8 │       5.2 │      4.8 │ 99.0 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 8
#  Hyperparameters: Dict{String, Any}("C" => 10.0, "kernel" => "rbf", "gamma" => 0.5)
# =====================================================
#  Accuracy (mean)               : 0.945
#  Accuracy (std)                : 0.0056
#  Error Rate (mean)             : 0.055
#  Error Rate (std)              : 0.0056
#  Sensitivity/Recall (mean)     : 0.945
#  Sensitivity/Recall (std)      : 0.0056
#  Specificity (mean)            : 0.9831
#  Specificity (std)             : 0.0014
#  PPV (mean)                    : 0.9446
#  PPV (std)                     : 0.006
#  NPV (mean)                    : 0.9867
#  NPV (std)                     : 0.002
#  F1 Score (mean)               : 0.9444
#  F1 Score (std)                : 0.0055
#
# Confusion Matrix:
# Float32[267.2 0.4 3.6 2.2; 3.6 177.6 6.4 3.6; 2.6 4.8 210.8 5.4; 3.0 4.4 4.0 100.4]
# ┌───────────┬───────┬───────────┬──────────┬───────┐
# │           │  Good │ Hazardous │ Moderate │  Poor │
# ├───────────┼───────┼───────────┼──────────┼───────┤
# │      Good │ 267.2 │       0.4 │      3.6 │   2.2 │
# │ Hazardous │   3.6 │     177.6 │      6.4 │   3.6 │
# │  Moderate │   2.6 │       4.8 │    210.8 │   5.4 │
# │      Poor │   3.0 │       4.4 │      4.0 │ 100.4 │
# └───────────┴───────┴───────────┴──────────┴───────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 6
#  Hyperparameters: Dict{String, Any}("C" => 1.0, "kernel" => "sigmoid", "gamma" => 1.0)
# =====================================================
#  Accuracy (mean)               : 0.9397
#  Accuracy (std)                : 0.0066
#  Error Rate (mean)             : 0.0603
#  Error Rate (std)              : 0.0066
#  Sensitivity/Recall (mean)     : 0.9397
#  Sensitivity/Recall (std)      : 0.0066
#  Specificity (mean)            : 0.9797
#  Specificity (std)             : 0.0014
#  PPV (mean)                    : 0.9391
#  PPV (std)                     : 0.0073
#  NPV (mean)                    : 0.9854
#  NPV (std)                     : 0.0017
#  F1 Score (mean)               : 0.9389
#  F1 Score (std)                : 0.0068
#
# Confusion Matrix:
# Float32[268.6 0.0 3.6 1.2; 4.4 175.8 7.6 3.4; 2.6 6.0 208.8 6.2; 3.2 5.2 4.8 98.6]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 268.6 │       0.0 │      3.6 │  1.2 │
# │ Hazardous │   4.4 │     175.8 │      7.6 │  3.4 │
# │  Moderate │   2.6 │       6.0 │    208.8 │  6.2 │
# │      Poor │   3.2 │       5.2 │      4.8 │ 98.6 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 7
#  Hyperparameters: Dict{String, Any}("C" => 1.0, "kernel" => "sigmoid", "gamma" => 1.0)
# =====================================================
#  Accuracy (mean)               : 0.9407
#  Accuracy (std)                : 0.0048
#  Error Rate (mean)             : 0.0593
#  Error Rate (std)              : 0.0048
#  Sensitivity/Recall (mean)     : 0.9407
#  Sensitivity/Recall (std)      : 0.0048
#  Specificity (mean)            : 0.9801
#  Specificity (std)             : 0.001
#  PPV (mean)                    : 0.9402
#  PPV (std)                     : 0.005
#  NPV (mean)                    : 0.9853
#  NPV (std)                     : 0.001
#  F1 Score (mean)               : 0.94
#  F1 Score (std)                : 0.0049
#
# Confusion Matrix:
# Float32[268.4 0.2 3.6 1.2; 4.4 176.4 6.8 3.6; 2.0 6.0 210.0 5.6; 3.6 5.2 5.2 97.8]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 268.4 │       0.2 │      3.6 │  1.2 │
# │ Hazardous │   4.4 │     176.4 │      6.8 │  3.6 │
# │  Moderate │   2.0 │       6.0 │    210.0 │  5.6 │
# │      Poor │   3.6 │       5.2 │      5.2 │ 97.8 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 8
#  Hyperparameters: Dict{String, Any}("C" => 1.0, "kernel" => "sigmoid", "gamma" => 1.0)
# =====================================================
#  Accuracy (mean)               : 0.9395
#  Accuracy (std)                : 0.0056
#  Error Rate (mean)             : 0.0605
#  Error Rate (std)              : 0.0056
#  Sensitivity/Recall (mean)     : 0.9395
#  Sensitivity/Recall (std)      : 0.0056
#  Specificity (mean)            : 0.9809
#  Specificity (std)             : 0.0007
#  PPV (mean)                    : 0.9387
#  PPV (std)                     : 0.0062
#  NPV (mean)                    : 0.9855
#  NPV (std)                     : 0.0011
#  F1 Score (mean)               : 0.9388
#  F1 Score (std)                : 0.0058
#
# Confusion Matrix:
# Float32[267.6 0.4 3.6 1.8; 4.2 176.8 6.4 3.8; 2.6 5.6 209.6 5.8; 3.6 5.4 5.2 97.6]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 267.6 │       0.4 │      3.6 │  1.8 │
# │ Hazardous │   4.2 │     176.8 │      6.4 │  3.8 │
# │  Moderate │   2.6 │       5.6 │    209.6 │  5.8 │
# │      Poor │   3.6 │       5.4 │      5.2 │ 97.6 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 6
#  Hyperparameters: Dict{String, Any}("C" => 1.0, "kernel" => "poly", "gamma" => 1.0, "degree" => 3)
# =====================================================
#  Accuracy (mean)               : 0.7623
#  Accuracy (std)                : 0.0131
#  Error Rate (mean)             : 0.2377
#  Error Rate (std)              : 0.0131
#  Sensitivity/Recall (mean)     : 0.7623
#  Sensitivity/Recall (std)      : 0.0131
#  Specificity (mean)            : 0.9037
#  Specificity (std)             : 0.0071
#  PPV (mean)                    : 0.8258
#  PPV (std)                     : 0.004
#  NPV (mean)                    : 0.9155
#  NPV (std)                     : 0.007
#  F1 Score (mean)               : 0.7599
#  F1 Score (std)                : 0.0123
#
# Confusion Matrix:
# Float32[210.8 11.8 33.4 17.4; 17.6 131.2 40.6 1.8; 15.2 16.2 172.6 19.6; 3.6 7.4 5.6 95.2]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 210.8 │      11.8 │     33.4 │ 17.4 │
# │ Hazardous │  17.6 │     131.2 │     40.6 │  1.8 │
# │  Moderate │  15.2 │      16.2 │    172.6 │ 19.6 │
# │      Poor │   3.6 │       7.4 │      5.6 │ 95.2 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 7
#  Hyperparameters: Dict{String, Any}("C" => 1.0, "kernel" => "poly", "gamma" => 1.0, "degree" => 3)
# =====================================================
#  Accuracy (mean)               : 0.7643
#  Accuracy (std)                : 0.0136
#  Error Rate (mean)             : 0.2357
#  Error Rate (std)              : 0.0136
#  Sensitivity/Recall (mean)     : 0.7643
#  Sensitivity/Recall (std)      : 0.0136
#  Specificity (mean)            : 0.9047
#  Specificity (std)             : 0.0071
#  PPV (mean)                    : 0.8261
#  PPV (std)                     : 0.0064
#  NPV (mean)                    : 0.9161
#  NPV (std)                     : 0.007
#  F1 Score (mean)               : 0.762
#  F1 Score (std)                : 0.0133
#
# Confusion Matrix:
# Float32[211.4 11.8 33.0 17.2; 16.8 132.8 39.4 2.2; 15.2 16.2 172.6 19.6; 3.8 7.8 5.6 94.6]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 211.4 │      11.8 │     33.0 │ 17.2 │
# │ Hazardous │  16.8 │     132.8 │     39.4 │  2.2 │
# │  Moderate │  15.2 │      16.2 │    172.6 │ 19.6 │
# │      Poor │   3.8 │       7.8 │      5.6 │ 94.6 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 8
#  Hyperparameters: Dict{String, Any}("C" => 1.0, "kernel" => "poly", "gamma" => 1.0, "degree" => 3)
# =====================================================
#  Accuracy (mean)               : 0.7675
#  Accuracy (std)                : 0.0121
#  Error Rate (mean)             : 0.2325
#  Error Rate (std)              : 0.0121
#  Sensitivity/Recall (mean)     : 0.7675
#  Sensitivity/Recall (std)      : 0.0121
#  Specificity (mean)            : 0.9059
#  Specificity (std)             : 0.0066
#  PPV (mean)                    : 0.8293
#  PPV (std)                     : 0.005
#  NPV (mean)                    : 0.9168
#  NPV (std)                     : 0.0068
#  F1 Score (mean)               : 0.7654
#  F1 Score (std)                : 0.0116
#
# Confusion Matrix:
# Float32[211.8 11.8 32.8 17.0; 16.8 133.6 38.4 2.4; 15.0 16.0 173.0 19.6; 3.4 7.6 5.2 95.6]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 211.8 │      11.8 │     32.8 │ 17.0 │
# │ Hazardous │  16.8 │     133.6 │     38.4 │  2.4 │
# │  Moderate │  15.0 │      16.0 │    173.0 │ 19.6 │
# │      Poor │   3.4 │       7.6 │      5.2 │ 95.6 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 6
#  Hyperparameters: Dict{String, Any}("C" => 5.0, "kernel" => "poly", "gamma" => 0.5, "degree" => 4)
# =====================================================
#  Accuracy (mean)               : 0.4587
#  Accuracy (std)                : 0.0015
#  Error Rate (mean)             : 0.5413
#  Error Rate (std)              : 0.0015
#  Sensitivity/Recall (mean)     : 0.4587
#  Sensitivity/Recall (std)      : 0.0015
#  Specificity (mean)            : 0.6334
#  Specificity (std)             : 0.0015
#  PPV (mean)                    : 0.3092
#  PPV (std)                     : 0.0868
#  NPV (mean)                    : 0.8665
#  NPV (std)                     : 0.0003
#  F1 Score (mean)               : 0.3127
#  F1 Score (std)                : 0.0024
#
# Confusion Matrix:
# Float32[193.8 31.4 48.2 0.0; 85.6 74.2 30.6 0.8; 110.4 48.2 64.8 0.2; 62.8 7.4 7.4 34.2]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 193.8 │      31.4 │     48.2 │  0.0 │
# │ Hazardous │  85.6 │      74.2 │     30.6 │  0.8 │
# │  Moderate │ 110.4 │      48.2 │     64.8 │  0.2 │
# │      Poor │  62.8 │       7.4 │      7.4 │ 34.2 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 7
#  Hyperparameters: Dict{String, Any}("C" => 5.0, "kernel" => "poly", "gamma" => 0.5, "degree" => 4)
# =====================================================
#  Accuracy (mean)               : 0.4605
#  Accuracy (std)                : 0.0019
#  Error Rate (mean)             : 0.5395
#  Error Rate (std)              : 0.0019
#  Sensitivity/Recall (mean)     : 0.4605
#  Sensitivity/Recall (std)      : 0.0019
#  Specificity (mean)            : 0.6345
#  Specificity (std)             : 0.002
#  PPV (mean)                    : 0.31
#  PPV (std)                     : 0.0869
#  NPV (mean)                    : 0.8667
#  NPV (std)                     : 0.0004
#  F1 Score (mean)               : 0.3146
#  F1 Score (std)                : 0.003
#
# Confusion Matrix:
# Float32[193.8 31.4 48.2 0.0; 86.0 74.0 30.6 0.6; 110.4 48.2 64.8 0.2; 62.2 7.0 6.8 35.8]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 193.8 │      31.4 │     48.2 │  0.0 │
# │ Hazardous │  86.0 │      74.0 │     30.6 │  0.6 │
# │  Moderate │ 110.4 │      48.2 │     64.8 │  0.2 │
# │      Poor │  62.2 │       7.0 │      6.8 │ 35.8 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: SVC | PCA outdim: 8
#  Hyperparameters: Dict{String, Any}("C" => 5.0, "kernel" => "poly", "gamma" => 0.5, "degree" => 4)
# =====================================================
#  Accuracy (mean)               : 0.4593
#  Accuracy (std)                : 0.0038
#  Error Rate (mean)             : 0.5407
#  Error Rate (std)              : 0.0038
#  Sensitivity/Recall (mean)     : 0.4593
#  Sensitivity/Recall (std)      : 0.0038
#  Specificity (mean)            : 0.6336
#  Specificity (std)             : 0.0031
#  PPV (mean)                    : 0.3098
#  PPV (std)                     : 0.087
#  NPV (mean)                    : 0.8666
#  NPV (std)                     : 0.0005
#  F1 Score (mean)               : 0.3133
#  F1 Score (std)                : 0.0045
#
# Confusion Matrix:
# Float32[193.8 31.4 48.2 0.0; 86.6 73.4 30.6 0.6; 110.4 48.2 64.8 0.2; 61.8 7.8 6.8 35.4]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 193.8 │      31.4 │     48.2 │  0.0 │
# │ Hazardous │  86.6 │      73.4 │     30.6 │  0.6 │
# │  Moderate │ 110.4 │      48.2 │     64.8 │  0.2 │
# │      Poor │  61.8 │       7.8 │      6.8 │ 35.4 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================

# %%
########################
# 2. SVM FINAL TESTING 
########################

# BEST HYPERPARAMETERS
hp = Dict("kernel"=>"rbf", "C"=>1.0, "gamma"=>2.0)
dimPCA = 8

# Compute normalization parameters from TRAINING set only
normParams = calculateMinMaxNormalizationParameters(trainingInputs)
train_df = normalizeMinMax(trainingInputs, normParams)
test_df = normalizeMinMax(testInputs, normParams)

pca_model = PCA_model(maxoutdim=dimPCA)
# Train the PCA model
pca_mach = machine(pca_model, MLJ.table(train_df))
MLJ.fit!(pca_mach, verbosity=0)
# Transform the data
train_df = MLJBase.matrix(MLJBase.transform(pca_mach, MLJ.table(train_df)))
test_df  = MLJBase.matrix(MLJBase.transform(pca_mach, MLJ.table(test_df)))

# --- Convert targets ---
train_y_cat = categorical(vec(trainingTargets))
test_y_cat  = categorical(vec(testTargets))

# Load model (insert hyperparameters manually)
model = SVMClassifier(kernel=LIBSVM.Kernel.RadialBasis, cost=Float64(1), gamma=Float64(2))
    
# --- Train machine ---
mach = machine(model, MLJ.table(train_df), train_y_cat)
MLJ.fit!(mach)
    
# --- Predict ---
ŷ = MLJ.predict(mach, test_df)              # probabilistic predictions
y_pred = CategoricalArray(ŷ)         # convert to class labels
    
# --- Compute metrics ---
metrics = confusionMatrix(y_pred, test_y_cat)

printPCAResult(:SVC, hp, metrics, dimPCA, label_names)
# Out:
# ┌ Info: Training machine(SVC(kernel = RadialBasis, …), …).
# └ @ MLJBase C:\Users\gianp\.julia\packages\MLJBase\7nGJF\src\machines.jl:499
# =====================================================
#  Model: SVC outdim 8
#  Hyperparameters: Dict{String, Any}("C" => 1.0, "kernel" => "rbf", "gamma" => 2.0)
# =====================================================
#  Accuracy                : 0.927
#  Error Rate              : 0.073
#  Sensitivity/Recall      : 0.927
#  Specificity             : 0.9782
#  PPV                     : 0.9264
#  NPV                     : 0.982
#  F1 Score                : 0.9262
#
# Confusion Matrix:
# [77 0 0 26; 0 283 1 12; 0 0 383 0; 12 22 0 184]
# =====================================================
#
# ┌───────────┬──────┬───────────┬──────────┬──────┐
# │           │ Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼──────┼───────────┼──────────┼──────┤
# │      Good │   77 │         0 │        0 │   26 │
# │ Hazardous │    0 │       283 │        1 │   12 │
# │  Moderate │    0 │         0 │      383 │    0 │
# │      Poor │   12 │        22 │        0 │  184 │
# └───────────┴──────┴───────────┴──────────┴──────┘

# %% [markdown]
# # Decission Trees

# %%
DTClassifier = MLJ.@load DecisionTreeClassifier pkg=DecisionTree verbosity=0
# Out:
# MLJDecisionTreeInterface.DecisionTreeClassifier

# %%
############# 3. DECISION TREES (6 depths) #############
default_dt = Dict(
    "rng" => Random.MersenneTwister(1)
)

dt_search_space = [
    Dict("max_depth"=>2),
    Dict("max_depth"=>3),
    Dict("max_depth"=>4),
    Dict("max_depth"=>5),
    Dict("max_depth"=>6),
    Dict("max_depth"=>8)
]
# Out:
# 6-element Vector{Dict{String, Int64}}:
#  Dict("max_depth" => 2)
#  Dict("max_depth" => 3)
#  Dict("max_depth" => 4)
#  Dict("max_depth" => 5)
#  Dict("max_depth" => 6)
#  Dict("max_depth" => 8)

# %%
########################
# 3. DECISION TREE GRID SEARCH
########################
dt_results = []

for hp in dt_search_space
    for dim in dimsPCA
        println("\n=== Decision Tree experiment: max_depth=$(hp["max_depth"]) | PCA maxoutdim = $(dim) ===")
        full_hp = merge(default_dt, hp)
        res = modelCrossValidationPCA(:DecisionTreeClassifier, full_hp, (trainingInputs, trainingTargets), crossValidationIndices, dim)
        push!(dt_results, (model=:DT, hyperparams=hp, dimPCA=dim, results=res))
    end
end

results[:DT] = dt_results
# Out:
# === Decision Tree experiment: max_depth=2 | PCA maxoutdim = 6 ===
# === Decision Tree experiment: max_depth=2 | PCA maxoutdim = 7 ===
#
# === Decision Tree experiment: max_depth=2 | PCA maxoutdim = 8 ===
#
# === Decision Tree experiment: max_depth=3 | PCA maxoutdim = 6 ===
#
# === Decision Tree experiment: max_depth=3 | PCA maxoutdim = 7 ===
#
# === Decision Tree experiment: max_depth=3 | PCA maxoutdim = 8 ===
#
# === Decision Tree experiment: max_depth=4 | PCA maxoutdim = 6 ===
#
# === Decision Tree experiment: max_depth=4 | PCA maxoutdim = 7 ===
#
# === Decision Tree experiment: max_depth=4 | PCA maxoutdim = 8 ===
#
# === Decision Tree experiment: max_depth=5 | PCA maxoutdim = 6 ===
#
# === Decision Tree experiment: max_depth=5 | PCA maxoutdim = 7 ===
#
# === Decision Tree experiment: max_depth=5 | PCA maxoutdim = 8 ===
#
# === Decision Tree experiment: max_depth=6 | PCA maxoutdim = 6 ===
#
# === Decision Tree experiment: max_depth=6 | PCA maxoutdim = 7 ===
#
# === Decision Tree experiment: max_depth=6 | PCA maxoutdim = 8 ===
#
# === Decision Tree experiment: max_depth=8 | PCA maxoutdim = 6 ===
#
# === Decision Tree experiment: max_depth=8 | PCA maxoutdim = 7 ===
#
# === Decision Tree experiment: max_depth=8 | PCA maxoutdim = 8 ===
# 18-element Vector{Any}:
#  (model = :DT, hyperparams = Dict("max_depth" => 2), dimPCA = 6, results = ((0.83324766f0, 0.0047318414f0), (0.1667523f0, 0.0047318325f0), (0.83324766f0, 0.0047318414f0), (0.94338644f0, 0.0029785472f0), (0.765292f0, 0.0050344025f0), (0.9658946f0, 0.0021908178f0), (0.79555875f0, 0.004722839f0), Float32[261.0 1.0 11.2 0.2; 8.6 158.8 23.8 0.0; 4.4 8.8 204.8 5.6; 20.6 31.8 17.4 42.0]))
#  (model = :DT, hyperparams = Dict("max_depth" => 2), dimPCA = 7, results = ((0.83324766f0, 0.0047318414f0), (0.1667523f0, 0.0047318325f0), (0.83324766f0, 0.0047318414f0), (0.94338644f0, 0.0029785472f0), (0.765292f0, 0.0050344025f0), (0.9658946f0, 0.0021908178f0), (0.79555875f0, 0.004722839f0), Float32[261.0 1.0 11.2 0.2; 8.6 158.8 23.8 0.0; 4.4 8.8 204.8 5.6; 20.6 31.8 17.4 42.0]))
#  (model = :DT, hyperparams = Dict("max_depth" => 2), dimPCA = 8, results = ((0.83324766f0, 0.0047318414f0), (0.1667523f0, 0.0047318325f0), (0.83324766f0, 0.0047318414f0), (0.94338644f0, 0.0029785472f0), (0.765292f0, 0.0050344025f0), (0.9658946f0, 0.0021908178f0), (0.79555875f0, 0.004722839f0), Float32[261.0 1.0 11.2 0.2; 8.6 158.8 23.8 0.0; 4.4 8.8 204.8 5.6; 20.6 31.8 17.4 42.0]))
#  (model = :DT, hyperparams = Dict("max_depth" => 3), dimPCA = 6, results = ((0.9115011f0, 0.00656216f0), (0.08849883f0, 0.006562167f0), (0.9115011f0, 0.00656216f0), (0.9696323f0, 0.0029839703f0), (0.9115287f0, 0.006798216f0), (0.9751474f0, 0.0023579497f0), (0.9100841f0, 0.0068340367f0), Float32[261.2 1.2 8.8 2.2; 5.8 168.6 11.2 5.6; 4.2 7.8 202.6 9.0; 4.8 5.0 5.2 96.8]))
#  (model = :DT, hyperparams = Dict("max_depth" => 3), dimPCA = 7, results = ((0.9115011f0, 0.00656216f0), (0.08849883f0, 0.006562167f0), (0.9115011f0, 0.00656216f0), (0.9696323f0, 0.0029839703f0), (0.9115287f0, 0.006798216f0), (0.9751474f0, 0.0023579497f0), (0.9100841f0, 0.0068340367f0), Float32[261.2 1.2 8.8 2.2; 5.8 168.6 11.2 5.6; 4.2 7.8 202.6 9.0; 4.8 5.0 5.2 96.8]))
#  (model = :DT, hyperparams = Dict("max_depth" => 3), dimPCA = 8, results = ((0.9115011f0, 0.00656216f0), (0.08849883f0, 0.006562167f0), (0.9115011f0, 0.00656216f0), (0.9696323f0, 0.0029839703f0), (0.9115287f0, 0.006798216f0), (0.9751474f0, 0.0023579497f0), (0.9100841f0, 0.0068340367f0), Float32[261.2 1.2 8.8 2.2; 5.8 168.6 11.2 5.6; 4.2 7.8 202.6 9.0; 4.8 5.0 5.2 96.8]))
#  (model = :DT, hyperparams = Dict("max_depth" => 4), dimPCA = 6, results = ((0.9157443f0, 0.0101282215f0), (0.08425568f0, 0.010128205f0), (0.9157443f0, 0.0101282215f0), (0.9734131f0, 0.003099862f0), (0.91665f0, 0.009273037f0), (0.9746788f0, 0.00525812f0), (0.9155401f0, 0.009711209f0), Float32[261.8 1.4 7.6 2.6; 5.8 169.8 10.0 5.6; 3.8 7.8 204.6 7.4; 4.0 5.0 6.4 96.4]))
#  (model = :DT, hyperparams = Dict("max_depth" => 4), dimPCA = 7, results = ((0.91499436f0, 0.009214174f0), (0.08500568f0, 0.009214164f0), (0.91499436f0, 0.009214174f0), (0.9729663f0, 0.003098136f0), (0.915895f0, 0.00834265f0), (0.9742945f0, 0.004976731f0), (0.91478527f0, 0.008751078f0), Float32[261.8 1.4 7.6 2.6; 5.8 169.6 10.2 5.6; 3.8 7.8 204.6 7.4; 4.4 5.0 6.4 96.0]))
#  (model = :DT, hyperparams = Dict("max_depth" => 4), dimPCA = 8, results = ((0.91574365f0, 0.009371598f0), (0.0842563f0, 0.009371592f0), (0.91574365f0, 0.009371598f0), (0.9733502f0, 0.0033134047f0), (0.9166455f0, 0.00848689f0), (0.974754f0, 0.005254497f0), (0.9155197f0, 0.008871724f0), Float32[262.2 1.2 7.4 2.6; 5.8 169.8 10.0 5.6; 3.8 7.8 204.6 7.4; 4.4 5.0 6.4 96.0]))
#  (model = :DT, hyperparams = Dict("max_depth" => 5), dimPCA = 6, results = ((0.9215015f0, 0.0051555135f0), (0.07849847f0, 0.005155506f0), (0.9215015f0, 0.0051555135f0), (0.9747796f0, 0.0024166093f0), (0.92118627f0, 0.005231643f0), (0.97757405f0, 0.0019560263f0), (0.92093384f0, 0.005321608f0), Float32[263.6 1.6 5.8 2.4; 4.6 172.0 9.0 5.6; 4.8 6.4 205.0 7.4; 4.6 5.0 5.6 96.6]))
#  (model = :DT, hyperparams = Dict("max_depth" => 5), dimPCA = 7, results = ((0.92174995f0, 0.0053494056f0), (0.078250036f0, 0.005349418f0), (0.92174995f0, 0.0053494056f0), (0.9749665f0, 0.0025577126f0), (0.9213792f0, 0.005649762f0), (0.97785884f0, 0.0017636212f0), (0.9211547f0, 0.005566371f0), Float32[264.0 1.6 5.2 2.6; 4.6 172.0 8.8 5.8; 5.2 6.4 204.6 7.4; 4.4 5.0 5.6 96.8]))
#  (model = :DT, hyperparams = Dict("max_depth" => 5), dimPCA = 8, results = ((0.9244978f0, 0.0054614283f0), (0.0755022f0, 0.0054614306f0), (0.9244978f0, 0.0054614283f0), (0.9762716f0, 0.00335555f0), (0.9242059f0, 0.005930545f0), (0.9787138f0, 0.0021451544f0), (0.92404443f0, 0.005574158f0), Float32[264.0 1.6 5.2 2.6; 3.8 173.2 8.4 5.8; 5.0 5.8 205.4 7.4; 4.2 5.0 5.6 97.0]))
#  (model = :DT, hyperparams = Dict("max_depth" => 6), dimPCA = 6, results = ((0.91776f0, 0.0062900945f0), (0.08224006f0, 0.006290099f0), (0.91776f0, 0.0062900945f0), (0.9740796f0, 0.0021952814f0), (0.91857815f0, 0.0070395134f0), (0.976528f0, 0.0027137622f0), (0.91728294f0, 0.0064603114f0), Float32[260.8 2.4 5.2 5.0; 4.6 171.0 11.0 4.6; 5.2 5.6 207.4 5.4; 3.4 6.0 7.4 95.0]))
#  (model = :DT, hyperparams = Dict("max_depth" => 6), dimPCA = 7, results = ((0.9182571f0, 0.004388993f0), (0.08174286f0, 0.00438899f0), (0.9182571f0, 0.004388993f0), (0.97437257f0, 0.0024678777f0), (0.9190254f0, 0.00548771f0), (0.9769877f0, 0.002210859f0), (0.91774714f0, 0.004586976f0), Float32[261.2 2.2 5.0 5.0; 4.6 171.2 10.6 4.8; 5.4 5.4 207.4 5.4; 3.6 6.0 7.4 94.8]))
#  (model = :DT, hyperparams = Dict("max_depth" => 6), dimPCA = 8, results = ((0.92125213f0, 0.0049453108f0), (0.078747846f0, 0.004945318f0), (0.92125213f0, 0.0049453108f0), (0.97613364f0, 0.003439184f0), (0.9219987f0, 0.005436086f0), (0.97755176f0, 0.0025237906f0), (0.92101467f0, 0.004993669f0), Float32[262.8 1.2 4.4 5.0; 4.2 171.6 10.6 4.8; 5.4 4.6 206.8 6.8; 3.4 6.0 6.6 95.8]))
#  (model = :DT, hyperparams = Dict("max_depth" => 8), dimPCA = 6, results = ((0.91875774f0, 0.0068869665f0), (0.08124223f0, 0.0068869623f0), (0.91875774f0, 0.0068869665f0), (0.97371674f0, 0.0028800298f0), (0.9187315f0, 0.007137082f0), (0.9766399f0, 0.003037801f0), (0.9182774f0, 0.0067769093f0), Float32[262.2 2.6 5.4 3.2; 3.8 172.0 10.6 4.8; 5.4 6.8 204.8 6.6; 4.6 5.2 6.0 96.0]))
#  (model = :DT, hyperparams = Dict("max_depth" => 8), dimPCA = 7, results = ((0.91825837f0, 0.012040024f0), (0.081741616f0, 0.012040037f0), (0.91825837f0, 0.012040024f0), (0.9736789f0, 0.004233198f0), (0.91861266f0, 0.011438703f0), (0.97688675f0, 0.0048083244f0), (0.917822f0, 0.011641511f0), Float32[262.8 2.2 4.8 3.6; 3.6 174.2 10.0 3.4; 7.6 5.8 203.4 6.8; 5.0 6.2 6.4 94.2]))
#  (model = :DT, hyperparams = Dict("max_depth" => 8), dimPCA = 8, results = ((0.92249906f0, 0.0084427195f0), (0.077500954f0, 0.008442703f0), (0.92249906f0, 0.0084427195f0), (0.97495973f0, 0.0050701024f0), (0.9224291f0, 0.008564307f0), (0.97820157f0, 0.0034268699f0), (0.92199147f0, 0.008508154f0), Float32[263.6 1.8 4.4 3.6; 4.0 173.6 10.2 3.4; 5.2 5.4 206.2 6.8; 4.8 6.2 6.2 94.6]))

# %%
for entry in results[:DT]
    printExperimentResult(entry.model, entry.hyperparams, entry.dimPCA, entry.results, label_names)
end
# Out:
# =====================================================
#  Model: DT | PCA outdim: 6
#  Hyperparameters: Dict("max_depth" => 2)
# =====================================================
#  Accuracy (mean)               : 0.8332
#  Accuracy (std)                : 0.0047
#  Error Rate (mean)             : 0.1668
#  Error Rate (std)              : 0.0047
#  Sensitivity/Recall (mean)     : 0.8332
#  Sensitivity/Recall (std)      : 0.0047
#  Specificity (mean)            : 0.9434
#  Specificity (std)             : 0.003
#  PPV (mean)                    : 0.7653
#  PPV (std)                     : 0.005
#  NPV (mean)                    : 0.9659
#  NPV (std)                     : 0.0022
#  F1 Score (mean)               : 0.7956
#  F1 Score (std)                : 0.0047
#
# Confusion Matrix:
# Float32[261.0 1.0 11.2 0.2; 8.6 158.8 23.8 0.0; 4.4 8.8 204.8 5.6; 20.6 31.8 17.4 42.0]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 261.0 │       1.0 │     11.2 │  0.2 │
# │ Hazardous │   8.6 │     158.8 │     23.8 │  0.0 │
# │  Moderate │   4.4 │       8.8 │    204.8 │  5.6 │
# │      Poor │  20.6 │      31.8 │     17.4 │ 42.0 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: DT | PCA outdim: 7
#  Hyperparameters: Dict("max_depth" => 2)
# =====================================================
#  Accuracy (mean)               : 0.8332
#  Accuracy (std)                : 0.0047
#  Error Rate (mean)             : 0.1668
#  Error Rate (std)              : 0.0047
#  Sensitivity/Recall (mean)     : 0.8332
#  Sensitivity/Recall (std)      : 0.0047
#  Specificity (mean)            : 0.9434
#  Specificity (std)             : 0.003
#  PPV (mean)                    : 0.7653
#  PPV (std)                     : 0.005
#  NPV (mean)                    : 0.9659
#  NPV (std)                     : 0.0022
#  F1 Score (mean)               : 0.7956
#  F1 Score (std)                : 0.0047
#
# Confusion Matrix:
# Float32[261.0 1.0 11.2 0.2; 8.6 158.8 23.8 0.0; 4.4 8.8 204.8 5.6; 20.6 31.8 17.4 42.0]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 261.0 │       1.0 │     11.2 │  0.2 │
# │ Hazardous │   8.6 │     158.8 │     23.8 │  0.0 │
# │  Moderate │   4.4 │       8.8 │    204.8 │  5.6 │
# │      Poor │  20.6 │      31.8 │     17.4 │ 42.0 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: DT | PCA outdim: 8
#  Hyperparameters: Dict("max_depth" => 2)
# =====================================================
#  Accuracy (mean)               : 0.8332
#  Accuracy (std)                : 0.0047
#  Error Rate (mean)             : 0.1668
#  Error Rate (std)              : 0.0047
#  Sensitivity/Recall (mean)     : 0.8332
#  Sensitivity/Recall (std)      : 0.0047
#  Specificity (mean)            : 0.9434
#  Specificity (std)             : 0.003
#  PPV (mean)                    : 0.7653
#  PPV (std)                     : 0.005
#  NPV (mean)                    : 0.9659
#  NPV (std)                     : 0.0022
#  F1 Score (mean)               : 0.7956
#  F1 Score (std)                : 0.0047
#
# Confusion Matrix:
# Float32[261.0 1.0 11.2 0.2; 8.6 158.8 23.8 0.0; 4.4 8.8 204.8 5.6; 20.6 31.8 17.4 42.0]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 261.0 │       1.0 │     11.2 │  0.2 │
# │ Hazardous │   8.6 │     158.8 │     23.8 │  0.0 │
# │  Moderate │   4.4 │       8.8 │    204.8 │  5.6 │
# │      Poor │  20.6 │      31.8 │     17.4 │ 42.0 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: DT | PCA outdim: 6
#  Hyperparameters: Dict("max_depth" => 3)
# =====================================================
#  Accuracy (mean)               : 0.9115
#  Accuracy (std)                : 0.0066
#  Error Rate (mean)             : 0.0885
#  Error Rate (std)              : 0.0066
#  Sensitivity/Recall (mean)     : 0.9115
#  Sensitivity/Recall (std)      : 0.0066
#  Specificity (mean)            : 0.9696
#  Specificity (std)             : 0.003
#  PPV (mean)                    : 0.9115
#  PPV (std)                     : 0.0068
#  NPV (mean)                    : 0.9751
#  NPV (std)                     : 0.0024
#  F1 Score (mean)               : 0.9101
#  F1 Score (std)                : 0.0068
#
# Confusion Matrix:
# Float32[261.2 1.2 8.8 2.2; 5.8 168.6 11.2 5.6; 4.2 7.8 202.6 9.0; 4.8 5.0 5.2 96.8]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 261.2 │       1.2 │      8.8 │  2.2 │
# │ Hazardous │   5.8 │     168.6 │     11.2 │  5.6 │
# │  Moderate │   4.2 │       7.8 │    202.6 │  9.0 │
# │      Poor │   4.8 │       5.0 │      5.2 │ 96.8 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: DT | PCA outdim: 7
#  Hyperparameters: Dict("max_depth" => 3)
# =====================================================
#  Accuracy (mean)               : 0.9115
#  Accuracy (std)                : 0.0066
#  Error Rate (mean)             : 0.0885
#  Error Rate (std)              : 0.0066
#  Sensitivity/Recall (mean)     : 0.9115
#  Sensitivity/Recall (std)      : 0.0066
#  Specificity (mean)            : 0.9696
#  Specificity (std)             : 0.003
#  PPV (mean)                    : 0.9115
#  PPV (std)                     : 0.0068
#  NPV (mean)                    : 0.9751
#  NPV (std)                     : 0.0024
#  F1 Score (mean)               : 0.9101
#  F1 Score (std)                : 0.0068
#
# Confusion Matrix:
# Float32[261.2 1.2 8.8 2.2; 5.8 168.6 11.2 5.6; 4.2 7.8 202.6 9.0; 4.8 5.0 5.2 96.8]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 261.2 │       1.2 │      8.8 │  2.2 │
# │ Hazardous │   5.8 │     168.6 │     11.2 │  5.6 │
# │  Moderate │   4.2 │       7.8 │    202.6 │  9.0 │
# │      Poor │   4.8 │       5.0 │      5.2 │ 96.8 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: DT | PCA outdim: 8
#  Hyperparameters: Dict("max_depth" => 3)
# =====================================================
#  Accuracy (mean)               : 0.9115
#  Accuracy (std)                : 0.0066
#  Error Rate (mean)             : 0.0885
#  Error Rate (std)              : 0.0066
#  Sensitivity/Recall (mean)     : 0.9115
#  Sensitivity/Recall (std)      : 0.0066
#  Specificity (mean)            : 0.9696
#  Specificity (std)             : 0.003
#  PPV (mean)                    : 0.9115
#  PPV (std)                     : 0.0068
#  NPV (mean)                    : 0.9751
#  NPV (std)                     : 0.0024
#  F1 Score (mean)               : 0.9101
#  F1 Score (std)                : 0.0068
#
# Confusion Matrix:
# Float32[261.2 1.2 8.8 2.2; 5.8 168.6 11.2 5.6; 4.2 7.8 202.6 9.0; 4.8 5.0 5.2 96.8]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 261.2 │       1.2 │      8.8 │  2.2 │
# │ Hazardous │   5.8 │     168.6 │     11.2 │  5.6 │
# │  Moderate │   4.2 │       7.8 │    202.6 │  9.0 │
# │      Poor │   4.8 │       5.0 │      5.2 │ 96.8 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: DT | PCA outdim: 6
#  Hyperparameters: Dict("max_depth" => 4)
# =====================================================
#  Accuracy (mean)               : 0.9157
#  Accuracy (std)                : 0.0101
#  Error Rate (mean)             : 0.0843
#  Error Rate (std)              : 0.0101
#  Sensitivity/Recall (mean)     : 0.9157
#  Sensitivity/Recall (std)      : 0.0101
#  Specificity (mean)            : 0.9734
#  Specificity (std)             : 0.0031
#  PPV (mean)                    : 0.9166
#  PPV (std)                     : 0.0093
#  NPV (mean)                    : 0.9747
#  NPV (std)                     : 0.0053
#  F1 Score (mean)               : 0.9155
#  F1 Score (std)                : 0.0097
#
# Confusion Matrix:
# Float32[261.8 1.4 7.6 2.6; 5.8 169.8 10.0 5.6; 3.8 7.8 204.6 7.4; 4.0 5.0 6.4 96.4]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 261.8 │       1.4 │      7.6 │  2.6 │
# │ Hazardous │   5.8 │     169.8 │     10.0 │  5.6 │
# │  Moderate │   3.8 │       7.8 │    204.6 │  7.4 │
# │      Poor │   4.0 │       5.0 │      6.4 │ 96.4 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: DT | PCA outdim: 7
#  Hyperparameters: Dict("max_depth" => 4)
# =====================================================
#  Accuracy (mean)               : 0.915
#  Accuracy (std)                : 0.0092
#  Error Rate (mean)             : 0.085
#  Error Rate (std)              : 0.0092
#  Sensitivity/Recall (mean)     : 0.915
#  Sensitivity/Recall (std)      : 0.0092
#  Specificity (mean)            : 0.973
#  Specificity (std)             : 0.0031
#  PPV (mean)                    : 0.9159
#  PPV (std)                     : 0.0083
#  NPV (mean)                    : 0.9743
#  NPV (std)                     : 0.005
#  F1 Score (mean)               : 0.9148
#  F1 Score (std)                : 0.0088
#
# Confusion Matrix:
# Float32[261.8 1.4 7.6 2.6; 5.8 169.6 10.2 5.6; 3.8 7.8 204.6 7.4; 4.4 5.0 6.4 96.0]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 261.8 │       1.4 │      7.6 │  2.6 │
# │ Hazardous │   5.8 │     169.6 │     10.2 │  5.6 │
# │  Moderate │   3.8 │       7.8 │    204.6 │  7.4 │
# │      Poor │   4.4 │       5.0 │      6.4 │ 96.0 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: DT | PCA outdim: 8
#  Hyperparameters: Dict("max_depth" => 4)
# =====================================================
#  Accuracy (mean)               : 0.9157
#  Accuracy (std)                : 0.0094
#  Error Rate (mean)             : 0.0843
#  Error Rate (std)              : 0.0094
#  Sensitivity/Recall (mean)     : 0.9157
#  Sensitivity/Recall (std)      : 0.0094
#  Specificity (mean)            : 0.9734
#  Specificity (std)             : 0.0033
#  PPV (mean)                    : 0.9166
#  PPV (std)                     : 0.0085
#  NPV (mean)                    : 0.9748
#  NPV (std)                     : 0.0053
#  F1 Score (mean)               : 0.9155
#  F1 Score (std)                : 0.0089
#
# Confusion Matrix:
# Float32[262.2 1.2 7.4 2.6; 5.8 169.8 10.0 5.6; 3.8 7.8 204.6 7.4; 4.4 5.0 6.4 96.0]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 262.2 │       1.2 │      7.4 │  2.6 │
# │ Hazardous │   5.8 │     169.8 │     10.0 │  5.6 │
# │  Moderate │   3.8 │       7.8 │    204.6 │  7.4 │
# │      Poor │   4.4 │       5.0 │      6.4 │ 96.0 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: DT | PCA outdim: 6
#  Hyperparameters: Dict("max_depth" => 5)
# =====================================================
#  Accuracy (mean)               : 0.9215
#  Accuracy (std)                : 0.0052
#  Error Rate (mean)             : 0.0785
#  Error Rate (std)              : 0.0052
#  Sensitivity/Recall (mean)     : 0.9215
#  Sensitivity/Recall (std)      : 0.0052
#  Specificity (mean)            : 0.9748
#  Specificity (std)             : 0.0024
#  PPV (mean)                    : 0.9212
#  PPV (std)                     : 0.0052
#  NPV (mean)                    : 0.9776
#  NPV (std)                     : 0.002
#  F1 Score (mean)               : 0.9209
#  F1 Score (std)                : 0.0053
#
# Confusion Matrix:
# Float32[263.6 1.6 5.8 2.4; 4.6 172.0 9.0 5.6; 4.8 6.4 205.0 7.4; 4.6 5.0 5.6 96.6]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 263.6 │       1.6 │      5.8 │  2.4 │
# │ Hazardous │   4.6 │     172.0 │      9.0 │  5.6 │
# │  Moderate │   4.8 │       6.4 │    205.0 │  7.4 │
# │      Poor │   4.6 │       5.0 │      5.6 │ 96.6 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: DT | PCA outdim: 7
#  Hyperparameters: Dict("max_depth" => 5)
# =====================================================
#  Accuracy (mean)               : 0.9217
#  Accuracy (std)                : 0.0053
#  Error Rate (mean)             : 0.0783
#  Error Rate (std)              : 0.0053
#  Sensitivity/Recall (mean)     : 0.9217
#  Sensitivity/Recall (std)      : 0.0053
#  Specificity (mean)            : 0.975
#  Specificity (std)             : 0.0026
#  PPV (mean)                    : 0.9214
#  PPV (std)                     : 0.0056
#  NPV (mean)                    : 0.9779
#  NPV (std)                     : 0.0018
#  F1 Score (mean)               : 0.9212
#  F1 Score (std)                : 0.0056
#
# Confusion Matrix:
# Float32[264.0 1.6 5.2 2.6; 4.6 172.0 8.8 5.8; 5.2 6.4 204.6 7.4; 4.4 5.0 5.6 96.8]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 264.0 │       1.6 │      5.2 │  2.6 │
# │ Hazardous │   4.6 │     172.0 │      8.8 │  5.8 │
# │  Moderate │   5.2 │       6.4 │    204.6 │  7.4 │
# │      Poor │   4.4 │       5.0 │      5.6 │ 96.8 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: DT | PCA outdim: 8
#  Hyperparameters: Dict("max_depth" => 5)
# =====================================================
#  Accuracy (mean)               : 0.9245
#  Accuracy (std)                : 0.0055
#  Error Rate (mean)             : 0.0755
#  Error Rate (std)              : 0.0055
#  Sensitivity/Recall (mean)     : 0.9245
#  Sensitivity/Recall (std)      : 0.0055
#  Specificity (mean)            : 0.9763
#  Specificity (std)             : 0.0034
#  PPV (mean)                    : 0.9242
#  PPV (std)                     : 0.0059
#  NPV (mean)                    : 0.9787
#  NPV (std)                     : 0.0021
#  F1 Score (mean)               : 0.924
#  F1 Score (std)                : 0.0056
#
# Confusion Matrix:
# Float32[264.0 1.6 5.2 2.6; 3.8 173.2 8.4 5.8; 5.0 5.8 205.4 7.4; 4.2 5.0 5.6 97.0]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 264.0 │       1.6 │      5.2 │  2.6 │
# │ Hazardous │   3.8 │     173.2 │      8.4 │  5.8 │
# │  Moderate │   5.0 │       5.8 │    205.4 │  7.4 │
# │      Poor │   4.2 │       5.0 │      5.6 │ 97.0 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: DT | PCA outdim: 6
#  Hyperparameters: Dict("max_depth" => 6)
# =====================================================
#  Accuracy (mean)               : 0.9178
#  Accuracy (std)                : 0.0063
#  Error Rate (mean)             : 0.0822
#  Error Rate (std)              : 0.0063
#  Sensitivity/Recall (mean)     : 0.9178
#  Sensitivity/Recall (std)      : 0.0063
#  Specificity (mean)            : 0.9741
#  Specificity (std)             : 0.0022
#  PPV (mean)                    : 0.9186
#  PPV (std)                     : 0.007
#  NPV (mean)                    : 0.9765
#  NPV (std)                     : 0.0027
#  F1 Score (mean)               : 0.9173
#  F1 Score (std)                : 0.0065
#
# Confusion Matrix:
# Float32[260.8 2.4 5.2 5.0; 4.6 171.0 11.0 4.6; 5.2 5.6 207.4 5.4; 3.4 6.0 7.4 95.0]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 260.8 │       2.4 │      5.2 │  5.0 │
# │ Hazardous │   4.6 │     171.0 │     11.0 │  4.6 │
# │  Moderate │   5.2 │       5.6 │    207.4 │  5.4 │
# │      Poor │   3.4 │       6.0 │      7.4 │ 95.0 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: DT | PCA outdim: 7
#  Hyperparameters: Dict("max_depth" => 6)
# =====================================================
#  Accuracy (mean)               : 0.9183
#  Accuracy (std)                : 0.0044
#  Error Rate (mean)             : 0.0817
#  Error Rate (std)              : 0.0044
#  Sensitivity/Recall (mean)     : 0.9183
#  Sensitivity/Recall (std)      : 0.0044
#  Specificity (mean)            : 0.9744
#  Specificity (std)             : 0.0025
#  PPV (mean)                    : 0.919
#  PPV (std)                     : 0.0055
#  NPV (mean)                    : 0.977
#  NPV (std)                     : 0.0022
#  F1 Score (mean)               : 0.9177
#  F1 Score (std)                : 0.0046
#
# Confusion Matrix:
# Float32[261.2 2.2 5.0 5.0; 4.6 171.2 10.6 4.8; 5.4 5.4 207.4 5.4; 3.6 6.0 7.4 94.8]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 261.2 │       2.2 │      5.0 │  5.0 │
# │ Hazardous │   4.6 │     171.2 │     10.6 │  4.8 │
# │  Moderate │   5.4 │       5.4 │    207.4 │  5.4 │
# │      Poor │   3.6 │       6.0 │      7.4 │ 94.8 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: DT | PCA outdim: 8
#  Hyperparameters: Dict("max_depth" => 6)
# =====================================================
#  Accuracy (mean)               : 0.9213
#  Accuracy (std)                : 0.0049
#  Error Rate (mean)             : 0.0787
#  Error Rate (std)              : 0.0049
#  Sensitivity/Recall (mean)     : 0.9213
#  Sensitivity/Recall (std)      : 0.0049
#  Specificity (mean)            : 0.9761
#  Specificity (std)             : 0.0034
#  PPV (mean)                    : 0.922
#  PPV (std)                     : 0.0054
#  NPV (mean)                    : 0.9776
#  NPV (std)                     : 0.0025
#  F1 Score (mean)               : 0.921
#  F1 Score (std)                : 0.005
#
# Confusion Matrix:
# Float32[262.8 1.2 4.4 5.0; 4.2 171.6 10.6 4.8; 5.4 4.6 206.8 6.8; 3.4 6.0 6.6 95.8]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 262.8 │       1.2 │      4.4 │  5.0 │
# │ Hazardous │   4.2 │     171.6 │     10.6 │  4.8 │
# │  Moderate │   5.4 │       4.6 │    206.8 │  6.8 │
# │      Poor │   3.4 │       6.0 │      6.6 │ 95.8 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: DT | PCA outdim: 6
#  Hyperparameters: Dict("max_depth" => 8)
# =====================================================
#  Accuracy (mean)               : 0.9188
#  Accuracy (std)                : 0.0069
#  Error Rate (mean)             : 0.0812
#  Error Rate (std)              : 0.0069
#  Sensitivity/Recall (mean)     : 0.9188
#  Sensitivity/Recall (std)      : 0.0069
#  Specificity (mean)            : 0.9737
#  Specificity (std)             : 0.0029
#  PPV (mean)                    : 0.9187
#  PPV (std)                     : 0.0071
#  NPV (mean)                    : 0.9766
#  NPV (std)                     : 0.003
#  F1 Score (mean)               : 0.9183
#  F1 Score (std)                : 0.0068
#
# Confusion Matrix:
# Float32[262.2 2.6 5.4 3.2; 3.8 172.0 10.6 4.8; 5.4 6.8 204.8 6.6; 4.6 5.2 6.0 96.0]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 262.2 │       2.6 │      5.4 │  3.2 │
# │ Hazardous │   3.8 │     172.0 │     10.6 │  4.8 │
# │  Moderate │   5.4 │       6.8 │    204.8 │  6.6 │
# │      Poor │   4.6 │       5.2 │      6.0 │ 96.0 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: DT | PCA outdim: 7
#  Hyperparameters: Dict("max_depth" => 8)
# =====================================================
#  Accuracy (mean)               : 0.9183
#  Accuracy (std)                : 0.012
#  Error Rate (mean)             : 0.0817
#  Error Rate (std)              : 0.012
#  Sensitivity/Recall (mean)     : 0.9183
#  Sensitivity/Recall (std)      : 0.012
#  Specificity (mean)            : 0.9737
#  Specificity (std)             : 0.0042
#  PPV (mean)                    : 0.9186
#  PPV (std)                     : 0.0114
#  NPV (mean)                    : 0.9769
#  NPV (std)                     : 0.0048
#  F1 Score (mean)               : 0.9178
#  F1 Score (std)                : 0.0116
#
# Confusion Matrix:
# Float32[262.8 2.2 4.8 3.6; 3.6 174.2 10.0 3.4; 7.6 5.8 203.4 6.8; 5.0 6.2 6.4 94.2]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 262.8 │       2.2 │      4.8 │  3.6 │
# │ Hazardous │   3.6 │     174.2 │     10.0 │  3.4 │
# │  Moderate │   7.6 │       5.8 │    203.4 │  6.8 │
# │      Poor │   5.0 │       6.2 │      6.4 │ 94.2 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: DT | PCA outdim: 8
#  Hyperparameters: Dict("max_depth" => 8)
# =====================================================
#  Accuracy (mean)               : 0.9225
#  Accuracy (std)                : 0.0084
#  Error Rate (mean)             : 0.0775
#  Error Rate (std)              : 0.0084
#  Sensitivity/Recall (mean)     : 0.9225
#  Sensitivity/Recall (std)      : 0.0084
#  Specificity (mean)            : 0.975
#  Specificity (std)             : 0.0051
#  PPV (mean)                    : 0.9224
#  PPV (std)                     : 0.0086
#  NPV (mean)                    : 0.9782
#  NPV (std)                     : 0.0034
#  F1 Score (mean)               : 0.922
#  F1 Score (std)                : 0.0085
#
# Confusion Matrix:
# Float32[263.6 1.8 4.4 3.6; 4.0 173.6 10.2 3.4; 5.2 5.4 206.2 6.8; 4.8 6.2 6.2 94.6]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 263.6 │       1.8 │      4.4 │  3.6 │
# │ Hazardous │   4.0 │     173.6 │     10.2 │  3.4 │
# │  Moderate │   5.2 │       5.4 │    206.2 │  6.8 │
# │      Poor │   4.8 │       6.2 │      6.2 │ 94.6 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================

# %%
########################
# 3. DT FINAL TESTING 
########################

# BEST HYPERPARAMETERS
hp = Dict("max_depth"=>5)
dimPCA = 8

# Compute normalization parameters from TRAINING set only
normParams = calculateMinMaxNormalizationParameters(trainingInputs)
train_df = normalizeMinMax(trainingInputs, normParams)
test_df = normalizeMinMax(testInputs, normParams)

pca_model = PCA_model(maxoutdim=dimPCA)
# Train the PCA model
pca_mach = machine(pca_model, MLJ.table(train_df))
MLJ.fit!(pca_mach, verbosity=0)
# Transform the data
train_df = MLJBase.matrix(MLJBase.transform(pca_mach, MLJ.table(train_df)))
test_df  = MLJBase.matrix(MLJBase.transform(pca_mach, MLJ.table(test_df)))

# --- Convert targets ---
train_y_cat = categorical(vec(trainingTargets))
test_y_cat  = categorical(vec(testTargets))

# Load model (insert hyperparameters manually)
model = DTClassifier(max_depth=5, rng=Random.MersenneTwister(1))    

# --- Train machine ---
mach = machine(model, MLJ.table(train_df), train_y_cat)
MLJ.fit!(mach)
    
# --- Predict ---
ŷ = MLJ.predict(mach, MLJ.table(test_df))              # probabilistic predictions
y_pred = CategoricalArray(mode.(ŷ))         # convert to class labels
    
# --- Compute metrics ---
metrics = confusionMatrix(y_pred, test_y_cat)

printPCAResult(:DT, hp, metrics, dimPCA, label_names)
# Out:
# =====================================================
# [ Info: Training machine(DecisionTreeClassifier(max_depth = 5, …), …).
#  Model: DT outdim 8
#  Hyperparameters: Dict("max_depth" => 5)
# =====================================================
#  Accuracy                : 0.903
#  Error Rate              : 0.097
#  Sensitivity/Recall      : 0.903
#  Specificity             : 0.9697
#  PPV                     : 0.9023
#  NPV                     : 0.9724
#  F1 Score                : 0.9023
#
# Confusion Matrix:
# [76 0 0 27; 0 276 4 16; 0 6 377 0; 17 27 0 174]
# =====================================================
#
# ┌───────────┬──────┬───────────┬──────────┬──────┐
# │           │ Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼──────┼───────────┼──────────┼──────┤
# │      Good │   76 │         0 │        0 │   27 │
# │ Hazardous │    0 │       276 │        4 │   16 │
# │  Moderate │    0 │         6 │      377 │    0 │
# │      Poor │   17 │        27 │        0 │  174 │
# └───────────┴──────┴───────────┴──────────┴──────┘

# %% [markdown]
# # K-Nearest Neighbors

# %%
kNNClassifier = MLJ.@load KNNClassifier pkg=NearestNeighborModels verbosity=0
# Out:
# NearestNeighborModels.KNNClassifier

# %%
############# 4. kNN (6 values) #############
knn_search_space = [
    Dict("K"=>1),
    Dict("K"=>3),
    Dict("K"=>5),
    Dict("K"=>7),
    Dict("K"=>9),
    Dict("K"=>11)
]
# Out:
# 6-element Vector{Dict{String, Int64}}:
#  Dict("K" => 1)
#  Dict("K" => 3)
#  Dict("K" => 5)
#  Dict("K" => 7)
#  Dict("K" => 9)
#  Dict("K" => 11)

# %%
########################
# 4. KNN GRID SEARCH
########################
knn_results = []

for hp in knn_search_space
    for dim in dimsPCA
        println("\n=== kNN experiment: K=$(hp["K"]) | PCA maxoutdim = $(dim) ===")
        res = modelCrossValidationPCA(:KNeighborsClassifier, hp, (trainingInputs, trainingTargets), crossValidationIndices, dim)
        push!(knn_results, (model=:KNN, hyperparams=hp, dimPCA=dim, results=res))
    end
end

results[:KNN] = knn_results
# Out:
# === kNN experiment: K=1 | PCA maxoutdim = 6 ===
#
# === kNN experiment: K=1 | PCA maxoutdim = 7 ===
#
# === kNN experiment: K=1 | PCA maxoutdim = 8 ===
#
# === kNN experiment: K=3 | PCA maxoutdim = 6 ===
#
# === kNN experiment: K=3 | PCA maxoutdim = 7 ===
#
# === kNN experiment: K=3 | PCA maxoutdim = 8 ===
#
# === kNN experiment: K=5 | PCA maxoutdim = 6 ===
#
# === kNN experiment: K=5 | PCA maxoutdim = 7 ===
#
# === kNN experiment: K=5 | PCA maxoutdim = 8 ===
#
# === kNN experiment: K=7 | PCA maxoutdim = 6 ===
#
# === kNN experiment: K=7 | PCA maxoutdim = 7 ===
#
# === kNN experiment: K=7 | PCA maxoutdim = 8 ===
#
# === kNN experiment: K=9 | PCA maxoutdim = 6 ===
#
# === kNN experiment: K=9 | PCA maxoutdim = 7 ===
#
# === kNN experiment: K=9 | PCA maxoutdim = 8 ===
#
# === kNN experiment: K=11 | PCA maxoutdim = 6 ===
#
# === kNN experiment: K=11 | PCA maxoutdim = 7 ===
#
# === kNN experiment: K=11 | PCA maxoutdim = 8 ===
# 18-element Vector{Any}:
#  (model = :KNN, hyperparams = Dict("K" => 1), dimPCA = 6, results = ((0.9144928f0, 0.014752504f0), (0.08550726f0, 0.014752496f0), (0.9144928f0, 0.014752504f0), (0.97475255f0, 0.0050279847f0), (0.91425735f0, 0.014948676f0), (0.97718126f0, 0.0047332426f0), (0.914081f0, 0.014821795f0), Float32[262.4 1.6 5.0 4.4; 2.6 173.8 10.0 4.8; 4.2 8.6 201.8 9.0; 5.0 6.6 6.6 93.6]))
#  (model = :KNN, hyperparams = Dict("K" => 1), dimPCA = 7, results = ((0.91949683f0, 0.012265669f0), (0.080503166f0, 0.0122656645f0), (0.91949683f0, 0.012265669f0), (0.97496843f0, 0.0050757597f0), (0.91841316f0, 0.012384645f0), (0.9790126f0, 0.0044209934f0), (0.91873264f0, 0.012305275f0), Float32[264.2 0.8 5.6 2.8; 3.2 173.0 10.2 4.8; 5.0 7.0 204.2 7.4; 4.4 7.2 6.0 94.2]))
#  (model = :KNN, hyperparams = Dict("K" => 1), dimPCA = 8, results = ((0.91624653f0, 0.011937856f0), (0.0837535f0, 0.011937853f0), (0.91624653f0, 0.011937856f0), (0.97444886f0, 0.0040559336f0), (0.91527414f0, 0.011805885f0), (0.979064f0, 0.003963913f0), (0.91533023f0, 0.011725778f0), Float32[264.2 0.8 5.6 2.8; 3.6 171.6 11.8 4.2; 4.6 7.0 203.6 8.4; 4.6 6.6 7.0 93.6]))
#  (model = :KNN, hyperparams = Dict("K" => 3), dimPCA = 6, results = ((0.931999f0, 0.0093283f0), (0.06800093f0, 0.009328306f0), (0.931999f0, 0.0093283f0), (0.97841024f0, 0.003749694f0), (0.9310951f0, 0.009370893f0), (0.98392916f0, 0.003847738f0), (0.93098223f0, 0.009214277f0), Float32[266.2 0.2 3.8 3.2; 3.8 176.0 8.2 3.2; 2.4 7.0 207.8 6.4; 4.0 7.0 5.2 95.6]))
#  (model = :KNN, hyperparams = Dict("K" => 3), dimPCA = 7, results = ((0.92925817f0, 0.0067694974f0), (0.07074187f0, 0.006769506f0), (0.92925817f0, 0.0067694974f0), (0.9774315f0, 0.0032386682f0), (0.9283322f0, 0.006631399f0), (0.9833581f0, 0.003247212f0), (0.9281311f0, 0.0065639378f0), Float32[266.8 0.2 4.6 1.8; 3.6 175.2 8.4 4.0; 3.6 6.6 208.4 5.0; 4.6 8.0 6.2 93.0]))
#  (model = :KNN, hyperparams = Dict("K" => 3), dimPCA = 8, results = ((0.92925227f0, 0.005166109f0), (0.07074781f0, 0.005166099f0), (0.92925227f0, 0.005166109f0), (0.97755414f0, 0.002817924f0), (0.9280798f0, 0.00536529f0), (0.983888f0, 0.0022931844f0), (0.9279769f0, 0.0052049565f0), Float32[267.4 0.2 4.4 1.4; 3.6 174.2 9.2 4.2; 2.6 6.6 208.0 6.4; 4.6 8.4 5.0 93.8]))
#  (model = :KNN, hyperparams = Dict("K" => 5), dimPCA = 6, results = ((0.9319931f0, 0.0076942667f0), (0.06800686f0, 0.007694269f0), (0.9319931f0, 0.0076942667f0), (0.9777045f0, 0.0031092593f0), (0.93133557f0, 0.008162402f0), (0.9841213f0, 0.0030387652f0), (0.9308095f0, 0.007729141f0), Float32[266.6 0.0 4.4 2.4; 4.0 175.8 8.4 3.0; 2.4 6.6 208.2 6.4; 3.6 7.4 5.8 95.0]))
#  (model = :KNN, hyperparams = Dict("K" => 5), dimPCA = 7, results = ((0.9340081f0, 0.0068173925f0), (0.065991856f0, 0.006817386f0), (0.9340081f0, 0.0068173925f0), (0.97817594f0, 0.0029283487f0), (0.93294203f0, 0.0074463207f0), (0.9851923f0, 0.0024744866f0), (0.9327176f0, 0.006954269f0), Float32[266.2 0.4 5.2 1.6; 4.4 175.8 7.2 3.8; 2.2 5.8 210.2 5.4; 4.4 7.2 5.2 95.0]))
#  (model = :KNN, hyperparams = Dict("K" => 5), dimPCA = 8, results = ((0.93350184f0, 0.0031797828f0), (0.06649811f0, 0.0031797742f0), (0.93350184f0, 0.0031797828f0), (0.9779388f0, 0.0022192881f0), (0.9324468f0, 0.0030635449f0), (0.98541385f0, 0.0017298243f0), (0.9320866f0, 0.0030427764f0), Float32[267.6 0.0 4.8 1.0; 4.4 175.0 8.4 3.4; 2.0 5.6 209.2 6.8; 4.6 7.4 4.8 95.0]))
#  (model = :KNN, hyperparams = Dict("K" => 7), dimPCA = 6, results = ((0.9322504f0, 0.011026297f0), (0.067749664f0, 0.011026286f0), (0.9322504f0, 0.011026297f0), (0.9772531f0, 0.00448325f0), (0.9316431f0, 0.011284549f0), (0.984238f0, 0.004257103f0), (0.9310075f0, 0.011042091f0), Float32[265.6 0.0 5.2 2.6; 3.8 177.0 8.0 2.4; 2.8 6.4 207.8 6.6; 4.0 7.4 5.0 95.4]))
#  (model = :KNN, hyperparams = Dict("K" => 7), dimPCA = 7, results = ((0.9315109f0, 0.008786598f0), (0.06848906f0, 0.008786611f0), (0.9315109f0, 0.008786598f0), (0.97744215f0, 0.003961235f0), (0.9303986f0, 0.00948386f0), (0.9846422f0, 0.0031609172f0), (0.93012697f0, 0.00897147f0), Float32[265.8 0.4 5.8 1.4; 4.0 176.4 7.2 3.6; 2.2 5.8 209.4 6.2; 4.4 8.2 5.6 93.6]))
#  (model = :KNN, hyperparams = Dict("K" => 7), dimPCA = 8, results = ((0.933255f0, 0.0046339673f0), (0.06674499f0, 0.004633972f0), (0.933255f0, 0.0046339673f0), (0.97783375f0, 0.0025503815f0), (0.93211305f0, 0.0049433517f0), (0.98524916f0, 0.0019878051f0), (0.9318012f0, 0.0047940793f0), Float32[267.2 0.0 5.0 1.2; 4.6 175.4 7.4 3.8; 2.0 6.6 209.2 5.8; 4.4 7.4 5.2 94.8]))
#  (model = :KNN, hyperparams = Dict("K" => 9), dimPCA = 6, results = ((0.93375254f0, 0.0077205026f0), (0.06624748f0, 0.00772049f0), (0.93375254f0, 0.0077205026f0), (0.97741f0, 0.00428309f0), (0.93314725f0, 0.007797127f0), (0.9847838f0, 0.0036655334f0), (0.93245476f0, 0.0076404996f0), Float32[266.0 0.0 5.4 2.0; 3.8 177.6 7.6 2.2; 2.0 6.6 209.0 6.0; 4.2 7.6 5.6 94.4]))
#  (model = :KNN, hyperparams = Dict("K" => 9), dimPCA = 7, results = ((0.9310068f0, 0.008086969f0), (0.06899313f0, 0.008086977f0), (0.9310068f0, 0.008086969f0), (0.9768565f0, 0.0040822257f0), (0.93004113f0, 0.008633372f0), (0.98455983f0, 0.0031918972f0), (0.929554f0, 0.008265615f0), Float32[266.0 0.2 6.0 1.2; 3.8 176.8 7.4 3.2; 2.0 6.6 208.8 6.2; 4.2 8.6 5.8 93.2]))
#  (model = :KNN, hyperparams = Dict("K" => 9), dimPCA = 8, results = ((0.93175125f0, 0.0025405013f0), (0.068248734f0, 0.0025405055f0), (0.93175125f0, 0.0025405013f0), (0.97712696f0, 0.0019232007f0), (0.9309851f0, 0.0026661044f0), (0.9849125f0, 0.0017417093f0), (0.9302782f0, 0.0023271958f0), Float32[267.4 0.0 4.8 1.2; 4.4 175.2 8.6 3.0; 2.6 6.4 208.6 6.0; 4.6 8.0 5.0 94.2]))
#  (model = :KNN, hyperparams = Dict("K" => 11), dimPCA = 6, results = ((0.9320015f0, 0.006194441f0), (0.067998424f0, 0.006194435f0), (0.9320015f0, 0.006194441f0), (0.97662127f0, 0.0035723562f0), (0.93152034f0, 0.0061536194f0), (0.9845974f0, 0.0028265102f0), (0.93059045f0, 0.0061354465f0), Float32[266.4 0.0 5.4 1.6; 4.0 176.8 8.2 2.2; 2.2 6.6 208.4 6.4; 4.6 7.8 5.4 94.0]))
#  (model = :KNN, hyperparams = Dict("K" => 11), dimPCA = 7, results = ((0.9309994f0, 0.004629247f0), (0.06900062f0, 0.0046292446f0), (0.9309994f0, 0.004629247f0), (0.9762329f0, 0.002935392f0), (0.93066454f0, 0.0045794533f0), (0.98445785f0, 0.0021415488f0), (0.92957956f0, 0.004535333f0), Float32[267.8 0.0 5.2 0.4; 4.2 175.4 8.8 2.8; 2.4 6.6 208.8 5.8; 5.2 8.4 5.4 92.8]))
#  (model = :KNN, hyperparams = Dict("K" => 11), dimPCA = 8, results = ((0.9302498f0, 0.0042704702f0), (0.0697503f0, 0.0042704633f0), (0.9302498f0, 0.0042704702f0), (0.9757288f0, 0.0027615519f0), (0.9298519f0, 0.004288784f0), (0.98430026f0, 0.0020481246f0), (0.92872685f0, 0.0041814465f0), Float32[267.4 0.0 5.2 0.8; 5.0 173.8 9.6 2.8; 2.8 6.2 208.8 5.8; 5.2 7.6 4.8 94.2]))

# %%
for entry in results[:KNN]
    printExperimentResult(entry.model, entry.hyperparams, entry.dimPCA, entry.results, label_names)
end
# Out:
# =====================================================
#  Model: KNN | PCA outdim: 6
#  Hyperparameters: Dict("K" => 1)
# =====================================================
#  Accuracy (mean)               : 0.9145
#  Accuracy (std)                : 0.0148
#  Error Rate (mean)             : 0.0855
#  Error Rate (std)              : 0.0148
#  Sensitivity/Recall (mean)     : 0.9145
#  Sensitivity/Recall (std)      : 0.0148
#  Specificity (mean)            : 0.9748
#  Specificity (std)             : 0.005
#  PPV (mean)                    : 0.9143
#  PPV (std)                     : 0.0149
#  NPV (mean)                    : 0.9772
#  NPV (std)                     : 0.0047
#  F1 Score (mean)               : 0.9141
#  F1 Score (std)                : 0.0148
#
# Confusion Matrix:
# Float32[262.4 1.6 5.0 4.4; 2.6 173.8 10.0 4.8; 4.2 8.6 201.8 9.0; 5.0 6.6 6.6 93.6]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 262.4 │       1.6 │      5.0 │  4.4 │
# │ Hazardous │   2.6 │     173.8 │     10.0 │  4.8 │
# │  Moderate │   4.2 │       8.6 │    201.8 │  9.0 │
# │      Poor │   5.0 │       6.6 │      6.6 │ 93.6 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN | PCA outdim: 7
#  Hyperparameters: Dict("K" => 1)
# =====================================================
#  Accuracy (mean)               : 0.9195
#  Accuracy (std)                : 0.0123
#  Error Rate (mean)             : 0.0805
#  Error Rate (std)              : 0.0123
#  Sensitivity/Recall (mean)     : 0.9195
#  Sensitivity/Recall (std)      : 0.0123
#  Specificity (mean)            : 0.975
#  Specificity (std)             : 0.0051
#  PPV (mean)                    : 0.9184
#  PPV (std)                     : 0.0124
#  NPV (mean)                    : 0.979
#  NPV (std)                     : 0.0044
#  F1 Score (mean)               : 0.9187
#  F1 Score (std)                : 0.0123
#
# Confusion Matrix:
# Float32[264.2 0.8 5.6 2.8; 3.2 173.0 10.2 4.8; 5.0 7.0 204.2 7.4; 4.4 7.2 6.0 94.2]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 264.2 │       0.8 │      5.6 │  2.8 │
# │ Hazardous │   3.2 │     173.0 │     10.2 │  4.8 │
# │  Moderate │   5.0 │       7.0 │    204.2 │  7.4 │
# │      Poor │   4.4 │       7.2 │      6.0 │ 94.2 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN | PCA outdim: 8
#  Hyperparameters: Dict("K" => 1)
# =====================================================
#  Accuracy (mean)               : 0.9162
#  Accuracy (std)                : 0.0119
#  Error Rate (mean)             : 0.0838
#  Error Rate (std)              : 0.0119
#  Sensitivity/Recall (mean)     : 0.9162
#  Sensitivity/Recall (std)      : 0.0119
#  Specificity (mean)            : 0.9744
#  Specificity (std)             : 0.0041
#  PPV (mean)                    : 0.9153
#  PPV (std)                     : 0.0118
#  NPV (mean)                    : 0.9791
#  NPV (std)                     : 0.004
#  F1 Score (mean)               : 0.9153
#  F1 Score (std)                : 0.0117
#
# Confusion Matrix:
# Float32[264.2 0.8 5.6 2.8; 3.6 171.6 11.8 4.2; 4.6 7.0 203.6 8.4; 4.6 6.6 7.0 93.6]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 264.2 │       0.8 │      5.6 │  2.8 │
# │ Hazardous │   3.6 │     171.6 │     11.8 │  4.2 │
# │  Moderate │   4.6 │       7.0 │    203.6 │  8.4 │
# │      Poor │   4.6 │       6.6 │      7.0 │ 93.6 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN | PCA outdim: 6
#  Hyperparameters: Dict("K" => 3)
# =====================================================
#  Accuracy (mean)               : 0.932
#  Accuracy (std)                : 0.0093
#  Error Rate (mean)             : 0.068
#  Error Rate (std)              : 0.0093
#  Sensitivity/Recall (mean)     : 0.932
#  Sensitivity/Recall (std)      : 0.0093
#  Specificity (mean)            : 0.9784
#  Specificity (std)             : 0.0037
#  PPV (mean)                    : 0.9311
#  PPV (std)                     : 0.0094
#  NPV (mean)                    : 0.9839
#  NPV (std)                     : 0.0038
#  F1 Score (mean)               : 0.931
#  F1 Score (std)                : 0.0092
#
# Confusion Matrix:
# Float32[266.2 0.2 3.8 3.2; 3.8 176.0 8.2 3.2; 2.4 7.0 207.8 6.4; 4.0 7.0 5.2 95.6]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 266.2 │       0.2 │      3.8 │  3.2 │
# │ Hazardous │   3.8 │     176.0 │      8.2 │  3.2 │
# │  Moderate │   2.4 │       7.0 │    207.8 │  6.4 │
# │      Poor │   4.0 │       7.0 │      5.2 │ 95.6 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN | PCA outdim: 7
#  Hyperparameters: Dict("K" => 3)
# =====================================================
#  Accuracy (mean)               : 0.9293
#  Accuracy (std)                : 0.0068
#  Error Rate (mean)             : 0.0707
#  Error Rate (std)              : 0.0068
#  Sensitivity/Recall (mean)     : 0.9293
#  Sensitivity/Recall (std)      : 0.0068
#  Specificity (mean)            : 0.9774
#  Specificity (std)             : 0.0032
#  PPV (mean)                    : 0.9283
#  PPV (std)                     : 0.0066
#  NPV (mean)                    : 0.9834
#  NPV (std)                     : 0.0032
#  F1 Score (mean)               : 0.9281
#  F1 Score (std)                : 0.0066
#
# Confusion Matrix:
# Float32[266.8 0.2 4.6 1.8; 3.6 175.2 8.4 4.0; 3.6 6.6 208.4 5.0; 4.6 8.0 6.2 93.0]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 266.8 │       0.2 │      4.6 │  1.8 │
# │ Hazardous │   3.6 │     175.2 │      8.4 │  4.0 │
# │  Moderate │   3.6 │       6.6 │    208.4 │  5.0 │
# │      Poor │   4.6 │       8.0 │      6.2 │ 93.0 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN | PCA outdim: 8
#  Hyperparameters: Dict("K" => 3)
# =====================================================
#  Accuracy (mean)               : 0.9293
#  Accuracy (std)                : 0.0052
#  Error Rate (mean)             : 0.0707
#  Error Rate (std)              : 0.0052
#  Sensitivity/Recall (mean)     : 0.9293
#  Sensitivity/Recall (std)      : 0.0052
#  Specificity (mean)            : 0.9776
#  Specificity (std)             : 0.0028
#  PPV (mean)                    : 0.9281
#  PPV (std)                     : 0.0054
#  NPV (mean)                    : 0.9839
#  NPV (std)                     : 0.0023
#  F1 Score (mean)               : 0.928
#  F1 Score (std)                : 0.0052
#
# Confusion Matrix:
# Float32[267.4 0.2 4.4 1.4; 3.6 174.2 9.2 4.2; 2.6 6.6 208.0 6.4; 4.6 8.4 5.0 93.8]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 267.4 │       0.2 │      4.4 │  1.4 │
# │ Hazardous │   3.6 │     174.2 │      9.2 │  4.2 │
# │  Moderate │   2.6 │       6.6 │    208.0 │  6.4 │
# │      Poor │   4.6 │       8.4 │      5.0 │ 93.8 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN | PCA outdim: 6
#  Hyperparameters: Dict("K" => 5)
# =====================================================
#  Accuracy (mean)               : 0.932
#  Accuracy (std)                : 0.0077
#  Error Rate (mean)             : 0.068
#  Error Rate (std)              : 0.0077
#  Sensitivity/Recall (mean)     : 0.932
#  Sensitivity/Recall (std)      : 0.0077
#  Specificity (mean)            : 0.9777
#  Specificity (std)             : 0.0031
#  PPV (mean)                    : 0.9313
#  PPV (std)                     : 0.0082
#  NPV (mean)                    : 0.9841
#  NPV (std)                     : 0.003
#  F1 Score (mean)               : 0.9308
#  F1 Score (std)                : 0.0077
#
# Confusion Matrix:
# Float32[266.6 0.0 4.4 2.4; 4.0 175.8 8.4 3.0; 2.4 6.6 208.2 6.4; 3.6 7.4 5.8 95.0]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 266.6 │       0.0 │      4.4 │  2.4 │
# │ Hazardous │   4.0 │     175.8 │      8.4 │  3.0 │
# │  Moderate │   2.4 │       6.6 │    208.2 │  6.4 │
# │      Poor │   3.6 │       7.4 │      5.8 │ 95.0 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN | PCA outdim: 7
#  Hyperparameters: Dict("K" => 5)
# =====================================================
#  Accuracy (mean)               : 0.934
#  Accuracy (std)                : 0.0068
#  Error Rate (mean)             : 0.066
#  Error Rate (std)              : 0.0068
#  Sensitivity/Recall (mean)     : 0.934
#  Sensitivity/Recall (std)      : 0.0068
#  Specificity (mean)            : 0.9782
#  Specificity (std)             : 0.0029
#  PPV (mean)                    : 0.9329
#  PPV (std)                     : 0.0074
#  NPV (mean)                    : 0.9852
#  NPV (std)                     : 0.0025
#  F1 Score (mean)               : 0.9327
#  F1 Score (std)                : 0.007
#
# Confusion Matrix:
# Float32[266.2 0.4 5.2 1.6; 4.4 175.8 7.2 3.8; 2.2 5.8 210.2 5.4; 4.4 7.2 5.2 95.0]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 266.2 │       0.4 │      5.2 │  1.6 │
# │ Hazardous │   4.4 │     175.8 │      7.2 │  3.8 │
# │  Moderate │   2.2 │       5.8 │    210.2 │  5.4 │
# │      Poor │   4.4 │       7.2 │      5.2 │ 95.0 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN | PCA outdim: 8
#  Hyperparameters: Dict("K" => 5)
# =====================================================
#  Accuracy (mean)               : 0.9335
#  Accuracy (std)                : 0.0032
#  Error Rate (mean)             : 0.0665
#  Error Rate (std)              : 0.0032
#  Sensitivity/Recall (mean)     : 0.9335
#  Sensitivity/Recall (std)      : 0.0032
#  Specificity (mean)            : 0.9779
#  Specificity (std)             : 0.0022
#  PPV (mean)                    : 0.9324
#  PPV (std)                     : 0.0031
#  NPV (mean)                    : 0.9854
#  NPV (std)                     : 0.0017
#  F1 Score (mean)               : 0.9321
#  F1 Score (std)                : 0.003
#
# Confusion Matrix:
# Float32[267.6 0.0 4.8 1.0; 4.4 175.0 8.4 3.4; 2.0 5.6 209.2 6.8; 4.6 7.4 4.8 95.0]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 267.6 │       0.0 │      4.8 │  1.0 │
# │ Hazardous │   4.4 │     175.0 │      8.4 │  3.4 │
# │  Moderate │   2.0 │       5.6 │    209.2 │  6.8 │
# │      Poor │   4.6 │       7.4 │      4.8 │ 95.0 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN | PCA outdim: 6
#  Hyperparameters: Dict("K" => 7)
# =====================================================
#  Accuracy (mean)               : 0.9323
#  Accuracy (std)                : 0.011
#  Error Rate (mean)             : 0.0677
#  Error Rate (std)              : 0.011
#  Sensitivity/Recall (mean)     : 0.9323
#  Sensitivity/Recall (std)      : 0.011
#  Specificity (mean)            : 0.9773
#  Specificity (std)             : 0.0045
#  PPV (mean)                    : 0.9316
#  PPV (std)                     : 0.0113
#  NPV (mean)                    : 0.9842
#  NPV (std)                     : 0.0043
#  F1 Score (mean)               : 0.931
#  F1 Score (std)                : 0.011
#
# Confusion Matrix:
# Float32[265.6 0.0 5.2 2.6; 3.8 177.0 8.0 2.4; 2.8 6.4 207.8 6.6; 4.0 7.4 5.0 95.4]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 265.6 │       0.0 │      5.2 │  2.6 │
# │ Hazardous │   3.8 │     177.0 │      8.0 │  2.4 │
# │  Moderate │   2.8 │       6.4 │    207.8 │  6.6 │
# │      Poor │   4.0 │       7.4 │      5.0 │ 95.4 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN | PCA outdim: 7
#  Hyperparameters: Dict("K" => 7)
# =====================================================
#  Accuracy (mean)               : 0.9315
#  Accuracy (std)                : 0.0088
#  Error Rate (mean)             : 0.0685
#  Error Rate (std)              : 0.0088
#  Sensitivity/Recall (mean)     : 0.9315
#  Sensitivity/Recall (std)      : 0.0088
#  Specificity (mean)            : 0.9774
#  Specificity (std)             : 0.004
#  PPV (mean)                    : 0.9304
#  PPV (std)                     : 0.0095
#  NPV (mean)                    : 0.9846
#  NPV (std)                     : 0.0032
#  F1 Score (mean)               : 0.9301
#  F1 Score (std)                : 0.009
#
# Confusion Matrix:
# Float32[265.8 0.4 5.8 1.4; 4.0 176.4 7.2 3.6; 2.2 5.8 209.4 6.2; 4.4 8.2 5.6 93.6]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 265.8 │       0.4 │      5.8 │  1.4 │
# │ Hazardous │   4.0 │     176.4 │      7.2 │  3.6 │
# │  Moderate │   2.2 │       5.8 │    209.4 │  6.2 │
# │      Poor │   4.4 │       8.2 │      5.6 │ 93.6 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN | PCA outdim: 8
#  Hyperparameters: Dict("K" => 7)
# =====================================================
#  Accuracy (mean)               : 0.9333
#  Accuracy (std)                : 0.0046
#  Error Rate (mean)             : 0.0667
#  Error Rate (std)              : 0.0046
#  Sensitivity/Recall (mean)     : 0.9333
#  Sensitivity/Recall (std)      : 0.0046
#  Specificity (mean)            : 0.9778
#  Specificity (std)             : 0.0026
#  PPV (mean)                    : 0.9321
#  PPV (std)                     : 0.0049
#  NPV (mean)                    : 0.9852
#  NPV (std)                     : 0.002
#  F1 Score (mean)               : 0.9318
#  F1 Score (std)                : 0.0048
#
# Confusion Matrix:
# Float32[267.2 0.0 5.0 1.2; 4.6 175.4 7.4 3.8; 2.0 6.6 209.2 5.8; 4.4 7.4 5.2 94.8]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 267.2 │       0.0 │      5.0 │  1.2 │
# │ Hazardous │   4.6 │     175.4 │      7.4 │  3.8 │
# │  Moderate │   2.0 │       6.6 │    209.2 │  5.8 │
# │      Poor │   4.4 │       7.4 │      5.2 │ 94.8 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN | PCA outdim: 6
#  Hyperparameters: Dict("K" => 9)
# =====================================================
#  Accuracy (mean)               : 0.9338
#  Accuracy (std)                : 0.0077
#  Error Rate (mean)             : 0.0662
#  Error Rate (std)              : 0.0077
#  Sensitivity/Recall (mean)     : 0.9338
#  Sensitivity/Recall (std)      : 0.0077
#  Specificity (mean)            : 0.9774
#  Specificity (std)             : 0.0043
#  PPV (mean)                    : 0.9331
#  PPV (std)                     : 0.0078
#  NPV (mean)                    : 0.9848
#  NPV (std)                     : 0.0037
#  F1 Score (mean)               : 0.9325
#  F1 Score (std)                : 0.0076
#
# Confusion Matrix:
# Float32[266.0 0.0 5.4 2.0; 3.8 177.6 7.6 2.2; 2.0 6.6 209.0 6.0; 4.2 7.6 5.6 94.4]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 266.0 │       0.0 │      5.4 │  2.0 │
# │ Hazardous │   3.8 │     177.6 │      7.6 │  2.2 │
# │  Moderate │   2.0 │       6.6 │    209.0 │  6.0 │
# │      Poor │   4.2 │       7.6 │      5.6 │ 94.4 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN | PCA outdim: 7
#  Hyperparameters: Dict("K" => 9)
# =====================================================
#  Accuracy (mean)               : 0.931
#  Accuracy (std)                : 0.0081
#  Error Rate (mean)             : 0.069
#  Error Rate (std)              : 0.0081
#  Sensitivity/Recall (mean)     : 0.931
#  Sensitivity/Recall (std)      : 0.0081
#  Specificity (mean)            : 0.9769
#  Specificity (std)             : 0.0041
#  PPV (mean)                    : 0.93
#  PPV (std)                     : 0.0086
#  NPV (mean)                    : 0.9846
#  NPV (std)                     : 0.0032
#  F1 Score (mean)               : 0.9296
#  F1 Score (std)                : 0.0083
#
# Confusion Matrix:
# Float32[266.0 0.2 6.0 1.2; 3.8 176.8 7.4 3.2; 2.0 6.6 208.8 6.2; 4.2 8.6 5.8 93.2]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 266.0 │       0.2 │      6.0 │  1.2 │
# │ Hazardous │   3.8 │     176.8 │      7.4 │  3.2 │
# │  Moderate │   2.0 │       6.6 │    208.8 │  6.2 │
# │      Poor │   4.2 │       8.6 │      5.8 │ 93.2 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN | PCA outdim: 8
#  Hyperparameters: Dict("K" => 9)
# =====================================================
#  Accuracy (mean)               : 0.9318
#  Accuracy (std)                : 0.0025
#  Error Rate (mean)             : 0.0682
#  Error Rate (std)              : 0.0025
#  Sensitivity/Recall (mean)     : 0.9318
#  Sensitivity/Recall (std)      : 0.0025
#  Specificity (mean)            : 0.9771
#  Specificity (std)             : 0.0019
#  PPV (mean)                    : 0.931
#  PPV (std)                     : 0.0027
#  NPV (mean)                    : 0.9849
#  NPV (std)                     : 0.0017
#  F1 Score (mean)               : 0.9303
#  F1 Score (std)                : 0.0023
#
# Confusion Matrix:
# Float32[267.4 0.0 4.8 1.2; 4.4 175.2 8.6 3.0; 2.6 6.4 208.6 6.0; 4.6 8.0 5.0 94.2]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 267.4 │       0.0 │      4.8 │  1.2 │
# │ Hazardous │   4.4 │     175.2 │      8.6 │  3.0 │
# │  Moderate │   2.6 │       6.4 │    208.6 │  6.0 │
# │      Poor │   4.6 │       8.0 │      5.0 │ 94.2 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN | PCA outdim: 6
#  Hyperparameters: Dict("K" => 11)
# =====================================================
#  Accuracy (mean)               : 0.932
#  Accuracy (std)                : 0.0062
#  Error Rate (mean)             : 0.068
#  Error Rate (std)              : 0.0062
#  Sensitivity/Recall (mean)     : 0.932
#  Sensitivity/Recall (std)      : 0.0062
#  Specificity (mean)            : 0.9766
#  Specificity (std)             : 0.0036
#  PPV (mean)                    : 0.9315
#  PPV (std)                     : 0.0062
#  NPV (mean)                    : 0.9846
#  NPV (std)                     : 0.0028
#  F1 Score (mean)               : 0.9306
#  F1 Score (std)                : 0.0061
#
# Confusion Matrix:
# Float32[266.4 0.0 5.4 1.6; 4.0 176.8 8.2 2.2; 2.2 6.6 208.4 6.4; 4.6 7.8 5.4 94.0]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 266.4 │       0.0 │      5.4 │  1.6 │
# │ Hazardous │   4.0 │     176.8 │      8.2 │  2.2 │
# │  Moderate │   2.2 │       6.6 │    208.4 │  6.4 │
# │      Poor │   4.6 │       7.8 │      5.4 │ 94.0 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN | PCA outdim: 7
#  Hyperparameters: Dict("K" => 11)
# =====================================================
#  Accuracy (mean)               : 0.931
#  Accuracy (std)                : 0.0046
#  Error Rate (mean)             : 0.069
#  Error Rate (std)              : 0.0046
#  Sensitivity/Recall (mean)     : 0.931
#  Sensitivity/Recall (std)      : 0.0046
#  Specificity (mean)            : 0.9762
#  Specificity (std)             : 0.0029
#  PPV (mean)                    : 0.9307
#  PPV (std)                     : 0.0046
#  NPV (mean)                    : 0.9845
#  NPV (std)                     : 0.0021
#  F1 Score (mean)               : 0.9296
#  F1 Score (std)                : 0.0045
#
# Confusion Matrix:
# Float32[267.8 0.0 5.2 0.4; 4.2 175.4 8.8 2.8; 2.4 6.6 208.8 5.8; 5.2 8.4 5.4 92.8]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 267.8 │       0.0 │      5.2 │  0.4 │
# │ Hazardous │   4.2 │     175.4 │      8.8 │  2.8 │
# │  Moderate │   2.4 │       6.6 │    208.8 │  5.8 │
# │      Poor │   5.2 │       8.4 │      5.4 │ 92.8 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================
#
#
# =====================================================
#  Model: KNN | PCA outdim: 8
#  Hyperparameters: Dict("K" => 11)
# =====================================================
#  Accuracy (mean)               : 0.9302
#  Accuracy (std)                : 0.0043
#  Error Rate (mean)             : 0.0698
#  Error Rate (std)              : 0.0043
#  Sensitivity/Recall (mean)     : 0.9302
#  Sensitivity/Recall (std)      : 0.0043
#  Specificity (mean)            : 0.9757
#  Specificity (std)             : 0.0028
#  PPV (mean)                    : 0.9299
#  PPV (std)                     : 0.0043
#  NPV (mean)                    : 0.9843
#  NPV (std)                     : 0.002
#  F1 Score (mean)               : 0.9287
#  F1 Score (std)                : 0.0042
#
# Confusion Matrix:
# Float32[267.4 0.0 5.2 0.8; 5.0 173.8 9.6 2.8; 2.8 6.2 208.8 5.8; 5.2 7.6 4.8 94.2]
# ┌───────────┬───────┬───────────┬──────────┬──────┐
# │           │  Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼───────┼───────────┼──────────┼──────┤
# │      Good │ 267.4 │       0.0 │      5.2 │  0.8 │
# │ Hazardous │   5.0 │     173.8 │      9.6 │  2.8 │
# │  Moderate │   2.8 │       6.2 │    208.8 │  5.8 │
# │      Poor │   5.2 │       7.6 │      4.8 │ 94.2 │
# └───────────┴───────┴───────────┴──────────┴──────┘
# =====================================================

# %%
########################
# 4. KNN FINAL TESTING 
########################

# BEST HYPERPARAMETERS
hp = Dict("K"=>5)
dimPCA = 7

# Compute normalization parameters from TRAINING set only
normParams = calculateMinMaxNormalizationParameters(trainingInputs)
train_df = normalizeMinMax(trainingInputs, normParams)
test_df = normalizeMinMax(testInputs, normParams)

pca_model = PCA_model(maxoutdim=dimPCA)
# Train the PCA model
pca_mach = machine(pca_model, MLJ.table(train_df))
MLJ.fit!(pca_mach, verbosity=0)
# Transform the data
train_df = MLJBase.matrix(MLJBase.transform(pca_mach, MLJ.table(train_df)))
test_df  = MLJBase.matrix(MLJBase.transform(pca_mach, MLJ.table(test_df)))

# --- Convert targets ---
train_y_cat = categorical(vec(trainingTargets))
test_y_cat  = categorical(vec(testTargets))

# Load model (insert hyperparameters manually)
model = kNNClassifier(K=5)

# --- Train machine ---
mach = machine(model, MLJ.table(train_df), train_y_cat)
MLJ.fit!(mach)
    
# --- Predict ---
ŷ = MLJ.predict(mach, MLJ.table(test_df))              # probabilistic predictions
y_pred = CategoricalArray(mode.(ŷ))         # convert to class labels
    
# --- Compute metrics ---
metrics = confusionMatrix(y_pred, test_y_cat)

printPCAResult(:KNN, hp, metrics, dimPCA, label_names)
# Out:
# =====================================================
#  Model: KNN outdim 7
#  Hyperparameters: Dict("K" => 5)
# =====================================================
#  Accuracy                : 0.912
#  Error Rate              : 0.088
#  Sensitivity/Recall      : 0.912
#  Specificity             : 0.9709
#  PPV                     : 0.9115
#  NPV                     : 0.9779
#  F1 Score                : 0.9105
#
# Confusion Matrix:
# [71 0 0 32; 0 277 7 12; 0 0 383 0; 10 27 0 181]
# =====================================================
#
# ┌───────────┬──────┬───────────┬──────────┬──────┐
# │           │ Good │ Hazardous │ Moderate │ Poor │
# ├───────────┼──────┼───────────┼──────────┼──────┤
# │      Good │   71 │         0 │        0 │   32 │
# │ Hazardous │    0 │       277 │        7 │   12 │
# │  Moderate │    0 │         0 │      383 │    0 │
# │      Poor │   10 │        27 │        0 │  181 │
# └───────────┴──────┴───────────┴──────────┴──────┘
# [ Info: Training machine(KNNClassifier(K = 5, …), …).

# %% [markdown]
# # Stacking Ensemble

# %%
SVMClassifier = @load ProbabilisticSVC pkg=LIBSVM verbosity=0
DTClassifier  = @load DecisionTreeClassifier pkg=DecisionTree verbosity=0
kNNClassifier = @load KNNClassifier pkg=NearestNeighborModels verbosity=0
PCA = MLJ.@load PCA pkg="MultivariateStats" verbosity=0

trainIdx, testIdx = holdOut(size(df,1), 0.2)

trainingInputs  = inputs[trainIdx, :]
testInputs      = inputs[testIdx, :]

trainingTargets = targets[trainIdx]
testTargets     = targets[testIdx]

# X as DataFrame
train_df = DataFrame(trainingInputs, :auto)
test_df  = DataFrame(testInputs, :auto)

# y as categorical
train_y_cat = categorical(trainingTargets)
test_y_cat  = categorical(testTargets)

# ---- Base Models ----
svm_pca = Pipeline(
    pca = PCA(maxoutdim=8),
    model = SVMClassifier(kernel=LIBSVM.Kernel.RadialBasis, cost=1.0, gamma=2.0)
)

dt_pca = Pipeline(
    pca = PCA(maxoutdim=8),
    model = DTClassifier(max_depth=5)
)

knn_pca = Pipeline(
    pca = PCA(maxoutdim=7),
    model = kNNClassifier(K=5)
)

# ---- Stacking Model ----
stack_model = Stack(;
    metalearner = DTClassifier(max_depth=3, rng=Random.MersenneTwister(1)),
    resampling = CV(nfolds=5, shuffle=true, rng=123),
    measure = accuracy, 
    svm = svm_pca,
    knn = knn_pca,
    dt = dt_pca
)

# Train the stacking model on your train dataset
stack_mach = machine(stack_model, train_df, train_y_cat) |> MLJ.fit!

y_pred = mode.(MLJ.predict(stack_mach, test_df))
acc = MLJ.accuracy(y_pred, test_y_cat)
println("Stack ensemble accuracy = $(round(acc*100, digits=2)) %")
# Out:
# ┌ Warning: Could not infer input_scitype of the stack
# └ @ MLJBase ~/.julia/packages/MLJBase/GY2fM/src/composition/models/stacking.jl:187
# [ Info: Training machine(ProbabilisticStack(metalearner = DecisionTreeClassifier(max_depth = 3, …), …), …).
# [ Info: Training machine(:svm, …).
# [ Info: Training machine(:knn, …).
# [ Info: Training machine(:dt, …).
# [ Info: Training machine(:svm, …).
# [ Info: Training machine(:knn, …).
# [ Info: Training machine(:dt, …).
# [ Info: Training machine(:svm, …).
# [ Info: Training machine(:knn, …).
# [ Info: Training machine(:dt, …).
# [ Info: Training machine(:svm, …).
# [ Info: Training machine(:knn, …).
# [ Info: Training machine(:dt, …).
# [ Info: Training machine(:svm, …).
# [ Info: Training machine(:knn, …).
# [ Info: Training machine(:dt, …).
# [ Info: Training machine(:svm, …).
# [ Info: Training machine(:knn, …).
# [ Info: Training machine(:dt, …).
# [ Info: Training machine(:pca, …).
# [ Info: Training machine(:pca, …).
# [ Info: Training machine(:pca, …).
# [ Info: Training machine(:pca, …).
# [ Info: Training machine(:pca, …).
# [ Info: Training machine(:pca, …).
# [ Info: Training machine(:pca, …).
# [ Info: Training machine(:pca, …).
# [ Info: Training machine(:pca, …).
# [ Info: Training machine(:pca, …).
# [ Info: Training machine(:pca, …).
# [ Info: Training machine(:pca, …).
# [ Info: Training machine(:pca, …).
# [ Info: Training machine(:pca, …).
# [ Info: Training machine(:pca, …).
# [ Info: Training machine(:pca, …).
# [ Info: Training machine(:pca, …).
# [ Info: Training machine(:model, …).
# [ Info: Training machine(:pca, …).
# [ Info: Training machine(:model, …).
# [ Info: Training machine(:model, …).
# [ Info: Training machine(:model, …).
# [ Info: Training machine(:model, …).
# [ Info: Training machine(:model, …).
# [ Info: Training machine(:model, …).
# [ Info: Training machine(:model, …).
# [ Info: Training machine(:model, …).
# [ Info: Training machine(:model, …).
# [ Info: Training machine(:model, …).
# [ Info: Training machine(:model, …).
# [ Info: Training machine(:model, …).
# [ Info: Training machine(:model, …).
# [ Info: Training machine(:model, …).
# [ Info: Training machine(:model, …).
# [ Info: Training machine(:model, …).
# [ Info: Training machine(:model, …).
# [ Info: Training machine(:metalearner, …).
# Stack ensemble accuracy = 63.0 %
